# %% [markdown]
# ### `Sigmoid` code

# %%
import numpy as np
import torch # needed for tests
from tqdm import tqdm # needed for tests

# %%
class Sigmoid:
    ''' Computes Sigmoid activation given the input '''
    
    ''' * The class implementation will be along the lines of torch.nn.Sigmoid in order to 
          enable comparison of this NumPy only implementation and seamless testing
        * Can expect extensive refactoring of the existing code in the days to come
        * As part of refactoring, some code will be de-modularized
        * Old code will be retained at the end of the notebook for reference
    '''
    '''
        TODO:
        * Replace `torch.round()` with `np.allclose()` for tests
        * Optimizing code
    '''
    
    def __init__(
        self,
        inplace = False,
        verbose = False
        ):
        super(Sigmoid, self).__init__()
        
        ''' mandatory parameters '''
        # None
        
        ''' optional parameters '''
        # None
        
        ''' optional parameters (dummy, yet to be implemented)'''
        # None
        
        ''' additional parameters (different from torch.nn.Conv2D)'''
        self.verbose = verbose
        self.verboseprint = print if self.verbose else lambda *a, **k: None
        self.verboseprint('*** parameters ***')
        self.verboseprint('\n')
    
    def forward(self, _input):
        ''' forward pass to perform Sigmoid activation '''
        
        ''' error checking '''
        if not (isinstance(_input, int) or isinstance(_input, float) or isinstance(_input, np.ndarray)):
            raise Exception('invalid input: input should either be an int, a float, or a NumPy ndarray')
            
        ''' compute Sigmoid activation '''
        output = 1 / (1 + np.exp(-_input))
        self.verboseprint(output)
        self.verboseprint('\n')
        return output

# %% [markdown]
# ### Standalone test (random input)

# %%
_input = np.random.rand(10, 20, 3) # define a random input

# %%
# get Sigmoid output with the random input

sigmoid = Sigmoid(_input) # call an instance of the class with the input
_output = sigmoid.forward(_input) # perform Sigmoid activation
print("*** Sigmoid output ***")
print(_output)
# Out:
# *** Sigmoid output ***
# [[[0.60853075 0.70793628 0.5035494 ]
#   [0.59485843 0.58181536 0.72567081]
#   [0.6531097  0.5710276  0.52397209]
#   [0.58895698 0.67440179 0.63225884]
#   [0.55842298 0.6522823  0.52263639]
#   [0.56676411 0.54063506 0.6691447 ]
#   [0.61309273 0.54396323 0.62509763]
#   [0.61500979 0.58643033 0.55167669]
#   [0.61788871 0.70428184 0.67189323]
#   [0.72122775 0.65556317 0.64341647]
#   [0.52028587 0.57527901 0.71376106]
#   [0.57870541 0.72334992 0.7017357 ]
#   [0.66552929 0.61539584 0.69850748]
#   [0.68352541 0.50177195 0.52860042]
#   [0.59715015 0.61631093 0.72337192]
#   [0.65830494 0.61197586 0.5193315 ]
#   [0.50809015 0.62800767 0.67940947]
#   [0.6802552  0.62494572 0.68995084]
#   [0.66850854 0.51196524 0.64252593]
#   [0.67863459 0.60469969 0.5873672 ]]
#
#  [[0.52898516 0.67639648 0.70896409]
#   [0.58675285 0.64686905 0.68477504]
#   [0.53505905 0.5831935  0.69788618]
#   [0.72192877 0.55231765 0.53938478]
#   [0.71552182 0.66467074 0.56262522]
#   [0.55333452 0.69784257 0.69832929]
#   [0.62979838 0.52871241 0.66631168]
#   [0.64293372 0.59414947 0.68949597]
#   [0.68428208 0.54444681 0.52035972]
#   [0.52097388 0.63795862 0.68196597]
#   [0.69797748 0.61617036 0.69639242]
#   [0.50251412 0.72157228 0.5701421 ]
#   [0.69284713 0.63021884 0.64766007]
#   [0.54811437 0.68409318 0.6577138 ]
#   [0.58686891 0.58660593 0.63479604]
#   [0.68896832 0.7224266  0.53425505]
#   [0.54635883 0.69791763 0.50540453]
#   [0.5005418  0.73029432 0.50825824]
#   [0.67232881 0.71577339 0.67253805]
#   [0.69142923 0.64349633 0.67223117]]
#
#  [[0.7308437  0.51369709 0.66865668]
#   [0.72315637 0.67035783 0.51774515]
#   [0.5507365  0.70752531 0.70561234]
#   [0.54500826 0.58030382 0.69260513]
#   [0.65349672 0.65112377 0.60763301]
#   [0.65499879 0.6672189  0.57702033]
#   [0.56666718 0.50826414 0.61908542]
#   [0.52220222 0.67727143 0.71157234]
#   [0.5713736  0.58717112 0.63481658]
#   [0.52780705 0.54941962 0.68753805]
#   [0.50478674 0.71485331 0.66706444]
#   [0.59251572 0.64108785 0.60588413]
#   [0.63256779 0.68065163 0.53397487]
#   [0.63158082 0.55650769 0.51979507]
#   [0.51149728 0.52629562 0.52503883]
#   [0.56243219 0.64016914 0.5646005 ]
#   [0.7197042  0.67897992 0.59452662]
#   [0.72169788 0.6723778  0.71837929]
#   [0.65406399 0.57162243 0.64162739]
#   [0.69173367 0.58743735 0.73091372]]
#
#  [[0.68931021 0.67481404 0.61235075]
#   [0.55851744 0.71391913 0.72238425]
#   [0.62197    0.63151258 0.6322984 ]
#   [0.63958188 0.64216055 0.58399295]
#   [0.60959689 0.56240128 0.62228223]
#   [0.6819055  0.66279123 0.55765333]
#   [0.58210029 0.60794131 0.56218411]
#   [0.62561029 0.63677602 0.53446312]
#   [0.50565459 0.5641734  0.54953121]
#   [0.59559061 0.55057559 0.65944874]
#   [0.62708519 0.55964874 0.59871077]
#   [0.65279138 0.52631715 0.54277091]
#   [0.58813558 0.61226208 0.61938345]
#   [0.67106642 0.65311482 0.68141969]
#   [0.71744529 0.50097908 0.64296689]
#   [0.70117414 0.6333709  0.67088403]
#   [0.58776755 0.67412895 0.72109081]
#   [0.52152522 0.54421112 0.54497809]
#   [0.50656103 0.58979116 0.51724809]
#   [0.60285126 0.71217582 0.55539602]]
#
#  [[0.67407692 0.500508   0.71388736]
#   [0.61899908 0.64957192 0.55568107]
#   [0.57610779 0.61101942 0.55768798]
#   [0.59700392 0.63482809 0.65705174]
#   [0.59859732 0.64076503 0.60923992]
#   [0.63603686 0.72563538 0.64801169]
#   [0.55453506 0.58673862 0.64232096]
#   [0.55912827 0.73029692 0.57223454]
#   [0.51471172 0.5554506  0.53934143]
#   [0.68267719 0.55346679 0.61501172]
#   [0.63864957 0.71013333 0.5356872 ]
#   [0.61200224 0.53349674 0.6887233 ]
#   [0.5435335  0.71028184 0.630618  ]
#   [0.68597989 0.62012279 0.59239124]
#   [0.56612586 0.53808477 0.50068449]
#   [0.73050968 0.65190556 0.67206112]
#   [0.58191907 0.72898434 0.56164762]
#   [0.6256332  0.60558153 0.5844029 ]
#   [0.65644583 0.54383743 0.72928339]
#   [0.68943679 0.55021318 0.72573684]]
#
#  [[0.63034568 0.52943037 0.63063229]
#   [0.63630048 0.68254503 0.62693761]
#   [0.64287058 0.54393263 0.72235072]
#   [0.70863365 0.70586364 0.71278593]
#   [0.62588638 0.68566091 0.58955726]
#   [0.61258741 0.71750574 0.52504437]
#   [0.71203795 0.64649622 0.56220888]
#   [0.63253101 0.54663405 0.69251413]
#   [0.51477283 0.52894057 0.59927108]
#   [0.70283312 0.53264548 0.61991846]
#   [0.55837974 0.58082535 0.71610017]
#   [0.6595607  0.56198586 0.7138172 ]
#   [0.60335465 0.6940627  0.61854313]
#   [0.72398353 0.70841035 0.51458199]
#   [0.67543271 0.64366841 0.58677594]
#   [0.66552647 0.70426229 0.60281893]
#   [0.63492568 0.57491284 0.51294259]
#   [0.64072993 0.5092476  0.59016069]
#   [0.5392475  0.55192612 0.51974296]
#   [0.7047045  0.57698319 0.63286912]]
#
#  [[0.5014291  0.52366337 0.61344622]
#   [0.52472892 0.64019505 0.71413691]
#   [0.60663077 0.63625797 0.52419214]
#   [0.72642033 0.58319108 0.72695197]
#   [0.67121642 0.60372811 0.51856805]
#   [0.54915735 0.73099669 0.53621152]
#   [0.68176601 0.71895974 0.70336757]
#   [0.592292   0.6440559  0.50809411]
#   [0.62269466 0.67737772 0.58354451]
#   [0.58500249 0.52676138 0.69862191]
#   [0.50297786 0.61846559 0.50825827]
#   [0.54864507 0.6868708  0.61094926]
#   [0.64329101 0.62067264 0.64487817]
#   [0.52146848 0.69842874 0.52145443]
#   [0.61336872 0.65410701 0.58807772]
#   [0.65359864 0.64429776 0.62930854]
#   [0.6655221  0.64698843 0.69498036]
#   [0.5100494  0.51259335 0.54833793]
#   [0.57162306 0.69071195 0.51883174]
#   [0.50204991 0.59929287 0.65615232]]
#
#  [[0.56472275 0.66682863 0.56663156]
#   [0.63761826 0.62947704 0.72148732]
#   [0.54783774 0.59129293 0.52933925]
#   [0.61311556 0.73067468 0.51839521]
#   [0.64031096 0.69286865 0.53371842]
#   [0.51914397 0.68229212 0.61950904]
#   [0.72228468 0.72390403 0.60127144]
#   [0.69116998 0.66274654 0.65087932]
#   [0.55309883 0.50183499 0.72610418]
#   [0.70866967 0.58583749 0.58622955]
#   [0.71757794 0.6855564  0.56926768]
#   [0.57809691 0.51859778 0.58768903]
#   [0.50493712 0.64517976 0.5351668 ]
#   [0.6132365  0.69867198 0.703847  ]
#   [0.7091888  0.55444986 0.54642369]
#   [0.64293631 0.61010695 0.72104933]
#   [0.70347802 0.54258441 0.72599815]
#   [0.71484128 0.5675863  0.51380414]
#   [0.60665497 0.72213644 0.54782377]
#   [0.69402821 0.5043214  0.52497632]]
#
#  [[0.69148982 0.68605475 0.69859465]
#   [0.61564188 0.7262803  0.5593153 ]
#   [0.69149726 0.66545508 0.59503909]
#   [0.59343608 0.66854231 0.58726752]
#   [0.65601443 0.60546035 0.73055373]
#   [0.57925849 0.62023443 0.67189295]
#   [0.66453975 0.5824844  0.7127487 ]
#   [0.63728843 0.62747676 0.51308036]
#   [0.6350244  0.62630558 0.64830842]
#   [0.53744202 0.70527447 0.6736278 ]
#   [0.72460985 0.59077811 0.67331072]
#   [0.62845494 0.50513372 0.70360816]
#   [0.5750702  0.69007875 0.72477656]
#   [0.542668   0.69688745 0.64017937]
#   [0.64629101 0.72260586 0.63270853]
#   [0.56091541 0.68685122 0.68864417]
#   [0.64454207 0.63806355 0.6178276 ]
#   [0.53685123 0.52817688 0.7126125 ]
#   [0.71846146 0.56476428 0.59635588]
#   [0.63925471 0.70472309 0.66310936]]
#
#  [[0.62065577 0.59632777 0.5546716 ]
#   [0.68260534 0.6868133  0.5640213 ]
#   [0.71434354 0.68823536 0.66364848]
#   [0.63727026 0.59725284 0.57715334]
#   [0.67145549 0.5152753  0.64668096]
#   [0.56306136 0.70464939 0.63411172]
#   [0.71765365 0.63418723 0.68838858]
#   [0.71776231 0.72359018 0.66778162]
#   [0.52014593 0.61605461 0.66955264]
#   [0.69653503 0.58029423 0.5343435 ]
#   [0.72645519 0.51854228 0.61505925]
#   [0.5062759  0.61935268 0.60129752]
#   [0.72994627 0.58369209 0.69197568]
#   [0.70628532 0.54115316 0.6884829 ]
#   [0.59642968 0.68464654 0.72832348]
#   [0.71482955 0.66265865 0.63832167]
#   [0.6106672  0.62026005 0.65788283]
#   [0.65240062 0.59898767 0.65197221]
#   [0.50997904 0.69096873 0.72692322]
#   [0.51041921 0.5750254  0.52642976]]]

# %%
# get PyTorch output with the same random inputs as above

x = torch.DoubleTensor(_input)
m = torch.nn.Sigmoid()
output = m(x)
print("*** PyTorch output ***")
print(output)
# Out:
# *** PyTorch output ***
# tensor([[[0.6085, 0.7079, 0.5035],
#          [0.5949, 0.5818, 0.7257],
#          [0.6531, 0.5710, 0.5240],
#          [0.5890, 0.6744, 0.6323],
#          [0.5584, 0.6523, 0.5226],
#          [0.5668, 0.5406, 0.6691],
#          [0.6131, 0.5440, 0.6251],
#          [0.6150, 0.5864, 0.5517],
#          [0.6179, 0.7043, 0.6719],
#          [0.7212, 0.6556, 0.6434],
#          [0.5203, 0.5753, 0.7138],
#          [0.5787, 0.7233, 0.7017],
#          [0.6655, 0.6154, 0.6985],
#          [0.6835, 0.5018, 0.5286],
#          [0.5972, 0.6163, 0.7234],
#          [0.6583, 0.6120, 0.5193],
#          [0.5081, 0.6280, 0.6794],
#          [0.6803, 0.6249, 0.6900],
#          [0.6685, 0.5120, 0.6425],
#          [0.6786, 0.6047, 0.5874]],
#
#         [[0.5290, 0.6764, 0.7090],
#          [0.5868, 0.6469, 0.6848],
#          [0.5351, 0.5832, 0.6979],
#          [0.7219, 0.5523, 0.5394],
#          [0.7155, 0.6647, 0.5626],
#          [0.5533, 0.6978, 0.6983],
#          [0.6298, 0.5287, 0.6663],
#          [0.6429, 0.5941, 0.6895],
#          [0.6843, 0.5444, 0.5204],
#          [0.5210, 0.6380, 0.6820],
#          [0.6980, 0.6162, 0.6964],
#          [0.5025, 0.7216, 0.5701],
#          [0.6928, 0.6302, 0.6477],
#          [0.5481, 0.6841, 0.6577],
#          [0.5869, 0.5866, 0.6348],
#          [0.6890, 0.7224, 0.5343],
#          [0.5464, 0.6979, 0.5054],
#          [0.5005, 0.7303, 0.5083],
#          [0.6723, 0.7158, 0.6725],
#          [0.6914, 0.6435, 0.6722]],
#
#         [[0.7308, 0.5137, 0.6687],
#          [0.7232, 0.6704, 0.5177],
#          [0.5507, 0.7075, 0.7056],
#          [0.5450, 0.5803, 0.6926],
#          [0.6535, 0.6511, 0.6076],
#          [0.6550, 0.6672, 0.5770],
#          [0.5667, 0.5083, 0.6191],
#          [0.5222, 0.6773, 0.7116],
#          [0.5714, 0.5872, 0.6348],
#          [0.5278, 0.5494, 0.6875],
#          [0.5048, 0.7149, 0.6671],
#          [0.5925, 0.6411, 0.6059],
#          [0.6326, 0.6807, 0.5340],
#          [0.6316, 0.5565, 0.5198],
#          [0.5115, 0.5263, 0.5250],
#          [0.5624, 0.6402, 0.5646],
#          [0.7197, 0.6790, 0.5945],
#          [0.7217, 0.6724, 0.7184],
#          [0.6541, 0.5716, 0.6416],
#          [0.6917, 0.5874, 0.7309]],
#
#         [[0.6893, 0.6748, 0.6124],
#          [0.5585, 0.7139, 0.7224],
#          [0.6220, 0.6315, 0.6323],
#          [0.6396, 0.6422, 0.5840],
#          [0.6096, 0.5624, 0.6223],
#          [0.6819, 0.6628, 0.5577],
#          [0.5821, 0.6079, 0.5622],
#          [0.6256, 0.6368, 0.5345],
#          [0.5057, 0.5642, 0.5495],
#          [0.5956, 0.5506, 0.6594],
#          [0.6271, 0.5596, 0.5987],
#          [0.6528, 0.5263, 0.5428],
#          [0.5881, 0.6123, 0.6194],
#          [0.6711, 0.6531, 0.6814],
#          [0.7174, 0.5010, 0.6430],
#          [0.7012, 0.6334, 0.6709],
#          [0.5878, 0.6741, 0.7211],
#          [0.5215, 0.5442, 0.5450],
#          [0.5066, 0.5898, 0.5172],
#          [0.6029, 0.7122, 0.5554]],
#
#         [[0.6741, 0.5005, 0.7139],
#          [0.6190, 0.6496, 0.5557],
#          [0.5761, 0.6110, 0.5577],
#          [0.5970, 0.6348, 0.6571],
#          [0.5986, 0.6408, 0.6092],
#          [0.6360, 0.7256, 0.6480],
#          [0.5545, 0.5867, 0.6423],
#          [0.5591, 0.7303, 0.5722],
#          [0.5147, 0.5555, 0.5393],
#          [0.6827, 0.5535, 0.6150],
#          [0.6386, 0.7101, 0.5357],
#          [0.6120, 0.5335, 0.6887],
#          [0.5435, 0.7103, 0.6306],
#          [0.6860, 0.6201, 0.5924],
#          [0.5661, 0.5381, 0.5007],
#          [0.7305, 0.6519, 0.6721],
#          [0.5819, 0.7290, 0.5616],
#          [0.6256, 0.6056, 0.5844],
#          [0.6564, 0.5438, 0.7293],
#          [0.6894, 0.5502, 0.7257]],
#
#         [[0.6303, 0.5294, 0.6306],
#          [0.6363, 0.6825, 0.6269],
#          [0.6429, 0.5439, 0.7224],
#          [0.7086, 0.7059, 0.7128],
#          [0.6259, 0.6857, 0.5896],
#          [0.6126, 0.7175, 0.5250],
#          [0.7120, 0.6465, 0.5622],
#          [0.6325, 0.5466, 0.6925],
#          [0.5148, 0.5289, 0.5993],
#          [0.7028, 0.5326, 0.6199],
#          [0.5584, 0.5808, 0.7161],
#          [0.6596, 0.5620, 0.7138],
#          [0.6034, 0.6941, 0.6185],
#          [0.7240, 0.7084, 0.5146],
#          [0.6754, 0.6437, 0.5868],
#          [0.6655, 0.7043, 0.6028],
#          [0.6349, 0.5749, 0.5129],
#          [0.6407, 0.5092, 0.5902],
#          [0.5392, 0.5519, 0.5197],
#          [0.7047, 0.5770, 0.6329]],
#
#         [[0.5014, 0.5237, 0.6134],
#          [0.5247, 0.6402, 0.7141],
#          [0.6066, 0.6363, 0.5242],
#          [0.7264, 0.5832, 0.7270],
#          [0.6712, 0.6037, 0.5186],
#          [0.5492, 0.7310, 0.5362],
#          [0.6818, 0.7190, 0.7034],
#          [0.5923, 0.6441, 0.5081],
#          [0.6227, 0.6774, 0.5835],
#          [0.5850, 0.5268, 0.6986],
#          [0.5030, 0.6185, 0.5083],
#          [0.5486, 0.6869, 0.6109],
#          [0.6433, 0.6207, 0.6449],
#          [0.5215, 0.6984, 0.5215],
#          [0.6134, 0.6541, 0.5881],
#          [0.6536, 0.6443, 0.6293],
#          [0.6655, 0.6470, 0.6950],
#          [0.5100, 0.5126, 0.5483],
#          [0.5716, 0.6907, 0.5188],
#          [0.5020, 0.5993, 0.6562]],
#
#         [[0.5647, 0.6668, 0.5666],
#          [0.6376, 0.6295, 0.7215],
#          [0.5478, 0.5913, 0.5293],
#          [0.6131, 0.7307, 0.5184],
#          [0.6403, 0.6929, 0.5337],
#          [0.5191, 0.6823, 0.6195],
#          [0.7223, 0.7239, 0.6013],
#          [0.6912, 0.6627, 0.6509],
#          [0.5531, 0.5018, 0.7261],
#          [0.7087, 0.5858, 0.5862],
#          [0.7176, 0.6856, 0.5693],
#          [0.5781, 0.5186, 0.5877],
#          [0.5049, 0.6452, 0.5352],
#          [0.6132, 0.6987, 0.7038],
#          [0.7092, 0.5544, 0.5464],
#          [0.6429, 0.6101, 0.7210],
#          [0.7035, 0.5426, 0.7260],
#          [0.7148, 0.5676, 0.5138],
#          [0.6067, 0.7221, 0.5478],
#          [0.6940, 0.5043, 0.5250]],
#
#         [[0.6915, 0.6861, 0.6986],
#          [0.6156, 0.7263, 0.5593],
#          [0.6915, 0.6655, 0.5950],
#          [0.5934, 0.6685, 0.5873],
#          [0.6560, 0.6055, 0.7306],
#          [0.5793, 0.6202, 0.6719],
#          [0.6645, 0.5825, 0.7127],
#          [0.6373, 0.6275, 0.5131],
#          [0.6350, 0.6263, 0.6483],
#          [0.5374, 0.7053, 0.6736],
#          [0.7246, 0.5908, 0.6733],
#          [0.6285, 0.5051, 0.7036],
#          [0.5751, 0.6901, 0.7248],
#          [0.5427, 0.6969, 0.6402],
#          [0.6463, 0.7226, 0.6327],
#          [0.5609, 0.6869, 0.6886],
#          [0.6445, 0.6381, 0.6178],
#          [0.5369, 0.5282, 0.7126],
#          [0.7185, 0.5648, 0.5964],
#          [0.6393, 0.7047, 0.6631]],
#
#         [[0.6207, 0.5963, 0.5547],
#          [0.6826, 0.6868, 0.5640],
#          [0.7143, 0.6882, 0.6636],
#          [0.6373, 0.5973, 0.5772],
#          [0.6715, 0.5153, 0.6467],
#          [0.5631, 0.7046, 0.6341],
#          [0.7177, 0.6342, 0.6884],
#          [0.7178, 0.7236, 0.6678],
#          [0.5201, 0.6161, 0.6696],
#          [0.6965, 0.5803, 0.5343],
#          [0.7265, 0.5185, 0.6151],
#          [0.5063, 0.6194, 0.6013],
#          [0.7299, 0.5837, 0.6920],
#          [0.7063, 0.5412, 0.6885],
#          [0.5964, 0.6846, 0.7283],
#          [0.7148, 0.6627, 0.6383],
#          [0.6107, 0.6203, 0.6579],
#          [0.6524, 0.5990, 0.6520],
#          [0.5100, 0.6910, 0.7269],
#          [0.5104, 0.5750, 0.5264]]], dtype=torch.float64)

# %%
# compare outputs of Conv2D and PyTorch
print(torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output))) # need to round the output due to precision difference
# Out:
# True

# %% [markdown]
# ### Extensive tests (random input)

# %%
def run_tests(num_tests):
    ''' sweep different input parameters and test by comparing outputs of Sigmoid and PyTorch '''
    
    num_passed = 0
    print('Number of tests: {}\n\n'.format(num_tests))
    
    for i in tqdm(range(num_tests)):
        num_dim = np.random.randint(6) + 1 # number of input dimensions
        dim = tuple(np.random.randint(5) + 1 for _ in range(num_dim)) # shape of input
        _input = np.random.rand(*dim) # generate an input based on the dimensions and shape
        print('Test: {}\nInput shape: {}'.format(i, dim))
        
        try:
            # get Sigmoid output with the random input
            sigmoid = Sigmoid(_input) # call an instance of the class with the input
            _output = sigmoid.forward(_input) # perform Sigmoid activation

            # get PyTorch output with the same random input as above
            x = torch.DoubleTensor(_input)
            m = torch.nn.Sigmoid()
            output = m(x)
            
        except Exception as e:
            print(e)
            print('Result: False\n\n') # treating exception as a failed test
            continue

        # compare outputs of Sigmoid and PyTorch
        result = torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output)) # need to round the output due to precision difference
        print('Result: {}\n\n'.format(result))
        if result:
            num_passed += 1

    print('{} out of {} ({}%) tests passed'.format(num_passed, num_tests, float(100 * num_passed / num_tests)))

# %%
num_tests = 1000
run_tests(num_tests)
# Out:
# Number of tests: 1000
#  31%|███████████▋                          | 308/1000 [00:00<00:00, 3079.84it/s]
# Test: 0
# Input shape: (1,)
# Result: True
#
#
# Test: 1
# Input shape: (5, 2)
# Result: True
#
#
# Test: 2
# Input shape: (1, 1)
# Result: True
#
#
# Test: 3
# Input shape: (1,)
# Result: True
#
#
# Test: 4
# Input shape: (3, 5, 5)
# Result: True
#
#
# Test: 5
# Input shape: (1, 4, 1, 5)
# Result: True
#
#
# Test: 6
# Input shape: (5, 4, 1, 4, 4, 1)
# Result: True
#
#
# Test: 7
# Input shape: (3, 5, 4, 5, 4)
# Result: True
#
#
# Test: 8
# Input shape: (4, 4, 1, 5, 1)
# Result: True
#
#
# Test: 9
# Input shape: (3, 5, 2, 5)
# Result: True
#
#
# Test: 10
# Input shape: (1, 5)
# Result: True
#
#
# Test: 11
# Input shape: (3, 4, 4, 3, 5, 2)
# Result: True
#
#
# Test: 12
# Input shape: (1, 1, 3, 4, 5, 3)
# Result: True
#
#
# Test: 13
# Input shape: (5, 1, 3, 2)
# Result: True
#
#
# Test: 14
# Input shape: (4,)
# Result: True
#
#
# Test: 15
# Input shape: (2, 2, 2, 3, 4)
# Result: True
#
#
# Test: 16
# Input shape: (1, 3)
# Result: True
#
#
# Test: 17
# Input shape: (4, 1)
# Result: True
#
#
# Test: 18
# Input shape: (4, 4)
# Result: True
#
#
# Test: 19
# Input shape: (4, 4, 5, 2)
# Result: True
#
#
# Test: 20
# Input shape: (2, 1, 1)
# Result: True
#
#
# Test: 21
# Input shape: (2, 1, 2)
# Result: True
#
#
# Test: 22
# Input shape: (3, 3, 4)
# Result: True
#
#
# Test: 23
# Input shape: (2, 1, 5, 5, 5, 2)
# Result: True
#
#
# Test: 24
# Input shape: (5, 4)
# Result: True
#
#
# Test: 25
# Input shape: (2, 1, 1, 5, 1, 1)
# Result: True
#
#
# Test: 26
# Input shape: (2, 2)
# Result: True
#
#
# Test: 27
# Input shape: (2, 3, 1)
# Result: True
#
#
# Test: 28
# Input shape: (3, 2, 4, 2, 3)
# Result: True
#
#
# Test: 29
# Input shape: (1, 4, 4)
# Result: True
#
#
# Test: 30
# Input shape: (5,)
# Result: True
#
#
# Test: 31
# Input shape: (3, 5, 5, 3, 2, 5)
# Result: True
#
#
# Test: 32
# Input shape: (3, 4)
# Result: True
#
#
# Test: 33
# Input shape: (4, 3, 5, 5)
# Result: True
#
#
# Test: 34
# Input shape: (4,)
# Result: True
#
#
# Test: 35
# Input shape: (3, 3, 2, 4)
# Result: True
#
#
# Test: 36
# Input shape: (4, 5, 2, 2, 4)
# Result: True
#
#
# Test: 37
# Input shape: (4, 5, 1, 5, 5)
# Result: True
#
#
# Test: 38
# Input shape: (4, 4, 3, 1)
# Result: True
#
#
# Test: 39
# Input shape: (4,)
# Result: True
#
#
# Test: 40
# Input shape: (2, 3, 2)
# Result: True
#
#
# Test: 41
# Input shape: (3, 1, 4, 5)
# Result: True
#
#
# Test: 42
# Input shape: (3, 4, 3)
# Result: True
#
#
# Test: 43
# Input shape: (5, 2, 2, 2, 3, 5)
# Result: True
#
#
# Test: 44
# Input shape: (3, 2, 5, 4, 3)
# Result: True
#
#
# Test: 45
# Input shape: (4, 4, 3, 5)
# Result: True
#
#
# Test: 46
# Input shape: (5, 5, 5)
# Result: True
#
#
# Test: 47
# Input shape: (5, 5, 4, 4, 4, 5)
# Result: True
#
#
# Test: 48
# Input shape: (3, 5)
# Result: True
#
#
# Test: 49
# Input shape: (4, 2, 3, 5, 1)
# Result: True
#
#
# Test: 50
# Input shape: (4, 4, 1)
# Result: True
#
#
# Test: 51
# Input shape: (3, 3, 1)
# Result: True
#
#
# Test: 52
# Input shape: (5, 3, 5)
# Result: True
#
#
# Test: 53
# Input shape: (5, 3, 1, 4, 3)
# Result: True
#
#
# Test: 54
# Input shape: (2, 2, 5, 3, 4, 3)
# Result: True
#
#
# Test: 55
# Input shape: (1, 3, 2)
# Result: True
#
#
# Test: 56
# Input shape: (3, 5)
# Result: True
#
#
# Test: 57
# Input shape: (2, 2, 2, 4, 1, 2)
# Result: True
#
#
# Test: 58
# Input shape: (3, 5, 2, 1)
# Result: True
#
#
# Test: 59
# Input shape: (4, 3, 4)
# Result: True
#
#
# Test: 60
# Input shape: (2, 3, 4, 5)
# Result: True
#
#
# Test: 61
# Input shape: (4, 2, 4)
# Result: True
#
#
# Test: 62
# Input shape: (4, 1, 4, 2, 5, 1)
# Result: True
#
#
# Test: 63
# Input shape: (1, 2)
# Result: True
#
#
# Test: 64
# Input shape: (3, 1, 2, 4, 1)
# Result: True
#
#
# Test: 65
# Input shape: (4, 2)
# Result: True
#
#
# Test: 66
# Input shape: (1, 3, 5, 5, 3, 3)
# Result: True
#
#
# Test: 67
# Input shape: (3, 2, 4)
# Result: True
#
#
# Test: 68
# Input shape: (2, 2, 3, 4, 2)
# Result: True
#
#
# Test: 69
# Input shape: (4, 5, 5, 3, 3, 1)
# Result: True
#
#
# Test: 70
# Input shape: (3,)
# Result: True
#
#
# Test: 71
# Input shape: (1, 4, 1, 3)
# Result: True
#
#
# Test: 72
# Input shape: (4, 5)
# Result: True
#
#
# Test: 73
# Input shape: (1, 5, 3)
# Result: True
#
#
# Test: 74
# Input shape: (2,)
# Result: True
#
#
# Test: 75
# Input shape: (3, 5)
# Result: True
#
#
# Test: 76
# Input shape: (5, 1, 1, 4)
# Result: True
#
#
# Test: 77
# Input shape: (5, 4, 1, 1, 3, 4)
# Result: True
#
#
# Test: 78
# Input shape: (1, 4, 1)
# Result: True
#
#
# Test: 79
# Input shape: (3, 5, 1, 4, 2)
# Result: True
#
#
# Test: 80
# Input shape: (4, 5)
# Result: True
#
#
# Test: 81
# Input shape: (2, 4)
# Result: True
#
#
# Test: 82
# Input shape: (2,)
# Result: True
#
#
# Test: 83
# Input shape: (5,)
# Result: True
#
#
# Test: 84
# Input shape: (4, 4, 4, 5, 3)
# Result: True
#
#
# Test: 85
# Input shape: (1, 4)
# Result: True
#
#
# Test: 86
# Input shape: (1, 2, 4)
# Result: True
#
#
# Test: 87
# Input shape: (1, 3)
# Result: True
#
#
# Test: 88
# Input shape: (3, 5)
# Result: True
#
#
# Test: 89
# Input shape: (2, 3, 3, 2)
# Result: True
#
#
# Test: 90
# Input shape: (5, 5)
# Result: True
#
#
# Test: 91
# Input shape: (1, 4, 3)
# Result: True
#
#
# Test: 92
# Input shape: (1, 3, 1)
# Result: True
#
#
# Test: 93
# Input shape: (3, 4, 3)
# Result: True
#
#
# Test: 94
# Input shape: (2, 5, 2, 5, 4, 5)
# Result: True
#
#
# Test: 95
# Input shape: (1, 3, 3, 3, 2)
# Result: True
#
#
# Test: 96
# Input shape: (4, 5)
# Result: True
#
#
# Test: 97
# Input shape: (2, 4)
# Result: True
#
#
# Test: 98
# Input shape: (4, 4, 1)
# Result: True
#
#
# Test: 99
# Input shape: (3, 5, 1)
# Result: True
#
#
# Test: 100
# Input shape: (2,)
# Result: True
#
#
# Test: 101
# Input shape: (4, 1, 5, 3, 4)
# Result: True
#
#
# Test: 102
# Input shape: (1,)
# Result: True
#
#
# Test: 103
# Input shape: (1, 3, 3)
# Result: True
#
#
# Test: 104
# Input shape: (4, 3, 4, 2, 1)
# Result: True
#
#
# Test: 105
# Input shape: (4, 1, 3, 3, 1)
# Result: True
#
#
# Test: 106
# Input shape: (1, 5, 3, 3)
# Result: True
#
#
# Test: 107
# Input shape: (1, 4)
# Result: True
#
#
# Test: 108
# Input shape: (4, 5, 5, 2, 2, 1)
# Result: True
#
#
# Test: 109
# Input shape: (1, 3)
# Result: True
#
#
# Test: 110
# Input shape: (3,)
# Result: True
#
#
# Test: 111
# Input shape: (1, 1, 5, 5)
# Result: True
#
#
# Test: 112
# Input shape: (4, 5, 4)
# Result: True
#
#
# Test: 113
# Input shape: (1, 2, 2, 2)
# Result: True
#
#
# Test: 114
# Input shape: (2, 3, 3, 3, 2, 1)
# Result: True
#
#
# Test: 115
# Input shape: (1, 5, 4, 3, 4)
# Result: True
#
#
# Test: 116
# Input shape: (4,)
# Result: True
#
#
# Test: 117
# Input shape: (4, 1, 4, 4, 1)
# Result: True
#
#
# Test: 118
# Input shape: (3, 2, 1, 5, 2, 4)
# Result: True
#
#
# Test: 119
# Input shape: (1, 2, 5, 5, 3, 2)
# Result: True
#
#
# Test: 120
# Input shape: (2, 4)
# Result: True
#
#
# Test: 121
# Input shape: (4, 3)
# Result: True
#
#
# Test: 122
# Input shape: (3, 2)
# Result: True
#
#
# Test: 123
# Input shape: (2, 1, 4, 2)
# Result: True
#
#
# Test: 124
# Input shape: (2, 3, 5, 3)
# Result: True
#
#
# Test: 125
# Input shape: (3,)
# Result: True
#
#
# Test: 126
# Input shape: (2, 2, 3, 2)
# Result: True
#
#
# Test: 127
# Input shape: (1, 4, 3, 1, 1, 1)
# Result: True
#
#
# Test: 128
# Input shape: (3, 3)
# Result: True
#
#
# Test: 129
# Input shape: (3, 5, 3, 3, 1, 4)
# Result: True
#
#
# Test: 130
# Input shape: (4, 1, 3, 2, 5, 2)
# Result: True
#
#
# Test: 131
# Input shape: (5,)
# Result: True
#
#
# Test: 132
# Input shape: (1, 1, 2, 4, 3)
# Result: True
#
#
# Test: 133
# Input shape: (5, 5, 2, 2, 3, 4)
# Result: True
#
#
# Test: 134
# Input shape: (3, 1, 1)
# Result: True
#
#
# Test: 135
# Input shape: (5,)
# Result: True
#
#
# Test: 136
# Input shape: (5, 1, 4, 4)
# Result: True
#
#
# Test: 137
# Input shape: (3, 1, 4, 4, 3, 5)
# Result: True
#
#
# Test: 138
# Input shape: (5, 1, 3, 2)
# Result: True
#
#
# Test: 139
# Input shape: (1, 3, 1)
# Result: True
#
#
# Test: 140
# Input shape: (3, 4, 2, 5)
# Result: True
#
#
# Test: 141
# Input shape: (1, 4, 2, 3, 4, 1)
# Result: True
#
#
# Test: 142
# Input shape: (3, 4, 4, 2, 4)
# Result: True
#
#
# Test: 143
# Input shape: (4, 1, 4, 2, 5)
# Result: True
#
#
# Test: 144
# Input shape: (3,)
# Result: True
#
#
# Test: 145
# Input shape: (3, 2)
# Result: True
#
#
# Test: 146
# Input shape: (3, 1, 2, 1, 1, 3)
# Result: True
#
#
# Test: 147
# Input shape: (2,)
# Result: True
#
#
# Test: 148
# Input shape: (4, 4, 2, 1)
# Result: True
#
#
# Test: 149
# Input shape: (5, 1)
# Result: True
#
#
# Test: 150
# Input shape: (1, 2, 3, 4, 5)
# Result: True
#
#
# Test: 151
# Input shape: (3, 3)
# Result: True
#
#
# Test: 152
# Input shape: (2, 2, 1, 3)
# Result: True
#
#
# Test: 153
# Input shape: (5, 4, 1)
# Result: True
#
#
# Test: 154
# Input shape: (5, 5, 5, 5)
# Result: True
#
#
# Test: 155
# Input shape: (5, 2, 5, 5, 2)
# Result: True
#
#
# Test: 156
# Input shape: (2, 2, 2)
# Result: True
#
#
# Test: 157
# Input shape: (3, 2)
# Result: True
#
#
# Test: 158
# Input shape: (4, 5, 2, 2, 3, 1)
# Result: True
#
#
# Test: 159
# Input shape: (4, 1)
# Result: True
#
#
# Test: 160
# Input shape: (5, 2)
# Result: True
#
#
# Test: 161
# Input shape: (1, 1, 2, 2)
# Result: True
#
#
# Test: 162
# Input shape: (5, 1, 1, 4, 5, 1)
# Result: True
#
#
# Test: 163
# Input shape: (4, 5, 3, 3, 1, 2)
# Result: True
#
#
# Test: 164
# Input shape: (1, 5)
# Result: True
#
#
# Test: 165
# Input shape: (4, 5)
# Result: True
#
#
# Test: 166
# Input shape: (1,)
# Result: True
#
#
# Test: 167
# Input shape: (1, 3, 2, 2)
# Result: True
#
#
# Test: 168
# Input shape: (4, 1, 2)
# Result: True
#
#
# Test: 169
# Input shape: (4, 5)
# Result: True
#
#
# Test: 170
# Input shape: (3,)
# Result: True
#
#
# Test: 171
# Input shape: (1, 3)
# Result: True
#
#
# Test: 172
# Input shape: (2, 1, 3, 1, 5)
# Result: True
#
#
# Test: 173
# Input shape: (3, 2)
# Result: True
#
#
# Test: 174
# Input shape: (1, 5)
# Result: True
#
#
# Test: 175
# Input shape: (1, 2, 5, 3)
# Result: True
#
#
# Test: 176
# Input shape: (3, 1, 3, 5)
# Result: True
#
#
# Test: 177
# Input shape: (1, 2)
# Result: True
#
#
# Test: 178
# Input shape: (4, 2, 5, 2, 4, 5)
# Result: True
#
#
# Test: 179
# Input shape: (3, 1, 5, 1, 3, 4)
# Result: True
#
#
# Test: 180
# Input shape: (5, 2, 1, 3)
# Result: True
#
#
# Test: 181
# Input shape: (4,)
# Result: True
#
#
# Test: 182
# Input shape: (4, 4, 3, 5, 4)
# Result: True
#
#
# Test: 183
# Input shape: (5, 4)
# Result: True
#
#
# Test: 184
# Input shape: (2,)
# Result: True
#
#
# Test: 185
# Input shape: (1, 3, 3, 3)
# Result: True
#
#
# Test: 186
# Input shape: (4, 5, 1, 4, 1, 4)
# Result: True
#
#
# Test: 187
# Input shape: (5, 5, 5, 2, 2)
# Result: True
#
#
# Test: 188
# Input shape: (2, 5)
# Result: True
#
#
# Test: 189
# Input shape: (3, 3)
# Result: True
#
#
# Test: 190
# Input shape: (4, 3, 1, 1, 2, 1)
# Result: True
#
#
# Test: 191
# Input shape: (5,)
# Result: True
#
#
# Test: 192
# Input shape: (1, 1, 5)
# Result: True
#
#
# Test: 193
# Input shape: (4, 2, 3)
# Result: True
#
#
# Test: 194
# Input shape: (5, 5, 5, 1)
# Result: True
#
#
# Test: 195
# Input shape: (4, 3, 4)
# Result: True
#
#
# Test: 196
# Input shape: (2, 4, 4, 1, 5)
# Result: True
#
#
# Test: 197
# Input shape: (1,)
# Result: True
#
#
# Test: 198
# Input shape: (2,)
# Result: True
#
#
# Test: 199
# Input shape: (5, 5, 3, 2, 3)
# Result: True
#
#
# Test: 200
# Input shape: (1,)
# Result: True
#
#
# Test: 201
# Input shape: (3, 5, 4, 4)
# Result: True
#
#
# Test: 202
# Input shape: (2, 3, 4, 2)
# Result: True
#
#
# Test: 203
# Input shape: (1, 5, 4, 2, 2, 3)
# Result: True
#
#
# Test: 204
# Input shape: (1, 5, 4, 5)
# Result: True
#
#
# Test: 205
# Input shape: (3, 4, 4, 5)
# Result: True
#
#
# Test: 206
# Input shape: (1, 1, 3, 4, 5)
# Result: True
#
#
# Test: 207
# Input shape: (4,)
# Result: True
#
#
# Test: 208
# Input shape: (2, 3, 2, 4)
# Result: True
#
#
# Test: 209
# Input shape: (4, 4, 5, 2, 3)
# Result: True
#
#
# Test: 210
# Input shape: (2, 4, 3, 3, 5, 3)
# Result: True
#
#
# Test: 211
# Input shape: (1, 5)
# Result: True
#
#
# Test: 212
# Input shape: (1,)
# Result: True
#
#
# Test: 213
# Input shape: (5, 1, 3)
# Result: True
#
#
# Test: 214
# Input shape: (3, 2, 1, 5)
# Result: True
#
#
# Test: 215
# Input shape: (1, 2, 3, 2, 2, 3)
# Result: True
#
#
# Test: 216
# Input shape: (3,)
# Result: True
#
#
# Test: 217
# Input shape: (4, 4, 1)
# Result: True
#
#
# Test: 218
# Input shape: (1, 5, 5)
# Result: True
#
#
# Test: 219
# Input shape: (3, 5, 2, 2, 5, 1)
# Result: True
#
#
# Test: 220
# Input shape: (3, 4, 5, 5)
# Result: True
#
#
# Test: 221
# Input shape: (4, 5)
# Result: True
#
#
# Test: 222
# Input shape: (1, 4)
# Result: True
#
#
# Test: 223
# Input shape: (1, 3, 4)
# Result: True
#
#
# Test: 224
# Input shape: (3, 2)
# Result: True
#
#
# Test: 225
# Input shape: (3, 3)
# Result: True
#
#
# Test: 226
# Input shape: (4, 4)
# Result: True
#
#
# Test: 227
# Input shape: (1, 2)
# Result: True
#
#
# Test: 228
# Input shape: (2, 5, 4)
# Result: True
#
#
# Test: 229
# Input shape: (5, 3, 4, 2, 4)
# Result: True
#
#
# Test: 230
# Input shape: (2, 2)
# Result: True
#
#
# Test: 231
# Input shape: (5,)
# Result: True
#
#
# Test: 232
# Input shape: (1, 4)
# Result: True
#
#
# Test: 233
# Input shape: (3, 5, 4)
# Result: True
#
#
# Test: 234
# Input shape: (3, 5)
# Result: True
#
#
# Test: 235
# Input shape: (5, 5, 2, 2)
# Result: True
#
#
# Test: 236
# Input shape: (3, 4)
# Result: True
#
#
# Test: 237
# Input shape: (3, 4, 5, 3, 2)
# Result: True
#
#
# Test: 238
# Input shape: (2, 1, 4, 1, 4)
# Result: True
#
#
# Test: 239
# Input shape: (1, 1, 4)
# Result: True
#
#
# Test: 240
# Input shape: (5, 3)
# Result: True
#
#
# Test: 241
# Input shape: (5, 1, 5, 2, 2, 2)
# Result: True
#
#
# Test: 242
# Input shape: (5, 1, 3)
# Result: True
#
#
# Test: 243
# Input shape: (2, 5, 4)
# Result: True
#
#
# Test: 244
# Input shape: (1, 1)
# Result: True
#
#
# Test: 245
# Input shape: (2, 5)
# Result: True
#
#
# Test: 246
# Input shape: (2, 5, 1)
# Result: True
#
#
# Test: 247
# Input shape: (2, 1, 5, 5, 1, 3)
# Result: True
#
#
# Test: 248
# Input shape: (5, 5, 3, 4)
# Result: True
#
#
# Test: 249
# Input shape: (2, 1, 5)
# Result: True
#
#
# Test: 250
# Input shape: (1, 4)
# Result: True
#
#
# Test: 251
# Input shape: (4, 3, 2, 3, 3)
# Result: True
#
#
# Test: 252
# Input shape: (4, 1, 5, 3, 4, 4)
# Result: True
#
#
# Test: 253
# Input shape: (4, 2, 1, 1, 4)
# Result: True
#
#
# Test: 254
# Input shape: (2, 1, 2)
# Result: True
#
#
# Test: 255
# Input shape: (2, 1)
# Result: True
#
#
# Test: 256
# Input shape: (2, 1, 2, 3, 5)
# Result: True
#
#
# Test: 257
# Input shape: (2, 2)
# Result: True
#
#
# Test: 258
# Input shape: (5, 4, 4, 4, 2)
# Result: True
#
#
# Test: 259
# Input shape: (2, 2)
# Result: True
#
#
# Test: 260
# Input shape: (3, 2, 2, 1)
# Result: True
#
#
# Test: 261
# Input shape: (1, 4, 5, 5)
# Result: True
#
#
# Test: 262
# Input shape: (5, 3)
# Result: True
#
#
# Test: 263
# Input shape: (3, 1)
# Result: True
#
#
# Test: 264
# Input shape: (4,)
# Result: True
#
#
# Test: 265
# Input shape: (5, 2, 3, 2, 5)
# Result: True
#
#
# Test: 266
# Input shape: (2,)
# Result: True
#
#
# Test: 267
# Input shape: (5,)
# Result: True
#
#
# Test: 268
# Input shape: (4, 4, 5)
# Result: True
#
#
# Test: 269
# Input shape: (2, 4, 4)
# Result: True
#
#
# Test: 270
# Input shape: (3, 3, 1, 5, 3)
# Result: True
#
#
# Test: 271
# Input shape: (3, 3, 1, 5, 3, 5)
# Result: True
#
#
# Test: 272
# Input shape: (5, 3, 5, 2, 5)
# Result: True
#
#
# Test: 273
# Input shape: (4,)
# Result: True
#
#
# Test: 274
# Input shape: (5, 3, 1)
# Result: True
#
#
# Test: 275
# Input shape: (1,)
# Result: True
#
#
# Test: 276
# Input shape: (5, 4, 1, 3, 5)
# Result: True
#
#
# Test: 277
# Input shape: (2, 3, 5, 3, 2)
# Result: True
#
#
# Test: 278
# Input shape: (2, 2, 4, 5, 2)
# Result: True
#
#
# Test: 279
# Input shape: (4, 3)
# Result: True
#
#
# Test: 280
# Input shape: (2,)
# Result: True
#
#
# Test: 281
# Input shape: (3, 5, 2, 2, 4)
# Result: True
#
#
# Test: 282
# Input shape: (1, 2, 2, 4, 2)
# Result: True
#
#
# Test: 283
# Input shape: (4, 2)
# Result: True
#
#
# Test: 284
# Input shape: (1, 5, 4, 4)
# Result: True
#
#
# Test: 285
# Input shape: (2, 3, 5)
# Result: True
#
#
# Test: 286
# Input shape: (5, 4, 4, 5, 5, 4)
# Result: True
#
#
# Test: 287
# Input shape: (3, 2, 1)
# Result: True
#
#
# Test: 288
# Input shape: (3, 5, 1, 5, 4)
# Result: True
#
#
# Test: 289
# Input shape: (3,)
# Result: True
#
#
# Test: 290
# Input shape: (1,)
# Result: True
#
#
# Test: 291
# Input shape: (3, 2, 1, 1, 5)
# Result: True
#
#
# Test: 292
# Input shape: (1,)
# Result: True
#
#
# Test: 293
# Input shape: (5,)
# Result: True
#
#
# Test: 294
# Input shape: (3, 5)
# Result: True
#
#
# Test: 295
# Input shape: (5, 5, 5, 1, 4)
# Result: True
#
#
# Test: 296
# Input shape: (4, 2)
# Result: True
#
#
# Test: 297
# Input shape: (1, 5, 2, 4, 5)
# Result: True
#
#
# Test: 298
# Input shape: (2, 3, 3, 3)
# Result: True
#
#
# Test: 299
# Input shape: (3, 5, 3, 4, 5, 4)
# Result: True
#
#
# Test: 300
# Input shape: (1, 5)
# Result: True
#
#
# Test: 301
# Input shape: (1, 3, 5, 1, 1)
# Result: True
#
#
# Test: 302
# Input shape: (2, 5)
# Result: True
#
#
# Test: 303
# Input shape: (1, 1, 5, 3, 3, 2)
# Result: True
#
#
# Test: 304
# Input shape: (3, 4, 3, 2)
# Result: True
#
#
# Test: 305
# Input shape: (2, 1)
# Result: True
#
#
# Test: 306
# Input shape: (5, 3, 2)
# Result: True
#
#
# Test: 307
# Input shape: (2, 3)
# Result: True
#
#
# Test: 308
# Input shape: (4, 3, 5, 4)
# Result: True
#
#
# Test: 309
# Input shape: (5, 1, 1, 3, 4)
# Result: True
#
#
# Test: 310
# Input shape: (2,)
# Result: True
#
#
# Test: 311
# Input shape: (1, 4, 2, 4)
# Result: True
#
#
# Test: 312
# Input shape: (3, 3, 2, 1, 5)
# Result: True
#
#
# Test: 313
# Input shape: (3,)
# Result: True
#
#
# Test: 314
# Input shape: (4,)
# Result: True
#
#
# Test: 315
# Input shape: (2, 3, 4, 3, 2)
# Result: True
#
#
# Test: 316
# Input shape: (4, 1)
# Result: True
#
#
# Test: 317
# Input shape: (3, 2)
# Result: True
#
#
# Test: 318
# Input shape: (4, 2)
# Result: True
#
#
# Test: 319
# Input shape: (4, 5, 3, 4)
# Result: True
#
#
# Test: 320
# Input shape: (4, 5, 4, 5, 1, 4)
# Result: True
#
#
# Test: 321
# Input shape: (5, 2, 2, 5, 3)
# Result: True
#
#
# Test: 322
# Input shape: (1, 3, 1, 3, 3, 1)
# Result: True
#
#
# Test: 323
# Input shape: (4,)
# Result: True
#
#
# Test: 324
# Input shape: (4,)
# Result: True
#
#
# Test: 325
# Input shape: (1, 3, 1, 3, 1, 1)
# Result: True
#
#
# Test: 326
# Input shape: (2, 5, 3, 2, 1)
# Result: True
#
#
# Test: 327
# Input shape: (1, 5, 1, 2)
# Result: True
#
#
# Test: 328
# Input shape: (4, 5, 1)
# Result: True
#
#
# Test: 329
# Input shape: (5, 3, 1, 3)
# Result: True
#
#
# Test: 330
# Input shape: (1, 5, 2, 1, 3)
# Result: True
#
#
# Test: 331
# Input shape: (4, 2)
# Result: True
#
#
# Test: 332
# Input shape: (2, 1, 2, 3)
# Result: True
#
#
# Test: 333
# Input shape: (2,)
# Result: True
#
#
# Test: 334
# Input shape: (3,)
# Result: True
#
#
# Test: 335
# Input shape: (3, 2, 2, 5, 1, 2)
# Result: True
#
#
# Test: 336
# Input shape: (2, 4, 1, 2, 5)
# Result: True
#
#
# Test: 337
# Input shape: (4,)
# Result: True
#
#
# Test: 338
# Input shape: (2, 4)
# Result: True
#
#
# Test: 339
# Input shape: (4, 2, 5)
# Result: True
#
#
# Test: 340
# Input shape: (3, 3, 3, 1)
# Result: True
#
#
# Test: 341
# Input shape: (2, 1, 5, 5, 3, 4)
# Result: True
#
#
# Test: 342
# Input shape: (1, 2, 2)
# Result: True
#
#
# Test: 343
# Input shape: (1, 5, 1, 3)
# Result: True
#
#
# Test: 344
# Input shape: (1,)
# Result: True
#
#
# Test: 345
# Input shape: (1, 4, 5, 5)
# Result: True
#
#
# Test: 346
# Input shape: (5,)
# Result: True
#
#
# Test: 347
# Input shape: (1, 4, 5, 3)
# Result: True
#
#
# Test: 348
# Input shape: (5, 4, 4, 5, 1, 2)
# Result: True
#
#
# Test: 349
# Input shape: (5, 1, 5, 5, 1)
# Result: True
#
#
# Test: 350
# Input shape: (2, 3, 1, 2, 4)
# Result: True
#
#
# Test: 351
# Input shape: (1, 2, 3)
# Result: True
#
#
# Test: 352
# Input shape: (3, 1, 1)
# Result: True
#
#
# Test: 353
# Input shape: (2, 1)
# Result: True
#
#
# Test: 354
# Input shape: (1,)
# Result: True
#
#
# Test: 355
# Input shape: (1, 4, 3, 1)
# Result: True
#
#
# Test: 356
# Input shape: (3, 5, 5)
# Result: True
#
#
# Test: 357
# Input shape: (4,)
# Result: True
#
#
# Test: 358
# Input shape: (2, 3, 1, 5)
# Result: True
#
#
# Test: 359
# Input shape: (5, 5, 2)
# Result: True
#
#
# Test: 360
# Input shape: (5, 2)
# Result: True
#
#
# Test: 361
# Input shape: (3, 5, 1, 2)
# Result: True
#
#
# Test: 362
# Input shape: (5, 4, 1, 2, 4, 2)
# Result: True
#
#
# Test: 363
# Input shape: (4, 4, 5)
# Result: True
#
#
# Test: 364
# Input shape: (5,)
# Result: True
#
#
# Test: 365
# Input shape: (4, 4, 3, 2, 1)
# Result: True
#
#
# Test: 366
# Input shape: (2, 2, 3, 1, 3)
# Result: True
#
#
# Test: 367
# Input shape: (3, 1)
# Result: True
#
#
# Test: 368
# Input shape: (3, 5)
# Result: True
#
#
# Test: 369
# Input shape: (5,)
# Result: True
#
#
# Test: 370
# Input shape: (1,)
# Result: True
#
#
# Test: 371
# Input shape: (1,)
# Result: True
#
#
# Test: 372
# Input shape: (2, 5, 2, 5, 3)
# Result: True
#
#
# Test: 373
# Input shape: (5, 2, 1)
# Result: True
#
#
# Test: 374
# Input shape: (2, 4, 2)
# Result: True
#
#
# Test: 375
# Input shape: (1, 5, 4, 3, 5, 2)
# Result: True
#
#
# Test: 376
# Input shape: (1, 1, 3, 4, 3)
# Result: True
#
#
# Test: 377
# Input shape: (5, 5)
# Result: True
#
#
# Test: 378
# Input shape: (5, 1, 2, 4)
# Result: True
#
#
# Test: 379
# Input shape: (5, 2)
# Result: True
#
#
# Test: 380
# Input shape: (1, 3, 5, 4, 3)
# Result: True
#
#
# Test: 381
# Input shape: (1, 1, 1, 3)
# Result: True
#
#
# Test: 382
# Input shape: (3, 2, 4, 1, 4)
# Result: True
#
#
# Test: 383
# Input shape: (2, 4, 3, 5, 4, 5)
# Result: True
#
#
# Test: 384
# Input shape: (1, 3, 1, 5, 5, 5)
# Result: True
#
#
# Test: 385
# Input shape: (3, 2, 1, 2)
# Result: True
#
#
# Test: 386
# Input shape: (1,)
# Result: True
#
#
# Test: 387
# Input shape: (3, 1)
# Result: True
#
#
# Test: 388
# Input shape: (1, 3, 2, 4, 5, 3)
# Result: True
#
#
# Test: 389
# Input shape: (1, 3)
# Result: True
#
#
# Test: 390
# Input shape: (3, 3, 3, 5)
# Result: True
#
#
# Test: 391
# Input shape: (3, 1, 3, 1)
# Result: True
#
#
# Test: 392
# Input shape: (2, 2, 3)
# Result: True
#
#
# Test: 393
# Input shape: (5,)
# Result: True
#
#
# Test: 394
# Input shape: (4, 3, 3, 3)
# Result: True
#
#
# Test: 395
# Input shape: (5, 3, 2, 5)
# Result: True
#
#
# Test: 396
# Input shape: (3, 1, 5, 1, 5, 4)
# Result: True
#
#
# Test: 397
# Input shape: (1,)
# Result: True
#
#
# Test: 398
# Input shape: (1, 1, 1, 2)
# Result: True
#
#
# Test: 399
# Input shape: (5, 1, 2)
# Result: True
#
#
# Test: 400
# Input shape: (1, 1, 2, 5, 3)
# Result: True
#
#
# Test: 401
# Input shape: (1, 3, 1)
# Result: True
#
#
# Test: 402
# Input shape: (1, 3, 1, 4)
# Result: True
#
#
# Test: 403
# Input shape: (1, 4, 3, 2, 1)
# Result: True
#
#
# Test: 404
# Input shape: (1, 5, 5, 1)
# Result: True
#
#
# Test: 405
# Input shape: (1, 5, 3)
# Result: True
#
#
# Test: 406
# Input shape: (5, 5, 3)
# Result: True
#
#
# Test: 407
# Input shape: (1, 4, 5)
# Result: True
#
#
# Test: 408
# Input shape: (3, 4)
# Result: True
#
#
# Test: 409
# Input shape: (4, 2, 5)
# Result: True
#
#
# Test: 410
# Input shape: (4, 4, 2, 2)
# Result: True
#
#
# Test: 411
# Input shape: (5,)
# Result: True
#
#
# Test: 412
# Input shape: (5, 5, 2, 1, 4, 2)
# Result: True
#
#
# Test: 413
# Input shape: (3, 5, 4)
# Result: True
#
#
# Test: 414
# Input shape: (5, 3, 2, 4, 3)
# Result: True
#
#
# Test: 415
# Input shape: (5, 3, 3, 2, 2, 3)
# Result: True
#
#
# Test: 416
# Input shape: (4, 1, 1, 3, 2)
# Result: True
#
#
# Test: 417
# Input shape: (1, 3)
# Result: True
#
#
# Test: 418
# Input shape: (1, 2, 2)
# Result: True
#
#
# Test: 419
# Input shape: (1, 1, 3, 4, 1)
# Result: True
#
#
# Test: 420
# Input shape: (2, 1, 4, 1)
# Result: True
#
#
# Test: 421
# Input shape: (5,)
# Result: True
#
#
# Test: 422
# Input shape: (5, 2, 2, 1, 2, 5)
# Result: True
#
#
# Test: 423
# Input shape: (1, 1, 2, 5, 4, 3)
# Result: True
#
#
# Test: 424
# Input shape: (3,)
# Result: True
#
#
# Test: 425
# Input shape: (3, 5, 5, 1)
# Result: True
#
#
# Test: 426
# Input shape: (3, 5, 2, 1, 5, 4)
# Result: True
#
#
# Test: 427
# Input shape: (1, 2, 2, 1)
# Result: True
#
#
# Test: 428
# Input shape: (5, 5, 1, 1, 3)
# Result: True
#
#
# Test: 429
# Input shape: (3, 4, 5)
# Result: True
#
#
# Test: 430
# Input shape: (1, 5, 5, 4)
# Result: True
#
#
# Test: 431
# Input shape: (5, 2, 5, 4)
# Result: True
#
#
# Test: 432
# Input shape: (4, 3, 3, 4, 2)
# Result: True
#
#
# Test: 433
# Input shape: (3, 2, 1, 3, 5)
# Result: True
#
#
# Test: 434
# Input shape: (4, 4, 1, 2)
# Result: True
#
#
# Test: 435
# Input shape: (2, 1, 1)
# Result: True
#
#
# Test: 436
# Input shape: (3, 1, 3, 4, 5)
# Result: True
#
#
# Test: 437
# Input shape: (2, 3)
# Result: True
#
#
# Test: 438
# Input shape: (4, 3, 2, 5)
# Result: True
#
#
# Test: 439
# Input shape: (5, 3)
# Result: True
#
#
# Test: 440
# Input shape: (3, 2, 2)
# Result: True
#
#
# Test: 441
# Input shape: (1, 3, 5, 2, 4)
# Result: True
#
#
# Test: 442
# Input shape: (3, 4, 1, 3)
# Result: True
#
#
# Test: 443
# Input shape: (3, 3, 1, 5, 4, 3)
# Result: True
#
#
# Test: 444
# Input shape: (2, 3, 2, 5, 2, 1)
# Result: True
#
#
# Test: 445
# Input shape: (1, 2, 1)
# Result: True
#
#
# Test: 446
# Input shape: (5, 3, 5, 5)
# Result: True
#
#
# Test: 447
# Input shape: (1, 5, 3, 3, 2, 3)
# Result: True
#
#
# Test: 448
# Input shape: (1, 5, 2, 1, 1)
# Result: True
#
#
# Test: 449
# Input shape: (5,)
# Result: True
#
#
# Test: 450
# Input shape: (5,)
# Result: True
#
#
# Test: 451
# Input shape: (1, 1, 2, 1)
# Result: True
#
#
# Test: 452
# Input shape: (4, 5, 3, 3)
# Result: True
#
#
# Test: 453
# Input shape: (4,)
# Result: True
#
#
# Test: 454
# Input shape: (5, 3, 3, 2, 1)
# Result: True
#
#
# Test: 455
# Input shape: (4, 3, 3, 3)
# Result: True
#
#
# Test: 456
# Input shape: (4, 5, 2, 2, 2, 2)
# Result: True
#
#
# Test: 457
# Input shape: (1, 2, 1)
# Result: True
#
#
# Test: 458
# Input shape: (5, 5, 2, 2, 2, 2)
# Result: True
#
#
# Test: 459
# Input shape: (4,)
# Result: True
#
#
# Test: 460
# Input shape: (5, 5, 4, 3, 1)
# Result: True
#
#
# Test: 461
# Input shape: (3, 2, 1, 4)
# Result: True
#
#
# Test: 462
# Input shape: (3, 4, 1, 1)
# Result: True
#
#
# Test: 463
# Input shape: (2, 2)
# Result: True
#
#
# Test: 464
# Input shape: (2, 4, 2, 5)
# Result: True
#
#
# Test: 465
# Input shape: (3, 4, 2, 3)
# Result: True
#
#
# Test: 466
# Input shape: (4, 4, 2, 2)
# Result: True
#
#
# Test: 467
# Input shape: (3, 3)
# Result: True
#
#
# Test: 468
# Input shape: (4,)
# Result: True
#
#
# Test: 469
# Input shape: (2,)
# Result: True
#
#
# Test: 470
# Input shape: (3, 5)
# Result: True
#
#
# Test: 471
# Input shape: (2,)
# Result: True
#
#
# Test: 472
# Input shape: (1, 3)
# Result: True
#
#
# Test: 473
# Input shape: (1, 5)
# Result: True
#
#
# Test: 474
# Input shape: (4, 1, 1, 2, 5)
# Result: True
#
#
# Test: 475
# Input shape: (1, 5, 4, 5)
# Result: True
#
#
# Test: 476
# Input shape: (1, 1, 5, 5)
# Result: True
#
#
# Test: 477
# Input shape: (5, 3, 4)
# Result: True
#
#
# Test: 478
# Input shape: (3, 4, 3)
# Result: True
#
#
# Test: 479
# Input shape: (3, 4)
# Result: True
#
#
# Test: 480
# Input shape: (1, 5, 3, 2, 2, 4)
# Result: True
#
#
# Test: 481
# Input shape: (4, 4)
# Result: True
#
#
# Test: 482
# Input shape: (4,)
# Result: True
#
#
# Test: 483
# Input shape: (2, 5)
# Result: True
#
#
# Test: 484
# Input shape: (5, 1, 2, 3)
# Result: True
#
#
# Test: 485
# Input shape: (3, 4)
# Result: True
#
#
# Test: 486
# Input shape: (3, 2, 4, 3, 1, 4)
# Result: True
#
#
# Test: 487
# Input shape: (4,)
# Result: True
#
#
# Test: 488
# Input shape: (3, 1, 3)
# Result: True
#
#
# Test: 489
# Input shape: (4, 3, 1)
# Result: True
#
#
# Test: 490
# Input shape: (2, 4, 1)
# Result: True
#
#
# Test: 491
# Input shape: (1, 2, 2, 4, 5)
# Result: True
#
#
# Test: 492
# Input shape: (3, 5, 2, 3, 2)
# Result: True
#
#
# Test: 493
# Input shape: (5, 3, 4)
# Result: True
#
#
# Test: 494
# Input shape: (2, 5, 3, 1)
# Result: True
#
#
# Test: 495
# Input shape: (1, 3)
# Result: True
#
#
# Test: 496
# Input shape: (5, 3)
# Result: True
#
#
# Test: 497
# Input shape: (2, 2, 2, 4, 1, 2)
# Result: True
#
#
# Test: 498
# Input shape: (1, 5, 4, 1, 4)
# Result: True
#
#
# Test: 499
# Input shape: (1,)
# Result: True
#
#
# Test: 500
# Input shape: (3,)
# Result: True
#
#
# Test: 501
# Input shape: (3, 3)
# Result: True
#
#
# Test: 502
# Input shape: (4, 5, 3, 3, 4, 4)
# Result: True
#
#
# Test: 503
# Input shape: (2, 3)
# Result: True
#
#
# Test: 504
# Input shape: (3, 3)
# Result: True
#
#
# Test: 505
# Input shape: (1,)
# Result: True
#
#
# Test: 506
# Input shape: (5, 1, 2, 1, 2, 4)
# Result: True
#
#
# Test: 507
# Input shape: (2,)
# Result: True
#
#
# Test: 508
# Input shape: (2, 3)
# Result: True
#
#
# Test: 509
# Input shape: (1, 1)
# Result: True
#
#
# Test: 510
# Input shape: (1, 2, 2, 1, 4)
# Result: True
#
#
# Test: 511
# Input shape: (5, 1, 3, 4, 5, 1)
# Result: True
#
#
# Test: 512
# Input shape: (3, 3, 4, 4)
# Result: True
#
#
# Test: 513
# Input shape: (3, 3, 1)
# Result: True
#
#
# Test: 514
# Input shape: (5, 3, 1)
# Result: True
#
#
# Test: 515
# Input shape: (5, 2, 3)
# Result: True
#
#
# Test: 516
# Input shape: (5,)
# Result: True
#
#
# Test: 517
# Input shape: (2, 4)
# Result: True
#
#
# Test: 518
# Input shape: (5, 2, 3, 3)
# Result: True
#
#
# Test: 519
# Input shape: (4, 3, 3)
# Result: True
#
#
# Test: 520
# Input shape: (4,)
# Result: True
#
#
# Test: 521
# Input shape: (1, 4, 3, 2, 4)
# Result: True
#
#
# Test: 522
# Input shape: (2,)
# Result: True
#
#
# Test: 523
# Input shape: (3, 2, 1, 2, 5, 4)
# Result: True
#
#
# Test: 524
# Input shape: (1, 5)
# Result: True
#
#
# Test: 525
# Input shape: (3, 2, 1, 5, 4, 5)
# Result: True
#
#
# Test: 526
# Input shape: (1, 2, 2, 1)
# Result: True
#
#
# Test: 527
# Input shape: (2, 1)
# Result: True
#
#
# Test: 528
# Input shape: (1, 3, 2, 4, 2, 4)
# Result: True
#
#
# Test: 529
# Input shape: (4, 5, 4, 3, 3, 5)
# Result: True
#
#
# Test: 530
# Input shape: (2, 2, 4, 1, 1, 2)
# Result: True
#
#
# Test: 531
# Input shape: (3, 5, 1, 2, 1)
# Result: True
#
#
# Test: 532
# Input shape: (2, 4, 4)
# Result: True
#
#
# Test: 533
# Input shape: (2, 1, 1, 5, 5)
# Result: True
#
#
# Test: 534
# Input shape: (4,)
# Result: True
#
#
# Test: 535
# Input shape: (1, 5, 5, 1, 2)
# Result: True
#
#
# Test: 536
# Input shape: (5, 3, 2)
# Result: True
#
#
# Test: 537
# Input shape: (2, 4, 2, 3, 3, 5)
# Result: True
#
#
# Test: 538
# Input shape: (2, 2)
# Result: True
#
#
# Test: 539
# Input shape: (1, 2, 2, 1)
# Result: True
#
#
# Test: 540
# Input shape: (2,)
# Result: True
#
#
# Test: 541
# Input shape: (3, 4, 3)
# Result: True
#
#
# Test: 542
# Input shape: (5, 5, 2)
# Result: True
#
#
# Test: 543
# Input shape: (4, 5, 2, 1, 2, 5)
# Result: True
#
#
# Test: 544
# Input shape: (1, 5, 3)
# Result: True
#
#
# Test: 545
# Input shape: (3, 2, 5, 1)
# Result: True
#
#
# Test: 546
# Input shape: (5, 1, 3, 4, 5)
# Result: True
#
#
# Test: 547
# Input shape: (5, 4)
# Result: True
#
#
# Test: 548
# Input shape: (5, 5)
# Result: True
#
#
# Test: 549
# Input shape: (4, 2, 1, 2)
# Result: True
#
#
# Test: 550
# Input shape: (2,)
# Result: True
#
#
# Test: 551
# Input shape: (4, 2, 4, 5)
# Result: True
#
#
# Test: 552
# Input shape: (2, 2, 5)
# Result: True
#
#
# Test: 553
# Input shape: (4, 2, 2)
# Result: True
#
#
# Test: 554
# Input shape: (2,)
# Result: True
#
#
# Test: 555
# Input shape: (2, 4, 3, 2, 4)
# Result: True
#
#
# Test: 556
# Input shape: (3, 2, 2, 3, 2, 5)
# Result: True
#
#
# Test: 557
# Input shape: (3,)
# Result: True
#
#
# Test: 558
# Input shape: (2, 4, 1, 5, 5)
# Result: True
#
#
# Test: 559
# Input shape: (2, 5, 1)
# Result: True
#
#
# Test: 560
# Input shape: (1, 2, 1)
# Result: True
#
#
# Test: 561
# Input shape: (4, 4, 1, 1, 4, 4)
# Result: True
#
#
# Test: 562
# Input shape: (5, 1, 5, 1, 5, 5)
# Result: True
#
#
# Test: 563
# Input shape: (4,)
# Result: True
#
#
# Test: 564
# Input shape: (4, 5, 3, 1, 3)
# Result: True
#
#
# Test: 565
# Input shape: (1, 3, 4, 3, 3, 1)
# Result: True
#
#
# Test: 566
# Input shape: (1, 4, 4, 5, 4)
# Result: True
#
#
# Test: 567
# Input shape: (1, 5, 1, 4, 1, 1)
# Result: True
#
#
# Test: 568
# Input shape: (4,)
# Result: True
#
#
# Test: 569
# Input shape: (3, 2, 5, 4)
# Result: True
#
#
# Test: 570
# Input shape: (2, 3, 1)
# Result: True
#
#
# Test: 571
# Input shape: (5, 4, 3)
# Result: True
#
#
# Test: 572
# Input shape: (4, 3, 4, 1)
# Result: True
#
#
# Test: 573
# Input shape: (1, 5, 2, 5, 2, 5)
# Result: True
#
#
# Test: 574
# Input shape: (1, 3, 2)
# Result: True
#
#
# Test: 575
# Input shape: (5, 3, 2)
# Result: True
#
#
# Test: 576
# Input shape: (5, 1, 4, 5, 4)
# Result: True
#
#
# Test: 577
# Input shape: (3, 5, 4)
# Result: True
#
#
# Test: 578
# Input shape: (3, 4)
# Result: True
#
#
# Test: 579
# Input shape: (5, 4, 2, 2)
# Result: True
#
#
# Test: 580
# Input shape: (3, 3, 4, 4, 2, 5)
# Result: True
#
#
# Test: 581
# Input shape: (1, 1)
# Result: True
#
#
# Test: 582
# Input shape: (3, 3, 5, 5)
# Result: True
#
#
# Test: 583
# Input shape: (5, 4)
# Result: True
#
#
# Test: 584
# Input shape: (2, 5)
# Result: True
#
#
# Test: 585
# Input shape: (5, 1, 3)
# Result: True
#
#
# Test: 586
# Input shape: (4, 4, 1)
# Result: True
#
#
# Test: 587
# Input shape: (5, 3, 2)
# Result: True
#
#
# Test: 588
# Input shape: (2, 1, 2)
# Result: True
#
#
# Test: 589
# Input shape: (2,)
# Result: True
#
#
# Test: 590
# Input shape: (5,)
# Result: True
#
#
# Test: 591
# Input shape: (3,)
# Result: True
#
#
# Test: 592
# Input shape: (3,)
# Result: True
#
#
# Test: 593
# Input shape: (3,)
# Result: True
#
#
# Test: 594
# Input shape: (1, 1)
# Result: True
#
#
# Test: 595
# Input shape: (4, 5, 4, 4, 3)
# Result: True
#
#
# Test: 596
# Input shape: (5, 5, 1, 4)
# Result: True
#
#
# Test: 597
# Input shape: (3,)
# Result: True
#
#
# Test: 598
# Input shape: (2, 3, 1)
# Result: True
#
#
# Test: 599
# Input shape: (5,)
# Result: True
#
#
# Test: 600
# Input shape: (2, 2, 2, 5, 4)
# Result: True
#
#
# Test: 601
# Input shape: (5, 3, 3, 2, 3, 4)
# Result: True
#
#
# Test: 602
# Input shape: (2,)
# Result: True
#
#
# Test: 603
# Input shape: (3,)
# Result: True
#
#
# Test: 604
# Input shape: (4,)
# Result: True
#
#
# Test: 605
# Input shape: (3, 4, 2)
# Result: True
#
#
# Test: 606
# Input shape: (2, 5, 3, 4, 5, 4)
# Result: True
#
#
# Test: 607
# Input shape: (4, 4, 3)
# Result: True
#
#
# Test: 608
# Input shape: (1, 3, 3, 2, 4, 4)
# Result: True
#
#
# Test: 609
# Input shape: (3,)
# Result: True
#
#
# Test: 610
# Input shape: (4, 2, 3, 2, 5, 4)
# Result: True
#
#
# Test: 611
# Input shape: (2, 3)
# Result: True
#
#
# Test: 612
# Input shape: (1,)
# Result: True
#
#
# Test: 613
# Input shape: (1, 2)
# Result: True
#
#
# Test: 614
# Input shape: (5, 4)
# Result: True
#
#
# Test: 615
# Input shape: (1,)
# Result: True
#
#
# Test: 616
# Input shape: (4, 2, 1, 4, 2)
# Result: True
#
#
# Test: 617
# Input shape: (3, 1, 2, 5, 5, 2)
# Result: True
#
#
# Test: 618
# Input shape: (1, 5, 4, 5)
# Result: True
#
#
# Test: 619
# Input shape: (1, 4, 2, 3)
# Result: True
#
#
# Test: 620
# Input shape: (3, 2, 3, 4)
# Result: True
#
#
# Test: 621
# Input shape: (4, 3, 3, 2, 5, 2)
# Result: True
#
#
# Test: 622
# Input shape: (1,)
# Result: True
#
#
# Test: 623
# Input shape: (5, 2, 1)
# Result: True
#
#
# Test: 624
# Input shape: (5, 2)
# Result: True
#
#
# Test: 625
# Input shape: (3, 5)
# Result: True
#
#
# Test: 626
# Input shape: (5, 5, 2, 1, 1, 4)
# Result: True
#
#
# Test: 627
# Input shape: (3, 2, 3, 4, 4)
# Result: True
#
#
# Test: 628
# Input shape: (5,)
# Result: True
#
#
# Test: 629
# Input shape: (3, 1, 2, 4)
# Result: True
#
#
# Test: 630
# Input shape: (5, 3, 1, 2, 3)
# Result: True
#
#
# Test: 631
# Input shape: (1,)
# Result: True
#
#
# Test: 632
# Input shape: (5, 1, 4)
# Result: True
#
#
# Test: 633
# Input shape: (1, 1, 3, 5, 5, 2)
# Result: True
#
#
# Test: 634
# Input shape: (3, 5, 2, 3, 5)
# Result: True
#
#
# Test: 635
# Input shape: (4, 4, 4, 5, 1)
# Result: True
#
#
# Test: 636
# Input shape: (3, 1, 3, 1)
# Result: True
#
#
# Test: 637
# Input shape: (4,)
# Result: True
#
#
# Test: 638
# Input shape: (3, 5, 1, 5, 5, 1)
# Result: True
#
#
# Test: 639
# Input shape: (5, 3, 3, 1)
# Result: True
#
#
# Test: 640
# Input shape: (4, 4, 2)
# Result: True
#
#
# Test: 641
# Input shape: (5, 1, 3, 5)
# Result: True
#
#
# Test: 642
# Input shape: (2, 2, 3, 1, 2, 5)
# Result: True
#
#
# Test: 643
# Input shape: (3,)
# Result: True
#
#
# Test: 644
# Input shape: (1, 4)
# Result: True
#
#
# Test: 645
# Input shape: (1, 2, 4)
# Result: True
#
#
# Test: 646
# Input shape: (5, 5)
# Result: True
#
#
# Test: 647
# Input shape: (4, 2, 3, 1, 2)
# Result: True
#
#
# Test: 648
# Input shape: (2,)
# Result: True
#
#
# Test: 649
# Input shape: (5, 1, 4, 1, 4)
# Result: True
#
#
# Test: 650
# Input shape: (2, 4, 2)
# Result: True
#
#
# Test: 651
# Input shape: (1, 3, 5)
# Result: True
#
#
# Test: 652
# Input shape: (5, 1, 2, 1, 4, 4)
# Result: True
#
#
# Test: 653
# Input shape: (5,)
# Result: True
#
#
# Test: 654
# Input shape: (2,)
# Result: True
#
#
# Test: 655
# Input shape: (2, 3, 1, 3)
# Result: True
#
#
# Test: 656
# Input shape: (1, 5, 1, 2, 5)
# Result: True
#
#
# Test: 657
# Input shape: (4, 2, 1, 5)
# Result: True
#
#
# Test: 658
# Input shape: (3, 3)
# Result: True
#
#
# Test: 659
# Input shape: (2, 1, 3, 2, 2, 1)
# Result: True
#
#
# Test: 660
# Input shape: (3, 1, 4, 4, 4)
# Result: True
#
#
# Test: 661
# Input shape: (4, 3)
# Result: True
#
#
# Test: 662
# Input shape: (3, 2, 1, 2, 1, 2)
# Result: True
#
#
# Test: 663
# Input shape: (4, 3, 1, 2)
# Result: True
#
#
# Test: 664
# Input shape: (2, 4, 4, 1, 5)
# Result: True
#
#
# Test: 665
# Input shape: (3,)
# Result: True
#
#
# Test: 666
# Input shape: (5, 4, 1, 1, 1)
# Result: True
#
#
# Test: 667
# Input shape: (3,)
# Result: True
#
#
# Test: 668
# Input shape: (1, 2, 2)
# Result: True
#
#
# Test: 669
# Input shape: (3, 1, 5, 1, 5)
# Result: True
#
#
# Test: 670
# Input shape: (5,)
# Result: True
#
#
# Test: 671
# Input shape: (1, 4, 3)
# Result: True
#
#
# Test: 672
# Input shape: (5,)
# Result: True
#
#
# Test: 673
# Input shape: (5, 4, 2, 4, 5)
# Result: True
#
#
# Test: 674
# Input shape: (5, 4, 2, 2, 2, 5)
# Result: True
#
#
# Test: 675
# Input shape: (3,)
# Result: True
#
#
# Test: 676
# Input shape: (5,)
# Result: True
#
#
# Test: 677
# Input shape: (3, 2)
# Result: True
#
#
# Test: 678
# Input shape: (2, 4, 3, 2, 2, 5)
# Result: True
#
#
# Test: 679
# Input shape: (2,)
# Result: True
#
#
# Test: 680
# Input shape: (4, 3, 1, 3, 4, 5)
# Result: True
#
#
# Test: 681
# Input shape: (4, 1, 4, 1, 5)
# Result: True
#
#
# Test: 682
# Input shape: (2, 3, 4)
# Result: True
#
#
# Test: 683
# Input shape: (2, 3, 5, 5, 1)
# Result: True
#
#
# Test: 684
# Input shape: (2,)
# Result: True
#
#
# Test: 685
# Input shape: (1,)
# Result: True
#
#
# Test: 686
# Input shape: (2, 1, 1, 4, 2)
# Result: True
#
#
# Test: 687
# Input shape: (1, 3, 4, 2, 1)
# Result: True
#
#
# Test: 688
# Input shape: (3, 4, 3)
# Result: True
#
#
# Test: 689
# Input shape: (1, 4, 1, 5, 4)
# Result: True
#
#
# Test: 690
# Input shape: (5, 1, 2, 1, 1, 5)
# Result: True
#
#
# Test: 691
# Input shape: (5, 4, 2, 3, 5)
# Result: True
#
#
# Test: 692
# Input shape: (1, 4)
# Result: True
#
#
# Test: 693
# Input shape: (1, 4, 4, 3)
# Result: True
#
#
# Test: 694
# Input shape: (2, 4, 5, 1)
# Result: True
#
#
# Test: 695
# Input shape: (1, 2, 2, 1)
# Result: True
#
#
# Test: 696
# Input shape: (5, 1, 2, 2, 4, 2)
# Result: True
#
#
# Test: 697
# Input shape: (2,)
# Result: True
#
#
# Test: 698
# Input shape: (1, 4, 4, 5, 3, 3)
# Result: True
#
#
# Test: 699
# Input shape: (2, 5, 1, 4, 3, 5)
# Result: True
#
#
# Test: 700
# Input shape: (3, 4)
# Result: True
#
#
# Test: 701
# Input shape: (1, 5, 3, 1, 5, 3)
# Result: True
#
#
# Test: 702
# Input shape: (4,)
# Result: True
#
#
# Test: 703
# Input shape: (1,)
# Result: True
#
#
# Test: 704
# Input shape: (1, 3, 2, 3, 2, 4)
# Result: True
#
#
# Test: 705
# Input shape: (3, 4, 2, 1)
# Result: True
#
#
# Test: 706
# Input shape: (4, 4, 2, 2, 1)
# Result: True
#
#
# Test: 707
# Input shape: (3, 3, 4, 1, 2)
# Result: True
#
#
# Test: 708
# Input shape: (5, 5, 2, 2)
# Result: True
#
#
# Test: 709
# Input shape: (2, 4)
# Result: True
#
#
# Test: 710
# Input shape: (1, 4, 2)
# Result: True
#
#
# Test: 711
# Input shape: (4, 4, 2, 5, 5, 3)
# Result: True
#
#
# Test: 712
# Input shape: (5, 4, 3, 5, 1)
# Result: True
#
#
# Test: 713
# Input shape: (4, 4)
# Result: True
#
#
# Test: 714
# Input shape: (2, 2, 3, 4, 2, 4)
# Result: True
#
#
# Test: 715
# Input shape: (1, 1, 3, 5, 1)
# Result: True
#
#
# Test: 716
# Input shape: (1,)
# Result: True
#
#
# Test: 717
# Input shape: (4, 4, 2, 2, 2)
# Result: True
#
#
# Test: 718
# Input shape: (5, 4)
# Result: True
#
#
# Test: 719
# Input shape: (2, 5)
# Result: True
#
#
# Test: 720
# Input shape: (1, 3, 4, 2)
# Result: True
#
#
# Test: 721
# Input shape: (5, 4, 4)
# Result: True
#
#
# Test: 722
# Input shape: (1, 4, 1)
# Result: True
#
#
# Test: 723
# Input shape: (1, 5, 3, 5)
# Result: True
#
#
# Test: 724
# Input shape: (4, 4, 5, 5, 3)
# Result: True
#
#
# Test: 725
# Input shape: (1, 2, 4, 2)
# Result: True
#
#
# Test: 726
# Input shape: (3, 4, 2, 3, 3, 1)
# Result: True
#
#
# Test: 727
# Input shape: (4, 1, 3, 1, 2)
# Result: True
#
#
# Test: 728
# Input shape: (1,)
# Result: True
#
#
# Test: 729
# Input shape: (4, 4)
# Result: True
#
#
# Test: 730
# Input shape: (2, 4, 1)
# Result: True
#
#
# Test: 731
# Input shape: (4, 5, 5, 1, 2)
# Result: True
#
#
# Test: 732
# Input shape: (4, 3, 5, 1)
# Result: True
#
#
# Test: 733
# Input shape: (1, 2, 3, 2, 4, 3)
# Result: True
#
#
# Test: 734
# Input shape: (5, 2, 1, 2, 2, 4)
# Result: True
#
#
# Test: 735
# Input shape: (1, 3, 2, 5, 1, 4)
# Result: True
#
#
# Test: 736
# Input shape: (4, 5)
# Result: True
#
#
# Test: 737
# Input shape: (3,)
# Result: True
#
#
# Test: 738
# Input shape: (3, 2)
# Result: True
#
#
# Test: 739
# Input shape: (5, 2, 3, 2, 3)
# Result: True
#
#
# Test: 740
# Input shape: (1, 2, 1)
# Result: True
#
#
# Test: 741
# Input shape: (2, 2, 4)
# Result: True
#
#
# Test: 742
# Input shape: (1, 5, 2, 5, 2, 4)
# Result: True
#
#
# Test: 743
# Input shape: (1, 4, 4, 3, 3, 1)
# Result: True
#
#
# Test: 744
# Input shape: (4,)
# Result: True
#
#
# Test: 745
# Input shape: (4, 5, 1, 1, 2)
# Result: True
#
#
# Test: 746
# Input shape: (3, 4, 3, 3, 5, 4)
# Result: True
#
#
# Test: 747
# Input shape: (5, 2, 1)
# Result: True
#
#
# Test: 748
# Input shape: (3, 3, 2, 2, 3, 2)
# Result: True
#
#
# Test: 749
# Input shape: (2, 5, 1)
# Result: True
#
#
# Test: 750
# Input shape: (2,)
# Result: True
#
#
# Test: 751
# Input shape: (1, 5, 4)
# Result: True
#
#
# Test: 752
# Input shape: (5, 1, 1)
# Result: True
#
#
# Test: 753
# Input shape: (1, 3, 1, 4, 4)
# Result: True
#
#
# Test: 754
# Input shape: (2,)
# Result: True
#
#
# Test: 755
# Input shape: (4,)
# Result: True
#
#
# Test: 756
# Input shape: (5, 3, 1, 2, 4, 3)
# Result: True
#
#
# Test: 757
# Input shape: (5,)
# Result: True
#
#
# Test: 758
# Input shape: (5, 3, 4)
# Result: True
#
#
# Test: 759
# Input shape: (3, 5, 5)
# Result: True
#
#
# Test: 760
# Input shape: (2, 5, 4)
# Result: True
#
#
# Test: 761
# Input shape: (1, 3, 2, 5, 1, 2)
# Result: True
#
#
# Test: 762
# Input shape: (4, 4, 1)
# Result: True
#
#
# Test: 763
# Input shape: (3, 1, 3, 3, 5)
# Result: True
#
#
# Test: 764
# Input shape: (2, 4, 2, 4, 5)
# Result: True
#
#
# Test: 765
# Input shape: (2, 3, 1)
# Result: True
#
#
# Test: 766
# Input shape: (2, 2, 2, 4)
# Result: True
#
#
# Test: 767
# Input shape: (4, 4, 2, 4, 3)
# Result: True
#
#
# Test: 768
# Input shape: (5, 4, 5, 2, 3)
# Result: True
#
#
# Test: 769
# Input shape: (2, 2)
# Result: True
#
#
# Test: 770
# Input shape: (4, 3, 2, 5)
# Result: True
#
#
# Test: 771
# Input shape: (3, 1, 4, 2, 1)
# Result: True
#
#
# Test: 772
# Input shape: (2,)
# Result: True
#
#
# Test: 773
# Input shape: (2, 1, 3, 5)
# Result: True
#
#
# Test: 774
# Input shape: (3, 3)
# Result: True
#
#
# Test: 775
# Input shape: (2,)
# Result: True
#
#
# Test: 776
# Input shape: (5, 4)
# Result: True
#
#
# Test: 777
# Input shape: (3, 2, 4, 2)
# Result: True
#
#
# Test: 778
# Input shape: (3, 4, 5)
# Result: True
#
#
# Test: 779
# Input shape: (3, 3)
# Result: True
#
#
# Test: 780
# Input shape: (1, 2, 1, 1)
# Result: True
#
#
# Test: 781
# Input shape: (2, 4, 4, 3, 2)
# Result: True
#
#
# Test: 782
# Input shape: (5,)
# Result: True
#
#
# Test: 783
# Input shape: (5, 2, 3, 2, 1)
# Result: True
#
#
# Test: 784
# Input shape: (4, 3, 4, 1, 3, 2)
# Result: True
#
#
# Test: 785
# Input shape: (4, 2, 1, 1)
# Result: True
#
#
# Test: 786
# Input shape: (4, 4, 1)
# Result: True
#
#
# Test: 787
# Input shape: (1, 4, 1, 1)
# Result: True
#
#
# Test: 788
# Input shape: (2,)
# Result: True
#
#
# Test: 789
# Input shape: (1, 2, 2, 1)
# Result: True
#
#
# Test: 790
# Input shape: (5, 5, 5)
# Result: True
#
#
# Test: 791
# Input shape: (4, 4, 4)
# Result: True
#
#
# Test: 792
# Input shape: (2, 1)
# Result: True
#
#
# Test: 793
# Input shape: (1, 3, 4)
# Result: True
#
#
# Test: 794
# Input shape: (2, 1, 1, 1)
# Result: True
#
#
# Test: 795
# Input shape: (2,)
# Result: True
#
#
# Test: 796
# Input shape: (2, 5, 4, 2)
# Result: True
#
#
# Test: 797
# Input shape: (2, 5, 5, 2, 5, 4)
# Result: True
#
#
# Test: 798
# Input shape: (1, 1, 2)
# Result: True
#
#
# Test: 799
# Input shape: (5, 3)
# Result: True
#
#
# Test: 800
# Input shape: (5, 5, 5, 3, 2)
# Result: True
#
#
# Test: 801
# Input shape: (3, 3, 4)
# Result: True
#
#
# Test: 802
# Input shape: (2, 3, 5, 5, 1)
# Result: True
#
#
# Test: 803
# Input shape: (3, 1, 2, 3)
# Result: True
#
#
# Test: 804
# Input shape: (3, 5, 3, 2, 1)
# Result: True
#
#
# Test: 805
# Input shape: (4, 1, 4, 1, 2, 1)
# Result: True
#
#
# Test: 806
# Input shape: (3, 3, 3)
# Result: True
#
#
# Test: 807
# Input shape: (3, 1, 3, 1, 3, 5)
# Result: True
#
#
# Test: 808
# Input shape: (1, 5)
# Result: True
#
#
# Test: 809
# Input shape: (2, 5, 3, 4, 1, 4)
# Result: True
#
#
# Test: 810
# Input shape: (4, 2, 2, 5, 3)
# Result: True
#
#
# Test: 811
# Input shape: (5, 1, 2)
# Result: True
#
#
# Test: 812
# Input shape: (5, 3)
# Result: True
#
#
# Test: 813
# Input shape: (4, 1, 2)
# Result: True
#
#
# Test: 814
# Input shape: (3, 4, 1, 4, 2, 4)
# Result: True
#
#
# Test: 815
# Input shape: (2, 3)
# Result: True
#
#
# Test: 816
# Input shape: (5, 5, 1, 5, 5)
# Result: True
#
#
# Test: 817
# Input shape: (3, 5, 1, 3, 5)
# Result: True
#
#
# Test: 818
# Input shape: (3, 1, 2, 2, 2)
# Result: True
#
#
# Test: 819
# Input shape: (3, 4, 2, 2, 3, 4)
# Result: True
#
#
# Test: 820
# Input shape: (5, 5)
# Result: True
#
#
# Test: 821
# Input shape: (1, 2, 1, 5, 2, 5)
# Result: True
#
#
# Test: 822
# Input shape: (4, 2, 4, 5)
# Result: True
#
#
# Test: 823
# Input shape: (2, 2, 1)
# Result: True
#
#
# Test: 824
# Input shape: (3, 4, 3, 3)
# Result: True
#
#
# Test: 825
# Input shape: (3, 1)
# Result: True
#
#
# Test: 826
# Input shape: (1, 4, 1, 4, 4)
# Result: True
#
#
# Test: 827
# Input shape: (4, 3, 3, 3, 1)
# Result: True
#
#
# Test: 828
# Input shape: (4, 4, 4)
# Result: True
#
#
# Test: 829
# Input shape: (1, 2, 5, 1, 2)
# Result: True
#
#
# Test: 830
# Input shape: (1, 5, 4, 3, 4)
# Result: True
#
#
# Test: 831
# Input shape: (1, 2, 5, 5)
# Result: True
#
#
# Test: 832
# Input shape: (4, 1, 5)
# Result: True
#
#
# Test: 833
# Input shape: (4, 3, 1)
# Result: True
#
#
# Test: 834
# Input shape: (3, 5, 3, 4)
# Result: True
#
#
# Test: 835
# Input shape: (3, 3, 5)
# Result: True
#
#
# Test: 836
# Input shape: (3, 4, 5, 3)
# Result: True
#
#
# Test: 837
# Input shape: (5, 3, 1, 1)
# Result: True
#
#
# Test: 838
# Input shape: (4, 4)
# Result: True
#
#
# Test: 839
# Input shape: (2,)
# Result: True
#
#
# Test: 840
# Input shape: (2, 4, 3, 4)
# Result: True
#
#
# Test: 841
# Input shape: (3, 2)
# Result: True
#
#
# Test: 842
# Input shape: (3,)
# Result: True
#
#
# Test: 843
# Input shape: (1, 5, 4, 5, 3, 3)
# Result: True
#
#
# Test: 844
# Input shape: (3, 3, 5, 4, 1, 3)
# Result: True
#
#
# Test: 845
# Input shape: (1, 5, 2, 3, 1, 3)
# Result: True
#
#
# Test: 846
# Input shape: (3, 2, 4, 1, 3, 1)
# Result: True
#
#
# Test: 847
# Input shape: (2,)
# Result: True
#
#
# Test: 848
# Input shape: (3, 3, 4, 2, 1)
# Result: True
#
#
# Test: 849
# Input shape: (1, 2)
# Result: True
#
#
# Test: 850
# Input shape: (1, 4, 2, 1, 2, 4)
# Result: True
#
#
# Test: 851
# Input shape: (4, 2, 5, 2, 5)
# Result: True
#
#
# Test: 852
# Input shape: (3, 5, 2, 2, 1, 5)
# Result: True
#
#
# Test: 853
# Input shape: (3,)
# Result: True
#
#
# Test: 854
# Input shape: (2,)
# Result: True
#
#
# Test: 855
# Input shape: (3, 5, 5, 4, 1)
# Result: True
#
#
# Test: 856
# Input shape: (3, 2, 5, 5)
# Result: True
#
#
# Test: 857
# Input shape: (5, 1, 5, 2, 3, 5)
# Result: True
#
#
# Test: 858
# Input shape: (2,)
# Result: True
#
#
# Test: 859
# Input shape: (3,)
# Result: True
#
#
# Test: 860
# Input shape: (1, 5)
# Result: True
#
#
# Test: 861
# Input shape: (3,)
# Result: True
#
#
# Test: 862
# Input shape: (4, 3, 3, 2, 2)
# Result: True
#
#
# Test: 863
# Input shape: (4,)
# Result: True
#
#
# Test: 864
# Input shape: (3, 3, 4, 2)
# Result: True
#
#
# Test: 865
# Input shape: (4, 1)
# Result: True
#
#
# Test: 866
# Input shape: (3,)
# Result: True
#
#
# Test: 867
# Input shape: (4, 3, 2)
# Result: True
#
#
# Test: 868
# Input shape: (2, 2)
# Result: True
#
#
# Test: 869
# Input shape: (3, 5, 1, 1, 3)
# Result: True
#
#
# Test: 870
# Input shape: (1, 3, 3, 1, 3, 5)
# Result: True
#
#
# Test: 871
# Input shape: (4, 2)
# Result: True
#
#
# Test: 872
# Input shape: (4,)
# Result: True
#
#
# Test: 873
# Input shape: (2,)
# Result: True
#
#
# Test: 874
# Input shape: (5, 2, 1, 3, 5, 3)
# Result: True
#
#
# Test: 875
# Input shape: (2, 5, 3, 1, 5)
# Result: True
#
#
# Test: 876
# Input shape: (3, 3, 5)
# Result: True
#
#
# Test: 877
# Input shape: (1, 2, 5, 1)
# Result: True
#
#
# Test: 878
# Input shape: (5, 4, 4)
# Result: True
#
#
# Test: 879
# Input shape: (2, 5)
# Result: True
#
#
# Test: 880
# Input shape: (2, 2, 4, 3, 2)
# Result: True
#
#
# Test: 881
# Input shape: (1, 1, 4, 2, 4, 4)
# Result: True
#
#
# Test: 882
# Input shape: (4,)
# Result: True
#
#
# Test: 883
# Input shape: (5, 2, 4)
# Result: True
#
#
# Test: 884
# Input shape: (5, 5)
# Result: True
#
#
# Test: 885
# Input shape: (3, 2, 3, 4, 1)
# Result: True
#
#
# Test: 886
# Input shape: (1, 3, 4, 2)
# Result: True
#
#
# Test: 887
# Input shape: (5, 3, 1)
# Result: True
#
#
# Test: 888
# Input shape: (2, 2)
# Result: True
#
#
# Test: 889
# Input shape: (3,)
# Result: True
#
#
# Test: 890
# Input shape: (2,)
# Result: True
#
#
# Test: 891
# Input shape: (4, 2, 4, 3, 4)
# Result: True
#
#
# Test: 892
# Input shape: (4, 3, 5, 1)
# Result: True
#
#
# Test: 893
# Input shape: (4, 5, 2, 1)
# Result: True
#
#
# Test: 894
# Input shape: (5,)
# Result: True
#
#
# Test: 895
# Input shape: (1, 4, 5)
# Result: True
#
#
# Test: 896
# Input shape: (2,)
# Result: True
#
#
# Test: 897
# Input shape: (2, 1, 5, 3, 2, 1)
# Result: True
#
#
# Test: 898
# Input shape: (4, 1, 1, 5, 5)
# Result: True
#
#
# Test: 899
# Input shape: (1, 5, 3, 1)
# Result: True
#
#
# Test: 900
# Input shape: (1, 1)
# Result: True
#
#
# Test: 901
# Input shape: (1, 3, 3, 2)
# Result: True
#
#
# Test: 902
# Input shape: (3, 5, 3, 5)
# Result: True
#
#
# Test: 903
# Input shape: (2, 2, 2, 1)
# Result: True
#
#
# Test: 904
# Input shape: (2,)
# Result: True
#
#
# Test: 905
# Input shape: (2,)
# Result: True
#
#
# Test: 906
# Input shape: (4, 4, 4, 2, 1)
# Result: True
#
#
# Test: 907
# Input shape: (1, 2, 5, 1)
# Result: True
#
#
# Test: 908
# Input shape: (5, 4)
#  96%|████████████████████████████████████▌ | 962/1000 [00:00<00:00, 5114.94it/s]
# Result: True
#
#
# Test: 909
# Input shape: (3,)
# Result: True
#
#
# Test: 910
# Input shape: (3, 2, 3, 2)
# Result: True
#
#
# Test: 911
# Input shape: (3, 1)
# Result: True
#
#
# Test: 912
# Input shape: (4, 2, 1, 3)
# Result: True
#
#
# Test: 913
# Input shape: (3, 5, 3, 1, 4)
# Result: True
#
#
# Test: 914
# Input shape: (5,)
# Result: True
#
#
# Test: 915
# Input shape: (2, 2, 1, 4, 5)
# Result: True
#
#
# Test: 916
# Input shape: (4, 1)
# Result: True
#
#
# Test: 917
# Input shape: (1, 4)
# Result: True
#
#
# Test: 918
# Input shape: (3, 1)
# Result: True
#
#
# Test: 919
# Input shape: (1, 2, 5, 3, 1, 4)
# Result: True
#
#
# Test: 920
# Input shape: (4,)
# Result: True
#
#
# Test: 921
# Input shape: (4, 3, 3)
# Result: True
#
#
# Test: 922
# Input shape: (3, 1, 3, 1, 2, 5)
# Result: True
#
#
# Test: 923
# Input shape: (4, 1, 5)
# Result: True
#
#
# Test: 924
# Input shape: (2, 3)
# Result: True
#
#
# Test: 925
# Input shape: (5, 1, 1, 5)
# Result: True
#
#
# Test: 926
# Input shape: (3, 3)
# Result: True
#
#
# Test: 927
# Input shape: (2,)
# Result: True
#
#
# Test: 928
# Input shape: (2, 4, 2, 1, 5, 3)
# Result: True
#
#
# Test: 929
# Input shape: (5,)
# Result: True
#
#
# Test: 930
# Input shape: (2, 1, 2, 3, 2)
# Result: True
#
#
# Test: 931
# Input shape: (3, 1, 3, 4)
# Result: True
#
#
# Test: 932
# Input shape: (1, 3, 1, 1, 1)
# Result: True
#
#
# Test: 933
# Input shape: (5,)
# Result: True
#
#
# Test: 934
# Input shape: (3, 3, 3)
# Result: True
#
#
# Test: 935
# Input shape: (3, 3, 5, 5, 1, 2)
# Result: True
#
#
# Test: 936
# Input shape: (5, 4)
# Result: True
#
#
# Test: 937
# Input shape: (3, 1, 4, 5, 1, 3)
# Result: True
#
#
# Test: 938
# Input shape: (2, 1)
# Result: True
#
#
# Test: 939
# Input shape: (4,)
# Result: True
#
#
# Test: 940
# Input shape: (1, 1, 1)
# Result: True
#
#
# Test: 941
# Input shape: (1, 2, 3)
# Result: True
#
#
# Test: 942
# Input shape: (5, 5, 2, 2, 5)
# Result: True
#
#
# Test: 943
# Input shape: (4, 3, 2, 3, 5)
# Result: True
#
#
# Test: 944
# Input shape: (1, 3)
# Result: True
#
#
# Test: 945
# Input shape: (4, 2, 2, 4)
# Result: True
#
#
# Test: 946
# Input shape: (4,)
# Result: True
#
#
# Test: 947
# Input shape: (4, 3, 1, 1, 5)
# Result: True
#
#
# Test: 948
# Input shape: (5, 1, 1, 5, 1)
# Result: True
#
#
# Test: 949
# Input shape: (2, 2, 3, 2, 4)
# Result: True
#
#
# Test: 950
# Input shape: (4, 5, 5, 3)
# Result: True
#
#
# Test: 951
# Input shape: (2, 2, 3, 4, 5)
# Result: True
#
#
# Test: 952
# Input shape: (2, 5, 4, 1, 1, 1)
# Result: True
#
#
# Test: 953
# Input shape: (3,)
# Result: True
#
#
# Test: 954
# Input shape: (1, 2, 3)
# Result: True
#
#
# Test: 955
# Input shape: (5, 2)
# Result: True
#
#
# Test: 956
# Input shape: (3, 4, 2, 5, 2, 1)
# Result: True
#
#
# Test: 957
# Input shape: (2, 1, 3, 1, 4, 3)
# Result: True
#
#
# Test: 958
# Input shape: (2,)
# Result: True
#
#
# Test: 959
# Input shape: (2, 4, 5)
# Result: True
#
#
# Test: 960
# Input shape: (5, 4)
# Result: True
#
#
# Test: 961
# Input shape: (4, 5, 3)
# Result: True
#
#
# Test: 962
# Input shape: (3, 4)
# Result: True
#
#
# Test: 963
# Input shape: (3, 5, 3, 2, 1, 3)
# Result: True
#
#
# Test: 964
# Input shape: (5, 5)
# Result: True
#
#
# Test: 965
# Input shape: (3,)
# Result: True
#
#
# Test: 966
# Input shape: (3, 4, 4, 1, 3, 5)
# Result: True
#
#
# Test: 967
# Input shape: (4, 2, 1, 1, 2, 3)
# Result: True
#
#
# Test: 968
# Input shape: (4, 4)
# Result: True
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 4575.84it/s]
# Test: 969
# Input shape: (4, 4, 3, 5, 5)
# Result: True
#
#
# Test: 970
# Input shape: (5, 3, 3, 1, 5, 1)
# Result: True
#
#
# Test: 971
# Input shape: (5,)
# Result: True
#
#
# Test: 972
# Input shape: (5, 2, 5, 5, 3, 4)
# Result: True
#
#
# Test: 973
# Input shape: (2, 1, 2)
# Result: True
#
#
# Test: 974
# Input shape: (1,)
# Result: True
#
#
# Test: 975
# Input shape: (3, 5, 3, 3)
# Result: True
#
#
# Test: 976
# Input shape: (3, 5, 4)
# Result: True
#
#
# Test: 977
# Input shape: (3, 2, 5, 3, 5, 4)
# Result: True
#
#
# Test: 978
# Input shape: (1, 2, 1, 3, 4)
# Result: True
#
#
# Test: 979
# Input shape: (1, 3, 2, 5)
# Result: True
#
#
# Test: 980
# Input shape: (5, 2, 1)
# Result: True
#
#
# Test: 981
# Input shape: (1,)
# Result: True
#
#
# Test: 982
# Input shape: (5,)
# Result: True
#
#
# Test: 983
# Input shape: (1,)
# Result: True
#
#
# Test: 984
# Input shape: (2, 3, 3)
# Result: True
#
#
# Test: 985
# Input shape: (3, 5, 5, 3, 2, 4)
# Result: True
#
#
# Test: 986
# Input shape: (1,)
# Result: True
#
#
# Test: 987
# Input shape: (3, 5, 5, 5)
# Result: True
#
#
# Test: 988
# Input shape: (2,)
# Result: True
#
#
# Test: 989
# Input shape: (4, 4, 3, 5)
# Result: True
#
#
# Test: 990
# Input shape: (3, 2)
# Result: True
#
#
# Test: 991
# Input shape: (1, 5, 3, 5)
# Result: True
#
#
# Test: 992
# Input shape: (5, 5, 2)
# Result: True
#
#
# Test: 993
# Input shape: (3, 2, 4, 1)
# Result: True
#
#
# Test: 994
# Input shape: (1, 5)
# Result: True
#
#
# Test: 995
# Input shape: (5, 2, 2, 4, 2)
# Result: True
#
#
# Test: 996
# Input shape: (4, 1, 3, 5, 4, 1)
# Result: True
#
#
# Test: 997
# Input shape: (2, 4, 4, 4, 3, 5)
# Result: True
#
#
# Test: 998
# Input shape: (2, 3, 1)
# Result: True
#
#
# Test: 999
# Input shape: (2,)
# Result: True
#
#
# 1000 out of 1000 (100.0%) tests passed
