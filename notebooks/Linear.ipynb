# %% [markdown]
# ### `Linear` code

# %%
import numpy as np
import torch # needed for tests
from tqdm import tqdm # needed for tests

# %%
class Linear:
    ''' Applies a linear transformation given the input '''
    
    ''' * The class implementation will be along the lines of torch.nn.Linear in order to 
          enable comparison of this NumPy only implementation and seamless testing
        * Can expect extensive refactoring of the existing code in the days to come
        * As part of refactoring, some code will be de-modularized
        * Old code will be retained at the end of the notebook for reference
    '''
    '''
        TODO:
        * Replace `torch.round()` with `np.allclose()` for tests
        * Optimizing code
    '''
    
    def __init__(
        self,
        in_features,
        out_features,
        bias = True,
        device = None,
        dtype = None,
        verbose = False
        ):
        super(Linear, self).__init__()
        
        ''' mandatory parameters '''
        self.in_features = in_features
        self.out_features = out_features
        
        ''' optional parameters '''
        # None
        
        ''' optional parameters (dummy, yet to be implemented)'''
        self.bias = bias
        self.device = device
        self.dtype = dtype
        
        ''' additional parameters (different from torch.nn.Conv2D)'''
        self.verbose = verbose
        self.verboseprint = print if self.verbose else lambda *a, **k: None
        self.verboseprint('*** parameters ***')
        self.verboseprint('in_features: {}, out_features: {}, bias: {}'.format(self.in_features, self.out_features, self.bias))
        self.verboseprint('device: {}, dtype: {}'.format(self.device, self.dtype))
        self.verboseprint('\n')
    
    def forward(self, _input, weights = None, bias_weights = None):
        ''' forward pass to perform a linear transformation '''
        
        ''' error checking '''
        if not (isinstance(_input, int) or isinstance(_input, float) or isinstance(_input, np.ndarray)):
            raise Exception('invalid input: input should either be an int, a float, or a NumPy ndarray')
        
        ''' use the provided weights or create random weights based on the input parameters '''
        if weights is not None:
            self.verboseprint('*** weights ***')
            self.verboseprint('weights shape: {}'.format(weights.shape))
        else:
            weights = np.random.rand(self.out_features, self.in_features)
        self.verboseprint(weights)
        self.verboseprint('\n')                      
                              
        if self.bias:
            if bias_weights is not None:
                self.verboseprint('*** bias ***')
                self.verboseprint('bias shape: {}'.format(bias_weights.shape))
            else:
                bias_weights = np.random.rand(self.out_features)
                self.verboseprint('*** bias ***')
                self.verboseprint('bias shape: {}'.format(bias_weights.shape))
        else:
            bias_weights = np.zeroes(self.out_features)
        self.verboseprint(bias_weights)
        self.verboseprint('\n')
                              
        ''' apply linear transformation '''
        output = _input @ weights.T + bias_weights
        self.verboseprint(output)
        self.verboseprint('\n')
        return output

# %% [markdown]
# ### Standalone test (random input, weights, and bias)

# %%
in_samples = 128 # input samples
in_features = 20 # input features
out_features = 30 # output features
_input = np.random.rand(in_samples, in_features) # define a random input
_weights = np.random.rand(out_features, in_features) # define random weights
_bias = np.random.rand(out_features) # define random bias

# %%
# get Linear output with the random input

linear = Linear(in_features, out_features, verbose = True) # call an instance of the class with the input parameters
_output = linear.forward(_input, weights = _weights, bias_weights = _bias) # apply linear transformation
# _output = linear.forward(_input) # apply linear transformation
print("*** Linear output ***")
print(_output)
# Out:
# *** parameters ***
# in_features: 20, out_features: 30, bias: True
# device: None, dtype: None
#
#
# *** weights ***
# weights shape: (30, 20)
# [[9.83022151e-01 3.92545891e-01 4.17296137e-01 5.51176419e-02
#   1.50880478e-01 5.86725645e-01 8.30162111e-02 6.17526908e-02
#   6.62458348e-01 9.45134295e-02 1.78971277e-01 9.20063607e-01
#   9.15804574e-01 1.34192428e-02 3.78561532e-01 7.93727616e-01
#   7.65419183e-01 4.23665830e-01 8.23077116e-01 7.64988014e-01]
#  [3.78179003e-01 4.25781294e-01 4.13330975e-01 6.94117151e-01
#   4.74332548e-01 2.69599871e-01 3.45855274e-01 9.32160703e-01
#   9.28462513e-01 9.80391084e-02 2.43699174e-01 5.72328826e-01
#   4.49787722e-01 1.50855086e-01 7.46840601e-01 5.93001793e-01
#   8.33641289e-01 3.28482860e-01 8.69031175e-01 8.79293872e-01]
#  [9.34603743e-01 7.81517049e-01 1.61816904e-01 9.44794821e-01
#   2.27109998e-01 9.79636672e-01 7.21804516e-01 4.74233681e-01
#   1.43161133e-01 2.32153747e-01 8.51276182e-01 8.26214651e-01
#   5.98030885e-02 5.42760547e-01 5.66694263e-01 3.15704524e-01
#   4.05818606e-01 5.84806122e-01 5.20278731e-01 4.50890221e-01]
#  [1.64444693e-01 2.97754351e-01 2.94080640e-01 8.21862381e-01
#   6.29528901e-03 1.14959884e-01 6.24160716e-01 3.12786472e-01
#   3.03684085e-01 2.60779438e-01 3.89106333e-02 6.22126514e-01
#   8.74105254e-01 1.71383700e-01 3.78801757e-01 5.98911702e-01
#   5.70010403e-01 9.22591085e-01 9.76691931e-01 6.43956190e-01]
#  [8.80292895e-01 8.02050655e-01 7.74390025e-01 3.09990357e-01
#   1.31400569e-01 7.90755681e-01 5.60798552e-01 6.22380656e-01
#   5.74860199e-01 6.22364921e-01 6.48490200e-01 6.69494387e-01
#   8.83359411e-01 9.73403342e-01 2.66926570e-01 1.28946198e-01
#   8.04635376e-01 5.39324263e-01 4.23974495e-01 3.49524307e-01]
#  [1.71424895e-01 9.96193034e-01 2.92585294e-01 8.48421470e-01
#   9.30080379e-01 2.03821052e-01 9.05129404e-01 5.98761101e-01
#   9.47611947e-01 8.78210745e-01 3.71227150e-01 1.28381167e-01
#   1.69761013e-01 3.13220415e-02 7.12014457e-01 4.35482534e-01
#   4.52275366e-01 9.16029094e-01 1.55823187e-02 5.26062850e-01]
#  [9.59151208e-01 1.73258477e-01 2.87195797e-01 4.78411973e-01
#   6.67417172e-01 6.94531666e-01 7.88223825e-01 7.19654253e-01
#   3.00074562e-01 1.31774638e-01 7.95949479e-01 5.53832454e-01
#   9.67378806e-02 3.29922689e-01 8.67933265e-01 6.88845083e-01
#   8.62182718e-01 1.27302312e-01 7.64323487e-02 7.04120629e-01]
#  [8.26377043e-01 2.09940193e-02 6.71812665e-01 2.76078410e-01
#   4.44872757e-01 6.56534056e-01 7.01858771e-01 3.96326114e-01
#   1.65689578e-01 8.44793797e-01 6.09076509e-01 2.85559016e-01
#   7.43763806e-01 1.38788651e-02 9.44808271e-01 7.12933719e-01
#   3.65669689e-01 1.71214055e-01 1.99623870e-01 5.24914453e-01]
#  [3.99900150e-01 7.18290414e-01 5.98973341e-01 7.07857018e-01
#   8.25210228e-01 8.17329315e-01 4.97698682e-01 1.96835272e-01
#   7.30340046e-01 2.04474719e-01 3.01441424e-01 2.22297677e-01
#   2.58241514e-01 4.81949817e-01 9.02353285e-01 4.90689125e-01
#   4.50221224e-01 5.85055145e-01 7.28261995e-01 2.68044390e-01]
#  [2.34871360e-01 4.26468853e-01 2.52204110e-01 3.39881880e-01
#   7.40859848e-01 1.18029291e-02 8.71309275e-01 2.80716276e-02
#   6.00950600e-02 5.00758728e-01 2.22409185e-01 5.63435302e-01
#   7.09503264e-01 6.98385211e-02 2.25928749e-01 4.89760958e-02
#   4.46885570e-01 9.79215780e-01 1.21626555e-01 4.19467646e-01]
#  [7.09670564e-01 8.45449479e-01 8.89368317e-01 6.48178049e-01
#   8.64204308e-01 2.06840418e-01 4.57087484e-01 1.66222060e-01
#   8.99904633e-01 2.21092017e-01 7.86015506e-01 2.07760534e-01
#   8.67039941e-01 5.46018583e-01 4.07263959e-01 8.50859238e-01
#   6.53042349e-01 7.75550684e-01 3.93639680e-01 5.88929109e-01]
#  [7.01354256e-03 1.63628829e-01 1.25740926e-01 1.01886364e-01
#   9.58842743e-01 7.01126620e-01 4.71907473e-01 2.33073744e-01
#   6.62603225e-01 3.81210564e-01 1.32341942e-01 4.25999136e-01
#   6.58892604e-01 2.66462832e-01 1.31251217e-01 8.15579973e-01
#   6.85085480e-01 6.81509546e-01 2.34549670e-01 4.07223546e-01]
#  [4.49656547e-01 5.81664050e-01 4.29720992e-01 1.36970510e-01
#   5.65515864e-01 8.17637530e-02 1.46942226e-01 9.90210626e-01
#   8.41162398e-01 8.70363269e-01 2.39523953e-01 1.89933030e-01
#   1.00838821e-01 2.80053259e-01 1.88463060e-01 7.60363725e-01
#   2.04093282e-01 7.72316369e-01 4.91564384e-02 9.74799474e-01]
#  [2.19355086e-01 6.27838284e-01 3.65127838e-01 3.20660902e-01
#   5.06097924e-01 3.56863640e-01 7.14769868e-01 8.48442674e-01
#   3.22765386e-01 9.50653381e-01 6.00657849e-01 3.36836293e-01
#   4.64066708e-02 1.43012009e-02 7.92854782e-01 9.12325239e-01
#   8.20042609e-01 2.61970503e-01 1.66095911e-01 4.08037118e-01]
#  [4.26856770e-01 2.74073846e-01 9.19170690e-01 7.05502511e-01
#   2.45096232e-01 2.69634917e-01 4.41743956e-01 8.70205881e-01
#   2.99486389e-01 9.77989894e-01 3.42769610e-01 9.81349238e-01
#   4.09375636e-01 2.44043530e-01 2.29411080e-01 3.43180933e-01
#   5.64188540e-01 1.32814537e-01 3.12499971e-01 5.57292539e-01]
#  [2.16401823e-01 5.40650263e-01 1.65006616e-02 9.68792339e-01
#   9.58725652e-01 7.44567907e-01 6.74670165e-01 8.22359156e-01
#   4.07199762e-01 6.43215953e-01 1.99885608e-01 7.05949751e-01
#   5.74270154e-01 7.59459044e-01 2.41075514e-01 5.83014864e-01
#   9.81634118e-01 4.64119468e-01 9.43530875e-01 6.75600562e-01]
#  [8.68783971e-01 7.63571028e-01 6.04633029e-01 7.39493116e-01
#   1.59236771e-01 2.04188406e-01 2.30175536e-01 4.50060022e-01
#   2.26184233e-01 9.51633821e-01 6.25781755e-01 4.70710991e-01
#   7.73142005e-01 6.86016772e-01 7.90405078e-01 9.97869476e-01
#   3.72961745e-01 3.02332802e-02 5.48712242e-01 8.07299743e-01]
#  [8.34501051e-01 9.92648816e-02 4.67709980e-01 4.71483074e-01
#   1.07876337e-01 3.78117815e-01 5.79811238e-01 2.94265928e-01
#   2.99128669e-01 6.94262719e-01 6.08069464e-01 2.45518353e-01
#   5.61141910e-01 9.85980548e-01 9.58878339e-01 6.66243241e-01
#   3.46884679e-01 4.59223962e-01 8.32094501e-01 7.03825879e-02]
#  [5.89735556e-01 8.67885871e-01 2.44920528e-01 9.74450621e-01
#   2.67031485e-01 3.72176498e-01 5.52362164e-01 8.79666337e-01
#   6.94222829e-01 6.61830845e-01 7.08744754e-01 4.39463256e-01
#   9.55241039e-01 1.03757403e-02 7.78709334e-01 2.06049785e-01
#   5.72853137e-01 9.14195451e-01 4.46673653e-01 2.15657526e-01]
#  [4.32760997e-01 7.56873227e-01 5.36281187e-01 6.55476586e-01
#   7.88605228e-01 4.03672015e-01 7.99997202e-01 1.94814650e-01
#   2.37214977e-01 3.98306714e-01 7.15985384e-01 4.33017664e-01
#   9.37873470e-01 1.29194045e-01 3.64032275e-01 8.13124019e-01
#   3.47116961e-01 4.37412344e-02 7.81434311e-01 4.40849897e-01]
#  [6.50220649e-01 1.97313285e-01 3.78023008e-01 2.43128017e-01
#   6.82592110e-01 3.97883221e-01 3.29430045e-01 4.88244636e-01
#   7.77807146e-02 9.59582661e-01 6.32973467e-01 8.14660152e-01
#   4.08042432e-01 1.83547792e-01 8.12888800e-01 9.30882634e-01
#   9.94687881e-01 2.16741957e-01 1.63415890e-01 5.68213280e-01]
#  [6.36523129e-01 3.48635765e-01 5.30955717e-01 7.85251909e-01
#   7.74502960e-01 9.66607284e-01 3.86085118e-01 3.42849577e-01
#   8.65169411e-01 9.34134611e-02 3.41809950e-01 3.82483101e-01
#   6.63227987e-01 1.57991985e-01 4.37927837e-01 3.94758892e-01
#   7.29843129e-01 2.86197267e-02 9.47829461e-01 2.82569461e-01]
#  [3.78915871e-01 7.85786836e-01 7.04405297e-01 3.77901656e-01
#   6.46139465e-01 1.43126383e-03 4.05668035e-01 4.24232390e-01
#   6.23421988e-01 5.85549126e-01 5.12567565e-02 5.16949962e-01
#   5.00827595e-01 7.37629355e-01 9.07080665e-02 6.70709369e-01
#   4.13081117e-01 9.05872162e-01 4.09656817e-01 1.87627558e-01]
#  [4.70243327e-01 7.30131371e-02 6.62693377e-01 1.44415779e-01
#   3.73397218e-01 9.03654324e-01 3.77632945e-01 1.85402549e-01
#   5.54766892e-01 1.29606015e-02 9.02399911e-01 6.23500468e-01
#   4.28215605e-01 2.67294487e-01 2.58417034e-01 5.11331599e-01
#   8.84479402e-01 3.06246056e-01 8.08119279e-01 6.87972759e-02]
#  [7.47390019e-01 3.77348435e-01 8.77769678e-01 7.47793550e-01
#   3.73373101e-01 1.85779426e-01 4.70899080e-01 4.31216276e-01
#   2.87846160e-01 8.14018726e-01 8.76127131e-01 3.20209950e-01
#   6.89958760e-01 9.17657615e-01 7.25689880e-01 8.68585081e-01
#   8.85805577e-01 6.94021563e-01 6.11126853e-01 5.40879771e-01]
#  [2.45077045e-01 5.45665011e-01 7.09224254e-01 5.83793373e-02
#   3.43516645e-01 9.66008627e-04 3.35934042e-02 1.08830392e-01
#   2.66125876e-01 3.98604238e-01 2.62273726e-01 9.78099388e-01
#   4.41030074e-01 7.39483167e-01 8.94202820e-01 4.76534624e-01
#   4.91762740e-01 2.01955631e-01 1.58832958e-01 4.25800151e-01]
#  [4.43907660e-01 3.48108578e-01 5.46729393e-01 9.97915796e-01
#   8.29361553e-01 7.13319779e-02 8.75177169e-01 6.71584995e-02
#   9.87685408e-01 4.40961791e-01 4.71982287e-01 4.92132188e-01
#   7.30879049e-01 7.61236439e-01 8.62080139e-02 1.51581604e-01
#   3.42700787e-01 7.95260474e-01 1.90555423e-02 9.97343851e-01]
#  [3.66505060e-01 4.39940337e-01 4.70056568e-01 2.38354951e-01
#   9.99406883e-01 7.64381852e-01 2.38796316e-02 1.64761074e-02
#   5.72400332e-01 3.35114677e-01 9.48436954e-01 4.93592913e-01
#   2.49107901e-01 3.05597855e-01 7.82916554e-01 6.69903348e-01
#   9.98619897e-01 3.55448428e-02 3.64696450e-02 5.67732392e-01]
#  [4.58549992e-01 7.62075204e-01 9.94306913e-01 5.70608256e-01
#   6.82064898e-02 4.17261497e-01 6.69576706e-01 6.23052632e-01
#   5.69456737e-01 6.90461343e-01 9.64551691e-01 3.56887538e-01
#   1.00218691e-03 1.17497738e-01 8.16735570e-01 4.81038693e-01
#   8.30791193e-01 3.80990431e-01 5.43464428e-01 8.71373162e-01]
#  [2.17800822e-01 9.01207510e-01 9.48263978e-01 2.25549844e-01
#   9.68085827e-01 5.92810467e-01 4.34688402e-01 2.45134761e-02
#   1.08508966e-01 4.43263777e-01 7.49908959e-01 4.01920703e-01
#   5.76717618e-01 3.61354308e-01 7.20100476e-02 7.44344853e-01
#   5.28761403e-01 9.96747143e-01 3.24425727e-01 2.31215652e-01]]
#
#
# *** bias ***
# bias shape: (30,)
# [7.89078142e-01 5.05532590e-01 7.02596820e-04 6.61771838e-01
#  1.47880364e-01 4.06782827e-02 9.78830944e-02 2.01819578e-01
#  4.28235824e-01 9.79933216e-02 3.77624721e-01 3.69164002e-01
#  6.25208752e-01 3.35371030e-01 5.19576347e-01 7.41888105e-01
#  9.82032931e-01 2.56771112e-01 3.55151907e-01 9.48548382e-01
#  2.18377001e-01 8.50957274e-01 8.39995110e-01 4.89417520e-02
#  6.72008006e-01 5.04413189e-01 6.42965968e-01 9.70108125e-01
#  7.91451819e-01 7.51630115e-01]
#
#
# [[6.62273303 6.94039084 5.97067212 ... 6.53558398 7.50407444 5.92741309]
#  [4.78212323 5.38574957 4.16054798 ... 5.49496069 5.05056485 4.26849848]
#  [6.38174192 6.50533219 5.36814427 ... 6.744407   7.10499684 6.36834035]
#  ...
#  [5.60206108 6.00844423 6.11470346 ... 5.64174725 7.21858896 5.64353951]
#  [4.09617071 4.831654   4.73751493 ... 5.26788639 5.74166362 4.52690359]
#  [5.62767038 5.97237874 5.11542914 ... 5.9251499  6.42859693 6.15863589]]
#
#
# *** Linear output ***
# [[6.62273303 6.94039084 5.97067212 ... 6.53558398 7.50407444 5.92741309]
#  [4.78212323 5.38574957 4.16054798 ... 5.49496069 5.05056485 4.26849848]
#  [6.38174192 6.50533219 5.36814427 ... 6.744407   7.10499684 6.36834035]
#  ...
#  [5.60206108 6.00844423 6.11470346 ... 5.64174725 7.21858896 5.64353951]
#  [4.09617071 4.831654   4.73751493 ... 5.26788639 5.74166362 4.52690359]
#  [5.62767038 5.97237874 5.11542914 ... 5.9251499  6.42859693 6.15863589]]

# %%
# get PyTorch output with the same random inputs as above

x = torch.DoubleTensor(_input)
A = torch.DoubleTensor(_weights)
b = torch.DoubleTensor(_bias)
output = torch.nn.functional.linear(x, A, bias = b)
print("*** PyTorch output ***")
print(output)
# Out:
# *** PyTorch output ***
# tensor([[5.9197, 6.0041, 5.1066,  ..., 7.0375, 7.0805, 7.3120],
#         [3.6620, 5.2423, 3.8472,  ..., 4.7562, 5.2316, 4.8721],
#         [4.2813, 5.0258, 4.3232,  ..., 5.0951, 4.9565, 5.9333],
#         ...,
#         [4.8382, 5.4972, 4.4712,  ..., 5.7450, 4.3685, 6.0752],
#         [5.0863, 4.9158, 3.6148,  ..., 5.6218, 5.3140, 5.4417],
#         [4.9206, 5.2285, 4.6776,  ..., 6.1977, 5.6517, 6.8108]],
#        dtype=torch.float64)

# %%
# compare outputs of Conv2D and PyTorch
print(torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output))) # need to round the output due to precision difference
# Out:
# True

# %% [markdown]
# ### Extensive tests (random input, weights, and bias)

# %%
def valid_params(num_tests):
    ''' generates `num_tests` number of valid input and kernel parameters '''
    
    params_list = []
    sample_count = 0
    while sample_count < num_tests:
        in_samples = np.random.randint(200)
        in_features = np.random.randint(100) + 1
        out_features = np.random.randint(100) + 1
        params_list.append({'in_samples': in_samples, 'in_features': in_features, 'out_features': out_features})
        sample_count += 1
    return params_list

# %%
def run_tests(num_tests):
    ''' sweep different input parameters and test by comparing outputs of ReLU and PyTorch '''
    
    num_passed = 0
    params_list = valid_params(num_tests)
    print('Number of tests: {}\n\n'.format(len(params_list)))

    for i, params in enumerate(tqdm(params_list)):
        print('Test: {}\nParams: {}'.format(i, params))
        in_samples = params['in_samples'] # input samples
        in_features = params['in_features'] # input features
        out_features = params['out_features'] # output features
        
        _input = np.random.rand(in_samples, in_features) # define a random input
        _weights = np.random.rand(out_features, in_features) # define random weights
        _bias = np.random.rand(out_features) # define random bias
        
        try:
            # get Linear output with the random input
            linear = Linear(in_features, out_features) # call an instance of the class with the input parameters
            _output = linear.forward(_input, weights = _weights, bias_weights = _bias) # apply linear transformation

            # get PyTorch output with the same random inputs as above
            x = torch.DoubleTensor(_input)
            A = torch.DoubleTensor(_weights)
            b = torch.DoubleTensor(_bias)
            output = torch.nn.functional.linear(x, A, bias = b)
            
        except Exception as e:
            print(e)
            print('Result: False\n\n') # treating exception as a failed test
            continue

        # compare outputs of Linear and PyTorch
        result = torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output)) # need to round the output due to precision difference
        print('Result: {}\n\n'.format(result))
        if result:
            num_passed += 1

    print('{} out of {} ({}%) tests passed'.format(num_passed, num_tests, float(100 * num_passed / num_tests)))

# %%
num_tests = 1000
run_tests(num_tests)
# Out:
# Number of tests: 1000
#   1%|▎                                         | 7/1000 [00:00<00:16, 58.77it/s]
# Test: 0
# Params: {'in_samples': 71, 'in_features': 40, 'out_features': 4}
# Result: True
#
#
# Test: 1
# Params: {'in_samples': 0, 'in_features': 64, 'out_features': 69}
# Result: True
#
#
# Test: 2
# Params: {'in_samples': 83, 'in_features': 43, 'out_features': 79}
# Result: True
#
#
# Test: 3
# Params: {'in_samples': 151, 'in_features': 67, 'out_features': 78}
# Result: True
#
#
# Test: 4
# Params: {'in_samples': 57, 'in_features': 53, 'out_features': 19}
# Result: True
#
#
# Test: 5
# Params: {'in_samples': 151, 'in_features': 82, 'out_features': 67}
# Result: True
#
#
# Test: 6
# Params: {'in_samples': 132, 'in_features': 86, 'out_features': 94}
# Result: True
#
#
# Test: 7
# Params: {'in_samples': 112, 'in_features': 4, 'out_features': 59}
# Result: True
#
#
# Test: 8
# Params: {'in_samples': 46, 'in_features': 100, 'out_features': 97}
# Result: True
#
#
# Test: 9
# Params: {'in_samples': 57, 'in_features': 77, 'out_features': 11}
# Result: True
#
#
# Test: 10
# Params: {'in_samples': 178, 'in_features': 42, 'out_features': 64}
# Result: True
#
#
# Test: 11
# Params: {'in_samples': 104, 'in_features': 82, 'out_features': 55}
# Result: True
#
#
# Test: 12
# Params: {'in_samples': 51, 'in_features': 25, 'out_features': 63}
# Result: True
#
#
# Test: 13
# Params: {'in_samples': 76, 'in_features': 64, 'out_features': 84}
#   2%|▉                                        | 24/1000 [00:00<00:13, 70.00it/s]
# Result: True
#
#
# Test: 14
# Params: {'in_samples': 1, 'in_features': 56, 'out_features': 11}
# Result: True
#
#
# Test: 15
# Params: {'in_samples': 141, 'in_features': 27, 'out_features': 93}
# Result: True
#
#
# Test: 16
# Params: {'in_samples': 43, 'in_features': 87, 'out_features': 76}
# Result: True
#
#
# Test: 17
# Params: {'in_samples': 144, 'in_features': 92, 'out_features': 67}
# Result: True
#
#
# Test: 18
# Params: {'in_samples': 127, 'in_features': 99, 'out_features': 11}
# Result: True
#
#
# Test: 19
# Params: {'in_samples': 9, 'in_features': 86, 'out_features': 47}
# Result: True
#
#
# Test: 20
# Params: {'in_samples': 12, 'in_features': 64, 'out_features': 58}
# Result: True
#
#
# Test: 21
# Params: {'in_samples': 142, 'in_features': 61, 'out_features': 41}
# Result: True
#
#
# Test: 22
# Params: {'in_samples': 153, 'in_features': 19, 'out_features': 60}
# Result: True
#
#
# Test: 23
# Params: {'in_samples': 95, 'in_features': 74, 'out_features': 1}
# Result: True
#
#
# Test: 24
# Params: {'in_samples': 166, 'in_features': 94, 'out_features': 88}
# Result: True
#
#
# Test: 25
# Params: {'in_samples': 174, 'in_features': 31, 'out_features': 17}
# Result: True
#
#
# Test: 26
# Params: {'in_samples': 37, 'in_features': 63, 'out_features': 76}
# Result: True
#
#
# Test: 27
# Params: {'in_samples': 100, 'in_features': 26, 'out_features': 13}
# Result: True
#
#
# Test: 28
# Params: {'in_samples': 52, 'in_features': 84, 'out_features': 83}
# Result: True
#
#
# Test: 29
# Params: {'in_samples': 87, 'in_features': 58, 'out_features': 17}
# Result: True
#
#
# Test: 30
# Params: {'in_samples': 63, 'in_features': 8, 'out_features': 67}
# Result: True
#
#
# Test: 31
# Params: {'in_samples': 3, 'in_features': 34, 'out_features': 78}
# Result: True
#
#
# Test: 32
# Params: {'in_samples': 62, 'in_features': 67, 'out_features': 53}
# Result: True
#
#
# Test: 33
# Params: {'in_samples': 93, 'in_features': 52, 'out_features': 39}
# Result: True
#
#
# Test: 34
# Params: {'in_samples': 64, 'in_features': 1, 'out_features': 7}
# Result: True
#
#
# Test: 35
# Params: {'in_samples': 164, 'in_features': 24, 'out_features': 81}
#   7%|██▉                                     | 74/1000 [00:00<00:05, 167.58it/s]
# Result: True
#
#
# Test: 36
# Params: {'in_samples': 55, 'in_features': 18, 'out_features': 55}
# Result: True
#
#
# Test: 37
# Params: {'in_samples': 23, 'in_features': 60, 'out_features': 6}
# Result: True
#
#
# Test: 38
# Params: {'in_samples': 45, 'in_features': 1, 'out_features': 20}
# Result: True
#
#
# Test: 39
# Params: {'in_samples': 194, 'in_features': 42, 'out_features': 79}
# Result: True
#
#
# Test: 40
# Params: {'in_samples': 185, 'in_features': 27, 'out_features': 41}
# Result: True
#
#
# Test: 41
# Params: {'in_samples': 67, 'in_features': 28, 'out_features': 15}
# Result: True
#
#
# Test: 42
# Params: {'in_samples': 181, 'in_features': 19, 'out_features': 50}
# Result: True
#
#
# Test: 43
# Params: {'in_samples': 13, 'in_features': 76, 'out_features': 91}
# Result: True
#
#
# Test: 44
# Params: {'in_samples': 20, 'in_features': 13, 'out_features': 21}
# Result: True
#
#
# Test: 45
# Params: {'in_samples': 75, 'in_features': 79, 'out_features': 4}
# Result: True
#
#
# Test: 46
# Params: {'in_samples': 67, 'in_features': 37, 'out_features': 61}
# Result: True
#
#
# Test: 47
# Params: {'in_samples': 152, 'in_features': 7, 'out_features': 68}
# Result: True
#
#
# Test: 48
# Params: {'in_samples': 131, 'in_features': 42, 'out_features': 16}
# Result: True
#
#
# Test: 49
# Params: {'in_samples': 75, 'in_features': 85, 'out_features': 30}
# Result: True
#
#
# Test: 50
# Params: {'in_samples': 21, 'in_features': 8, 'out_features': 39}
# Result: True
#
#
# Test: 51
# Params: {'in_samples': 94, 'in_features': 61, 'out_features': 21}
# Result: True
#
#
# Test: 52
# Params: {'in_samples': 24, 'in_features': 69, 'out_features': 90}
# Result: True
#
#
# Test: 53
# Params: {'in_samples': 106, 'in_features': 63, 'out_features': 23}
# Result: True
#
#
# Test: 54
# Params: {'in_samples': 76, 'in_features': 84, 'out_features': 58}
# Result: True
#
#
# Test: 55
# Params: {'in_samples': 166, 'in_features': 89, 'out_features': 25}
# Result: True
#
#
# Test: 56
# Params: {'in_samples': 9, 'in_features': 99, 'out_features': 80}
# Result: True
#
#
# Test: 57
# Params: {'in_samples': 161, 'in_features': 30, 'out_features': 93}
# Result: True
#
#
# Test: 58
# Params: {'in_samples': 170, 'in_features': 44, 'out_features': 1}
# Result: True
#
#
# Test: 59
# Params: {'in_samples': 55, 'in_features': 59, 'out_features': 95}
# Result: True
#
#
# Test: 60
# Params: {'in_samples': 15, 'in_features': 37, 'out_features': 57}
# Result: True
#
#
# Test: 61
# Params: {'in_samples': 83, 'in_features': 18, 'out_features': 15}
# Result: True
#
#
# Test: 62
# Params: {'in_samples': 194, 'in_features': 20, 'out_features': 38}
# Result: True
#
#
# Test: 63
# Params: {'in_samples': 65, 'in_features': 65, 'out_features': 27}
# Result: True
#
#
# Test: 64
# Params: {'in_samples': 112, 'in_features': 1, 'out_features': 22}
# Result: True
#
#
# Test: 65
# Params: {'in_samples': 153, 'in_features': 20, 'out_features': 64}
# Result: True
#
#
# Test: 66
# Params: {'in_samples': 131, 'in_features': 77, 'out_features': 52}
# Result: True
#
#
# Test: 67
# Params: {'in_samples': 61, 'in_features': 21, 'out_features': 31}
# Result: True
#
#
# Test: 68
# Params: {'in_samples': 80, 'in_features': 29, 'out_features': 44}
# Result: True
#
#
# Test: 69
# Params: {'in_samples': 26, 'in_features': 8, 'out_features': 79}
# Result: True
#
#
# Test: 70
# Params: {'in_samples': 15, 'in_features': 35, 'out_features': 74}
# Result: True
#
#
# Test: 71
# Params: {'in_samples': 62, 'in_features': 42, 'out_features': 64}
# Result: True
#
#
# Test: 72
# Params: {'in_samples': 65, 'in_features': 50, 'out_features': 54}
# Result: True
#
#
# Test: 73
# Params: {'in_samples': 137, 'in_features': 93, 'out_features': 78}
# Result: True
#
#
# Test: 74
# Params: {'in_samples': 50, 'in_features': 97, 'out_features': 23}
# Result: True
#
#
# Test: 75
# Params: {'in_samples': 177, 'in_features': 29, 'out_features': 58}
#  17%|██████▋                                | 170/1000 [00:00<00:02, 316.99it/s]
# Result: True
#
#
# Test: 76
# Params: {'in_samples': 188, 'in_features': 50, 'out_features': 39}
# Result: True
#
#
# Test: 77
# Params: {'in_samples': 118, 'in_features': 55, 'out_features': 52}
# Result: True
#
#
# Test: 78
# Params: {'in_samples': 121, 'in_features': 37, 'out_features': 88}
# Result: True
#
#
# Test: 79
# Params: {'in_samples': 113, 'in_features': 28, 'out_features': 29}
# Result: True
#
#
# Test: 80
# Params: {'in_samples': 174, 'in_features': 17, 'out_features': 11}
# Result: True
#
#
# Test: 81
# Params: {'in_samples': 163, 'in_features': 1, 'out_features': 55}
# Result: True
#
#
# Test: 82
# Params: {'in_samples': 172, 'in_features': 46, 'out_features': 11}
# Result: True
#
#
# Test: 83
# Params: {'in_samples': 120, 'in_features': 78, 'out_features': 80}
# Result: True
#
#
# Test: 84
# Params: {'in_samples': 197, 'in_features': 87, 'out_features': 7}
# Result: True
#
#
# Test: 85
# Params: {'in_samples': 34, 'in_features': 88, 'out_features': 5}
# Result: True
#
#
# Test: 86
# Params: {'in_samples': 152, 'in_features': 64, 'out_features': 26}
# Result: True
#
#
# Test: 87
# Params: {'in_samples': 42, 'in_features': 66, 'out_features': 24}
# Result: True
#
#
# Test: 88
# Params: {'in_samples': 183, 'in_features': 77, 'out_features': 31}
# Result: True
#
#
# Test: 89
# Params: {'in_samples': 24, 'in_features': 45, 'out_features': 71}
# Result: True
#
#
# Test: 90
# Params: {'in_samples': 63, 'in_features': 62, 'out_features': 94}
# Result: True
#
#
# Test: 91
# Params: {'in_samples': 184, 'in_features': 46, 'out_features': 55}
# Result: True
#
#
# Test: 92
# Params: {'in_samples': 54, 'in_features': 40, 'out_features': 81}
# Result: True
#
#
# Test: 93
# Params: {'in_samples': 1, 'in_features': 64, 'out_features': 1}
# Result: True
#
#
# Test: 94
# Params: {'in_samples': 113, 'in_features': 9, 'out_features': 46}
# Result: True
#
#
# Test: 95
# Params: {'in_samples': 3, 'in_features': 54, 'out_features': 97}
# Result: True
#
#
# Test: 96
# Params: {'in_samples': 145, 'in_features': 34, 'out_features': 12}
# Result: True
#
#
# Test: 97
# Params: {'in_samples': 181, 'in_features': 70, 'out_features': 65}
# Result: True
#
#
# Test: 98
# Params: {'in_samples': 30, 'in_features': 80, 'out_features': 69}
# Result: True
#
#
# Test: 99
# Params: {'in_samples': 130, 'in_features': 37, 'out_features': 99}
# Result: True
#
#
# Test: 100
# Params: {'in_samples': 23, 'in_features': 5, 'out_features': 13}
# Result: True
#
#
# Test: 101
# Params: {'in_samples': 54, 'in_features': 58, 'out_features': 57}
# Result: True
#
#
# Test: 102
# Params: {'in_samples': 48, 'in_features': 88, 'out_features': 48}
# Result: True
#
#
# Test: 103
# Params: {'in_samples': 17, 'in_features': 82, 'out_features': 18}
# Result: True
#
#
# Test: 104
# Params: {'in_samples': 40, 'in_features': 24, 'out_features': 39}
# Result: True
#
#
# Test: 105
# Params: {'in_samples': 28, 'in_features': 84, 'out_features': 99}
# Result: True
#
#
# Test: 106
# Params: {'in_samples': 161, 'in_features': 94, 'out_features': 77}
# Result: True
#
#
# Test: 107
# Params: {'in_samples': 167, 'in_features': 69, 'out_features': 11}
# Result: True
#
#
# Test: 108
# Params: {'in_samples': 40, 'in_features': 86, 'out_features': 90}
# Result: True
#
#
# Test: 109
# Params: {'in_samples': 37, 'in_features': 22, 'out_features': 80}
# Result: True
#
#
# Test: 110
# Params: {'in_samples': 33, 'in_features': 81, 'out_features': 89}
# Result: True
#
#
# Test: 111
# Params: {'in_samples': 37, 'in_features': 39, 'out_features': 53}
# Result: True
#
#
# Test: 112
# Params: {'in_samples': 66, 'in_features': 26, 'out_features': 88}
# Result: True
#
#
# Test: 113
# Params: {'in_samples': 133, 'in_features': 78, 'out_features': 52}
# Result: True
#
#
# Test: 114
# Params: {'in_samples': 30, 'in_features': 37, 'out_features': 40}
# Result: True
#
#
# Test: 115
# Params: {'in_samples': 161, 'in_features': 25, 'out_features': 51}
# Result: True
#
#
# Test: 116
# Params: {'in_samples': 145, 'in_features': 23, 'out_features': 67}
# Result: True
#
#
# Test: 117
# Params: {'in_samples': 171, 'in_features': 43, 'out_features': 14}
# Result: True
#
#
# Test: 118
# Params: {'in_samples': 128, 'in_features': 24, 'out_features': 33}
# Result: True
#
#
# Test: 119
# Params: {'in_samples': 175, 'in_features': 47, 'out_features': 24}
# Result: True
#
#
# Test: 120
# Params: {'in_samples': 11, 'in_features': 68, 'out_features': 88}
# Result: True
#
#
# Test: 121
# Params: {'in_samples': 119, 'in_features': 25, 'out_features': 74}
# Result: True
#
#
# Test: 122
# Params: {'in_samples': 111, 'in_features': 9, 'out_features': 14}
# Result: True
#
#
# Test: 123
# Params: {'in_samples': 185, 'in_features': 96, 'out_features': 31}
# Result: True
#
#
# Test: 124
# Params: {'in_samples': 59, 'in_features': 23, 'out_features': 48}
# Result: True
#
#
# Test: 125
# Params: {'in_samples': 133, 'in_features': 12, 'out_features': 78}
# Result: True
#
#
# Test: 126
# Params: {'in_samples': 53, 'in_features': 37, 'out_features': 7}
# Result: True
#
#
# Test: 127
# Params: {'in_samples': 71, 'in_features': 41, 'out_features': 29}
# Result: True
#
#
# Test: 128
# Params: {'in_samples': 11, 'in_features': 89, 'out_features': 31}
# Result: True
#
#
# Test: 129
# Params: {'in_samples': 179, 'in_features': 69, 'out_features': 8}
# Result: True
#
#
# Test: 130
# Params: {'in_samples': 177, 'in_features': 68, 'out_features': 28}
# Result: True
#
#
# Test: 131
# Params: {'in_samples': 180, 'in_features': 33, 'out_features': 8}
# Result: True
#
#
# Test: 132
# Params: {'in_samples': 84, 'in_features': 47, 'out_features': 84}
# Result: True
#
#
# Test: 133
# Params: {'in_samples': 40, 'in_features': 83, 'out_features': 4}
# Result: True
#
#
# Test: 134
# Params: {'in_samples': 189, 'in_features': 85, 'out_features': 15}
# Result: True
#
#
# Test: 135
# Params: {'in_samples': 17, 'in_features': 98, 'out_features': 23}
# Result: True
#
#
# Test: 136
# Params: {'in_samples': 35, 'in_features': 40, 'out_features': 97}
# Result: True
#
#
# Test: 137
# Params: {'in_samples': 164, 'in_features': 91, 'out_features': 40}
# Result: True
#
#
# Test: 138
# Params: {'in_samples': 166, 'in_features': 52, 'out_features': 27}
# Result: True
#
#
# Test: 139
# Params: {'in_samples': 128, 'in_features': 93, 'out_features': 70}
# Result: True
#
#
# Test: 140
# Params: {'in_samples': 78, 'in_features': 93, 'out_features': 69}
# Result: True
#
#
# Test: 141
# Params: {'in_samples': 82, 'in_features': 39, 'out_features': 65}
# Result: True
#
#
# Test: 142
# Params: {'in_samples': 138, 'in_features': 8, 'out_features': 12}
# Result: True
#
#
# Test: 143
# Params: {'in_samples': 110, 'in_features': 11, 'out_features': 88}
# Result: True
#
#
# Test: 144
# Params: {'in_samples': 26, 'in_features': 9, 'out_features': 82}
# Result: True
#
#
# Test: 145
# Params: {'in_samples': 161, 'in_features': 23, 'out_features': 58}
# Result: True
#
#
# Test: 146
# Params: {'in_samples': 57, 'in_features': 93, 'out_features': 9}
# Result: True
#
#
# Test: 147
# Params: {'in_samples': 0, 'in_features': 43, 'out_features': 75}
# Result: True
#
#
# Test: 148
# Params: {'in_samples': 26, 'in_features': 29, 'out_features': 12}
# Result: True
#
#
# Test: 149
# Params: {'in_samples': 30, 'in_features': 78, 'out_features': 35}
# Result: True
#
#
# Test: 150
# Params: {'in_samples': 58, 'in_features': 66, 'out_features': 100}
# Result: True
#
#
# Test: 151
# Params: {'in_samples': 191, 'in_features': 97, 'out_features': 5}
# Result: True
#
#
# Test: 152
# Params: {'in_samples': 79, 'in_features': 2, 'out_features': 89}
# Result: True
#
#
# Test: 153
# Params: {'in_samples': 155, 'in_features': 1, 'out_features': 13}
# Result: True
#
#
# Test: 154
# Params: {'in_samples': 49, 'in_features': 10, 'out_features': 92}
# Result: True
#
#
# Test: 155
# Params: {'in_samples': 169, 'in_features': 96, 'out_features': 40}
# Result: True
#
#
# Test: 156
# Params: {'in_samples': 3, 'in_features': 12, 'out_features': 82}
# Result: True
#
#
# Test: 157
# Params: {'in_samples': 120, 'in_features': 72, 'out_features': 34}
# Result: True
#
#
# Test: 158
# Params: {'in_samples': 90, 'in_features': 82, 'out_features': 35}
# Result: True
#
#
# Test: 159
# Params: {'in_samples': 142, 'in_features': 12, 'out_features': 53}
# Result: True
#
#
# Test: 160
# Params: {'in_samples': 146, 'in_features': 63, 'out_features': 34}
# Result: True
#
#
# Test: 161
# Params: {'in_samples': 55, 'in_features': 6, 'out_features': 6}
# Result: True
#
#
# Test: 162
# Params: {'in_samples': 140, 'in_features': 93, 'out_features': 67}
# Result: True
#
#
# Test: 163
# Params: {'in_samples': 47, 'in_features': 45, 'out_features': 55}
# Result: True
#
#
# Test: 164
# Params: {'in_samples': 68, 'in_features': 59, 'out_features': 50}
# Result: True
#
#
# Test: 165
# Params: {'in_samples': 188, 'in_features': 13, 'out_features': 32}
# Result: True
#
#
# Test: 166
# Params: {'in_samples': 47, 'in_features': 92, 'out_features': 17}
# Result: True
#
#
# Test: 167
# Params: {'in_samples': 185, 'in_features': 94, 'out_features': 25}
# Result: True
#
#
# Test: 168
# Params: {'in_samples': 153, 'in_features': 73, 'out_features': 25}
# Result: True
#
#
# Test: 169
# Params: {'in_samples': 188, 'in_features': 56, 'out_features': 41}
# Result: True
#
#
# Test: 170
# Params: {'in_samples': 159, 'in_features': 79, 'out_features': 64}
# Result: True
#
#
# Test: 171
# Params: {'in_samples': 121, 'in_features': 95, 'out_features': 74}
# Result: True
#
#
# Test: 172
# Params: {'in_samples': 49, 'in_features': 8, 'out_features': 23}
# Result: True
#
#
# Test: 173
# Params: {'in_samples': 59, 'in_features': 70, 'out_features': 97}
# Result: True
#
#
# Test: 174
# Params: {'in_samples': 140, 'in_features': 99, 'out_features': 4}
# Result: True
#
#
# Test: 175
# Params: {'in_samples': 170, 'in_features': 79, 'out_features': 90}
# Result: True
#
#
# Test: 176
# Params: {'in_samples': 75, 'in_features': 64, 'out_features': 6}
# Result: True
#
#
# Test: 177
# Params: {'in_samples': 36, 'in_features': 22, 'out_features': 65}
# Result: True
#
#
# Test: 178
# Params: {'in_samples': 87, 'in_features': 25, 'out_features': 37}
# Result: True
#
#
# Test: 179
# Params: {'in_samples': 169, 'in_features': 24, 'out_features': 58}
# Result: True
#
#
# Test: 180
# Params: {'in_samples': 15, 'in_features': 41, 'out_features': 73}
# Result: True
#
#
# Test: 181
# Params: {'in_samples': 86, 'in_features': 100, 'out_features': 88}
# Result: True
#
#
# Test: 182
# Params: {'in_samples': 190, 'in_features': 22, 'out_features': 42}
# Result: True
#
#
# Test: 183
# Params: {'in_samples': 134, 'in_features': 21, 'out_features': 22}
# Result: True
#
#
# Test: 184
# Params: {'in_samples': 34, 'in_features': 18, 'out_features': 12}
# Result: True
#
#
# Test: 185
# Params: {'in_samples': 13, 'in_features': 1, 'out_features': 80}
# Result: True
#
#
# Test: 186
# Params: {'in_samples': 55, 'in_features': 25, 'out_features': 44}
# Result: True
#
#
# Test: 187
# Params: {'in_samples': 132, 'in_features': 100, 'out_features': 45}
# Result: True
#
#
# Test: 188
# Params: {'in_samples': 199, 'in_features': 3, 'out_features': 9}
# Result: True
#
#
# Test: 189
# Params: {'in_samples': 180, 'in_features': 93, 'out_features': 20}
# Result: True
#
#
# Test: 190
# Params: {'in_samples': 114, 'in_features': 48, 'out_features': 77}
#  20%|███████▉                               | 203/1000 [00:01<00:04, 184.72it/s]
# Result: True
#
#
# Test: 191
# Params: {'in_samples': 170, 'in_features': 64, 'out_features': 52}
# Result: True
#
#
# Test: 192
# Params: {'in_samples': 6, 'in_features': 85, 'out_features': 38}
# Result: True
#
#
# Test: 193
# Params: {'in_samples': 58, 'in_features': 70, 'out_features': 83}
# Result: True
#
#
# Test: 194
# Params: {'in_samples': 91, 'in_features': 37, 'out_features': 72}
# Result: True
#
#
# Test: 195
# Params: {'in_samples': 35, 'in_features': 54, 'out_features': 59}
# Result: True
#
#
# Test: 196
# Params: {'in_samples': 134, 'in_features': 52, 'out_features': 64}
# Result: True
#
#
# Test: 197
# Params: {'in_samples': 183, 'in_features': 28, 'out_features': 3}
# Result: True
#
#
# Test: 198
# Params: {'in_samples': 87, 'in_features': 20, 'out_features': 48}
# Result: True
#
#
# Test: 199
# Params: {'in_samples': 169, 'in_features': 7, 'out_features': 46}
# Result: True
#
#
# Test: 200
# Params: {'in_samples': 79, 'in_features': 93, 'out_features': 24}
# Result: True
#
#
# Test: 201
# Params: {'in_samples': 11, 'in_features': 23, 'out_features': 55}
# Result: True
#
#
# Test: 202
# Params: {'in_samples': 190, 'in_features': 10, 'out_features': 19}
# Result: True
#
#
# Test: 203
# Params: {'in_samples': 177, 'in_features': 37, 'out_features': 73}
# Result: True
#
#
# Test: 204
# Params: {'in_samples': 147, 'in_features': 44, 'out_features': 91}
# Result: True
#
#
# Test: 205
# Params: {'in_samples': 98, 'in_features': 50, 'out_features': 84}
# Result: True
#
#
# Test: 206
# Params: {'in_samples': 81, 'in_features': 89, 'out_features': 97}
#  23%|████████▉                              | 229/1000 [00:01<00:04, 160.68it/s]
# Result: True
#
#
# Test: 207
# Params: {'in_samples': 53, 'in_features': 25, 'out_features': 94}
# Result: True
#
#
# Test: 208
# Params: {'in_samples': 122, 'in_features': 52, 'out_features': 69}
# Result: True
#
#
# Test: 209
# Params: {'in_samples': 144, 'in_features': 62, 'out_features': 100}
# Result: True
#
#
# Test: 210
# Params: {'in_samples': 180, 'in_features': 66, 'out_features': 91}
# Result: True
#
#
# Test: 211
# Params: {'in_samples': 123, 'in_features': 12, 'out_features': 88}
# Result: True
#
#
# Test: 212
# Params: {'in_samples': 199, 'in_features': 14, 'out_features': 79}
# Result: True
#
#
# Test: 213
# Params: {'in_samples': 196, 'in_features': 35, 'out_features': 95}
# Result: True
#
#
# Test: 214
# Params: {'in_samples': 120, 'in_features': 45, 'out_features': 11}
# Result: True
#
#
# Test: 215
# Params: {'in_samples': 118, 'in_features': 81, 'out_features': 66}
# Result: True
#
#
# Test: 216
# Params: {'in_samples': 143, 'in_features': 4, 'out_features': 71}
# Result: True
#
#
# Test: 217
# Params: {'in_samples': 42, 'in_features': 83, 'out_features': 5}
# Result: True
#
#
# Test: 218
# Params: {'in_samples': 46, 'in_features': 45, 'out_features': 68}
# Result: True
#
#
# Test: 219
# Params: {'in_samples': 104, 'in_features': 14, 'out_features': 49}
# Result: True
#
#
# Test: 220
# Params: {'in_samples': 194, 'in_features': 83, 'out_features': 43}
# Result: True
#
#
# Test: 221
# Params: {'in_samples': 10, 'in_features': 61, 'out_features': 63}
# Result: True
#
#
# Test: 222
# Params: {'in_samples': 70, 'in_features': 68, 'out_features': 36}
# Result: True
#
#
# Test: 223
# Params: {'in_samples': 113, 'in_features': 83, 'out_features': 45}
# Result: True
#
#
# Test: 224
# Params: {'in_samples': 50, 'in_features': 42, 'out_features': 93}
# Result: True
#
#
# Test: 225
# Params: {'in_samples': 75, 'in_features': 72, 'out_features': 9}
# Result: True
#
#
# Test: 226
# Params: {'in_samples': 187, 'in_features': 45, 'out_features': 65}
# Result: True
#
#
# Test: 227
# Params: {'in_samples': 183, 'in_features': 75, 'out_features': 59}
# Result: True
#
#
# Test: 228
# Params: {'in_samples': 181, 'in_features': 9, 'out_features': 55}
# Result: True
#
#
# Test: 229
# Params: {'in_samples': 183, 'in_features': 13, 'out_features': 4}
# Result: True
#
#
# Test: 230
# Params: {'in_samples': 83, 'in_features': 75, 'out_features': 33}
# Result: True
#
#
# Test: 231
# Params: {'in_samples': 72, 'in_features': 28, 'out_features': 61}
# Result: True
#
#
# Test: 232
# Params: {'in_samples': 29, 'in_features': 55, 'out_features': 43}
# Result: True
#
#
# Test: 233
# Params: {'in_samples': 59, 'in_features': 3, 'out_features': 84}
# Result: True
#
#
# Test: 234
# Params: {'in_samples': 75, 'in_features': 22, 'out_features': 65}
# Result: True
#
#
# Test: 235
# Params: {'in_samples': 87, 'in_features': 41, 'out_features': 74}
# Result: True
#
#
# Test: 236
# Params: {'in_samples': 191, 'in_features': 91, 'out_features': 73}
# Result: True
#
#
# Test: 237
# Params: {'in_samples': 45, 'in_features': 46, 'out_features': 90}
# Result: True
#
#
# Test: 238
# Params: {'in_samples': 136, 'in_features': 83, 'out_features': 89}
# Result: True
#
#
# Test: 239
# Params: {'in_samples': 147, 'in_features': 52, 'out_features': 37}
# Result: True
#
#
# Test: 240
# Params: {'in_samples': 60, 'in_features': 64, 'out_features': 68}
# Result: True
#
#
# Test: 241
# Params: {'in_samples': 186, 'in_features': 79, 'out_features': 88}
# Result: True
#
#
# Test: 242
# Params: {'in_samples': 48, 'in_features': 73, 'out_features': 45}
# Result: True
#
#
# Test: 243
# Params: {'in_samples': 87, 'in_features': 99, 'out_features': 35}
# Result: True
#
#
# Test: 244
# Params: {'in_samples': 47, 'in_features': 12, 'out_features': 15}
# Result: True
#
#
# Test: 245
# Params: {'in_samples': 36, 'in_features': 65, 'out_features': 79}
# Result: True
#
#
# Test: 246
# Params: {'in_samples': 182, 'in_features': 62, 'out_features': 9}
# Result: True
#
#
# Test: 247
# Params: {'in_samples': 142, 'in_features': 13, 'out_features': 30}
# Result: True
#
#
# Test: 248
# Params: {'in_samples': 28, 'in_features': 35, 'out_features': 1}
# Result: True
#
#
# Test: 249
# Params: {'in_samples': 60, 'in_features': 85, 'out_features': 62}
# Result: True
#
#
# Test: 250
# Params: {'in_samples': 88, 'in_features': 68, 'out_features': 40}
# Result: True
#
#
# Test: 251
# Params: {'in_samples': 140, 'in_features': 42, 'out_features': 63}
# Result: True
#
#
# Test: 252
# Params: {'in_samples': 95, 'in_features': 89, 'out_features': 28}
# Result: True
#
#
# Test: 253
# Params: {'in_samples': 109, 'in_features': 85, 'out_features': 96}
# Result: True
#
#
# Test: 254
# Params: {'in_samples': 199, 'in_features': 85, 'out_features': 52}
# Result: True
#
#
# Test: 255
# Params: {'in_samples': 81, 'in_features': 62, 'out_features': 96}
# Result: True
#
#
# Test: 256
# Params: {'in_samples': 164, 'in_features': 21, 'out_features': 47}
# Result: True
#
#
# Test: 257
# Params: {'in_samples': 90, 'in_features': 64, 'out_features': 10}
# Result: True
#
#
# Test: 258
# Params: {'in_samples': 158, 'in_features': 61, 'out_features': 43}
# Result: True
#
#
# Test: 259
# Params: {'in_samples': 13, 'in_features': 40, 'out_features': 7}
# Result: True
#
#
# Test: 260
# Params: {'in_samples': 18, 'in_features': 56, 'out_features': 74}
# Result: True
#
#
# Test: 261
# Params: {'in_samples': 121, 'in_features': 21, 'out_features': 11}
# Result: True
#
#
# Test: 262
# Params: {'in_samples': 125, 'in_features': 40, 'out_features': 79}
# Result: True
#
#
# Test: 263
# Params: {'in_samples': 96, 'in_features': 87, 'out_features': 15}
# Result: True
#
#
# Test: 264
# Params: {'in_samples': 2, 'in_features': 14, 'out_features': 93}
# Result: True
#
#
# Test: 265
# Params: {'in_samples': 113, 'in_features': 24, 'out_features': 60}
# Result: True
#
#
# Test: 266
# Params: {'in_samples': 172, 'in_features': 73, 'out_features': 46}
# Result: True
#
#
# Test: 267
# Params: {'in_samples': 139, 'in_features': 5, 'out_features': 96}
# Result: True
#
#
# Test: 268
# Params: {'in_samples': 50, 'in_features': 57, 'out_features': 76}
# Result: True
#
#
# Test: 269
# Params: {'in_samples': 132, 'in_features': 46, 'out_features': 14}
# Result: True
#
#
# Test: 270
# Params: {'in_samples': 73, 'in_features': 68, 'out_features': 56}
# Result: True
#
#
# Test: 271
# Params: {'in_samples': 170, 'in_features': 22, 'out_features': 41}
# Result: True
#
#
# Test: 272
# Params: {'in_samples': 99, 'in_features': 87, 'out_features': 70}
# Result: True
#
#
# Test: 273
# Params: {'in_samples': 158, 'in_features': 25, 'out_features': 22}
# Result: True
#
#
# Test: 274
# Params: {'in_samples': 33, 'in_features': 54, 'out_features': 61}
# Result: True
#
#
# Test: 275
# Params: {'in_samples': 152, 'in_features': 68, 'out_features': 77}
# Result: True
#
#
# Test: 276
# Params: {'in_samples': 10, 'in_features': 63, 'out_features': 46}
# Result: True
#
#
# Test: 277
# Params: {'in_samples': 50, 'in_features': 56, 'out_features': 46}
# Result: True
#
#
# Test: 278
# Params: {'in_samples': 48, 'in_features': 19, 'out_features': 76}
# Result: True
#
#
# Test: 279
# Params: {'in_samples': 52, 'in_features': 43, 'out_features': 85}
# Result: True
#
#
# Test: 280
# Params: {'in_samples': 42, 'in_features': 10, 'out_features': 4}
# Result: True
#
#
# Test: 281
# Params: {'in_samples': 34, 'in_features': 86, 'out_features': 3}
# Result: True
#
#
# Test: 282
# Params: {'in_samples': 190, 'in_features': 1, 'out_features': 57}
# Result: True
#
#
# Test: 283
# Params: {'in_samples': 103, 'in_features': 51, 'out_features': 80}
# Result: True
#
#
# Test: 284
# Params: {'in_samples': 72, 'in_features': 5, 'out_features': 90}
# Result: True
#
#
# Test: 285
# Params: {'in_samples': 180, 'in_features': 98, 'out_features': 79}
# Result: True
#
#
# Test: 286
# Params: {'in_samples': 59, 'in_features': 71, 'out_features': 7}
# Result: True
#
#
# Test: 287
# Params: {'in_samples': 145, 'in_features': 42, 'out_features': 54}
#  29%|███████████▎                           | 289/1000 [00:01<00:03, 229.07it/s]
# Result: True
#
#
# Test: 288
# Params: {'in_samples': 135, 'in_features': 57, 'out_features': 83}
# Result: True
#
#
# Test: 289
# Params: {'in_samples': 174, 'in_features': 69, 'out_features': 51}
# Result: True
#
#
# Test: 290
# Params: {'in_samples': 64, 'in_features': 57, 'out_features': 10}
# Result: True
#
#
# Test: 291
# Params: {'in_samples': 130, 'in_features': 39, 'out_features': 96}
# Result: True
#
#
# Test: 292
# Params: {'in_samples': 178, 'in_features': 76, 'out_features': 90}
# Result: True
#
#
# Test: 293
# Params: {'in_samples': 113, 'in_features': 26, 'out_features': 22}
# Result: True
#
#
# Test: 294
# Params: {'in_samples': 86, 'in_features': 12, 'out_features': 33}
# Result: True
#
#
# Test: 295
# Params: {'in_samples': 85, 'in_features': 97, 'out_features': 70}
# Result: True
#
#
# Test: 296
# Params: {'in_samples': 58, 'in_features': 62, 'out_features': 80}
# Result: True
#
#
# Test: 297
# Params: {'in_samples': 131, 'in_features': 80, 'out_features': 80}
#  32%|████████████▍                          | 319/1000 [00:01<00:03, 190.62it/s]
# Result: True
#
#
# Test: 298
# Params: {'in_samples': 108, 'in_features': 48, 'out_features': 54}
# Result: True
#
#
# Test: 299
# Params: {'in_samples': 21, 'in_features': 36, 'out_features': 47}
# Result: True
#
#
# Test: 300
# Params: {'in_samples': 39, 'in_features': 27, 'out_features': 28}
# Result: True
#
#
# Test: 301
# Params: {'in_samples': 74, 'in_features': 27, 'out_features': 71}
# Result: True
#
#
# Test: 302
# Params: {'in_samples': 172, 'in_features': 4, 'out_features': 41}
# Result: True
#
#
# Test: 303
# Params: {'in_samples': 197, 'in_features': 36, 'out_features': 19}
# Result: True
#
#
# Test: 304
# Params: {'in_samples': 92, 'in_features': 38, 'out_features': 15}
# Result: True
#
#
# Test: 305
# Params: {'in_samples': 72, 'in_features': 20, 'out_features': 16}
# Result: True
#
#
# Test: 306
# Params: {'in_samples': 19, 'in_features': 79, 'out_features': 81}
# Result: True
#
#
# Test: 307
# Params: {'in_samples': 22, 'in_features': 88, 'out_features': 94}
# Result: True
#
#
# Test: 308
# Params: {'in_samples': 28, 'in_features': 89, 'out_features': 58}
# Result: True
#
#
# Test: 309
# Params: {'in_samples': 54, 'in_features': 77, 'out_features': 50}
# Result: True
#
#
# Test: 310
# Params: {'in_samples': 150, 'in_features': 15, 'out_features': 25}
# Result: True
#
#
# Test: 311
# Params: {'in_samples': 182, 'in_features': 61, 'out_features': 96}
# Result: True
#
#
# Test: 312
# Params: {'in_samples': 118, 'in_features': 85, 'out_features': 11}
# Result: True
#
#
# Test: 313
# Params: {'in_samples': 151, 'in_features': 40, 'out_features': 68}
# Result: True
#
#
# Test: 314
# Params: {'in_samples': 170, 'in_features': 59, 'out_features': 79}
# Result: True
#
#
# Test: 315
# Params: {'in_samples': 168, 'in_features': 9, 'out_features': 90}
# Result: True
#
#
# Test: 316
# Params: {'in_samples': 122, 'in_features': 15, 'out_features': 73}
# Result: True
#
#
# Test: 317
# Params: {'in_samples': 28, 'in_features': 27, 'out_features': 67}
# Result: True
#
#
# Test: 318
# Params: {'in_samples': 57, 'in_features': 49, 'out_features': 93}
# Result: True
#
#
# Test: 319
# Params: {'in_samples': 136, 'in_features': 68, 'out_features': 61}
# Result: True
#
#
# Test: 320
# Params: {'in_samples': 174, 'in_features': 41, 'out_features': 27}
# Result: True
#
#
# Test: 321
# Params: {'in_samples': 140, 'in_features': 94, 'out_features': 8}
# Result: True
#
#
# Test: 322
# Params: {'in_samples': 119, 'in_features': 91, 'out_features': 61}
# Result: True
#
#
# Test: 323
# Params: {'in_samples': 115, 'in_features': 66, 'out_features': 84}
# Result: True
#
#
# Test: 324
# Params: {'in_samples': 61, 'in_features': 6, 'out_features': 98}
# Result: True
#
#
# Test: 325
# Params: {'in_samples': 182, 'in_features': 81, 'out_features': 28}
# Result: True
#
#
# Test: 326
# Params: {'in_samples': 159, 'in_features': 53, 'out_features': 76}
# Result: True
#
#
# Test: 327
# Params: {'in_samples': 72, 'in_features': 88, 'out_features': 84}
# Result: True
#
#
# Test: 328
# Params: {'in_samples': 36, 'in_features': 55, 'out_features': 20}
# Result: True
#
#
# Test: 329
# Params: {'in_samples': 177, 'in_features': 35, 'out_features': 1}
# Result: True
#
#
# Test: 330
# Params: {'in_samples': 115, 'in_features': 64, 'out_features': 29}
# Result: True
#
#
# Test: 331
# Params: {'in_samples': 159, 'in_features': 66, 'out_features': 15}
# Result: True
#
#
# Test: 332
# Params: {'in_samples': 92, 'in_features': 12, 'out_features': 9}
# Result: True
#
#
# Test: 333
# Params: {'in_samples': 53, 'in_features': 58, 'out_features': 66}
# Result: True
#
#
# Test: 334
# Params: {'in_samples': 91, 'in_features': 88, 'out_features': 89}
# Result: True
#
#
# Test: 335
# Params: {'in_samples': 19, 'in_features': 57, 'out_features': 79}
# Result: True
#
#
# Test: 336
# Params: {'in_samples': 81, 'in_features': 91, 'out_features': 73}
# Result: True
#
#
# Test: 337
# Params: {'in_samples': 124, 'in_features': 97, 'out_features': 60}
# Result: True
#
#
# Test: 338
# Params: {'in_samples': 44, 'in_features': 54, 'out_features': 75}
# Result: True
#
#
# Test: 339
# Params: {'in_samples': 198, 'in_features': 53, 'out_features': 82}
# Result: True
#
#
# Test: 340
# Params: {'in_samples': 196, 'in_features': 86, 'out_features': 97}
# Result: True
#
#
# Test: 341
# Params: {'in_samples': 62, 'in_features': 92, 'out_features': 78}
# Result: True
#
#
# Test: 342
# Params: {'in_samples': 8, 'in_features': 69, 'out_features': 71}
# Result: True
#
#
# Test: 343
# Params: {'in_samples': 184, 'in_features': 70, 'out_features': 5}
#  34%|█████████████▍                         | 344/1000 [00:02<00:04, 141.05it/s]
# Result: True
#
#
# Test: 344
# Params: {'in_samples': 185, 'in_features': 80, 'out_features': 8}
# Result: True
#
#
# Test: 345
# Params: {'in_samples': 136, 'in_features': 53, 'out_features': 93}
# Result: True
#
#
# Test: 346
# Params: {'in_samples': 45, 'in_features': 3, 'out_features': 36}
# Result: True
#
#
# Test: 347
# Params: {'in_samples': 169, 'in_features': 30, 'out_features': 45}
# Result: True
#
#
# Test: 348
# Params: {'in_samples': 113, 'in_features': 42, 'out_features': 33}
# Result: True
#
#
# Test: 349
# Params: {'in_samples': 196, 'in_features': 89, 'out_features': 36}
# Result: True
#
#
# Test: 350
# Params: {'in_samples': 137, 'in_features': 26, 'out_features': 79}
# Result: True
#
#
# Test: 351
# Params: {'in_samples': 194, 'in_features': 81, 'out_features': 4}
# Result: True
#
#
# Test: 352
# Params: {'in_samples': 192, 'in_features': 59, 'out_features': 45}
# Result: True
#
#
# Test: 353
# Params: {'in_samples': 1, 'in_features': 20, 'out_features': 10}
# Result: True
#
#
# Test: 354
# Params: {'in_samples': 193, 'in_features': 85, 'out_features': 45}
# Result: True
#
#
# Test: 355
# Params: {'in_samples': 98, 'in_features': 67, 'out_features': 91}
# Result: True
#
#
# Test: 356
# Params: {'in_samples': 175, 'in_features': 57, 'out_features': 21}
# Result: True
#
#
# Test: 357
# Params: {'in_samples': 194, 'in_features': 59, 'out_features': 43}
# Result: True
#
#
# Test: 358
# Params: {'in_samples': 19, 'in_features': 33, 'out_features': 64}
# Result: True
#
#
# Test: 359
# Params: {'in_samples': 113, 'in_features': 57, 'out_features': 47}
# Result: True
#
#
# Test: 360
# Params: {'in_samples': 94, 'in_features': 87, 'out_features': 97}
#  38%|██████████████▊                        | 380/1000 [00:02<00:04, 127.43it/s]
# Result: True
#
#
# Test: 361
# Params: {'in_samples': 123, 'in_features': 15, 'out_features': 42}
# Result: True
#
#
# Test: 362
# Params: {'in_samples': 26, 'in_features': 10, 'out_features': 12}
# Result: True
#
#
# Test: 363
# Params: {'in_samples': 78, 'in_features': 95, 'out_features': 70}
# Result: True
#
#
# Test: 364
# Params: {'in_samples': 57, 'in_features': 42, 'out_features': 95}
# Result: True
#
#
# Test: 365
# Params: {'in_samples': 197, 'in_features': 77, 'out_features': 46}
# Result: True
#
#
# Test: 366
# Params: {'in_samples': 104, 'in_features': 45, 'out_features': 61}
# Result: True
#
#
# Test: 367
# Params: {'in_samples': 157, 'in_features': 61, 'out_features': 68}
# Result: True
#
#
# Test: 368
# Params: {'in_samples': 162, 'in_features': 80, 'out_features': 72}
# Result: True
#
#
# Test: 369
# Params: {'in_samples': 192, 'in_features': 59, 'out_features': 98}
# Result: True
#
#
# Test: 370
# Params: {'in_samples': 38, 'in_features': 21, 'out_features': 96}
# Result: True
#
#
# Test: 371
# Params: {'in_samples': 67, 'in_features': 65, 'out_features': 9}
# Result: True
#
#
# Test: 372
# Params: {'in_samples': 171, 'in_features': 28, 'out_features': 23}
# Result: True
#
#
# Test: 373
# Params: {'in_samples': 39, 'in_features': 38, 'out_features': 64}
# Result: True
#
#
# Test: 374
# Params: {'in_samples': 49, 'in_features': 61, 'out_features': 5}
# Result: True
#
#
# Test: 375
# Params: {'in_samples': 118, 'in_features': 64, 'out_features': 55}
# Result: True
#
#
# Test: 376
# Params: {'in_samples': 160, 'in_features': 5, 'out_features': 99}
# Result: True
#
#
# Test: 377
# Params: {'in_samples': 18, 'in_features': 37, 'out_features': 79}
# Result: True
#
#
# Test: 378
# Params: {'in_samples': 128, 'in_features': 15, 'out_features': 54}
# Result: True
#
#
# Test: 379
# Params: {'in_samples': 106, 'in_features': 17, 'out_features': 60}
# Result: True
#
#
# Test: 380
# Params: {'in_samples': 120, 'in_features': 60, 'out_features': 37}
# Result: True
#
#
# Test: 381
# Params: {'in_samples': 134, 'in_features': 9, 'out_features': 79}
# Result: True
#
#
# Test: 382
# Params: {'in_samples': 109, 'in_features': 50, 'out_features': 35}
# Result: True
#
#
# Test: 383
# Params: {'in_samples': 88, 'in_features': 15, 'out_features': 79}
# Result: True
#
#
# Test: 384
# Params: {'in_samples': 153, 'in_features': 54, 'out_features': 92}
# Result: True
#
#
# Test: 385
# Params: {'in_samples': 12, 'in_features': 69, 'out_features': 24}
# Result: True
#
#
# Test: 386
# Params: {'in_samples': 197, 'in_features': 54, 'out_features': 12}
# Result: True
#
#
# Test: 387
# Params: {'in_samples': 179, 'in_features': 9, 'out_features': 75}
# Result: True
#
#
# Test: 388
# Params: {'in_samples': 181, 'in_features': 15, 'out_features': 100}
# Result: True
#
#
# Test: 389
# Params: {'in_samples': 83, 'in_features': 90, 'out_features': 23}
# Result: True
#
#
# Test: 390
# Params: {'in_samples': 44, 'in_features': 55, 'out_features': 90}
# Result: True
#
#
# Test: 391
# Params: {'in_samples': 91, 'in_features': 58, 'out_features': 4}
# Result: True
#
#
# Test: 392
# Params: {'in_samples': 157, 'in_features': 17, 'out_features': 58}
# Result: True
#
#
# Test: 393
# Params: {'in_samples': 85, 'in_features': 77, 'out_features': 17}
# Result: True
#
#
# Test: 394
# Params: {'in_samples': 144, 'in_features': 71, 'out_features': 13}
# Result: True
#
#
# Test: 395
# Params: {'in_samples': 68, 'in_features': 81, 'out_features': 84}
# Result: True
#
#
# Test: 396
# Params: {'in_samples': 190, 'in_features': 91, 'out_features': 84}
# Result: True
#
#
# Test: 397
# Params: {'in_samples': 140, 'in_features': 14, 'out_features': 32}
# Result: True
#
#
# Test: 398
# Params: {'in_samples': 57, 'in_features': 20, 'out_features': 63}
# Result: True
#
#
# Test: 399
# Params: {'in_samples': 18, 'in_features': 21, 'out_features': 22}
# Result: True
#
#
# Test: 400
# Params: {'in_samples': 29, 'in_features': 39, 'out_features': 95}
# Result: True
#
#
# Test: 401
# Params: {'in_samples': 112, 'in_features': 2, 'out_features': 71}
# Result: True
#
#
# Test: 402
# Params: {'in_samples': 60, 'in_features': 98, 'out_features': 19}
# Result: True
#
#
# Test: 403
# Params: {'in_samples': 134, 'in_features': 74, 'out_features': 31}
# Result: True
#
#
# Test: 404
# Params: {'in_samples': 186, 'in_features': 45, 'out_features': 94}
# Result: True
#
#
# Test: 405
# Params: {'in_samples': 190, 'in_features': 16, 'out_features': 44}
# Result: True
#
#
# Test: 406
# Params: {'in_samples': 172, 'in_features': 42, 'out_features': 28}
# Result: True
#
#
# Test: 407
# Params: {'in_samples': 167, 'in_features': 77, 'out_features': 77}
# Result: True
#
#
# Test: 408
# Params: {'in_samples': 185, 'in_features': 68, 'out_features': 55}
# Result: True
#
#
# Test: 409
# Params: {'in_samples': 6, 'in_features': 44, 'out_features': 57}
# Result: True
#
#
# Test: 410
# Params: {'in_samples': 152, 'in_features': 9, 'out_features': 95}
# Result: True
#
#
# Test: 411
# Params: {'in_samples': 171, 'in_features': 19, 'out_features': 42}
#  44%|█████████████████                      | 436/1000 [00:02<00:03, 158.79it/s]
# Result: True
#
#
# Test: 412
# Params: {'in_samples': 111, 'in_features': 93, 'out_features': 38}
# Result: True
#
#
# Test: 413
# Params: {'in_samples': 97, 'in_features': 29, 'out_features': 46}
# Result: True
#
#
# Test: 414
# Params: {'in_samples': 60, 'in_features': 80, 'out_features': 63}
# Result: True
#
#
# Test: 415
# Params: {'in_samples': 102, 'in_features': 59, 'out_features': 88}
# Result: True
#
#
# Test: 416
# Params: {'in_samples': 80, 'in_features': 21, 'out_features': 88}
# Result: True
#
#
# Test: 417
# Params: {'in_samples': 137, 'in_features': 38, 'out_features': 94}
# Result: True
#
#
# Test: 418
# Params: {'in_samples': 19, 'in_features': 94, 'out_features': 67}
# Result: True
#
#
# Test: 419
# Params: {'in_samples': 9, 'in_features': 38, 'out_features': 100}
# Result: True
#
#
# Test: 420
# Params: {'in_samples': 132, 'in_features': 66, 'out_features': 15}
# Result: True
#
#
# Test: 421
# Params: {'in_samples': 36, 'in_features': 84, 'out_features': 42}
# Result: True
#
#
# Test: 422
# Params: {'in_samples': 97, 'in_features': 33, 'out_features': 46}
# Result: True
#
#
# Test: 423
# Params: {'in_samples': 108, 'in_features': 73, 'out_features': 52}
# Result: True
#
#
# Test: 424
# Params: {'in_samples': 157, 'in_features': 9, 'out_features': 9}
# Result: True
#
#
# Test: 425
# Params: {'in_samples': 29, 'in_features': 27, 'out_features': 5}
# Result: True
#
#
# Test: 426
# Params: {'in_samples': 115, 'in_features': 50, 'out_features': 2}
# Result: True
#
#
# Test: 427
# Params: {'in_samples': 165, 'in_features': 89, 'out_features': 44}
# Result: True
#
#
# Test: 428
# Params: {'in_samples': 98, 'in_features': 88, 'out_features': 4}
# Result: True
#
#
# Test: 429
# Params: {'in_samples': 46, 'in_features': 91, 'out_features': 91}
# Result: True
#
#
# Test: 430
# Params: {'in_samples': 93, 'in_features': 100, 'out_features': 31}
# Result: True
#
#
# Test: 431
# Params: {'in_samples': 90, 'in_features': 87, 'out_features': 26}
# Result: True
#
#
# Test: 432
# Params: {'in_samples': 23, 'in_features': 83, 'out_features': 65}
# Result: True
#
#
# Test: 433
# Params: {'in_samples': 2, 'in_features': 5, 'out_features': 76}
# Result: True
#
#
# Test: 434
# Params: {'in_samples': 95, 'in_features': 60, 'out_features': 24}
# Result: True
#
#
# Test: 435
# Params: {'in_samples': 81, 'in_features': 84, 'out_features': 69}
# Result: True
#
#
# Test: 436
# Params: {'in_samples': 74, 'in_features': 89, 'out_features': 5}
# Result: True
#
#
# Test: 437
# Params: {'in_samples': 73, 'in_features': 7, 'out_features': 53}
# Result: True
#
#
# Test: 438
# Params: {'in_samples': 196, 'in_features': 60, 'out_features': 58}
#  47%|██████████████████▎                    | 469/1000 [00:02<00:02, 188.13it/s]
# Result: True
#
#
# Test: 439
# Params: {'in_samples': 32, 'in_features': 44, 'out_features': 48}
# Result: True
#
#
# Test: 440
# Params: {'in_samples': 51, 'in_features': 37, 'out_features': 81}
# Result: True
#
#
# Test: 441
# Params: {'in_samples': 45, 'in_features': 91, 'out_features': 82}
# Result: True
#
#
# Test: 442
# Params: {'in_samples': 39, 'in_features': 87, 'out_features': 14}
# Result: True
#
#
# Test: 443
# Params: {'in_samples': 160, 'in_features': 40, 'out_features': 44}
# Result: True
#
#
# Test: 444
# Params: {'in_samples': 88, 'in_features': 25, 'out_features': 66}
# Result: True
#
#
# Test: 445
# Params: {'in_samples': 162, 'in_features': 51, 'out_features': 100}
# Result: True
#
#
# Test: 446
# Params: {'in_samples': 139, 'in_features': 11, 'out_features': 2}
# Result: True
#
#
# Test: 447
# Params: {'in_samples': 112, 'in_features': 95, 'out_features': 6}
# Result: True
#
#
# Test: 448
# Params: {'in_samples': 40, 'in_features': 94, 'out_features': 73}
# Result: True
#
#
# Test: 449
# Params: {'in_samples': 131, 'in_features': 92, 'out_features': 24}
# Result: True
#
#
# Test: 450
# Params: {'in_samples': 156, 'in_features': 38, 'out_features': 86}
# Result: True
#
#
# Test: 451
# Params: {'in_samples': 118, 'in_features': 46, 'out_features': 2}
# Result: True
#
#
# Test: 452
# Params: {'in_samples': 51, 'in_features': 87, 'out_features': 24}
# Result: True
#
#
# Test: 453
# Params: {'in_samples': 13, 'in_features': 6, 'out_features': 59}
# Result: True
#
#
# Test: 454
# Params: {'in_samples': 166, 'in_features': 2, 'out_features': 40}
# Result: True
#
#
# Test: 455
# Params: {'in_samples': 165, 'in_features': 79, 'out_features': 5}
# Result: True
#
#
# Test: 456
# Params: {'in_samples': 19, 'in_features': 55, 'out_features': 1}
# Result: True
#
#
# Test: 457
# Params: {'in_samples': 42, 'in_features': 9, 'out_features': 5}
# Result: True
#
#
# Test: 458
# Params: {'in_samples': 52, 'in_features': 75, 'out_features': 35}
# Result: True
#
#
# Test: 459
# Params: {'in_samples': 170, 'in_features': 64, 'out_features': 61}
# Result: True
#
#
# Test: 460
# Params: {'in_samples': 16, 'in_features': 42, 'out_features': 45}
# Result: True
#
#
# Test: 461
# Params: {'in_samples': 157, 'in_features': 43, 'out_features': 20}
# Result: True
#
#
# Test: 462
# Params: {'in_samples': 116, 'in_features': 47, 'out_features': 80}
# Result: True
#
#
# Test: 463
# Params: {'in_samples': 95, 'in_features': 66, 'out_features': 87}
# Result: True
#
#
# Test: 464
# Params: {'in_samples': 27, 'in_features': 92, 'out_features': 93}
# Result: True
#
#
# Test: 465
# Params: {'in_samples': 69, 'in_features': 45, 'out_features': 2}
# Result: True
#
#
# Test: 466
# Params: {'in_samples': 9, 'in_features': 46, 'out_features': 71}
# Result: True
#
#
# Test: 467
# Params: {'in_samples': 87, 'in_features': 66, 'out_features': 13}
# Result: True
#
#
# Test: 468
# Params: {'in_samples': 149, 'in_features': 79, 'out_features': 50}
# Result: True
#
#
# Test: 469
# Params: {'in_samples': 179, 'in_features': 90, 'out_features': 46}
# Result: True
#
#
# Test: 470
# Params: {'in_samples': 105, 'in_features': 83, 'out_features': 90}
# Result: True
#
#
# Test: 471
# Params: {'in_samples': 62, 'in_features': 35, 'out_features': 49}
# Result: True
#
#
# Test: 472
# Params: {'in_samples': 179, 'in_features': 13, 'out_features': 76}
# Result: True
#
#
# Test: 473
# Params: {'in_samples': 108, 'in_features': 13, 'out_features': 78}
# Result: True
#
#
# Test: 474
# Params: {'in_samples': 186, 'in_features': 56, 'out_features': 15}
# Result: True
#
#
# Test: 475
# Params: {'in_samples': 83, 'in_features': 78, 'out_features': 71}
# Result: True
#
#
# Test: 476
# Params: {'in_samples': 17, 'in_features': 90, 'out_features': 57}
# Result: True
#
#
# Test: 477
# Params: {'in_samples': 155, 'in_features': 2, 'out_features': 44}
# Result: True
#
#
# Test: 478
# Params: {'in_samples': 194, 'in_features': 39, 'out_features': 89}
# Result: True
#
#
# Test: 479
# Params: {'in_samples': 6, 'in_features': 61, 'out_features': 15}
# Result: True
#
#
# Test: 480
# Params: {'in_samples': 184, 'in_features': 87, 'out_features': 41}
# Result: True
#
#
# Test: 481
# Params: {'in_samples': 139, 'in_features': 43, 'out_features': 38}
# Result: True
#
#
# Test: 482
# Params: {'in_samples': 88, 'in_features': 94, 'out_features': 62}
# Result: True
#
#
# Test: 483
# Params: {'in_samples': 77, 'in_features': 88, 'out_features': 23}
# Result: True
#
#
# Test: 484
# Params: {'in_samples': 189, 'in_features': 60, 'out_features': 60}
# Result: True
#
#
# Test: 485
# Params: {'in_samples': 196, 'in_features': 94, 'out_features': 41}
# Result: True
#
#
# Test: 486
# Params: {'in_samples': 32, 'in_features': 2, 'out_features': 70}
# Result: True
#
#
# Test: 487
# Params: {'in_samples': 58, 'in_features': 6, 'out_features': 95}
# Result: True
#
#
# Test: 488
# Params: {'in_samples': 174, 'in_features': 26, 'out_features': 45}
# Result: True
#
#
# Test: 489
# Params: {'in_samples': 76, 'in_features': 1, 'out_features': 65}
# Result: True
#
#
# Test: 490
# Params: {'in_samples': 188, 'in_features': 84, 'out_features': 32}
# Result: True
#
#
# Test: 491
# Params: {'in_samples': 119, 'in_features': 65, 'out_features': 2}
# Result: True
#
#
# Test: 492
# Params: {'in_samples': 117, 'in_features': 2, 'out_features': 36}
# Result: True
#
#
# Test: 493
# Params: {'in_samples': 73, 'in_features': 12, 'out_features': 18}
# Result: True
#
#
# Test: 494
# Params: {'in_samples': 197, 'in_features': 16, 'out_features': 24}
# Result: True
#
#
# Test: 495
# Params: {'in_samples': 4, 'in_features': 72, 'out_features': 70}
# Result: True
#
#
# Test: 496
# Params: {'in_samples': 198, 'in_features': 50, 'out_features': 51}
# Result: True
#
#
# Test: 497
# Params: {'in_samples': 27, 'in_features': 82, 'out_features': 14}
# Result: True
#
#
# Test: 498
# Params: {'in_samples': 63, 'in_features': 54, 'out_features': 21}
# Result: True
#
#
# Test: 499
# Params: {'in_samples': 44, 'in_features': 75, 'out_features': 64}
# Result: True
#
#
# Test: 500
# Params: {'in_samples': 112, 'in_features': 78, 'out_features': 75}
# Result: True
#
#
# Test: 501
# Params: {'in_samples': 67, 'in_features': 53, 'out_features': 41}
# Result: True
#
#
# Test: 502
# Params: {'in_samples': 96, 'in_features': 46, 'out_features': 87}
# Result: True
#
#
# Test: 503
# Params: {'in_samples': 98, 'in_features': 41, 'out_features': 76}
# Result: True
#
#
# Test: 504
# Params: {'in_samples': 184, 'in_features': 17, 'out_features': 58}
# Result: True
#
#
# Test: 505
# Params: {'in_samples': 70, 'in_features': 42, 'out_features': 45}
# Result: True
#
#
# Test: 506
# Params: {'in_samples': 85, 'in_features': 37, 'out_features': 97}
# Result: True
#
#
# Test: 507
# Params: {'in_samples': 50, 'in_features': 5, 'out_features': 53}
# Result: True
#
#
# Test: 508
# Params: {'in_samples': 124, 'in_features': 59, 'out_features': 6}
# Result: True
#
#
# Test: 509
# Params: {'in_samples': 97, 'in_features': 61, 'out_features': 71}
# Result: True
#
#
# Test: 510
# Params: {'in_samples': 106, 'in_features': 15, 'out_features': 3}
# Result: True
#
#
# Test: 511
# Params: {'in_samples': 53, 'in_features': 23, 'out_features': 9}
# Result: True
#
#
# Test: 512
# Params: {'in_samples': 118, 'in_features': 54, 'out_features': 59}
# Result: True
#
#
# Test: 513
# Params: {'in_samples': 155, 'in_features': 15, 'out_features': 1}
# Result: True
#
#
# Test: 514
# Params: {'in_samples': 94, 'in_features': 12, 'out_features': 7}
# Result: True
#
#
# Test: 515
# Params: {'in_samples': 11, 'in_features': 11, 'out_features': 43}
# Result: True
#
#
# Test: 516
# ...
# Result: True
#
#
# Test: 831
# Params: {'in_samples': 77, 'in_features': 79, 'out_features': 10}
# Result: True
#
#
# Test: 832
# Params: {'in_samples': 65, 'in_features': 88, 'out_features': 9}
# Result: True
#
#
# Test: 833
# Params: {'in_samples': 2, 'in_features': 57, 'out_features': 12}
# Result: True
#
#
# Test: 834
# Params: {'in_samples': 102, 'in_features': 17, 'out_features': 32}
# Result: True
#
#
# Test: 835
# Params: {'in_samples': 120, 'in_features': 65, 'out_features': 63}
#  86%|██████████████████████████████████▎     | 858/1000 [00:06<00:01, 98.65it/s]
# Result: True
#
#
# Test: 836
# Params: {'in_samples': 91, 'in_features': 95, 'out_features': 79}
# Result: True
#
#
# Test: 837
# Params: {'in_samples': 151, 'in_features': 24, 'out_features': 51}
# Result: True
#
#
# Test: 838
# Params: {'in_samples': 143, 'in_features': 3, 'out_features': 55}
# Result: True
#
#
# Test: 839
# Params: {'in_samples': 83, 'in_features': 100, 'out_features': 65}
# Result: True
#
#
# Test: 840
# Params: {'in_samples': 113, 'in_features': 7, 'out_features': 19}
# Result: True
#
#
# Test: 841
# Params: {'in_samples': 132, 'in_features': 27, 'out_features': 97}
# Result: True
#
#
# Test: 842
# Params: {'in_samples': 26, 'in_features': 1, 'out_features': 5}
# Result: True
#
#
# Test: 843
# Params: {'in_samples': 34, 'in_features': 26, 'out_features': 63}
# Result: True
#
#
# Test: 844
# Params: {'in_samples': 19, 'in_features': 75, 'out_features': 10}
# Result: True
#
#
# Test: 845
# Params: {'in_samples': 130, 'in_features': 43, 'out_features': 43}
# Result: True
#
#
# Test: 846
# Params: {'in_samples': 20, 'in_features': 61, 'out_features': 91}
# Result: True
#
#
# Test: 847
# Params: {'in_samples': 149, 'in_features': 99, 'out_features': 16}
# Result: True
#
#
# Test: 848
# Params: {'in_samples': 14, 'in_features': 19, 'out_features': 12}
# Result: True
#
#
# Test: 849
# Params: {'in_samples': 44, 'in_features': 66, 'out_features': 43}
# Result: True
#
#
# Test: 850
# Params: {'in_samples': 21, 'in_features': 80, 'out_features': 78}
# Result: True
#
#
# Test: 851
# Params: {'in_samples': 191, 'in_features': 65, 'out_features': 99}
# Result: True
#
#
# Test: 852
# Params: {'in_samples': 142, 'in_features': 82, 'out_features': 13}
# Result: True
#
#
# Test: 853
# Params: {'in_samples': 183, 'in_features': 55, 'out_features': 52}
# Result: True
#
#
# Test: 854
# Params: {'in_samples': 38, 'in_features': 81, 'out_features': 60}
# Result: True
#
#
# Test: 855
# Params: {'in_samples': 172, 'in_features': 100, 'out_features': 4}
# Result: True
#
#
# Test: 856
# Params: {'in_samples': 125, 'in_features': 9, 'out_features': 90}
# Result: True
#
#
# Test: 857
# Params: {'in_samples': 190, 'in_features': 37, 'out_features': 57}
# Result: True
#
#
# Test: 858
# Params: {'in_samples': 124, 'in_features': 18, 'out_features': 85}
# Result: True
#
#
# Test: 859
# Params: {'in_samples': 167, 'in_features': 15, 'out_features': 54}
# Result: True
#
#
# Test: 860
# Params: {'in_samples': 24, 'in_features': 30, 'out_features': 98}
# Result: True
#
#
# Test: 861
# Params: {'in_samples': 151, 'in_features': 73, 'out_features': 81}
#  88%|███████████████████████████████████▏    | 880/1000 [00:06<00:01, 94.50it/s]
# Result: True
#
#
# Test: 862
# Params: {'in_samples': 118, 'in_features': 66, 'out_features': 90}
# Result: True
#
#
# Test: 863
# Params: {'in_samples': 9, 'in_features': 68, 'out_features': 77}
# Result: True
#
#
# Test: 864
# Params: {'in_samples': 166, 'in_features': 89, 'out_features': 55}
# Result: True
#
#
# Test: 865
# Params: {'in_samples': 132, 'in_features': 3, 'out_features': 79}
# Result: True
#
#
# Test: 866
# Params: {'in_samples': 106, 'in_features': 85, 'out_features': 18}
# Result: True
#
#
# Test: 867
# Params: {'in_samples': 191, 'in_features': 28, 'out_features': 61}
# Result: True
#
#
# Test: 868
# Params: {'in_samples': 159, 'in_features': 20, 'out_features': 54}
# Result: True
#
#
# Test: 869
# Params: {'in_samples': 12, 'in_features': 98, 'out_features': 90}
# Result: True
#
#
# Test: 870
# Params: {'in_samples': 112, 'in_features': 80, 'out_features': 18}
# Result: True
#
#
# Test: 871
# Params: {'in_samples': 72, 'in_features': 80, 'out_features': 28}
# Result: True
#
#
# Test: 872
# Params: {'in_samples': 139, 'in_features': 13, 'out_features': 11}
# Result: True
#
#
# Test: 873
# Params: {'in_samples': 112, 'in_features': 70, 'out_features': 85}
# Result: True
#
#
# Test: 874
# Params: {'in_samples': 19, 'in_features': 87, 'out_features': 24}
# Result: True
#
#
# Test: 875
# Params: {'in_samples': 182, 'in_features': 48, 'out_features': 96}
# Result: True
#
#
# Test: 876
# Params: {'in_samples': 148, 'in_features': 52, 'out_features': 60}
# Result: True
#
#
# Test: 877
# Params: {'in_samples': 87, 'in_features': 39, 'out_features': 22}
# Result: True
#
#
# Test: 878
# Params: {'in_samples': 154, 'in_features': 27, 'out_features': 66}
# Result: True
#
#
# Test: 879
# Params: {'in_samples': 185, 'in_features': 52, 'out_features': 97}
# Result: True
#
#
# Test: 880
# Params: {'in_samples': 143, 'in_features': 49, 'out_features': 12}
# Result: True
#
#
# Test: 881
# Params: {'in_samples': 15, 'in_features': 29, 'out_features': 13}
# Result: True
#
#
# Test: 882
# Params: {'in_samples': 93, 'in_features': 63, 'out_features': 63}
#  91%|███████████████████████████████████▌   | 913/1000 [00:06<00:00, 128.74it/s]
# Result: True
#
#
# Test: 883
# Params: {'in_samples': 77, 'in_features': 85, 'out_features': 64}
# Result: True
#
#
# Test: 884
# Params: {'in_samples': 167, 'in_features': 28, 'out_features': 61}
# Result: True
#
#
# Test: 885
# Params: {'in_samples': 162, 'in_features': 98, 'out_features': 91}
# Result: True
#
#
# Test: 886
# Params: {'in_samples': 8, 'in_features': 29, 'out_features': 81}
# Result: True
#
#
# Test: 887
# Params: {'in_samples': 41, 'in_features': 2, 'out_features': 99}
# Result: True
#
#
# Test: 888
# Params: {'in_samples': 23, 'in_features': 25, 'out_features': 50}
# Result: True
#
#
# Test: 889
# Params: {'in_samples': 3, 'in_features': 42, 'out_features': 88}
# Result: True
#
#
# Test: 890
# Params: {'in_samples': 39, 'in_features': 57, 'out_features': 49}
# Result: True
#
#
# Test: 891
# Params: {'in_samples': 184, 'in_features': 45, 'out_features': 27}
# Result: True
#
#
# Test: 892
# Params: {'in_samples': 140, 'in_features': 79, 'out_features': 81}
# Result: True
#
#
# Test: 893
# Params: {'in_samples': 62, 'in_features': 97, 'out_features': 87}
# Result: True
#
#
# Test: 894
# Params: {'in_samples': 91, 'in_features': 27, 'out_features': 92}
# Result: True
#
#
# Test: 895
# Params: {'in_samples': 100, 'in_features': 25, 'out_features': 99}
# Result: True
#
#
# Test: 896
# Params: {'in_samples': 1, 'in_features': 79, 'out_features': 89}
# Result: True
#
#
# Test: 897
# Params: {'in_samples': 2, 'in_features': 47, 'out_features': 4}
# Result: True
#
#
# Test: 898
# Params: {'in_samples': 178, 'in_features': 43, 'out_features': 26}
# Result: True
#
#
# Test: 899
# Params: {'in_samples': 24, 'in_features': 27, 'out_features': 65}
# Result: True
#
#
# Test: 900
# Params: {'in_samples': 87, 'in_features': 93, 'out_features': 62}
# Result: True
#
#
# Test: 901
# Params: {'in_samples': 131, 'in_features': 46, 'out_features': 28}
# Result: True
#
#
# Test: 902
# Params: {'in_samples': 99, 'in_features': 40, 'out_features': 30}
# Result: True
#
#
# Test: 903
# Params: {'in_samples': 29, 'in_features': 82, 'out_features': 82}
# Result: True
#
#
# Test: 904
# Params: {'in_samples': 106, 'in_features': 97, 'out_features': 19}
# Result: True
#
#
# Test: 905
# Params: {'in_samples': 197, 'in_features': 21, 'out_features': 26}
# Result: True
#
#
# Test: 906
# Params: {'in_samples': 150, 'in_features': 61, 'out_features': 51}
# Result: True
#
#
# Test: 907
# Params: {'in_samples': 16, 'in_features': 9, 'out_features': 73}
# Result: True
#
#
# Test: 908
# Params: {'in_samples': 93, 'in_features': 62, 'out_features': 34}
# Result: True
#
#
# Test: 909
# Params: {'in_samples': 55, 'in_features': 17, 'out_features': 88}
# Result: True
#
#
# Test: 910
# Params: {'in_samples': 173, 'in_features': 73, 'out_features': 11}
# Result: True
#
#
# Test: 911
# Params: {'in_samples': 17, 'in_features': 46, 'out_features': 20}
# Result: True
#
#
# Test: 912
# Params: {'in_samples': 55, 'in_features': 32, 'out_features': 35}
# Result: True
#
#
# Test: 913
# Params: {'in_samples': 36, 'in_features': 98, 'out_features': 18}
# Result: True
#
#
# Test: 914
# Params: {'in_samples': 104, 'in_features': 4, 'out_features': 57}
# Result: True
#
#
# Test: 915
# Params: {'in_samples': 32, 'in_features': 91, 'out_features': 79}
# Result: True
#
#
# Test: 916
# Params: {'in_samples': 182, 'in_features': 81, 'out_features': 38}
# Result: True
#
#
# Test: 917
# Params: {'in_samples': 4, 'in_features': 35, 'out_features': 94}
# Result: True
#
#
# Test: 918
# Params: {'in_samples': 180, 'in_features': 18, 'out_features': 36}
# Result: True
#
#
# Test: 919
# Params: {'in_samples': 32, 'in_features': 98, 'out_features': 79}
# Result: True
#
#
# Test: 920
# Params: {'in_samples': 39, 'in_features': 2, 'out_features': 79}
# Result: True
#
#
# Test: 921
# Params: {'in_samples': 74, 'in_features': 5, 'out_features': 6}
# Result: True
#
#
# Test: 922
# Params: {'in_samples': 16, 'in_features': 81, 'out_features': 100}
# Result: True
#
#
# Test: 923
# Params: {'in_samples': 150, 'in_features': 73, 'out_features': 40}
# Result: True
#
#
# Test: 924
# Params: {'in_samples': 129, 'in_features': 31, 'out_features': 65}
# Result: True
#
#
# Test: 925
# Params: {'in_samples': 2, 'in_features': 92, 'out_features': 65}
# Result: True
#
#
# Test: 926
# Params: {'in_samples': 55, 'in_features': 56, 'out_features': 44}
# Result: True
#
#
# Test: 927
# Params: {'in_samples': 112, 'in_features': 98, 'out_features': 84}
#  95%|█████████████████████████████████████▏ | 953/1000 [00:07<00:00, 152.23it/s]
# Result: True
#
#
# Test: 928
# Params: {'in_samples': 76, 'in_features': 6, 'out_features': 73}
# Result: True
#
#
# Test: 929
# Params: {'in_samples': 55, 'in_features': 49, 'out_features': 14}
# Result: True
#
#
# Test: 930
# Params: {'in_samples': 32, 'in_features': 100, 'out_features': 8}
# Result: True
#
#
# Test: 931
# Params: {'in_samples': 195, 'in_features': 67, 'out_features': 60}
# Result: True
#
#
# Test: 932
# Params: {'in_samples': 177, 'in_features': 58, 'out_features': 84}
# Result: True
#
#
# Test: 933
# Params: {'in_samples': 14, 'in_features': 23, 'out_features': 49}
# Result: True
#
#
# Test: 934
# Params: {'in_samples': 177, 'in_features': 71, 'out_features': 32}
# Result: True
#
#
# Test: 935
# Params: {'in_samples': 114, 'in_features': 85, 'out_features': 33}
# Result: True
#
#
# Test: 936
# Params: {'in_samples': 93, 'in_features': 15, 'out_features': 73}
# Result: True
#
#
# Test: 937
# Params: {'in_samples': 65, 'in_features': 27, 'out_features': 71}
# Result: True
#
#
# Test: 938
# Params: {'in_samples': 75, 'in_features': 27, 'out_features': 26}
# Result: True
#
#
# Test: 939
# Params: {'in_samples': 106, 'in_features': 94, 'out_features': 77}
# Result: True
#
#
# Test: 940
# Params: {'in_samples': 51, 'in_features': 16, 'out_features': 36}
# Result: True
#
#
# Test: 941
# Params: {'in_samples': 117, 'in_features': 74, 'out_features': 34}
# Result: True
#
#
# Test: 942
# Params: {'in_samples': 54, 'in_features': 2, 'out_features': 54}
# Result: True
#
#
# Test: 943
# Params: {'in_samples': 134, 'in_features': 59, 'out_features': 29}
# Result: True
#
#
# Test: 944
# Params: {'in_samples': 101, 'in_features': 23, 'out_features': 39}
# Result: True
#
#
# Test: 945
# Params: {'in_samples': 121, 'in_features': 77, 'out_features': 27}
# Result: True
#
#
# Test: 946
# Params: {'in_samples': 70, 'in_features': 78, 'out_features': 66}
# Result: True
#
#
# Test: 947
# Params: {'in_samples': 41, 'in_features': 69, 'out_features': 84}
# Result: True
#
#
# Test: 948
# Params: {'in_samples': 150, 'in_features': 92, 'out_features': 49}
# Result: True
#
#
# Test: 949
# Params: {'in_samples': 64, 'in_features': 67, 'out_features': 74}
# Result: True
#
#
# Test: 950
# Params: {'in_samples': 3, 'in_features': 82, 'out_features': 47}
# Result: True
#
#
# Test: 951
# Params: {'in_samples': 145, 'in_features': 24, 'out_features': 6}
# Result: True
#
#
# Test: 952
# Params: {'in_samples': 101, 'in_features': 63, 'out_features': 79}
# Result: True
#
#
# Test: 953
# Params: {'in_samples': 56, 'in_features': 38, 'out_features': 9}
# Result: True
#
#
# Test: 954
# Params: {'in_samples': 154, 'in_features': 92, 'out_features': 2}
# Result: True
#
#
# Test: 955
# Params: {'in_samples': 198, 'in_features': 74, 'out_features': 52}
# Result: True
#
#
# Test: 956
# Params: {'in_samples': 165, 'in_features': 6, 'out_features': 37}
# Result: True
#
#
# Test: 957
# Params: {'in_samples': 56, 'in_features': 75, 'out_features': 49}
# Result: True
#
#
# Test: 958
# Params: {'in_samples': 121, 'in_features': 25, 'out_features': 31}
# Result: True
#
#
# Test: 959
# Params: {'in_samples': 61, 'in_features': 13, 'out_features': 72}
# Result: True
#
#
# Test: 960
# Params: {'in_samples': 18, 'in_features': 65, 'out_features': 55}
# Result: True
#
#
# Test: 961
# Params: {'in_samples': 3, 'in_features': 99, 'out_features': 85}
# Result: True
#
#
# Test: 962
# Params: {'in_samples': 180, 'in_features': 18, 'out_features': 17}
#  97%|█████████████████████████████████████▊ | 969/1000 [00:07<00:00, 153.99it/s]
# Result: True
#
#
# Test: 963
# Params: {'in_samples': 7, 'in_features': 71, 'out_features': 22}
# Result: True
#
#
# Test: 964
# Params: {'in_samples': 196, 'in_features': 94, 'out_features': 94}
# Result: True
#
#
# Test: 965
# Params: {'in_samples': 58, 'in_features': 75, 'out_features': 78}
# Result: True
#
#
# Test: 966
# Params: {'in_samples': 47, 'in_features': 79, 'out_features': 99}
# Result: True
#
#
# Test: 967
# Params: {'in_samples': 44, 'in_features': 48, 'out_features': 75}
# Result: True
#
#
# Test: 968
# Params: {'in_samples': 55, 'in_features': 79, 'out_features': 15}
# Result: True
#
#
# Test: 969
# Params: {'in_samples': 40, 'in_features': 59, 'out_features': 48}
# Result: True
#
#
# Test: 970
# Params: {'in_samples': 88, 'in_features': 67, 'out_features': 26}
# Result: True
#
#
# Test: 971
# Params: {'in_samples': 189, 'in_features': 81, 'out_features': 89}
# Result: True
#
#
# Test: 972
# Params: {'in_samples': 109, 'in_features': 78, 'out_features': 24}
# Result: True
#
#
# Test: 973
# Params: {'in_samples': 115, 'in_features': 93, 'out_features': 30}
# Result: True
#
#
# Test: 974
# Params: {'in_samples': 115, 'in_features': 83, 'out_features': 54}
# Result: True
#
#
# Test: 975
# Params: {'in_samples': 116, 'in_features': 84, 'out_features': 15}
# Result: True
#
#
# Test: 976
# Params: {'in_samples': 78, 'in_features': 88, 'out_features': 38}
# Result: True
#
#
# Test: 977
# Params: {'in_samples': 47, 'in_features': 37, 'out_features': 99}
# Result: True
#
#
# Test: 978
# Params: {'in_samples': 58, 'in_features': 71, 'out_features': 10}
# Result: True
#
#
# Test: 979
# Params: {'in_samples': 155, 'in_features': 70, 'out_features': 81}
# Result: True
#
#
# Test: 980
# Params: {'in_samples': 169, 'in_features': 84, 'out_features': 1}
# Result: True
#
#
# Test: 981
# Params: {'in_samples': 43, 'in_features': 35, 'out_features': 75}
# Result: True
#
#
# Test: 982
# Params: {'in_samples': 56, 'in_features': 62, 'out_features': 18}
# Result: True
#
#
# Test: 983
# Params: {'in_samples': 164, 'in_features': 77, 'out_features': 99}
# 100%|██████████████████████████████████████| 1000/1000 [00:07<00:00, 133.58it/s]
# Result: True
#
#
# Test: 984
# Params: {'in_samples': 60, 'in_features': 83, 'out_features': 61}
# Result: True
#
#
# Test: 985
# Params: {'in_samples': 70, 'in_features': 47, 'out_features': 32}
# Result: True
#
#
# Test: 986
# Params: {'in_samples': 138, 'in_features': 74, 'out_features': 62}
# Result: True
#
#
# Test: 987
# Params: {'in_samples': 122, 'in_features': 52, 'out_features': 55}
# Result: True
#
#
# Test: 988
# Params: {'in_samples': 163, 'in_features': 86, 'out_features': 98}
# Result: True
#
#
# Test: 989
# Params: {'in_samples': 29, 'in_features': 87, 'out_features': 72}
# Result: True
#
#
# Test: 990
# Params: {'in_samples': 97, 'in_features': 5, 'out_features': 69}
# Result: True
#
#
# Test: 991
# Params: {'in_samples': 119, 'in_features': 8, 'out_features': 57}
# Result: True
#
#
# Test: 992
# Params: {'in_samples': 47, 'in_features': 14, 'out_features': 15}
# Result: True
#
#
# Test: 993
# Params: {'in_samples': 12, 'in_features': 4, 'out_features': 56}
# Result: True
#
#
# Test: 994
# Params: {'in_samples': 179, 'in_features': 19, 'out_features': 19}
# Result: True
#
#
# Test: 995
# Params: {'in_samples': 171, 'in_features': 68, 'out_features': 5}
# Result: True
#
#
# Test: 996
# Params: {'in_samples': 157, 'in_features': 87, 'out_features': 15}
# Result: True
#
#
# Test: 997
# Params: {'in_samples': 194, 'in_features': 88, 'out_features': 90}
# Result: True
#
#
# Test: 998
# Params: {'in_samples': 33, 'in_features': 4, 'out_features': 34}
# Result: True
#
#
# Test: 999
# Params: {'in_samples': 129, 'in_features': 85, 'out_features': 73}
# Result: True
#
#
# 1000 out of 1000 (100.0%) tests passed
