# %% [markdown]
# ### `MSELoss` code

# %%
import numpy as np
import torch # needed for tests
from tqdm import tqdm # needed for tests

# %%
class MSELoss:
    ''' Computes MSE Loss given the input and target '''
    
    ''' * The class implementation will be along the lines of torch.nn.MSELoss in order to 
          enable comparison of this NumPy only implementation and seamless testing
        * Can expect extensive refactoring of the existing code in the days to come
        * As part of refactoring, some code will be de-modularized
        * Old code will be retained at the end of the notebook for reference
    '''
    '''
        TODO:
        * Replace `torch.round()` with `np.allclose()` for tests
        * Optimizing code
    '''
    
    def __init__(
        self,
        size_average = None,
        reduce = None,
        reduction = 'mean',
        verbose = False
        ):
        super(MSELoss, self).__init__()
        
        ''' mandatory parameters '''
        # None
        
        ''' optional parameters '''
        self.reduction = 'reduction'
        
        ''' optional parameters (dummy, yet to be implemented)'''
        self.size_average = size_average
        self.reduce = reduce
        
        ''' additional parameters (different from torch.nn.Conv2D)'''
        self.verbose = verbose
        self.verboseprint = print if self.verbose else lambda *a, **k: None
        self.verboseprint('*** parameters ***')
        self.verboseprint('inplace: {},'.format(self.inplace))
        self.verboseprint('\n')
    
    def forward(self, _input):
        ''' forward pass to perform ReLU activation '''
        
        ''' error checking '''
        if not (isinstance(_input, int) or isinstance(_input, float) or isinstance(_input, np.ndarray)):
            raise Exception('invalid input: input should either be an int, a float, or a NumPy ndarray')
            
        ''' compute ReLU activation '''
        output = np.maximum(0, _input)
        self.verboseprint(output)
        self.verboseprint('\n')
        return output

# %% [markdown]
# ### Standalone test (random input)

# %%
_input = np.random.rand(10, 20, 3) # define a random input

# %%
# get ReLU output with the random input

relu = ReLU(_input) # call an instance of the class with the input
_output = relu.forward(_input) # perform ReLU activation
print("*** ReLU output ***")
print(_output)
# Out:
# *** ReLU output ***
# [[[9.36934338e-01 1.26416454e-01 1.62054411e-01]
#   [2.84821424e-01 7.56079805e-01 5.27152771e-01]
#   [3.30439654e-02 5.84784897e-01 3.59861690e-01]
#   [2.97308746e-01 4.24965291e-01 9.03696851e-01]
#   [4.27484151e-01 6.37278324e-02 2.79207724e-01]
#   [1.69124907e-01 8.11435006e-01 3.51485732e-01]
#   [1.17904414e-02 6.01124691e-01 2.03686670e-01]
#   [8.87569364e-01 5.03877480e-01 9.30781982e-01]
#   [5.32915765e-01 9.56836476e-01 2.28291944e-01]
#   [3.31254988e-01 5.85141363e-01 9.19945827e-01]
#   [7.46091265e-01 4.20470259e-01 3.58519066e-02]
#   [5.18581347e-01 7.58085319e-01 1.05271053e-01]
#   [8.93886870e-01 5.33950449e-01 1.01633895e-01]
#   [6.66256765e-01 2.03474065e-02 1.02041867e-01]
#   [5.38431030e-01 2.21890965e-01 9.10116103e-01]
#   [9.13896280e-01 7.57185333e-01 2.96389880e-01]
#   [8.24166751e-01 8.07635042e-01 2.30457978e-02]
#   [8.81777741e-01 6.62441609e-01 1.94631522e-01]
#   [2.75853337e-01 1.37970674e-01 1.77493508e-01]
#   [6.49974467e-02 7.20074367e-01 2.81653869e-01]]
#
#          [1.6246e-01, 3.6149e-02, 9.9456e-01],
#          [2.2198e-01, 5.3037e-01, 7.2801e-01],
#          [2.1504e-01, 6.5288e-02, 6.5615e-01],
#          [6.0171e-01, 3.4156e-02, 8.3470e-01],
#          [4.4854e-01, 9.3418e-01, 8.0887e-01],
#          [9.5368e-01, 7.6882e-01, 1.0283e-01],
#          [5.5233e-01, 6.2380e-01, 3.9867e-01],
#          [3.9616e-01, 8.5114e-02, 6.6367e-02],
#          [5.6539e-01, 6.0175e-01, 5.0071e-01],
#          [5.7967e-01, 6.9411e-01, 1.6180e-01],
#          [3.6279e-01, 8.6957e-01, 7.7100e-01],
#          [4.7059e-01, 2.9836e-01, 1.4894e-01],
#          [2.8547e-01, 2.9482e-01, 7.7912e-01],
#          [1.0395e-01, 5.0345e-01, 7.1157e-01],
#          [5.7199e-01, 9.3480e-01, 1.9819e-01],
#          [2.0124e-01, 7.8135e-01, 8.9284e-01]],
#
#         [[2.7202e-01, 6.2934e-01, 6.7043e-01],
#          [7.6021e-01, 9.9068e-01, 1.8825e-01],
#          [1.9312e-01, 7.9758e-01, 9.4381e-01],
#          [7.6011e-01, 6.8536e-01, 8.9953e-01],
#          [3.5310e-01, 4.0256e-01, 3.3513e-01],
#          [5.6110e-01, 1.6482e-02, 7.0135e-01],
#          [8.4533e-01, 4.4639e-01, 2.3106e-01],
#          [7.3809e-01, 5.3259e-02, 5.9200e-01],
#          [7.9583e-01, 7.6718e-01, 2.2462e-01],
#          [6.1423e-01, 6.2827e-01, 9.0259e-01],
#          [7.6320e-03, 5.0611e-01, 7.4609e-01],
#          [9.7060e-03, 2.3728e-01, 7.9515e-01],
#          [2.8774e-01, 1.8126e-01, 4.6609e-02],
#          [3.4784e-01, 7.3780e-01, 6.8322e-01],
#          [5.8804e-02, 7.5922e-01, 8.3951e-01],
#          [4.7128e-01, 9.5076e-01, 9.6728e-01],
#          [1.3197e-01, 5.3589e-01, 4.9494e-01],
#          [2.4681e-02, 1.9506e-01, 2.8156e-02],
#          [8.0824e-01, 1.7050e-01, 4.8533e-02],
#          [1.9552e-01, 7.7240e-02, 3.8060e-01]]], dtype=torch.float64)

# %%
# compare outputs of Conv2D and PyTorch
print(torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output))) # need to round the output due to precision difference
# Out:
# True

# %% [markdown]
# ### Extensive tests (random input)

# %%
def run_tests(num_tests):
    ''' sweep different input parameters and test by comparing outputs of ReLU and PyTorch '''
    
    num_passed = 0
    print('Number of tests: {}\n\n'.format(num_tests))
    
    for i in tqdm(range(num_tests)):
        num_dim = np.random.randint(6) + 1 # number of input dimensions
        dim = tuple(np.random.randint(5) + 1 for _ in range(num_dim)) # shape of input
        _input = np.random.rand(*dim) # generate an input based on the dimensions and shape
        print('Test: {}\nInput shape: {}'.format(i, dim))
        
        try:
            # get ReLU output with the random input
            relu = ReLU(_input) # call an instance of the class with the input
            _output = relu.forward(_input) # perform ReLU activation

            # get PyTorch output with the same random input as above
            x = torch.DoubleTensor(_input)
            m = torch.nn.ReLU()
            output = m(x)
            
        except Exception as e:
            print(e)
            print('Result: False\n\n') # treating exception as a failed test
            continue

        # compare outputs of ReLU and PyTorch
        result = torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output)) # need to round the output due to precision difference
        print('Result: {}\n\n'.format(result))
        if result:
            num_passed += 1

    print('{} out of {} ({}%) tests passed'.format(num_passed, num_tests, float(100 * num_passed / num_tests)))

# %%
num_tests = 1000
run_tests(num_tests)
# Out:
# Number of tests: 1000
#   9%|███▌                                    | 90/1000 [00:00<00:01, 897.03it/s]
# Test: 0
# Input shape: (5, 2, 3, 1)
# Result: True
#
#
# Test: 1
# Input shape: (1, 5, 1, 2, 1)
# Result: True
#
#
# Test: 2
# Input shape: (5, 4, 3, 2, 2)
# Result: True
#
#
# Test: 3
# Input shape: (3,)
# Result: True
#
#
# Test: 4
# Input shape: (3, 3, 1, 4, 1, 4)
# Result: True
#
#
# Test: 5
# Input shape: (4, 4, 1, 5, 1)
# Result: True
#
#
# Test: 6
# Input shape: (5, 3, 1)
# Result: True
#
#
# Test: 7
# Input shape: (1,)
# Result: True
#
#
# Test: 8
# Input shape: (5, 4, 5, 4, 1, 5)
# Result: True
#
#
# Test: 9
# Input shape: (2, 5, 2, 3)
# Result: True
#
#
# Test: 10
# Input shape: (2, 1)
# Result: True
#
#
# Test: 11
# Input shape: (4,)
# Result: True
#
#
# Test: 12
# Input shape: (2, 1, 3, 2, 2, 5)
# Result: True
#
#
# Test: 13
# Input shape: (2, 2)
# Result: True
#
#
# Test: 14
# Input shape: (2, 3)
# Result: True
#
#
# Test: 15
# Input shape: (5, 4, 5, 4, 4, 2)
# Result: True
#
#
# Test: 16
# Input shape: (1, 5, 5, 5)
# Result: True
#
#
# Test: 17
# Input shape: (4, 1, 5, 2)
# Result: True
#
#
# Test: 18
# Input shape: (4,)
# Result: True
#
#
# Test: 19
# Input shape: (5, 3, 4, 3)
# Result: True
#
#
# Test: 20
# Input shape: (1, 4, 5, 5)
# Result: True
#
#
# Test: 21
# Input shape: (3,)
# Result: True
#
#
# Test: 22
# Input shape: (5, 3, 4, 1, 1)
# Result: True
#
#
# Test: 23
# Input shape: (4,)
# Result: True
#
#
# Test: 24
# Input shape: (2,)
# Result: True
#
#
# Test: 25
# Input shape: (2, 4, 2)
# Result: True
#
#
# Test: 26
# Input shape: (5,)
# Result: True
#
#
# Test: 27
# Input shape: (2, 5, 4, 1)
# Result: True
#
#
# Test: 28
# Input shape: (4, 4, 3, 5, 4, 3)
# Result: True
#
#
# Test: 29
# Input shape: (1, 5, 1, 5, 2)
# Result: True
#
#
# Test: 30
# Input shape: (3, 2)
# Result: True
#
#
# Test: 31
# Input shape: (4, 2)
# Result: True
#
#
# Test: 32
# Input shape: (1, 1, 1)
# Result: True
#
#
# Test: 33
# Input shape: (4,)
# Result: True
#
#
# Test: 34
# Input shape: (2,)
# Result: True
#
#
# Test: 35
# Input shape: (2, 4)
# Result: True
#
#
# Test: 36
# Input shape: (3,)
# Result: True
#
#
# Test: 37
# Input shape: (4,)
# Result: True
#
#
# Test: 38
# Input shape: (3, 2)
# Result: True
#
#
# Test: 39
# Input shape: (4,)
# Result: True
#
#
# Test: 40
# Input shape: (1, 5, 5, 3, 5)
# Result: True
#
#
# Test: 41
# Input shape: (3, 1)
# Result: True
#
#
# Test: 42
# Input shape: (5, 3, 3, 2)
# Result: True
#
#
# Test: 43
# Input shape: (3, 2, 1, 2, 4, 4)
# Result: True
#
#
# Test: 44
# Input shape: (4, 4, 5)
# Result: True
#
#
# Test: 45
# Input shape: (2, 2)
# Result: True
#
#
# Test: 46
# Input shape: (2, 2, 1)
# Result: True
#
#
# Test: 47
# Input shape: (1, 4, 4, 5, 2)
# Result: True
#
#
# Test: 48
# Input shape: (5, 5, 5, 2, 3, 2)
# Result: True
#
#
# Test: 49
# Input shape: (1, 3, 1)
# Result: True
#
#
# Test: 50
# Input shape: (3, 2)
# Result: True
#
#
# Test: 51
# Input shape: (2, 2, 4)
# Result: True
#
#
# Test: 52
# Input shape: (2, 4, 4, 3)
# Result: True
#
#
# Test: 53
# Input shape: (4, 5, 1)
# Result: True
#
#
# Test: 54
# Input shape: (1,)
# Result: True
#
#
# Test: 55
# Input shape: (3, 2)
# Result: True
#
#
# Test: 56
# Input shape: (3, 5, 4, 1)
# Result: True
#
#
# Test: 57
# Input shape: (1, 4, 4, 1, 2)
# Result: True
#
#
# Test: 58
# Input shape: (1, 3, 4)
# Result: True
#
#
# Test: 59
# Input shape: (5, 4, 2, 4)
# Result: True
#
#
# Test: 60
# Input shape: (5, 4, 3, 1)
# Result: True
#
#
# Test: 61
# Input shape: (3, 4, 5, 4)
# Result: True
#
#
# Test: 62
# Input shape: (3, 5, 3)
# Result: True
#
#
# Test: 63
# Input shape: (2, 4, 4, 3, 2, 5)
# Result: True
#
#
# Test: 64
# Input shape: (1,)
# Result: True
#
#
# Test: 65
# Input shape: (5, 1)
# Result: True
#
#
# Test: 66
# Input shape: (5, 3)
# Result: True
#
#
# Test: 67
# Input shape: (3, 1)
# Result: True
#
#
# Test: 68
# Input shape: (2, 3, 4, 2, 3, 5)
# Result: True
#
#
# Test: 69
# Input shape: (3, 1, 4, 3, 3, 3)
# Result: True
#
#
# Test: 70
# Input shape: (1, 2, 1)
# Result: True
#
#
# Test: 71
# Input shape: (3, 2, 2, 3)
# Result: True
#
#
# Test: 72
# Input shape: (1, 1, 2, 3)
# Result: True
#
#
# Test: 73
# Input shape: (4,)
# Result: True
#
#
# Test: 74
# Input shape: (5, 2, 2, 2, 5)
# Result: True
#
#
# Test: 75
# Input shape: (1, 2)
# Result: True
#
#
# Test: 76
# Input shape: (1, 4)
# Result: True
#
#
# Test: 77
# Input shape: (3, 2)
# Result: True
#
#
# Test: 78
# Input shape: (3, 1)
# Result: True
#
#
# Test: 79
# Input shape: (1, 2)
# Result: True
#
#
# Test: 80
# Input shape: (3, 2, 4, 2, 1)
# Result: True
#
#
# Test: 81
# Input shape: (4, 5, 2, 3, 2)
# Result: True
#
#
# Test: 82
# Input shape: (3,)
# Result: True
#
#
# Test: 83
# Input shape: (5, 1, 5)
# Result: True
#
#
# Test: 84
# Input shape: (4, 3)
# Result: True
#
#
# Test: 85
# Input shape: (5, 4, 2, 3, 2)
# Result: True
#
#
# Test: 86
# Input shape: (4,)
# Result: True
#
#
# Test: 87
# Input shape: (2, 3)
# Result: True
#
#
# Test: 88
# Input shape: (5, 1, 2, 5)
# Result: True
#
#
# Test: 89
# Input shape: (3, 5, 3, 1, 5, 1)
# Result: True
#
#
# Test: 90
# Input shape: (2, 1)
# Result: True
#
#
# Test: 91
# Input shape: (2, 4)
# Result: True
#
#
# Test: 92
# Input shape: (4, 2, 4, 3)
# Result: True
#
#
# Test: 93
# Input shape: (3, 2)
# Result: True
#
#
# Test: 94
# Input shape: (3,)
# Result: True
#
#
# Test: 95
# Input shape: (2, 1, 3)
# Result: True
#
#
# Test: 96
# Input shape: (5,)
# Result: True
#
#
# Test: 97
# Input shape: (2, 4, 5, 2, 2)
# Result: True
#
#
# Test: 98
# Input shape: (3, 5)
# Result: True
#
#
# Test: 99
# Input shape: (2, 5, 4, 3, 2, 4)
# Result: True
#
#
# Test: 100
# Input shape: (5, 3, 5, 1, 5)
# Result: True
#
#
# Test: 101
# Input shape: (3, 4)
# Result: True
#
#
# Test: 102
# Input shape: (5, 2, 2, 1, 1)
# Result: True
#
#
# Test: 103
# Input shape: (3, 3, 3, 5, 5, 5)
# Result: True
#
#
# Test: 104
# Input shape: (3, 2)
# Result: True
#
#
# Test: 105
# Input shape: (3, 4)
# Result: True
#
#
# Test: 106
# Input shape: (3, 3, 1, 2, 5, 4)
# Result: True
#
#
# Test: 107
# Input shape: (2, 3, 4, 1, 5)
# Result: True
#
#
# Test: 108
# Input shape: (2, 5)
# Result: True
#
#
# Test: 109
# Input shape: (1, 3)
# Result: True
#
#
# Test: 110
# Input shape: (3, 3, 3)
# Result: True
#
#
# Test: 111
# Input shape: (4, 1)
# Result: True
#
#
# Test: 112
# Input shape: (2, 1, 2)
# Result: True
#
#
# Test: 113
# Input shape: (3, 1, 5, 5, 2)
# Result: True
#
#
# Test: 114
# Input shape: (3, 4, 3, 4, 3, 5)
# Result: True
#
#
# Test: 115
# Input shape: (4, 5)
# Result: True
#
#
# Test: 116
# Input shape: (1, 1, 2, 2)
# Result: True
#
#
# Test: 117
# Input shape: (5, 4, 1)
# Result: True
#
#
# Test: 118
# Input shape: (2, 2, 4, 1, 1)
# Result: True
#
#
# Test: 119
# Input shape: (2, 1, 4, 4, 2)
# Result: True
#
#
# Test: 120
# Input shape: (1, 4, 1, 5, 3, 2)
# Result: True
#
#
# Test: 121
# Input shape: (1, 3, 1, 2, 5)
# Result: True
#
#
# Test: 122
# Input shape: (1,)
# Result: True
#
#
# Test: 123
# Input shape: (3, 4, 4, 3, 4, 3)
# Result: True
#
#
# Test: 124
# Input shape: (5, 3, 4, 4)
# Result: True
#
#
# Test: 125
# Input shape: (1, 3)
# Result: True
#
#
# Test: 126
# Input shape: (3,)
# Result: True
#
#
# Test: 127
# Input shape: (5, 4, 3, 5, 5, 5)
#  30%|███████████▌                           | 295/1000 [00:00<00:00, 816.74it/s]
# Result: True
#
#
# Test: 128
# Input shape: (2, 5, 2, 2)
# Result: True
#
#
# Test: 129
# Input shape: (5, 4, 4, 3)
# Result: True
#
#
# Test: 130
# Input shape: (5, 3, 3, 2, 1, 3)
# Result: True
#
#
# Test: 131
# Input shape: (3, 1, 3)
# Result: True
#
#
# Test: 132
# Input shape: (2, 3, 4, 3, 3, 2)
# Result: True
#
#
# Test: 133
# Input shape: (1, 2)
# Result: True
#
#
# Test: 134
# Input shape: (5, 2, 1)
# Result: True
#
#
# Test: 135
# Input shape: (5, 5, 4, 3)
# Result: True
#
#
# Test: 136
# Input shape: (1, 3, 5, 2)
# Result: True
#
#
# Test: 137
# Input shape: (3, 4, 2, 3, 1)
# Result: True
#
#
# Test: 138
# Input shape: (5, 3, 1, 5, 5, 1)
# Result: True
#
#
# Test: 139
# Input shape: (4, 4, 1, 1, 4)
# Result: True
#
#
# Test: 140
# Input shape: (3, 5, 5, 4, 5)
# Result: True
#
#
# Test: 141
# Input shape: (3, 5, 4)
# Result: True
#
#
# Test: 142
# Input shape: (3, 1, 5, 5, 2)
# Result: True
#
#
# Test: 143
# Input shape: (3, 1, 1, 1, 5, 1)
# Result: True
#
#
# Test: 144
# Input shape: (1, 3, 4, 1, 2, 1)
# Result: True
#
#
# Test: 145
# Input shape: (4, 2)
# Result: True
#
#
# Test: 146
# Input shape: (4, 5, 2, 3)
# Result: True
#
#
# Test: 147
# Input shape: (3, 5, 3, 4, 4, 2)
# Result: True
#
#
# Test: 148
# Input shape: (1,)
# Result: True
#
#
# Test: 149
# Input shape: (1, 5, 5, 5, 5)
# Result: True
#
#
# Test: 150
# Input shape: (3,)
# Result: True
#
#
# Test: 151
# Input shape: (1, 2, 1, 3)
# Result: True
#
#
# Test: 152
# Input shape: (5, 1, 3, 2)
# Result: True
#
#
# Test: 153
# Input shape: (4, 1, 1, 1, 1)
# Result: True
#
#
# Test: 154
# Input shape: (3, 2)
# Result: True
#
#
# Test: 155
# Input shape: (4, 5, 1)
# Result: True
#
#
# Test: 156
# Input shape: (2, 2)
# Result: True
#
#
# Test: 157
# Input shape: (5,)
# Result: True
#
#
# Test: 158
# Input shape: (1, 1)
# Result: True
#
#
# Test: 159
# Input shape: (1, 4, 3, 1, 4)
# Result: True
#
#
# Test: 160
# Input shape: (1,)
# Result: True
#
#
# Test: 161
# Input shape: (2, 5, 2, 1, 5)
# Result: True
#
#
# Test: 162
# Input shape: (2, 4, 1, 5, 1)
# Result: True
#
#
# Test: 163
# Input shape: (2,)
# Result: True
#
#
# Test: 164
# Input shape: (1,)
# Result: True
#
#
# Test: 165
# Input shape: (4, 2, 1)
# Result: True
#
#
# Test: 166
# Input shape: (1, 4, 1, 1, 1, 5)
# Result: True
#
#
# Test: 167
# Input shape: (3, 4, 2)
# Result: True
#
#
# Test: 168
# Input shape: (4, 2, 5, 1, 1, 1)
# Result: True
#
#
# Test: 169
# Input shape: (5, 2, 4, 5)
# Result: True
#
#
# Test: 170
# Input shape: (5, 2, 5)
# Result: True
#
#
# Test: 171
# Input shape: (5, 4)
# Result: True
#
#
# Test: 172
# Input shape: (1, 2)
# Result: True
#
#
# Test: 173
# Input shape: (2, 5)
# Result: True
#
#
# Test: 174
# Input shape: (1, 5)
# Result: True
#
#
# Test: 175
# Input shape: (3,)
# Result: True
#
#
# Test: 176
# Input shape: (5, 4)
# Result: True
#
#
# Test: 177
# Input shape: (2, 5, 4, 4)
# Result: True
#
#
# Test: 178
# Input shape: (3, 5, 3)
# Result: True
#
#
# Test: 179
# Input shape: (2, 3, 1, 2, 4, 5)
# Result: True
#
#
# Test: 180
# Input shape: (2,)
# Result: True
#
#
# Test: 181
# Input shape: (1, 5, 3, 5, 4)
# Result: True
#
#
# Test: 182
# Input shape: (1, 4)
# Result: True
#
#
# Test: 183
# Input shape: (4, 5)
# Result: True
#
#
# Test: 184
# Input shape: (2, 3, 4, 2, 4)
# Result: True
#
#
# Test: 185
# Input shape: (2,)
# Result: True
#
#
# Test: 186
# Input shape: (4, 5, 1, 4)
# Result: True
#
#
# Test: 187
# Input shape: (1, 3, 3, 4, 4)
# Result: True
#
#
# Test: 188
# Input shape: (3, 5, 1, 2, 5, 3)
# Result: True
#
#
# Test: 189
# Input shape: (1, 5, 2, 1, 1)
# Result: True
#
#
# Test: 190
# Input shape: (4, 5)
# Result: True
#
#
# Test: 191
# Input shape: (4, 2)
# Result: True
#
#
# Test: 192
# Input shape: (2, 2, 2, 1, 4, 4)
# Result: True
#
#
# Test: 193
# Input shape: (4, 2, 3, 5)
# Result: True
#
#
# Test: 194
# Input shape: (1, 2)
# Result: True
#
#
# Test: 195
# Input shape: (4, 1, 1, 5, 2)
# Result: True
#
#
# Test: 196
# Input shape: (1, 5, 4)
# Result: True
#
#
# Test: 197
# Input shape: (5, 3, 3, 4, 5, 1)
# Result: True
#
#
# Test: 198
# Input shape: (5, 2, 4)
# Result: True
#
#
# Test: 199
# Input shape: (1, 2, 2)
# Result: True
#
#
# Test: 200
# Input shape: (2, 1, 3)
# Result: True
#
#
# Test: 201
# Input shape: (2, 2, 3, 1, 1, 1)
# Result: True
#
#
# Test: 202
# Input shape: (3, 3, 3, 5, 1)
# Result: True
#
#
# Test: 203
# Input shape: (2, 1, 4, 1, 4)
# Result: True
#
#
# Test: 204
# Input shape: (4, 5, 2, 2, 2)
# Result: True
#
#
# Test: 205
# Input shape: (5,)
# Result: True
#
#
# Test: 206
# Input shape: (1, 3, 3, 3)
# Result: True
#
#
# Test: 207
# Input shape: (2, 2, 3, 5)
# Result: True
#
#
# Test: 208
# Input shape: (3, 2, 2, 1, 2)
# Result: True
#
#
# Test: 209
# Input shape: (1, 1, 5, 3)
# Result: True
#
#
# Test: 210
# Input shape: (5, 4, 4)
# Result: True
#
#
# Test: 211
# Input shape: (3, 4)
# Result: True
#
#
# Test: 212
# Input shape: (2, 2, 5, 2)
# Result: True
#
#
# Test: 213
# Input shape: (3,)
# Result: True
#
#
# Test: 214
# Input shape: (1, 2, 3, 4)
# Result: True
#
#
# Test: 215
# Input shape: (2, 2, 2, 4)
# Result: True
#
#
# Test: 216
# Input shape: (1, 3, 3, 2, 4)
# Result: True
#
#
# Test: 217
# Input shape: (3,)
# Result: True
#
#
# Test: 218
# Input shape: (4, 3, 5, 5, 5, 4)
# Result: True
#
#
# Test: 219
# Input shape: (3,)
# Result: True
#
#
# Test: 220
# Input shape: (3,)
# Result: True
#
#
# Test: 221
# Input shape: (1, 1)
# Result: True
#
#
# Test: 222
# Input shape: (5,)
# Result: True
#
#
# Test: 223
# Input shape: (4, 4, 4, 5, 2)
# Result: True
#
#
# Test: 224
# Input shape: (5, 5)
# Result: True
#
#
# Test: 225
# Input shape: (2, 1)
# Result: True
#
#
# Test: 226
# Input shape: (2, 2, 3)
# Result: True
#
#
# Test: 227
# Input shape: (5, 3)
# Result: True
#
#
# Test: 228
# Input shape: (5, 2, 1, 1)
# Result: True
#
#
# Test: 229
# Input shape: (2,)
# Result: True
#
#
# Test: 230
# Input shape: (5, 1, 1, 5)
# Result: True
#
#
# Test: 231
# Input shape: (2, 2, 5)
# Result: True
#
#
# Test: 232
# Input shape: (1, 2, 5, 1)
# Result: True
#
#
# Test: 233
# Input shape: (4,)
# Result: True
#
#
# Test: 234
# Input shape: (1,)
# Result: True
#
#
# Test: 235
# Input shape: (2, 4)
# Result: True
#
#
# Test: 236
# Input shape: (3, 3)
# Result: True
#
#
# Test: 237
# Input shape: (4, 3, 2, 2, 5)
# Result: True
#
#
# Test: 238
# Input shape: (3,)
# Result: True
#
#
# Test: 239
# Input shape: (1, 4, 5)
# Result: True
#
#
# Test: 240
# Input shape: (4, 1, 2, 3, 1)
# Result: True
#
#
# Test: 241
# Input shape: (3, 5, 4, 2)
# Result: True
#
#
# Test: 242
# Input shape: (2, 3, 5)
# Result: True
#
#
# Test: 243
# Input shape: (1, 1, 1)
# Result: True
#
#
# Test: 244
# Input shape: (2, 5)
# Result: True
#
#
# Test: 245
# Input shape: (2,)
# Result: True
#
#
# Test: 246
# Input shape: (5,)
# Result: True
#
#
# Test: 247
# Input shape: (3, 4, 3, 2, 3)
# Result: True
#
#
# Test: 248
# Input shape: (4, 5)
# Result: True
#
#
# Test: 249
# Input shape: (5,)
# Result: True
#
#
# Test: 250
# Input shape: (2, 2, 2, 2, 5)
# Result: True
#
#
# Test: 251
# Input shape: (5, 4, 2, 5, 3, 2)
# Result: True
#
#
# Test: 252
# Input shape: (1, 2, 1, 3, 5)
# Result: True
#
#
# Test: 253
# Input shape: (1,)
# Result: True
#
#
# Test: 254
# Input shape: (2, 1)
# Result: True
#
#
# Test: 255
# Input shape: (2, 3, 2, 3, 2, 3)
# Result: True
#
#
# Test: 256
# Input shape: (2, 4, 3)
# Result: True
#
#
# Test: 257
# Input shape: (5, 4, 5)
# Result: True
#
#
# Test: 258
# Input shape: (2, 2, 3, 4, 5)
# Result: True
#
#
# Test: 259
# Input shape: (1, 4, 1)
# Result: True
#
#
# Test: 260
# Input shape: (3, 4)
# Result: True
#
#
# Test: 261
# Input shape: (4, 4, 5, 3, 3, 1)
# Result: True
#
#
# Test: 262
# Input shape: (1, 5)
# Result: True
#
#
# Test: 263
# Input shape: (1, 5, 3)
# Result: True
#
#
# Test: 264
# Input shape: (2, 4, 5, 4, 5, 1)
# Result: True
#
#
# Test: 265
# Input shape: (3, 1, 5, 4)
# Result: True
#
#
# Test: 266
# Input shape: (3, 3)
# Result: True
#
#
# Test: 267
# Input shape: (1, 3, 4, 4, 5, 4)
# Result: True
#
#
# Test: 268
# Input shape: (4, 5)
# Result: True
#
#
# Test: 269
# Input shape: (2, 2, 1, 1, 2, 5)
# Result: True
#
#
# Test: 270
# Input shape: (3, 2, 2)
# Result: True
#
#
# Test: 271
# Input shape: (4,)
# Result: True
#
#
# Test: 272
# Input shape: (3, 3, 5, 4)
# Result: True
#
#
# Test: 273
# Input shape: (4, 3, 5, 3, 3)
# Result: True
#
#
# Test: 274
# Input shape: (4, 2, 1)
# Result: True
#
#
# Test: 275
# Input shape: (5, 4, 5, 2, 3)
# Result: True
#
#
# Test: 276
# Input shape: (4, 5, 4, 5)
# Result: True
#
#
# Test: 277
# Input shape: (1, 5, 1, 5, 2, 5)
# Result: True
#
#
# Test: 278
# Input shape: (2, 5, 1, 4)
# Result: True
#
#
# Test: 279
# Input shape: (2, 5, 4, 2, 4)
# Result: True
#
#
# Test: 280
# Input shape: (4, 2, 4)
# Result: True
#
#
# Test: 281
# Input shape: (5, 1)
# Result: True
#
#
# Test: 282
# Input shape: (4, 3, 3, 2, 5)
# Result: True
#
#
# Test: 283
# Input shape: (1,)
# Result: True
#
#
# Test: 284
# Input shape: (2, 1, 4)
# Result: True
#
#
# Test: 285
# Input shape: (5, 2, 1, 5)
# Result: True
#
#
# Test: 286
# Input shape: (4, 2, 3, 3)
# Result: True
#
#
# Test: 287
# Input shape: (5, 1, 1, 4, 1, 1)
# Result: True
#
#
# Test: 288
# Input shape: (3, 2, 2, 2, 5, 2)
# Result: True
#
#
# Test: 289
# Input shape: (1, 1, 4, 1, 3)
# Result: True
#
#
# Test: 290
# Input shape: (1, 5, 4, 3)
# Result: True
#
#
# Test: 291
# Input shape: (4, 1)
# Result: True
#
#
# Test: 292
# Input shape: (5, 5, 3, 2, 4, 1)
# Result: True
#
#
# Test: 293
# Input shape: (1, 5, 3, 4)
# Result: True
#
#
# Test: 294
# Input shape: (2, 5, 3, 5, 1, 4)
# Result: True
#
#
# Test: 295
# Input shape: (4, 5, 1)
# Result: True
#
#
# Test: 296
# Input shape: (1, 3, 4, 2, 3)
# Result: True
#
#
# Test: 297
# Input shape: (2, 5, 1, 2, 1, 3)
# Result: True
#
#
# Test: 298
# Input shape: (2, 4)
# Result: True
#
#
# Test: 299
# Input shape: (4, 5, 3, 4, 3)
# Result: True
#
#
# Test: 300
# Input shape: (5, 2)
# Result: True
#
#
# Test: 301
# Input shape: (5,)
# Result: True
#
#
# Test: 302
# Input shape: (2, 2, 2, 2, 4)
# Result: True
#
#
# Test: 303
# Input shape: (2, 4, 2, 2)
# Result: True
#
#
# Test: 304
# Input shape: (3, 4, 5, 4, 3, 1)
# Result: True
#
#
# Test: 305
# Input shape: (3, 5, 1, 3, 5)
# Result: True
#
#
# Test: 306
# Input shape: (3, 5, 3, 4, 2)
# Result: True
#
#
# Test: 307
# Input shape: (5, 4, 5)
# Result: True
#
#
# Test: 308
# Input shape: (3, 3)
# Result: True
#
#
# Test: 309
# Input shape: (3, 2, 2)
# Result: True
#
#
# Test: 310
# Input shape: (3, 1, 2, 1)
# Result: True
#
#
# Test: 311
# Input shape: (3, 2, 5, 5, 2)
# Result: True
#
#
# Test: 312
# Input shape: (5,)
# Result: True
#
#
# Test: 313
# Input shape: (5, 3, 5, 2, 3)
# Result: True
#
#
# Test: 314
# Input shape: (2, 5, 5, 5)
# Result: True
#
#
# Test: 315
# Input shape: (5, 5, 5, 2, 2, 1)
# Result: True
#
#
# Test: 316
# Input shape: (5, 5, 1, 2, 1, 5)
# Result: True
#
#
# Test: 317
# Input shape: (3,)
# Result: True
#
#
# Test: 318
# Input shape: (4, 1)
# Result: True
#
#
# Test: 319
# Input shape: (3, 1, 3)
# Result: True
#
#
# Test: 320
# Input shape: (1, 5, 2, 1)
# Result: True
#
#
# Test: 321
# Input shape: (2, 2, 3, 2, 4, 2)
# Result: True
#
#
# Test: 322
# Input shape: (3, 4, 4, 2, 3, 5)
# Result: True
#
#
# Test: 323
# Input shape: (2, 2, 1, 4, 2, 5)
# Result: True
#
#
# Test: 324
# Input shape: (2,)
# Result: True
#
#
# Test: 325
# Input shape: (2, 1, 5, 4, 3, 1)
# Result: True
#
#
# Test: 326
# Input shape: (5, 2, 1, 1, 5)
# Result: True
#
#
# Test: 327
# Input shape: (5,)
# Result: True
#
#
# Test: 328
# Input shape: (4,)
# Result: True
#
#
# Test: 329
# Input shape: (2, 1, 1, 5, 4)
# Result: True
#
#
# Test: 330
# Input shape: (2, 3, 2, 2, 2)
# Result: True
#
#
# Test: 331
# Input shape: (5,)
# Result: True
#
#
# Test: 332
# Input shape: (2, 3, 4)
# Result: True
#
#
# Test: 333
# Input shape: (2, 5, 1, 3, 5)
# Result: True
#
#
# Test: 334
# Input shape: (3,)
# Result: True
#
#
# Test: 335
# Input shape: (4, 2)
# Result: True
#
#
# Test: 336
# Input shape: (4, 2, 4, 3, 3)
# Result: True
#
#
# Test: 337
# Input shape: (5, 3, 5, 2, 2)
# Result: True
#
#
# Test: 338
# Input shape: (2, 5)
# Result: True
#
#
# Test: 339
# Input shape: (2, 2)
# Result: True
#
#
# Test: 340
# Input shape: (3, 4)
# Result: True
#
#
# Test: 341
# Input shape: (2, 4, 2)
# Result: True
#
#
# Test: 342
# Input shape: (4,)
# Result: True
#
#
# Test: 343
# Input shape: (5, 3, 5, 1, 2, 1)
# Result: True
#
#
# Test: 344
# Input shape: (3, 3, 1)
# Result: True
#
#
# Test: 345
# Input shape: (2, 2, 2, 4, 2)
# Result: True
#
#
# Test: 346
# Input shape: (3,)
# Result: True
#
#
# Test: 347
# Input shape: (2,)
# Result: True
#
#
# Test: 348
# Input shape: (4, 3, 4, 5)
# Result: True
#
#
# Test: 349
# Input shape: (4, 1, 4, 4)
# Result: True
#
#
# Test: 350
# Input shape: (5,)
# Result: True
#
#
# Test: 351
# Input shape: (3, 5, 5, 1, 5)
# Result: True
#
#
# Test: 352
# Input shape: (4,)
# Result: True
#
#
# Test: 353
# Input shape: (2, 4, 1, 3)
# Result: True
#
#
# Test: 354
# Input shape: (1, 5)
# Result: True
#
#
# Test: 355
# Input shape: (2, 5, 2, 3)
# Result: True
#
#
# Test: 356
# Input shape: (4, 3, 3)
# Result: True
#
#
# Test: 357
# Input shape: (2,)
# Result: True
#
#
# Test: 358
# Input shape: (2, 3, 4, 1, 1, 5)
# Result: True
#
#
# Test: 359
# Input shape: (4, 1)
# Result: True
#
#
# Test: 360
# Input shape: (4, 5)
# Result: True
#
#
# Test: 361
# Input shape: (3, 5)
# Result: True
#
#
# Test: 362
# Input shape: (3, 2, 1, 4, 2)
# Result: True
#
#
# Test: 363
# Input shape: (3,)
# Result: True
#
#
# Test: 364
# Input shape: (4,)
# Result: True
#
#
# Test: 365
# Input shape: (2,)
# Result: True
#
#
# Test: 366
# Input shape: (4, 1, 4, 1)
# Result: True
#
#
# Test: 367
# Input shape: (2, 1, 2, 4, 1, 4)
# Result: True
#
#
# Test: 368
# Input shape: (2, 4, 2, 3, 3, 5)
# Result: True
#
#
# Test: 369
# Input shape: (5, 3, 4, 2)
# Result: True
#
#
# Test: 370
# Input shape: (5, 1)
# Result: True
#
#
# Test: 371
# Input shape: (2,)
# Result: True
#
#
# Test: 372
# Input shape: (2, 5, 3, 2, 4, 4)
# Result: True
#
#
# Test: 373
# Input shape: (4, 3)
# Result: True
#
#
# Test: 374
# Input shape: (5,)
# Result: True
#
#
# Test: 375
# Input shape: (3, 3, 3)
# Result: True
#
#
# Test: 376
# Input shape: (2, 1, 2, 1, 4, 4)
#  50%|███████████████████▍                   | 499/1000 [00:00<00:00, 880.59it/s]
# Result: True
#
#
# Test: 377
# Input shape: (3,)
# Result: True
#
#
# Test: 378
# Input shape: (5, 1, 3, 3)
# Result: True
#
#
# Test: 379
# Input shape: (4, 4, 3, 3, 1)
# Result: True
#
#
# Test: 380
# Input shape: (2,)
# Result: True
#
#
# Test: 381
# Input shape: (2, 5, 5, 5)
# Result: True
#
#
# Test: 382
# Input shape: (5, 3, 4, 4, 3, 5)
# Result: True
#
#
# Test: 383
# Input shape: (4,)
# Result: True
#
#
# Test: 384
# Input shape: (3, 2, 1, 4, 2)
# Result: True
#
#
# Test: 385
# Input shape: (1, 2, 5, 1, 1)
# Result: True
#
#
# Test: 386
# Input shape: (5, 2, 4, 2, 5)
# Result: True
#
#
# Test: 387
# Input shape: (4, 2)
# Result: True
#
#
# Test: 388
# Input shape: (4, 5)
# Result: True
#
#
# Test: 389
# Input shape: (2, 1, 1, 1, 2, 5)
# Result: True
#
#
# Test: 390
# Input shape: (3, 1, 1)
# Result: True
#
#
# Test: 391
# Input shape: (3,)
# Result: True
#
#
# Test: 392
# Input shape: (3, 4)
# Result: True
#
#
# Test: 393
# Input shape: (2,)
# Result: True
#
#
# Test: 394
# Input shape: (2, 5, 4, 5)
# Result: True
#
#
# Test: 395
# Input shape: (4, 5, 2, 5)
# Result: True
#
#
# Test: 396
# Input shape: (1, 4, 5, 4)
# Result: True
#
#
# Test: 397
# Input shape: (2, 5)
# Result: True
#
#
# Test: 398
# Input shape: (5, 2, 5)
# Result: True
#
#
# Test: 399
# Input shape: (4, 1, 2)
# Result: True
#
#
# Test: 400
# Input shape: (5,)
# Result: True
#
#
# Test: 401
# Input shape: (1, 1)
# Result: True
#
#
# Test: 402
# Input shape: (2, 3)
# Result: True
#
#
# Test: 403
# Input shape: (5, 5, 5)
# Result: True
#
#
# Test: 404
# Input shape: (5, 5, 5, 4, 5, 2)
# Result: True
#
#
# Test: 405
# Input shape: (4, 1, 3, 5, 4)
# Result: True
#
#
# Test: 406
# Input shape: (3, 1, 1)
# Result: True
#
#
# Test: 407
# Input shape: (2, 5, 5, 1)
# Result: True
#
#
# Test: 408
# Input shape: (3, 4)
# Result: True
#
#
# Test: 409
# Input shape: (3, 1, 1)
# Result: True
#
#
# Test: 410
# Input shape: (3, 1)
# Result: True
#
#
# Test: 411
# Input shape: (3, 5, 1, 2)
# Result: True
#
#
# Test: 412
# Input shape: (2, 5)
# Result: True
#
#
# Test: 413
# Input shape: (4, 2, 3, 5)
# Result: True
#
#
# Test: 414
# Input shape: (3, 3, 1, 1, 4, 2)
# Result: True
#
#
# Test: 415
# Input shape: (4,)
# Result: True
#
#
# Test: 416
# Input shape: (1, 3, 1, 1, 2)
# Result: True
#
#
# Test: 417
# Input shape: (3, 5, 4)
# Result: True
#
#
# Test: 418
# Input shape: (2, 4, 3, 4, 1, 1)
# Result: True
#
#
# Test: 419
# Input shape: (3, 4, 5, 2, 2, 4)
# Result: True
#
#
# Test: 420
# Input shape: (4, 1)
# Result: True
#
#
# Test: 421
# Input shape: (5, 1)
# Result: True
#
#
# Test: 422
# Input shape: (4,)
# Result: True
#
#
# Test: 423
# Input shape: (4, 5, 2, 5, 4, 2)
# Result: True
#
#
# Test: 424
# Input shape: (5, 1, 1)
# Result: True
#
#
# Test: 425
# Input shape: (1,)
# Result: True
#
#
# Test: 426
# Input shape: (3, 1, 3, 4, 3, 2)
# Result: True
#
#
# Test: 427
# Input shape: (2, 4)
# Result: True
#
#
# Test: 428
# Input shape: (4, 1)
# Result: True
#
#
# Test: 429
# Input shape: (3, 2)
# Result: True
#
#
# Test: 430
# Input shape: (3, 4, 3, 2)
# Result: True
#
#
# Test: 431
# Input shape: (3, 4, 5, 4, 5, 4)
# Result: True
#
#
# Test: 432
# Input shape: (3, 1)
# Result: True
#
#
# Test: 433
# Input shape: (2, 3, 3)
# Result: True
#
#
# Test: 434
# Input shape: (1, 2)
# Result: True
#
#
# Test: 435
# Input shape: (3, 1, 5, 2)
# Result: True
#
#
# Test: 436
# Input shape: (5, 2)
# Result: True
#
#
# Test: 437
# Input shape: (1, 3, 3, 5)
# Result: True
#
#
# Test: 438
# Input shape: (5, 4, 2, 4, 4, 5)
# Result: True
#
#
# Test: 439
# Input shape: (5, 2)
# Result: True
#
#
# Test: 440
# Input shape: (4, 5)
# Result: True
#
#
# Test: 441
# Input shape: (2, 5, 5)
# Result: True
#
#
# Test: 442
# Input shape: (5, 1, 2, 1)
# Result: True
#
#
# Test: 443
# Input shape: (5,)
# Result: True
#
#
# Test: 444
# Input shape: (3, 4, 3, 3)
# Result: True
#
#
# Test: 445
# Input shape: (4, 1, 4, 3, 3)
# Result: True
#
#
# Test: 446
# Input shape: (5, 1, 5, 2)
# Result: True
#
#
# Test: 447
# Input shape: (4, 4, 4, 3)
# Result: True
#
#
# Test: 448
# Input shape: (2,)
# Result: True
#
#
# Test: 449
# Input shape: (5, 1, 4)
# Result: True
#
#
# Test: 450
# Input shape: (2, 3)
# Result: True
#
#
# Test: 451
# Input shape: (1, 2, 3, 1, 4, 1)
# Result: True
#
#
# Test: 452
# Input shape: (5, 4)
# Result: True
#
#
# Test: 453
# Input shape: (2, 2, 4, 4, 5, 2)
# Result: True
#
#
# Test: 454
# Input shape: (3, 3, 2, 2, 2, 3)
# Result: True
#
#
# Test: 455
# Input shape: (5, 3)
# Result: True
#
#
# Test: 456
# Input shape: (3, 3, 2, 3, 2, 2)
# Result: True
#
#
# Test: 457
# Input shape: (1, 2)
# Result: True
#
#
# Test: 458
# Input shape: (5, 2, 5, 4)
# Result: True
#
#
# Test: 459
# Input shape: (3, 5, 2)
# Result: True
#
#
# Test: 460
# Input shape: (1, 4, 4, 2, 2, 3)
# Result: True
#
#
# Test: 461
# Input shape: (1, 2, 1, 3, 2)
# Result: True
#
#
# Test: 462
# Input shape: (2,)
# Result: True
#
#
# Test: 463
# Input shape: (4,)
# Result: True
#
#
# Test: 464
# Input shape: (1, 5, 3, 4, 4, 4)
# Result: True
#
#
# Test: 465
# Input shape: (1, 2)
# Result: True
#
#
# Test: 466
# Input shape: (5, 2, 3, 3)
# Result: True
#
#
# Test: 467
# Input shape: (4, 4, 2, 4, 1, 4)
# Result: True
#
#
# Test: 468
# Input shape: (3, 2, 3, 5)
# Result: True
#
#
# Test: 469
# Input shape: (1, 2, 5)
# Result: True
#
#
# Test: 470
# Input shape: (2, 4, 3, 4, 5, 2)
# Result: True
#
#
# Test: 471
# Input shape: (5, 3, 4, 3, 4)
# Result: True
#
#
# Test: 472
# Input shape: (4, 3, 2, 5)
# Result: True
#
#
# Test: 473
# Input shape: (3,)
# Result: True
#
#
# Test: 474
# Input shape: (3, 3, 5)
# Result: True
#
#
# Test: 475
# Input shape: (3, 5, 5)
# Result: True
#
#
# Test: 476
# Input shape: (4, 2, 4)
# Result: True
#
#
# Test: 477
# Input shape: (1, 3, 5)
# Result: True
#
#
# Test: 478
# Input shape: (5, 5, 4, 4, 1, 1)
# Result: True
#
#
# Test: 479
# Input shape: (1, 2, 5, 3)
# Result: True
#
#
# Test: 480
# Input shape: (3,)
# Result: True
#
#
# Test: 481
# Input shape: (3, 3, 5, 5, 4)
# Result: True
#
#
# Test: 482
# Input shape: (1, 5, 3, 4, 2, 3)
# Result: True
#
#
# Test: 483
# Input shape: (1, 5, 5, 1)
# Result: True
#
#
# Test: 484
# Input shape: (1, 2, 2)
# Result: True
#
#
# Test: 485
# Input shape: (2, 1)
# Result: True
#
#
# Test: 486
# Input shape: (4,)
# Result: True
#
#
# Test: 487
# Input shape: (1, 2)
# Result: True
#
#
# Test: 488
# Input shape: (3, 5, 5, 1, 1, 3)
# Result: True
#
#
# Test: 489
# Input shape: (4,)
# Result: True
#
#
# Test: 490
# Input shape: (3, 5, 3, 4, 2, 5)
# Result: True
#
#
# Test: 491
# Input shape: (1,)
# Result: True
#
#
# Test: 492
# Input shape: (4,)
# Result: True
#
#
# Test: 493
# Input shape: (2,)
# Result: True
#
#
# Test: 494
# Input shape: (4, 3, 2)
# Result: True
#
#
# Test: 495
# Input shape: (4, 2, 4, 5)
# Result: True
#
#
# Test: 496
# Input shape: (3, 2, 4, 3, 2, 1)
# Result: True
#
#
# Test: 497
# Input shape: (4, 2)
# Result: True
#
#
# Test: 498
# Input shape: (4, 2, 4, 4)
# Result: True
#
#
# Test: 499
# Input shape: (5, 5, 2)
# Result: True
#
#
# Test: 500
# Input shape: (3,)
# Result: True
#
#
# Test: 501
# Input shape: (1, 2, 2, 4)
# Result: True
#
#
# Test: 502
# Input shape: (2, 2, 3, 3, 1)
# Result: True
#
#
# Test: 503
# Input shape: (3, 2)
# Result: True
#
#
# Test: 504
# Input shape: (1, 1, 5, 3, 2)
# Result: True
#
#
# Test: 505
# Input shape: (3, 4, 5, 2)
# Result: True
#
#
# Test: 506
# Input shape: (3, 2, 4, 2)
# Result: True
#
#
# Test: 507
# Input shape: (2, 1, 2, 3, 4, 4)
# Result: True
#
#
# Test: 508
# Input shape: (1, 3, 1, 2)
# Result: True
#
#
# Test: 509
# Input shape: (4, 4, 5, 5, 1)
# Result: True
#
#
# Test: 510
# Input shape: (5, 5, 5, 3)
# Result: True
#
#
# Test: 511
# Input shape: (2, 1, 1, 1, 4)
# Result: True
#
#
# Test: 512
# Input shape: (1, 2)
# Result: True
#
#
# Test: 513
# Input shape: (1, 3, 1, 2, 4, 5)
# Result: True
#
#
# Test: 514
# Input shape: (4, 4, 5, 1, 2, 2)
# Result: True
#
#
# Test: 515
# Input shape: (4, 5, 4, 1, 4, 5)
# Result: True
#
#
# Test: 516
# Input shape: (2, 1, 2, 4)
# Result: True
#
#
# Test: 517
# Input shape: (2, 5)
# Result: True
#
#
# Test: 518
# Input shape: (3, 2)
# Result: True
#
#
# Test: 519
# Input shape: (1,)
# Result: True
#
#
# Test: 520
# Input shape: (1, 5, 2, 4)
# Result: True
#
#
# Test: 521
# Input shape: (4, 1, 1)
# Result: True
#
#
# Test: 522
# Input shape: (5,)
# Result: True
#
#
# Test: 523
# Input shape: (3, 2, 5, 4, 5)
# Result: True
#
#
# Test: 524
# Input shape: (5, 3, 4, 5)
# Result: True
#
#
# Test: 525
# Input shape: (5, 5, 5)
# Result: True
#
#
# Test: 526
# Input shape: (3, 1, 1, 1)
# Result: True
#
#
# Test: 527
# Input shape: (3, 3, 3)
# Result: True
#
#
# Test: 528
# Input shape: (5, 2, 4, 4, 4, 2)
# Result: True
#
#
# Test: 529
# Input shape: (3, 4)
# Result: True
#
#
# Test: 530
# Input shape: (5, 2, 3, 4)
# Result: True
#
#
# Test: 531
# Input shape: (4, 3, 5, 5, 1, 3)
# Result: True
#
#
# Test: 532
# Input shape: (5,)
# Result: True
#
#
# Test: 533
# Input shape: (4, 2)
# Result: True
#
#
# Test: 534
# Input shape: (3, 4, 4, 2, 4)
# Result: True
#
#
# Test: 535
# Input shape: (4, 2, 3, 4, 4)
# Result: True
#
#
# Test: 536
# Input shape: (1, 5, 4, 4, 3)
# Result: True
#
#
# Test: 537
# Input shape: (4, 1, 4, 5)
# Result: True
#
#
# Test: 538
# Input shape: (2, 2, 4)
#  70%|███████████████████████████▏           | 697/1000 [00:00<00:00, 941.47it/s]
# Result: True
#
#
# Test: 539
# Input shape: (5,)
# Result: True
#
#
# Test: 540
# Input shape: (3, 5, 1)
# Result: True
#
#
# Test: 541
# Input shape: (4, 3, 4, 4)
# Result: True
#
#
# Test: 542
# Input shape: (4, 4, 2, 1, 2)
# Result: True
#
#
# Test: 543
# Input shape: (2, 4, 3, 4, 5)
# Result: True
#
#
# Test: 544
# Input shape: (3, 2, 2, 3)
# Result: True
#
#
# Test: 545
# Input shape: (1, 1, 3, 2, 3, 1)
# Result: True
#
#
# Test: 546
# Input shape: (5, 1, 1, 1)
# Result: True
#
#
# Test: 547
# Input shape: (5, 5)
# Result: True
#
#
# Test: 548
# Input shape: (2, 4, 1, 1, 2, 4)
# Result: True
#
#
# Test: 549
# Input shape: (5,)
# Result: True
#
#
# Test: 550
# Input shape: (3, 1)
# Result: True
#
#
# Test: 551
# Input shape: (5, 2, 4, 3)
# Result: True
#
#
# Test: 552
# Input shape: (4, 4)
# Result: True
#
#
# Test: 553
# Input shape: (1,)
# Result: True
#
#
# Test: 554
# Input shape: (1, 5, 4, 2)
# Result: True
#
#
# Test: 555
# Input shape: (4,)
# Result: True
#
#
# Test: 556
# Input shape: (5,)
# Result: True
#
#
# Test: 557
# Input shape: (1, 1, 1)
# Result: True
#
#
# Test: 558
# Input shape: (2, 4)
# Result: True
#
#
# Test: 559
# Input shape: (1, 4, 4, 1, 5, 2)
# Result: True
#
#
# Test: 560
# Input shape: (4, 2, 3, 1, 2)
# Result: True
#
#
# Test: 561
# Input shape: (4,)
# Result: True
#
#
# Test: 562
# Input shape: (2, 4, 3, 4, 3, 1)
# Result: True
#
#
# Test: 563
# Input shape: (5, 1, 3, 3, 2)
# Result: True
#
#
# Test: 564
# Input shape: (1, 3)
# Result: True
#
#
# Test: 565
# Input shape: (5, 2)
# Result: True
#
#
# Test: 566
# Input shape: (3, 4, 1, 2)
# Result: True
#
#
# Test: 567
# Input shape: (2, 4, 5)
# Result: True
#
#
# Test: 568
# Input shape: (1, 2, 2, 3, 1)
# Result: True
#
#
# Test: 569
# Input shape: (4, 2, 2)
# Result: True
#
#
# Test: 570
# Input shape: (2, 4, 4, 5)
# Result: True
#
#
# Test: 571
# Input shape: (5, 4, 3, 4, 3, 5)
# Result: True
#
#
# Test: 572
# Input shape: (5, 3, 5, 1, 3, 2)
# Result: True
#
#
# Test: 573
# Input shape: (5, 3, 4)
# Result: True
#
#
# Test: 574
# Input shape: (1, 4)
# Result: True
#
#
# Test: 575
# Input shape: (5, 5)
# Result: True
#
#
# Test: 576
# Input shape: (4, 3, 1, 1, 3, 4)
# Result: True
#
#
# Test: 577
# Input shape: (3, 3, 4)
# Result: True
#
#
# Test: 578
# Input shape: (5, 5, 3, 5, 4)
# Result: True
#
#
# Test: 579
# Input shape: (4, 3, 4, 4, 3, 2)
# Result: True
#
#
# Test: 580
# Input shape: (5, 2, 4)
# Result: True
#
#
# Test: 581
# Input shape: (5,)
# Result: True
#
#
# Test: 582
# Input shape: (4, 4, 4, 4, 1)
# Result: True
#
#
# Test: 583
# Input shape: (2, 4, 1, 1)
# Result: True
#
#
# Test: 584
# Input shape: (1,)
# Result: True
#
#
# Test: 585
# Input shape: (4,)
# Result: True
#
#
# Test: 586
# Input shape: (1, 5, 3, 3, 4)
# Result: True
#
#
# Test: 587
# Input shape: (1,)
# Result: True
#
#
# Test: 588
# Input shape: (1, 5)
# Result: True
#
#
# Test: 589
# Input shape: (1, 4, 1, 1)
# Result: True
#
#
# Test: 590
# Input shape: (1, 1, 4, 4)
# Result: True
#
#
# Test: 591
# Input shape: (5, 4, 4, 2, 2, 4)
# Result: True
#
#
# Test: 592
# Input shape: (5, 5, 5, 1)
# Result: True
#
#
# Test: 593
# Input shape: (2, 4, 1, 3, 3)
# Result: True
#
#
# Test: 594
# Input shape: (5, 3, 2, 1, 1, 4)
# Result: True
#
#
# Test: 595
# Input shape: (5, 3, 5)
# Result: True
#
#
# Test: 596
# Input shape: (5,)
# Result: True
#
#
# Test: 597
# Input shape: (3, 5, 5, 5)
# Result: True
#
#
# Test: 598
# Input shape: (5, 5, 5, 5, 1, 2)
# Result: True
#
#
# Test: 599
# Input shape: (5, 2, 1)
# Result: True
#
#
# Test: 600
# Input shape: (3, 1, 1, 1)
# Result: True
#
#
# Test: 601
# Input shape: (5, 3, 4, 4, 1, 5)
# Result: True
#
#
# Test: 602
# Input shape: (5,)
# Result: True
#
#
# Test: 603
# Input shape: (5, 4)
# Result: True
#
#
# Test: 604
# Input shape: (4, 5, 2)
# Result: True
#
#
# Test: 605
# Input shape: (1, 1, 1, 1, 1)
# Result: True
#
#
# Test: 606
# Input shape: (4, 1)
# Result: True
#
#
# Test: 607
# Input shape: (5, 2, 5, 1, 5)
# Result: True
#
#
# Test: 608
# Input shape: (2, 5, 4)
# Result: True
#
#
# Test: 609
# Input shape: (1, 2)
# Result: True
#
#
# Test: 610
# Input shape: (4, 2)
# Result: True
#
#
# Test: 611
# Input shape: (3,)
# Result: True
#
#
# Test: 612
# Input shape: (5, 3, 5, 1, 3)
# Result: True
#
#
# Test: 613
# Input shape: (3, 5, 4, 4)
# Result: True
#
#
# Test: 614
# Input shape: (2, 1, 1, 5, 5, 5)
# Result: True
#
#
# Test: 615
# Input shape: (2, 2, 2)
# Result: True
#
#
# Test: 616
# Input shape: (5,)
# Result: True
#
#
# Test: 617
# Input shape: (2, 4, 1, 2, 1)
# Result: True
#
#
# Test: 618
# Input shape: (3,)
# Result: True
#
#
# Test: 619
# Input shape: (1, 5, 5, 2, 5)
# Result: True
#
#
# Test: 620
# Input shape: (5, 1)
# Result: True
#
#
# Test: 621
# Input shape: (5, 2, 1, 5, 1)
# Result: True
#
#
# Test: 622
# Input shape: (2, 5)
# Result: True
#
#
# Test: 623
# Input shape: (3, 3, 2, 2)
# Result: True
#
#
# Test: 624
# Input shape: (1, 1, 3, 4)
# Result: True
#
#
# Test: 625
# Input shape: (2, 2, 5, 2)
# Result: True
#
#
# Test: 626
# Input shape: (4, 1, 1, 1)
# Result: True
#
#
# Test: 627
# Input shape: (5, 4)
# Result: True
#
#
# Test: 628
# Input shape: (1, 1, 2, 3, 5)
# Result: True
#
#
# Test: 629
# Input shape: (3,)
# Result: True
#
#
# Test: 630
# Input shape: (4, 4, 2, 3, 2)
# Result: True
#
#
# Test: 631
# Input shape: (3, 2, 2)
# Result: True
#
#
# Test: 632
# Input shape: (2, 2, 5)
# Result: True
#
#
# Test: 633
# Input shape: (4, 5, 1, 5)
# Result: True
#
#
# Test: 634
# Input shape: (2, 4, 5)
# Result: True
#
#
# Test: 635
# Input shape: (2, 4, 4, 3)
# Result: True
#
#
# Test: 636
# Input shape: (5, 3)
# Result: True
#
#
# Test: 637
# Input shape: (3, 3)
# Result: True
#
#
# Test: 638
# Input shape: (1, 3, 1, 1, 5, 4)
# Result: True
#
#
# Test: 639
# Input shape: (4, 2, 5, 2, 2)
# Result: True
#
#
# Test: 640
# Input shape: (2, 2, 5, 3, 5, 3)
# Result: True
#
#
# Test: 641
# Input shape: (1, 4, 1, 3)
# Result: True
#
#
# Test: 642
# Input shape: (4, 3, 1, 3)
# Result: True
#
#
# Test: 643
# Input shape: (4,)
# Result: True
#
#
# Test: 644
# Input shape: (2, 2, 1, 1, 5, 3)
# Result: True
#
#
# Test: 645
# Input shape: (3, 3, 4, 3)
# Result: True
#
#
# Test: 646
# Input shape: (2, 1, 2, 1, 2)
# Result: True
#
#
# Test: 647
# Input shape: (3, 3, 2, 2, 1, 4)
# Result: True
#
#
# Test: 648
# Input shape: (5, 5, 1, 3)
# Result: True
#
#
# Test: 649
# Input shape: (3,)
# Result: True
#
#
# Test: 650
# Input shape: (2, 3, 5, 2)
# Result: True
#
#
# Test: 651
# Input shape: (2, 5)
# Result: True
#
#
# Test: 652
# Input shape: (2, 5, 3, 5, 3, 4)
# Result: True
#
#
# Test: 653
# Input shape: (2,)
# Result: True
#
#
# Test: 654
# Input shape: (5, 4, 5)
# Result: True
#
#
# Test: 655
# Input shape: (3, 1)
# Result: True
#
#
# Test: 656
# Input shape: (3, 2, 1, 1, 5, 5)
# Result: True
#
#
# Test: 657
# Input shape: (4,)
# Result: True
#
#
# Test: 658
# Input shape: (2,)
# Result: True
#
#
# Test: 659
# Input shape: (2, 3, 4, 2, 1)
# Result: True
#
#
# Test: 660
# Input shape: (2, 5, 2)
# Result: True
#
#
# Test: 661
# Input shape: (2, 5, 5)
# Result: True
#
#
# Test: 662
# Input shape: (5, 1, 3, 5, 3)
# Result: True
#
#
# Test: 663
# Input shape: (3, 5)
# Result: True
#
#
# Test: 664
# Input shape: (1, 1)
# Result: True
#
#
# Test: 665
# Input shape: (5, 2, 2, 5)
# Result: True
#
#
# Test: 666
# Input shape: (2, 5, 1, 5, 4, 4)
# Result: True
#
#
# Test: 667
# Input shape: (5, 2, 4, 1)
# Result: True
#
#
# Test: 668
# Input shape: (3,)
# Result: True
#
#
# Test: 669
# Input shape: (1, 5, 3, 1, 4, 2)
# Result: True
#
#
# Test: 670
# Input shape: (2, 5, 3)
# Result: True
#
#
# Test: 671
# Input shape: (3, 1, 3, 1, 3, 4)
# Result: True
#
#
# Test: 672
# Input shape: (2, 1)
# Result: True
#
#
# Test: 673
# Input shape: (1, 5)
# Result: True
#
#
# Test: 674
# Input shape: (3, 3, 1, 3, 1, 5)
# Result: True
#
#
# Test: 675
# Input shape: (5, 4, 3, 1, 1)
# Result: True
#
#
# Test: 676
# Input shape: (4, 4, 1)
# Result: True
#
#
# Test: 677
# Input shape: (2,)
# Result: True
#
#
# Test: 678
# Input shape: (2, 4, 5)
# Result: True
#
#
# Test: 679
# Input shape: (1, 1, 4)
# Result: True
#
#
# Test: 680
# Input shape: (5, 5)
# Result: True
#
#
# Test: 681
# Input shape: (3, 4)
# Result: True
#
#
# Test: 682
# Input shape: (4, 1, 1, 1)
# Result: True
#
#
# Test: 683
# Input shape: (4,)
# Result: True
#
#
# Test: 684
# Input shape: (1, 4, 4, 4, 1)
# Result: True
#
#
# Test: 685
# Input shape: (3,)
# Result: True
#
#
# Test: 686
# Input shape: (5, 2)
# Result: True
#
#
# Test: 687
# Input shape: (1, 3, 3)
# Result: True
#
#
# Test: 688
# Input shape: (3, 5, 3, 5)
# Result: True
#
#
# Test: 689
# Input shape: (5, 3)
# Result: True
#
#
# Test: 690
# Input shape: (1, 2, 3, 3)
# Result: True
#
#
# Test: 691
# Input shape: (5, 2, 4)
# Result: True
#
#
# Test: 692
# Input shape: (3, 3)
# Result: True
#
#
# Test: 693
# Input shape: (3,)
# Result: True
#
#
# Test: 694
# Input shape: (3, 4, 4, 5, 4, 3)
# Result: True
#
#
# Test: 695
# Input shape: (3,)
# Result: True
#
#
# Test: 696
# Input shape: (4, 4, 5, 2, 5, 3)
# Result: True
#
#
# Test: 697
# Input shape: (1, 3, 1, 3, 1)
# Result: True
#
#
# Test: 698
# Input shape: (1, 4)
# Result: True
#
#
# Test: 699
# Input shape: (1, 3, 2, 4)
# Result: True
#
#
# Test: 700
# Input shape: (3, 3, 5, 5, 4, 4)
#  79%|██████████████████████████████▉        | 793/1000 [00:00<00:00, 759.69it/s]
# Result: True
#
#
# Test: 701
# Input shape: (5, 5, 2, 5, 5, 5)
# Result: True
#
#
# Test: 702
# Input shape: (2, 1)
# Result: True
#
#
# Test: 703
# Input shape: (3, 1, 4, 5, 1, 5)
# Result: True
#
#
# Test: 704
# Input shape: (5, 5, 2)
# Result: True
#
#
# Test: 705
# Input shape: (5, 5, 4)
# Result: True
#
#
# Test: 706
# Input shape: (3,)
# Result: True
#
#
# Test: 707
# Input shape: (5, 5)
# Result: True
#
#
# Test: 708
# Input shape: (5, 4, 3)
# Result: True
#
#
# Test: 709
# Input shape: (2,)
# Result: True
#
#
# Test: 710
# Input shape: (5, 4, 3, 5, 3, 3)
# Result: True
#
#
# Test: 711
# Input shape: (1,)
# Result: True
#
#
# Test: 712
# Input shape: (5, 5, 4, 1)
# Result: True
#
#
# Test: 713
# Input shape: (3, 5, 3)
# Result: True
#
#
# Test: 714
# Input shape: (3, 3, 2, 4)
# Result: True
#
#
# Test: 715
# Input shape: (4, 1)
# Result: True
#
#
# Test: 716
# Input shape: (5, 5)
# Result: True
#
#
# Test: 717
# Input shape: (3, 5, 1, 3, 3)
# Result: True
#
#
# Test: 718
# Input shape: (3, 5, 4, 3)
# Result: True
#
#
# Test: 719
# Input shape: (3,)
# Result: True
#
#
# Test: 720
# Input shape: (5, 3, 4)
# Result: True
#
#
# Test: 721
# Input shape: (1,)
# Result: True
#
#
# Test: 722
# Input shape: (1, 3)
# Result: True
#
#
# Test: 723
# Input shape: (2, 2, 3, 4)
# Result: True
#
#
# Test: 724
# Input shape: (3, 4)
# Result: True
#
#
# Test: 725
# Input shape: (1, 3, 2, 4, 2, 3)
# Result: True
#
#
# Test: 726
# Input shape: (2, 1, 3, 3)
# Result: True
#
#
# Test: 727
# Input shape: (5,)
# Result: True
#
#
# Test: 728
# Input shape: (1, 1)
# Result: True
#
#
# Test: 729
# Input shape: (4, 2, 2, 2, 5)
# Result: True
#
#
# Test: 730
# Input shape: (5, 2, 3, 2)
# Result: True
#
#
# Test: 731
# Input shape: (2, 4)
# Result: True
#
#
# Test: 732
# Input shape: (1, 4, 4, 3, 3, 1)
# Result: True
#
#
# Test: 733
# Input shape: (3, 1, 2, 4, 1)
# Result: True
#
#
# Test: 734
# Input shape: (3, 2, 5, 1)
# Result: True
#
#
# Test: 735
# Input shape: (5, 4)
# Result: True
#
#
# Test: 736
# Input shape: (1, 2, 3, 5, 4)
# Result: True
#
#
# Test: 737
# Input shape: (3, 4, 5)
# Result: True
#
#
# Test: 738
# Input shape: (3, 4, 2, 2, 3)
# Result: True
#
#
# Test: 739
# Input shape: (2, 2, 1, 2)
# Result: True
#
#
# Test: 740
# Input shape: (4, 5, 4)
# Result: True
#
#
# Test: 741
# Input shape: (1, 3)
# Result: True
#
#
# Test: 742
# Input shape: (1, 5, 2, 4, 1, 1)
# Result: True
#
#
# Test: 743
# Input shape: (3,)
# Result: True
#
#
# Test: 744
# Input shape: (4, 5, 5, 5, 1)
# Result: True
#
#
# Test: 745
# Input shape: (4,)
# Result: True
#
#
# Test: 746
# Input shape: (3, 2, 5)
# Result: True
#
#
# Test: 747
# Input shape: (4, 4, 1, 4, 1)
# Result: True
#
#
# Test: 748
# Input shape: (2, 3, 1)
# Result: True
#
#
# Test: 749
# Input shape: (4, 4, 3, 4)
# Result: True
#
#
# Test: 750
# Input shape: (1, 2, 4)
# Result: True
#
#
# Test: 751
# Input shape: (1, 3, 5, 2, 3, 4)
# Result: True
#
#
# Test: 752
# Input shape: (4, 2, 3, 2)
# Result: True
#
#
# Test: 753
# Input shape: (4, 4, 3, 5)
# Result: True
#
#
# Test: 754
# Input shape: (1,)
# Result: True
#
#
# Test: 755
# Input shape: (1, 4, 5, 2)
# Result: True
#
#
# Test: 756
# Input shape: (3, 5)
# Result: True
#
#
# Test: 757
# Input shape: (4, 1, 5, 1, 3)
# Result: True
#
#
# Test: 758
# Input shape: (1,)
# Result: True
#
#
# Test: 759
# Input shape: (1, 3, 5)
# Result: True
#
#
# Test: 760
# Input shape: (5, 2, 3, 1)
# Result: True
#
#
# Test: 761
# Input shape: (4, 1, 1, 3, 2, 5)
# Result: True
#
#
# Test: 762
# Input shape: (5,)
# Result: True
#
#
# Test: 763
# Input shape: (2, 4, 3, 4, 4)
# Result: True
#
#
# Test: 764
# Input shape: (5, 4, 4)
# Result: True
#
#
# Test: 765
# Input shape: (5, 2, 5)
# Result: True
#
#
# Test: 766
# Input shape: (5, 2)
# Result: True
#
#
# Test: 767
# Input shape: (1, 4)
# Result: True
#
#
# Test: 768
# Input shape: (3, 5, 3, 3, 5)
# Result: True
#
#
# Test: 769
# Input shape: (1, 1, 1, 1, 4)
# Result: True
#
#
# Test: 770
# Input shape: (1, 2, 3, 5, 4, 5)
# Result: True
#
#
# Test: 771
# Input shape: (1,)
# Result: True
#
#
# Test: 772
# Input shape: (5,)
# Result: True
#
#
# Test: 773
# Input shape: (3, 3, 2, 1)
# Result: True
#
#
# Test: 774
# Input shape: (4, 5, 1, 1, 4, 5)
# Result: True
#
#
# Test: 775
# Input shape: (2, 2, 1, 5, 3)
# Result: True
#
#
# Test: 776
# Input shape: (2, 2, 2, 2, 4)
# Result: True
#
#
# Test: 777
# Input shape: (1, 5)
# Result: True
#
#
# Test: 778
# Input shape: (4, 4, 3, 3, 5)
# Result: True
#
#
# Test: 779
# Input shape: (4, 4, 3)
# Result: True
#
#
# Test: 780
# Input shape: (2, 1, 1, 3, 2, 4)
# Result: True
#
#
# Test: 781
# Input shape: (2,)
# Result: True
#
#
# Test: 782
# Input shape: (5,)
# Result: True
#
#
# Test: 783
# Input shape: (1, 3)
# Result: True
#
#
# Test: 784
# Input shape: (4, 3, 1, 5, 3)
# Result: True
#
#
# Test: 785
# Input shape: (5, 3, 5)
# Result: True
#
#
# Test: 786
# Input shape: (4,)
# Result: True
#
#
# Test: 787
# Input shape: (3, 1, 5)
# Result: True
#
#
# Test: 788
# Input shape: (1, 5, 2, 5)
# Result: True
#
#
# Test: 789
# Input shape: (5,)
# Result: True
#
#
# Test: 790
# Input shape: (3, 3, 1)
# Result: True
#
#
# Test: 791
# Input shape: (5, 3, 4, 4, 3, 1)
# Result: True
#
#
# Test: 792
# Input shape: (1, 1, 4, 5)
# Result: True
#
#
# Test: 793
# Input shape: (3, 4, 3, 1)
# Result: True
#
#
# Test: 794
# Input shape: (3, 4)
# Result: True
#
#
# Test: 795
# Input shape: (1, 5, 4, 5)
# Result: True
#
#
# Test: 796
# Input shape: (5,)
# Result: True
#
#
# Test: 797
# Input shape: (1, 1, 1, 5)
# Result: True
#
#
# Test: 798
# Input shape: (4, 1, 5)
# Result: True
#
#
# Test: 799
# Input shape: (5, 1, 1, 3)
# Result: True
#
#
# Test: 800
# Input shape: (3, 1, 1)
# Result: True
#
#
# Test: 801
# Input shape: (2, 3, 3, 5, 1, 1)
# Result: True
#
#
# Test: 802
# Input shape: (3, 4)
# Result: True
#
#
# Test: 803
# Input shape: (2, 5, 1, 3, 3, 3)
# Result: True
#
#
# Test: 804
# Input shape: (3, 2)
# Result: True
#
#
# Test: 805
# Input shape: (1, 5, 3, 1, 1)
# Result: True
#
#
# Test: 806
# Input shape: (4, 1, 4, 3)
# Result: True
#
#
# Test: 807
# Input shape: (1, 2, 1, 2, 5, 1)
# Result: True
#
#
# Test: 808
# Input shape: (5, 3, 2, 5)
# Result: True
#
#
# Test: 809
# Input shape: (5, 2, 2, 2)
# Result: True
#
#
# Test: 810
# Input shape: (1, 4)
# Result: True
#
#
# Test: 811
# Input shape: (5, 3, 4, 2, 4, 1)
# Result: True
#
#
# Test: 812
# Input shape: (3,)
# Result: True
#
#
# Test: 813
# Input shape: (3, 4, 1, 1)
# Result: True
#
#
# Test: 814
# Input shape: (3, 3, 3, 2, 3)
# Result: True
#
#
# Test: 815
# Input shape: (5, 2, 5, 4, 4, 2)
# Result: True
#
#
# Test: 816
# Input shape: (4,)
# Result: True
#
#
# Test: 817
# Input shape: (5,)
# Result: True
#
#
# Test: 818
# Input shape: (5, 2)
# Result: True
#
#
# Test: 819
# Input shape: (5, 3, 2, 1)
# Result: True
#
#
# Test: 820
# Input shape: (2, 3, 2, 1, 1)
# Result: True
#
#
# Test: 821
# Input shape: (4, 4, 5, 1, 3, 4)
# Result: True
#
#
# Test: 822
# Input shape: (2, 2)
# Result: True
#
#
# Test: 823
# Input shape: (4,)
# Result: True
#
#
# Test: 824
# Input shape: (2, 2, 3)
# Result: True
#
#
# Test: 825
# Input shape: (3, 2, 5, 3, 5, 2)
# Result: True
#
#
# Test: 826
# Input shape: (3, 5, 2, 5)
# Result: True
#
#
# Test: 827
# Input shape: (3,)
# Result: True
#
#
# Test: 828
# Input shape: (2, 2, 1, 2)
# Result: True
#
#
# Test: 829
# Input shape: (1, 3, 2, 5, 1)
# Result: True
#
#
# Test: 830
# Input shape: (4,)
# Result: True
#
#
# Test: 831
# Input shape: (1, 3, 5, 2)
# Result: True
#
#
# Test: 832
# Input shape: (2, 4, 5, 4)
# Result: True
#
#
# Test: 833
# Input shape: (2,)
# Result: True
#
#
# Test: 834
# Input shape: (4, 4, 5, 4, 1)
# Result: True
#
#
# Test: 835
# Input shape: (5, 3, 4)
# Result: True
#
#
# Test: 836
# Input shape: (2, 4, 3, 2)
# Result: True
#
#
# Test: 837
# Input shape: (5, 2, 5, 2, 4, 4)
# Result: True
#
#
# Test: 838
# Input shape: (2,)
# Result: True
#
#
# Test: 839
# Input shape: (5, 5)
# Result: True
#
#
# Test: 840
# Input shape: (5, 5, 5)
# Result: True
#
#
# Test: 841
# Input shape: (4, 1)
# Result: True
#
#
# Test: 842
# Input shape: (2, 1, 1)
# Result: True
#
#
# Test: 843
# Input shape: (1,)
# Result: True
#
#
# Test: 844
# Input shape: (3, 4)
# Result: True
#
#
# Test: 845
# Input shape: (4, 3, 5, 5, 1, 1)
# Result: True
#
#
# Test: 846
# Input shape: (5, 2, 3, 5)
# Result: True
#
#
# Test: 847
# Input shape: (4, 5, 3, 4, 5, 3)
# Result: True
#
#
# Test: 848
# Input shape: (3, 2)
# Result: True
#
#
# Test: 849
# Input shape: (5,)
# Result: True
#
#
# Test: 850
# Input shape: (3, 4, 5)
# Result: True
#
#
# Test: 851
# Input shape: (5, 3, 4)
# Result: True
#
#
# Test: 852
# Input shape: (3, 2)
# Result: True
#
#
# Test: 853
# Input shape: (1, 5, 3)
# Result: True
#
#
# Test: 854
# Input shape: (4,)
# Result: True
#
#
# Test: 855
# Input shape: (2, 4, 2)
# Result: True
#
#
# Test: 856
# Input shape: (4, 4, 1, 2, 5)
# Result: True
#
#
# Test: 857
# Input shape: (3, 3, 3, 1, 3)
# Result: True
#
#
# Test: 858
# Input shape: (3, 2, 5, 4, 3)
# Result: True
#
#
# Test: 859
# Input shape: (4, 3, 3, 1, 5, 5)
# Result: True
#
#
# Test: 860
# Input shape: (5, 4, 4, 2)
# Result: True
#
#
# Test: 861
# Input shape: (5, 3, 1, 1, 1, 1)
# 100%|██████████████████████████████████████| 1000/1000 [00:01<00:00, 803.18it/s]
# Result: True
#
#
# Test: 862
# Input shape: (3, 5, 2, 5)
# Result: True
#
#
# Test: 863
# Input shape: (2, 5, 2, 2)
# Result: True
#
#
# Test: 864
# Input shape: (4, 1, 3, 5)
# Result: True
#
#
# Test: 865
# Input shape: (4, 2, 5, 2, 2, 1)
# Result: True
#
#
# Test: 866
# Input shape: (2, 5, 4, 5)
# Result: True
#
#
# Test: 867
# Input shape: (3, 2, 3, 2, 3, 3)
# Result: True
#
#
# Test: 868
# Input shape: (5, 1, 2, 5)
# Result: True
#
#
# Test: 869
# Input shape: (5, 3, 3, 3, 3)
# Result: True
#
#
# Test: 870
# Input shape: (2,)
# Result: True
#
#
# Test: 871
# Input shape: (5, 4, 1, 4)
# Result: True
#
#
# Test: 872
# Input shape: (2,)
# Result: True
#
#
# Test: 873
# Input shape: (2,)
# Result: True
#
#
# Test: 874
# Input shape: (1, 5, 4, 4)
# Result: True
#
#
# Test: 875
# Input shape: (5, 4, 2)
# Result: True
#
#
# Test: 876
# Input shape: (3,)
# Result: True
#
#
# Test: 877
# Input shape: (2, 4, 2, 3, 2)
# Result: True
#
#
# Test: 878
# Input shape: (4, 1, 2)
# Result: True
#
#
# Test: 879
# Input shape: (4,)
# Result: True
#
#
# Test: 880
# Input shape: (1, 4, 1, 3, 2, 4)
# Result: True
#
#
# Test: 881
# Input shape: (4,)
# Result: True
#
#
# Test: 882
# Input shape: (3, 5, 2, 3)
# Result: True
#
#
# Test: 883
# Input shape: (5, 1, 2, 1, 4)
# Result: True
#
#
# Test: 884
# Input shape: (2,)
# Result: True
#
#
# Test: 885
# Input shape: (3, 2, 5, 3)
# Result: True
#
#
# Test: 886
# Input shape: (3, 4, 2, 5)
# Result: True
#
#
# Test: 887
# Input shape: (2, 2, 2, 1, 1)
# Result: True
#
#
# Test: 888
# Input shape: (5,)
# Result: True
#
#
# Test: 889
# Input shape: (2, 5, 4, 1, 5)
# Result: True
#
#
# Test: 890
# Input shape: (5, 2, 1, 3)
# Result: True
#
#
# Test: 891
# Input shape: (3, 5, 1)
# Result: True
#
#
# Test: 892
# Input shape: (4, 4, 5)
# Result: True
#
#
# Test: 893
# Input shape: (4, 2, 2, 1)
# Result: True
#
#
# Test: 894
# Input shape: (3, 2, 2, 2, 5, 5)
# Result: True
#
#
# Test: 895
# Input shape: (5, 3, 5, 5, 4, 5)
# Result: True
#
#
# Test: 896
# Input shape: (2, 5, 5, 5, 5)
# Result: True
#
#
# Test: 897
# Input shape: (1, 2)
# Result: True
#
#
# Test: 898
# Input shape: (2, 2, 3, 3, 1)
# Result: True
#
#
# Test: 899
# Input shape: (2, 1, 5)
# Result: True
#
#
# Test: 900
# Input shape: (3, 5, 1, 5)
# Result: True
#
#
# Test: 901
# Input shape: (4, 1, 5)
# Result: True
#
#
# Test: 902
# Input shape: (4, 3)
# Result: True
#
#
# Test: 903
# Input shape: (3, 1, 1)
# Result: True
#
#
# Test: 904
# Input shape: (1, 2, 1, 4, 1)
# Result: True
#
#
# Test: 905
# Input shape: (5, 3, 3, 1, 2, 1)
# Result: True
#
#
# Test: 906
# Input shape: (5, 5, 3, 3, 2)
# Result: True
#
#
# Test: 907
# Input shape: (3, 2, 1, 4, 5)
# Result: True
#
#
# Test: 908
# Input shape: (3, 5, 3, 4, 1)
# Result: True
#
#
# Test: 909
# Input shape: (3, 5, 1, 5, 3)
# Result: True
#
#
# Test: 910
# Input shape: (5, 5, 5, 2, 3, 4)
# Result: True
#
#
# Test: 911
# Input shape: (5, 3, 5)
# Result: True
#
#
# Test: 912
# Input shape: (1, 1, 2, 3)
# Result: True
#
#
# Test: 913
# Input shape: (4, 3)
# Result: True
#
#
# Test: 914
# Input shape: (5, 4, 2, 1)
# Result: True
#
#
# Test: 915
# Input shape: (3,)
# Result: True
#
#
# Test: 916
# Input shape: (1, 1, 4)
# Result: True
#
#
# Test: 917
# Input shape: (3, 4, 1)
# Result: True
#
#
# Test: 918
# Input shape: (4,)
# Result: True
#
#
# Test: 919
# Input shape: (5,)
# Result: True
#
#
# Test: 920
# Input shape: (1, 4, 1)
# Result: True
#
#
# Test: 921
# Input shape: (2, 1, 5, 5)
# Result: True
#
#
# Test: 922
# Input shape: (2, 3)
# Result: True
#
#
# Test: 923
# Input shape: (4, 2, 1, 4, 2)
# Result: True
#
#
# Test: 924
# Input shape: (3, 4, 3, 4)
# Result: True
#
#
# Test: 925
# Input shape: (3, 3, 1, 3, 2)
# Result: True
#
#
# Test: 926
# Input shape: (1,)
# Result: True
#
#
# Test: 927
# Input shape: (4, 1)
# Result: True
#
#
# Test: 928
# Input shape: (4, 4, 3, 2, 2, 1)
# Result: True
#
#
# Test: 929
# Input shape: (4, 1, 4, 1, 2)
# Result: True
#
#
# Test: 930
# Input shape: (3, 3, 2, 4, 2, 4)
# Result: True
#
#
# Test: 931
# Input shape: (4,)
# Result: True
#
#
# Test: 932
# Input shape: (2, 2, 3, 5, 1)
# Result: True
#
#
# Test: 933
# Input shape: (5, 4)
# Result: True
#
#
# Test: 934
# Input shape: (5,)
# Result: True
#
#
# Test: 935
# Input shape: (5, 4, 3, 5)
# Result: True
#
#
# Test: 936
# Input shape: (5, 1, 2)
# Result: True
#
#
# Test: 937
# Input shape: (1,)
# Result: True
#
#
# Test: 938
# Input shape: (3, 4, 4, 4, 5, 1)
# Result: True
#
#
# Test: 939
# Input shape: (5,)
# Result: True
#
#
# Test: 940
# Input shape: (1,)
# Result: True
#
#
# Test: 941
# Input shape: (5, 5, 2, 4)
# Result: True
#
#
# Test: 942
# Input shape: (3, 3, 4, 4, 1)
# Result: True
#
#
# Test: 943
# Input shape: (1, 1)
# Result: True
#
#
# Test: 944
# Input shape: (3,)
# Result: True
#
#
# Test: 945
# Input shape: (2, 3, 2, 5, 4, 1)
# Result: True
#
#
# Test: 946
# Input shape: (5, 3, 1, 2, 2)
# Result: True
#
#
# Test: 947
# Input shape: (4,)
# Result: True
#
#
# Test: 948
# Input shape: (4,)
# Result: True
#
#
# Test: 949
# Input shape: (2, 1, 5, 3)
# Result: True
#
#
# Test: 950
# Input shape: (4, 2, 2, 2, 1, 2)
# Result: True
#
#
# Test: 951
# Input shape: (5, 4, 4)
# Result: True
#
#
# Test: 952
# Input shape: (5, 1, 5, 4, 1, 2)
# Result: True
#
#
# Test: 953
# Input shape: (2, 5, 5, 1, 5, 1)
# Result: True
#
#
# Test: 954
# Input shape: (3, 2)
# Result: True
#
#
# Test: 955
# Input shape: (1, 2, 1, 1)
# Result: True
#
#
# Test: 956
# Input shape: (5, 4, 5, 5)
# Result: True
#
#
# Test: 957
# Input shape: (4, 4, 1, 4, 5)
# Result: True
#
#
# Test: 958
# Input shape: (4,)
# Result: True
#
#
# Test: 959
# Input shape: (3, 4, 5, 3, 4, 2)
# Result: True
#
#
# Test: 960
# Input shape: (5, 4, 5, 1, 3)
# Result: True
#
#
# Test: 961
# Input shape: (2, 2, 3)
# Result: True
#
#
# Test: 962
# Input shape: (4, 4, 5, 2, 2, 2)
# Result: True
#
#
# Test: 963
# Input shape: (4, 5)
# Result: True
#
#
# Test: 964
# Input shape: (2, 1, 2, 4, 4, 5)
# Result: True
#
#
# Test: 965
# Input shape: (2, 1)
# Result: True
#
#
# Test: 966
# Input shape: (3, 2, 5, 1, 2)
# Result: True
#
#
# Test: 967
# Input shape: (3, 5, 3, 4)
# Result: True
#
#
# Test: 968
# Input shape: (2, 5, 4, 1)
# Result: True
#
#
# Test: 969
# Input shape: (1, 1, 2, 4, 2, 1)
# Result: True
#
#
# Test: 970
# Input shape: (1, 3, 3, 2)
# Result: True
#
#
# Test: 971
# Input shape: (5,)
# Result: True
#
#
# Test: 972
# Input shape: (2, 4, 3)
# Result: True
#
#
# Test: 973
# Input shape: (1, 1, 1, 5, 4, 5)
# Result: True
#
#
# Test: 974
# Input shape: (1, 3)
# Result: True
#
#
# Test: 975
# Input shape: (1, 5)
# Result: True
#
#
# Test: 976
# Input shape: (3, 3, 4, 4, 3, 3)
# Result: True
#
#
# Test: 977
# Input shape: (2, 4, 2, 3)
# Result: True
#
#
# Test: 978
# Input shape: (2, 5, 3, 3, 3)
# Result: True
#
#
# Test: 979
# Input shape: (2, 4, 2)
# Result: True
#
#
# Test: 980
# Input shape: (3, 4, 4, 1)
# Result: True
#
#
# Test: 981
# Input shape: (3, 2, 4, 2, 3)
# Result: True
#
#
# Test: 982
# Input shape: (5, 5, 3, 2, 5, 2)
# Result: True
#
#
# Test: 983
# Input shape: (4, 3, 1, 5, 4)
# Result: True
#
#
# Test: 984
# Input shape: (1, 5, 3, 3, 3)
# Result: True
#
#
# Test: 985
# Input shape: (2, 3, 1, 2, 1, 4)
# Result: True
#
#
# Test: 986
# Input shape: (5, 5, 1)
# Result: True
#
#
# Test: 987
# Input shape: (2, 5, 1, 4, 2)
# Result: True
#
#
# Test: 988
# Input shape: (4, 3, 3, 1)
# Result: True
#
#
# Test: 989
# Input shape: (5, 3, 3, 3)
# Result: True
#
#
# Test: 990
# Input shape: (3, 2)
# Result: True
#
#
# Test: 991
# Input shape: (1, 5, 1, 3, 2, 2)
# Result: True
#
#
# Test: 992
# Input shape: (4, 4)
# Result: True
#
#
# Test: 993
# Input shape: (1, 5, 5, 5)
# Result: True
#
#
# Test: 994
# Input shape: (2,)
# Result: True
#
#
# Test: 995
# Input shape: (3, 2)
# Result: True
#
#
# Test: 996
# Input shape: (3, 1, 5)
# Result: True
#
#
# Test: 997
# Input shape: (2, 3, 2)
# Result: True
#
#
# Test: 998
# Input shape: (1, 4, 3)
# Result: True
#
#
# Test: 999
# Input shape: (2,)
# Result: True
#
#
# 1000 out of 1000 (100.0%) tests passed
