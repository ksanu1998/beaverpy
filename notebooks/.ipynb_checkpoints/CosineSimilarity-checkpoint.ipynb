# %% [markdown]
# ### `CosineSimilarity` code

# %%
import numpy as np
import torch # needed for tests
from tqdm import tqdm # needed for tests

# %%
class CosineSimilarity:
    ''' Computes CosineSimilarity Loss given the input1 and input2 '''
    
    ''' * The class implementation will be along the lines of torch.nn.CosineSimilarity in order to 
          enable comparison of this NumPy only implementation and seamless testing
        * Can expect extensive refactoring of the existing code in the days to come
        * As part of refactoring, some code will be de-modularized
        * Old code will be retained at the end of the notebook for reference
    '''
    '''
        TODO:
        * Replace `torch.round()` with `np.allclose()` for tests
        * Optimizing code
    '''
    
    def __init__(
        self,
        dim = 1,
        eps = 1e-08,
        verbose = False
        ):
        super(CosineSimilarity, self).__init__()
        
        ''' mandatory parameters '''
        # None
        
        ''' optional parameters '''
        self.dim = dim
        self.eps = eps
        
        ''' optional parameters (dummy, yet to be implemented)'''
        # None
        
        ''' additional parameters (different from torch.nn.Conv2D)'''
        self.verbose = verbose
        self.verboseprint = print if self.verbose else lambda *a, **k: None
        self.verboseprint('*** parameters ***')
        self.verboseprint('dim: {}, eps: {}'.format(self.dim, self.eps))
        self.verboseprint('\n')
    
    def forward(self, _input1, _input2):
        ''' forward pass to compute CosineSimilarity'''
        
        ''' error checking '''
        if not (isinstance(_input, int) or isinstance(_input, float) or isinstance(_input, np.ndarray)):
            raise Exception('invalid input: `input` should either be an int, a float, or a NumPy ndarray')
        
        if not (isinstance(_target, int) or isinstance(_target, float) or isinstance(_target, np.ndarray)):
            raise Exception('invalid input: `target` should either be an int, a float, or a NumPy ndarray')
            
        if (isinstance(_input, np.ndarray) and not isinstance(_target, np.ndarray))  or (not isinstance(_input, np.ndarray) and isinstance(_target, np.ndarray)):
            raise Exception('invalid input: `input` and `target` should both be a NumPy ndarray, or can be a mix of `int` and `float`')
            
        ''' compute CosineSimilarity '''
        dot_product = np.sum(_input1 * _input2, axis = self.dim)
        norm1 = np.sqrt(np.sum(_input1 ** 2, axis = self.dim))
        norm2 = np.sqrt(np.sum(_input2 ** 2, axis = self.dim))
        output = dot_product / (norm1 * norm2)
        self.verboseprint("*** CosineSimilarity output ***")
        self.verboseprint(output)
        self.verboseprint('\n')
        return output

# %% [markdown]
# ### Standalone test (random input, target)

# %%
num_dim = np.random.randint(6) + 1 # number of input dimensions
shape = tuple(np.random.randint(5) + 1 for _ in range(num_dim)) # shape of input
_input1 = np.random.rand(*shape) # generate an input based on the dimensions and shape
_input2 = np.random.rand(*shape) # generate another input based on the dimensions and shape

# %%
# compute CosineSimilarity using the random input and target
cosinesimilarity = CosineSimilarity() # call an instance of the class
_output = cosinesimilarity.forward(_input1, _input2) # compute CosineSimilarity
print("*** CosineSimilarity output ***")
print(_output)
# Out:
# *** CosineSimilarity output ***
# [[[[0.97247257]
#    [0.69733886]
#    [0.85502866]]]
#
#
#  [[[0.82571264]
#    [0.96903137]
#    [0.96056595]]]
#
#
#  [[[0.85698819]
#    [0.94667737]
#    [0.46939666]]]
#
#
#  [[[0.68825819]
#    [0.89645272]
#    [0.99787341]]]]

# %%
# get PyTorch output with the same random inputs as above

x = torch.DoubleTensor(_input1)
y = torch.DoubleTensor(_input2)
loss = torch.nn.CosineSimilarity()
output = loss(x, y)
print("*** PyTorch output ***")
print(output)
# Out:
# *** PyTorch output ***
# tensor([[[[0.9725],
#           [0.6973],
#           [0.8550]]],
#
#
#         [[[0.8257],
#           [0.9690],
#           [0.9606]]],
#
#
#         [[[0.8570],
#           [0.9467],
#           [0.4694]]],
#
#
#         [[[0.6883],
#           [0.8965],
#           [0.9979]]]], dtype=torch.float64)

# %%
# compare outputs of CosineSimilarity and PyTorch
if not isinstance(_output, np.ndarray): # if a singleton, convert PyTorch tensor to NumPy float, round, and compare
    output = output.numpy()
    print(np.equal(np.round(_output), np.round(output)))  
else:
    print(torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output))) # need to round the output due to precision difference
# Out:
# True

# %% [markdown]
# ### Extensive tests (random input, target)

# %%
def run_tests(num_tests):
    ''' sweep different input parameters and test by comparing outputs of ReLU and PyTorch '''
    
    num_passed = 0
    print('Number of tests: {}\n\n'.format(num_tests))
    
    for i in tqdm(range(num_tests)):
        num_dim = np.random.randint(6) + 1 # number of input dimensions
        shape = tuple(np.random.randint(5) + 1 for _ in range(num_dim)) # shape of input
        _input1 = np.random.rand(*shape) # generate an input based on the dimensions and shape
        _input2 = np.random.rand(*shape) # generate another input based on the dimensions and shape
        _dim = np.random.randint(num_dim) # dimension along which CosineSimilarity is to be computed
        _eps = np.random.uniform(low = 1e-10, high = 1e-6)
        print('Test: {}\nInput shape: {}, Dimension: {}, eps: {}'.format(i, shape, _dim, _eps))
        
        try:
            # compute CosineSimilarity using the random input and target
            cosinesimilarity = CosineSimilarity(dim = _dim, eps = _eps) # call an instance of the class
            _output = cosinesimilarity.forward(_input1, _input2) # compute CosineSimilarity

            # get PyTorch output with the same random inputs as above
            x = torch.DoubleTensor(_input1)
            y = torch.DoubleTensor(_input2)
            loss = torch.nn.CosineSimilarity(dim = _dim, eps = _eps)
            output = loss(x, y)

            
        except Exception as e:
            print(e)
            print('Result: False\n\n') # treating exception as a failed test
            continue

        # compare outputs of CosineSimilarity and PyTorch
        if not isinstance(_output, np.ndarray): # if a singleton, convert PyTorch tensor to NumPy float, round, and compare
            output = output.numpy()
            result = np.equal(np.round(_output), np.round(output)) 
        else:
            result = torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output)) # need to round the output due to precision difference
        print('Result: {}\n\n'.format(result))
        if result:
            num_passed += 1

    print('{} out of {} ({}%) tests passed'.format(num_passed, num_tests, float(100 * num_passed / num_tests)))

# %%
num_tests = 10000
run_tests(num_tests)
# Out:
# Number of tests: 10000
#   1%|▍                                    | 130/10000 [00:00<00:07, 1297.82it/s]
# Test: 0
# Input shape: (4, 1, 3), Dimension: 2, eps: 3.297823030069749e-07
# Result: True
#
#
# Test: 1
# Input shape: (3, 3, 3, 3, 2, 5), Dimension: 2, eps: 2.8539945587550483e-07
# Result: True
#
#
# Test: 2
# Input shape: (4, 1, 3, 2), Dimension: 3, eps: 1.684850357892493e-07
# Result: True
#
#
# Test: 3
# Input shape: (4, 1, 4, 4), Dimension: 1, eps: 3.553229444068826e-07
# Result: True
#
#
# Test: 4
# Input shape: (1, 4, 1, 2, 1), Dimension: 0, eps: 1.846755714511833e-07
# Result: True
#
#
# Test: 5
# Input shape: (4, 2, 2, 5, 4, 3), Dimension: 2, eps: 6.21641161876447e-07
# Result: True
#
#
# Test: 6
# Input shape: (4, 3, 3), Dimension: 1, eps: 5.49985628524777e-07
# Result: True
#
#
# Test: 7
# Input shape: (1, 4), Dimension: 0, eps: 3.284225846693936e-07
# Result: True
#
#
# Test: 8
# Input shape: (5, 2, 5, 4, 5), Dimension: 1, eps: 4.095485619239091e-08
# Result: True
#
#
# Test: 9
# Input shape: (3, 3, 4), Dimension: 1, eps: 2.0663914701281175e-07
# Result: True
#
#
# Test: 10
# Input shape: (1,), Dimension: 0, eps: 8.165827433661186e-07
# Result: True
#
#
# Test: 11
# Input shape: (1, 1, 2), Dimension: 2, eps: 5.653089518086103e-07
# Result: True
#
#
# Test: 12
# Input shape: (2, 1, 3), Dimension: 2, eps: 3.7294728034341304e-07
# Result: True
#
#
# Test: 13
# Input shape: (4, 1), Dimension: 1, eps: 5.755975848108352e-07
# Result: True
#
#
# Test: 14
# Input shape: (2, 5, 3, 3, 3, 2), Dimension: 1, eps: 9.73136754441138e-07
# Result: True
#
#
# Test: 15
# Input shape: (3, 2), Dimension: 1, eps: 5.987336389183129e-07
# Result: True
#
#
# Test: 16
# Input shape: (5, 2, 3, 4, 3), Dimension: 4, eps: 5.065101993675424e-07
# Result: True
#
#
# Test: 17
# Input shape: (2, 2, 2, 5, 5), Dimension: 0, eps: 7.219372072272284e-07
# Result: True
#
#
# Test: 18
# Input shape: (5,), Dimension: 0, eps: 8.1326331524781e-08
# Result: True
#
#
# Test: 19
# Input shape: (1, 3, 4), Dimension: 2, eps: 2.4726895217280555e-07
# Result: True
#
#
# Test: 20
# Input shape: (4, 1, 2, 5, 2, 5), Dimension: 1, eps: 2.4634484943725454e-08
# Result: True
#
#
# Test: 21
# Input shape: (5, 2, 2, 5, 2, 4), Dimension: 2, eps: 7.899122258064238e-07
# Result: True
#
#
# Test: 22
# Input shape: (1, 2, 1), Dimension: 1, eps: 2.809752520478949e-07
# Result: True
#
#
# Test: 23
# Input shape: (2, 5, 1, 5, 3), Dimension: 1, eps: 8.959161388557058e-07
# Result: True
#
#
# Test: 24
# Input shape: (4, 5, 2, 2), Dimension: 3, eps: 5.028158434916627e-07
# Result: True
#
#
# Test: 25
# Input shape: (4, 1), Dimension: 0, eps: 4.638846999281727e-07
# Result: True
#
#
# Test: 26
# Input shape: (2, 4, 2, 4), Dimension: 3, eps: 6.462883480363694e-07
# Result: True
#
#
# Test: 27
# Input shape: (5, 4), Dimension: 1, eps: 7.643704853377698e-07
# Result: True
#
#
# Test: 28
# Input shape: (5, 4), Dimension: 0, eps: 4.1181115121515396e-08
# Result: True
#
#
# Test: 29
# Input shape: (3, 2, 5, 5, 4, 4), Dimension: 3, eps: 1.2158299814798312e-07
# Result: True
#
#
# Test: 30
# Input shape: (1,), Dimension: 0, eps: 4.410741321285084e-07
# Result: True
#
#
# Test: 31
# Input shape: (5, 4, 2, 2, 3, 2), Dimension: 1, eps: 2.615012430995536e-07
# Result: True
#
#
# Test: 32
# Input shape: (2,), Dimension: 0, eps: 9.122714652329095e-07
# Result: True
#
#
# Test: 33
# Input shape: (2, 3, 4, 3, 2), Dimension: 0, eps: 9.879032680455239e-07
# Result: True
#
#
# Test: 34
# Input shape: (4,), Dimension: 0, eps: 8.14224366239218e-07
# Result: True
#
#
# Test: 35
# Input shape: (2,), Dimension: 0, eps: 2.279551759450616e-07
# Result: True
#
#
# Test: 36
# Input shape: (5, 4, 2, 1, 5), Dimension: 1, eps: 8.575809498425226e-07
# Result: True
#
#
# Test: 37
# Input shape: (3, 1), Dimension: 0, eps: 9.158097022838198e-07
# Result: True
#
#
# Test: 38
# Input shape: (3, 4), Dimension: 0, eps: 1.657777834894774e-07
# Result: True
#
#
# Test: 39
# Input shape: (5, 2), Dimension: 0, eps: 3.110022475320685e-07
# Result: True
#
#
# Test: 40
# Input shape: (3, 2, 5, 5, 2), Dimension: 3, eps: 4.803468862650099e-07
# Result: True
#
#
# Test: 41
# Input shape: (2,), Dimension: 0, eps: 4.806572669864518e-07
# Result: True
#
#
# Test: 42
# Input shape: (5, 2, 3, 4, 1, 2), Dimension: 2, eps: 4.865392367881543e-07
# Result: True
#
#
# Test: 43
# Input shape: (3, 4), Dimension: 0, eps: 7.42050305287136e-07
# Result: True
#
#
# Test: 44
# Input shape: (4, 5), Dimension: 0, eps: 8.254341454318071e-07
# Result: True
#
#
# Test: 45
# Input shape: (5,), Dimension: 0, eps: 4.723848387287496e-07
# Result: True
#
#
# Test: 46
# Input shape: (3, 1), Dimension: 1, eps: 5.665817831050246e-08
# Result: True
#
#
# Test: 47
# Input shape: (3,), Dimension: 0, eps: 1.8517668181183664e-07
# Result: True
#
#
# Test: 48
# Input shape: (1, 5, 1, 1, 5, 2), Dimension: 5, eps: 5.5756980063478814e-08
# Result: True
#
#
# Test: 49
# Input shape: (3, 2, 4), Dimension: 2, eps: 2.6616807008041354e-07
# Result: True
#
#
# Test: 50
# Input shape: (2, 1), Dimension: 1, eps: 3.4384017828502415e-07
# Result: True
#
#
# Test: 51
# Input shape: (3, 3), Dimension: 1, eps: 1.2716157811940668e-08
# Result: True
#
#
# Test: 52
# Input shape: (3, 1, 2, 3, 3), Dimension: 1, eps: 7.436191580766754e-08
# Result: True
#
#
# Test: 53
# Input shape: (1, 4, 1, 4, 2), Dimension: 0, eps: 2.5632673281876536e-07
# Result: True
#
#
# Test: 54
# Input shape: (5, 2, 3, 4, 5), Dimension: 3, eps: 2.8688720647421206e-07
# Result: True
#
#
# Test: 55
# Input shape: (4, 3, 1, 2, 3, 2), Dimension: 2, eps: 6.545849179182513e-07
# Result: True
#
#
# Test: 56
# Input shape: (5, 5, 2, 3, 3, 3), Dimension: 5, eps: 3.804947424985958e-07
# Result: True
#
#
# Test: 57
# Input shape: (4,), Dimension: 0, eps: 8.921766044304848e-07
# Result: True
#
#
# Test: 58
# Input shape: (2, 4), Dimension: 0, eps: 4.942036318303345e-07
# Result: True
#
#
# Test: 59
# Input shape: (1, 4, 4), Dimension: 1, eps: 6.114435875772357e-07
# Result: True
#
#
# Test: 60
# Input shape: (5, 1, 5), Dimension: 1, eps: 5.13017946682783e-07
# Result: True
#
#
# Test: 61
# Input shape: (5, 5, 5, 3, 1), Dimension: 3, eps: 7.56137048828931e-07
# Result: True
#
#
# Test: 62
# Input shape: (3, 5, 5, 2), Dimension: 2, eps: 2.2504492973389832e-07
# Result: True
#
#
# Test: 63
# Input shape: (5, 3, 5, 1, 5, 5), Dimension: 0, eps: 5.284733553978694e-07
# Result: True
#
#
# Test: 64
# Input shape: (5, 2, 4, 1, 3, 1), Dimension: 2, eps: 7.21680082968929e-07
# Result: True
#
#
# Test: 65
# Input shape: (2, 2, 2, 4, 1), Dimension: 0, eps: 7.042579085278366e-07
# Result: True
#
#
# Test: 66
# Input shape: (4, 1, 2), Dimension: 2, eps: 7.88429765743502e-07
# Result: True
#
#
# Test: 67
# Input shape: (4, 2, 4, 1, 4, 3), Dimension: 2, eps: 9.002618727513793e-07
# Result: True
#
#
# Test: 68
# Input shape: (2, 1, 5, 2, 1, 4), Dimension: 1, eps: 9.568741484793916e-07
# Result: True
#
#
# Test: 69
# Input shape: (2, 3, 4, 4, 5, 1), Dimension: 1, eps: 1.7584366820989726e-08
# Result: True
#
#
# Test: 70
# Input shape: (1, 1, 2, 4, 4), Dimension: 4, eps: 5.006337381982738e-07
# Result: True
#
#
# Test: 71
# Input shape: (3, 5, 5, 1, 5, 1), Dimension: 2, eps: 9.528259534025224e-07
# Result: True
#
#
# Test: 72
# Input shape: (3,), Dimension: 0, eps: 8.582787769062963e-07
# Result: True
#
#
# Test: 73
# Input shape: (3, 1), Dimension: 1, eps: 4.465342513971069e-07
# Result: True
#
#
# Test: 74
# Input shape: (2, 4, 5, 5, 1, 3), Dimension: 3, eps: 1.7709580881887543e-07
# Result: True
#
#
# Test: 75
# Input shape: (1, 1, 2, 1, 4, 2), Dimension: 5, eps: 1.1020772711941758e-07
# Result: True
#
#
# Test: 76
# Input shape: (5, 1, 1, 5, 4, 3), Dimension: 2, eps: 4.2146777164060614e-07
# Result: True
#
#
# Test: 77
# Input shape: (4, 4, 1, 3, 1, 2), Dimension: 3, eps: 9.36922629847423e-07
# Result: True
#
#
# Test: 78
# Input shape: (2, 2, 4, 5, 1, 2), Dimension: 4, eps: 4.900432387196312e-07
# Result: True
#
#
# Test: 79
# Input shape: (5, 1, 2, 3, 1, 1), Dimension: 3, eps: 6.898253983488271e-07
# Result: True
#
#
# Test: 80
# Input shape: (4, 5, 5, 1, 4, 2), Dimension: 2, eps: 9.146220699786369e-07
# Result: True
#
#
# Test: 81
# Input shape: (3, 4, 5), Dimension: 1, eps: 4.100337710615347e-07
# Result: True
#
#
# Test: 82
# Input shape: (4,), Dimension: 0, eps: 3.255797979311913e-07
# Result: True
#
#
# Test: 83
# Input shape: (5, 3, 3, 1), Dimension: 2, eps: 4.317478733905248e-07
# Result: True
#
#
# Test: 84
# Input shape: (5, 1, 1, 4, 3), Dimension: 4, eps: 3.8225036621367034e-07
# Result: True
#
#
# Test: 85
# Input shape: (4, 4, 3, 2, 4), Dimension: 3, eps: 1.3317896241292025e-08
# Result: True
#
#
# Test: 86
# Input shape: (3, 5, 2), Dimension: 0, eps: 1.879342494155903e-07
# Result: True
#
#
# Test: 87
# Input shape: (5, 1, 4, 3, 2), Dimension: 1, eps: 2.9929524186394225e-07
# Result: True
#
#
# Test: 88
# Input shape: (2, 5, 2, 5), Dimension: 3, eps: 1.863750412929936e-08
# Result: True
#
#
# Test: 89
# Input shape: (4, 4, 5, 3, 5), Dimension: 3, eps: 4.552996708446987e-07
# Result: True
#
#
# Test: 90
# Input shape: (2, 2, 5, 3), Dimension: 1, eps: 7.626458353937212e-07
# Result: True
#
#
# Test: 91
# Input shape: (1,), Dimension: 0, eps: 2.624304070097776e-07
# Result: True
#
#
# Test: 92
# Input shape: (4, 4, 1, 1), Dimension: 3, eps: 8.909085272373658e-07
# Result: True
#
#
# Test: 93
# Input shape: (4, 5, 5, 4, 3, 2), Dimension: 3, eps: 5.806388357198808e-07
# Result: True
#
#
# Test: 94
# Input shape: (2, 2, 2, 3), Dimension: 3, eps: 6.919822153731137e-07
# Result: True
#
#
# Test: 95
# Input shape: (3, 1, 3, 4), Dimension: 2, eps: 7.07842405613877e-07
# Result: True
#
#
# Test: 96
# Input shape: (5,), Dimension: 0, eps: 7.596562457945348e-07
# Result: True
#
#
# Test: 97
# Input shape: (1, 4), Dimension: 1, eps: 9.5660775065138e-07
# Result: True
#
#
# Test: 98
# Input shape: (1, 1, 3), Dimension: 2, eps: 4.198981611472476e-07
# Result: True
#
#
# Test: 99
# Input shape: (1, 2, 5, 4, 2, 3), Dimension: 5, eps: 7.715050367266706e-07
# Result: True
#
#
# Test: 100
# Input shape: (4, 3, 5, 5, 2, 2), Dimension: 4, eps: 6.810281577626596e-07
# Result: True
#
#
# Test: 101
# Input shape: (2, 5, 1, 2, 3), Dimension: 3, eps: 4.429275326245763e-07
# Result: True
#
#
# Test: 102
# Input shape: (2, 4, 1, 1, 1, 1), Dimension: 1, eps: 8.139278251484334e-07
# Result: True
#
#
# Test: 103
# Input shape: (2, 5), Dimension: 0, eps: 5.873515647760525e-07
# Result: True
#
#
# Test: 104
# Input shape: (5,), Dimension: 0, eps: 6.869002170235396e-08
# Result: True
#
#
# Test: 105
# Input shape: (5, 2), Dimension: 0, eps: 1.4480780709362009e-07
# Result: True
#
#
# Test: 106
# Input shape: (1, 5, 1, 1, 4), Dimension: 2, eps: 1.247918405662142e-07
# Result: True
#
#
# Test: 107
# Input shape: (1, 3, 2, 3, 4, 1), Dimension: 3, eps: 1.1500611493728634e-07
# Result: True
#
#
# Test: 108
# Input shape: (4, 5, 2), Dimension: 2, eps: 1.0224654121983327e-07
# Result: True
#
#
# Test: 109
# Input shape: (4, 5, 2, 2), Dimension: 2, eps: 4.671367597620083e-07
# Result: True
#
#
# Test: 110
# Input shape: (2, 5, 2, 5, 2), Dimension: 0, eps: 1.0684254685232436e-08
# Result: True
#
#
# Test: 111
# Input shape: (2, 2, 1, 5, 3, 3), Dimension: 3, eps: 4.108027098657842e-07
# Result: True
#
#
# Test: 112
# Input shape: (2, 2), Dimension: 0, eps: 4.893439271210092e-07
# Result: True
#
#
# Test: 113
# Input shape: (5, 5, 3), Dimension: 2, eps: 7.164544909551297e-07
# Result: True
#
#
# Test: 114
# Input shape: (4, 1, 2, 4, 4), Dimension: 2, eps: 5.853008810093537e-07
# Result: True
#
#
# Test: 115
# Input shape: (4, 2, 1, 5), Dimension: 1, eps: 7.945830209168126e-07
# Result: True
#
#
# Test: 116
# Input shape: (2, 2, 4), Dimension: 2, eps: 3.38209548636756e-07
# Result: True
#
#
# Test: 117
# Input shape: (2,), Dimension: 0, eps: 3.238413397638195e-07
# Result: True
#
#
# Test: 118
# Input shape: (5,), Dimension: 0, eps: 3.684722978422644e-07
# Result: True
#
#
# Test: 119
# Input shape: (3, 2, 5, 2, 2), Dimension: 0, eps: 5.219585783751597e-07
# Result: True
#
#
# Test: 120
# Input shape: (4, 1, 4, 1), Dimension: 1, eps: 9.241988774590274e-07
# Result: True
#
#
# Test: 121
# Input shape: (1, 3, 5), Dimension: 2, eps: 6.280181269052868e-08
# Result: True
#
#
# Test: 122
# Input shape: (4,), Dimension: 0, eps: 7.204050375906647e-07
# Result: True
#
#
# Test: 123
# Input shape: (3, 5, 3, 5, 1), Dimension: 4, eps: 9.271409314797243e-07
# Result: True
#
#
# Test: 124
# Input shape: (3,), Dimension: 0, eps: 7.423512289737966e-07
# Result: True
#
#
# Test: 125
# Input shape: (3,), Dimension: 0, eps: 1.0690019560422462e-07
# Result: True
#
#
# Test: 126
# Input shape: (1, 4, 4, 1, 4, 4), Dimension: 5, eps: 6.57493934323429e-07
# Result: True
#
#
# Test: 127
# Input shape: (2, 1, 3, 1), Dimension: 1, eps: 7.433877463445364e-07
# Result: True
#
#
# Test: 128
# Input shape: (4, 3), Dimension: 0, eps: 6.706091985986286e-07
# Result: True
#
#
# Test: 129
# Input shape: (5, 3, 4, 2), Dimension: 3, eps: 6.86415714385579e-07
# Result: True
#
#
# Test: 130
# Input shape: (5, 1), Dimension: 0, eps: 5.153767928380498e-07
# Result: True
#
#
# Test: 131
# Input shape: (2, 3, 3), Dimension: 1, eps: 7.348661217412523e-07
# Result: True
#
#
# Test: 132
# Input shape: (5, 2, 1), Dimension: 0, eps: 7.349046924895292e-07
# Result: True
#
#
# Test: 133
# Input shape: (1, 2, 5, 1, 2), Dimension: 2, eps: 4.989673252331898e-08
# Result: True
#
#
# Test: 134
# Input shape: (2, 4), Dimension: 1, eps: 7.036710221016169e-07
# Result: True
#
#
# Test: 135
# Input shape: (2, 4, 3, 4, 1), Dimension: 4, eps: 5.712781813911384e-07
# Result: True
#
#
# Test: 136
# Input shape: (2,), Dimension: 0, eps: 1.9199284812267482e-07
# Result: True
#
#
# Test: 137
# Input shape: (5, 2, 3, 4, 4, 2), Dimension: 0, eps: 4.304416802894978e-07
# Result: True
#
#
# Test: 138
# Input shape: (2,), Dimension: 0, eps: 4.0353642045996145e-07
# Result: True
#
#
# Test: 139
# Input shape: (2, 1, 4), Dimension: 1, eps: 6.720289591000458e-07
# Result: True
#
#
# Test: 140
# Input shape: (1, 3, 1), Dimension: 2, eps: 1.2882312046983194e-07
# Result: True
#
#
# Test: 141
# Input shape: (1,), Dimension: 0, eps: 4.677670972075213e-08
# Result: True
#
#
# Test: 142
# Input shape: (4, 1, 2, 3), Dimension: 3, eps: 4.864149738971299e-07
# Result: True
#
#
# Test: 143
# Input shape: (2, 3, 5), Dimension: 0, eps: 9.092488187569683e-07
# Result: True
#
#
# Test: 144
# Input shape: (5, 1), Dimension: 0, eps: 7.33774868288172e-10
# Result: True
#
#
# Test: 145
# Input shape: (1, 4, 3, 2, 2), Dimension: 4, eps: 2.8677979243283375e-07
# Result: True
#
#
# Test: 146
# Input shape: (1,), Dimension: 0, eps: 7.412222065817911e-07
# Result: True
#
#
# Test: 147
# Input shape: (4, 3), Dimension: 0, eps: 4.3170396722975803e-07
# Result: True
#
#
# Test: 148
# Input shape: (3, 2, 3), Dimension: 1, eps: 3.80598061084656e-07
# Result: True
#
#
# Test: 149
# Input shape: (1, 4), Dimension: 1, eps: 3.1820576522446026e-08
# Result: True
#
#
# Test: 150
# Input shape: (4, 3, 5, 4, 3), Dimension: 2, eps: 1.6619390573325645e-07
# Result: True
#
#
# Test: 151
# Input shape: (4,), Dimension: 0, eps: 3.422699280034364e-07
# Result: True
#
#
# Test: 152
# Input shape: (3, 4), Dimension: 1, eps: 1.4534325351705908e-08
# Result: True
#
#
# Test: 153
# Input shape: (2, 2, 1, 5, 5), Dimension: 0, eps: 1.9177568172504537e-07
# Result: True
#
#
# Test: 154
# Input shape: (1, 4, 2), Dimension: 0, eps: 6.135986114173858e-07
# Result: True
#
#
# Test: 155
# Input shape: (4, 4, 5, 2, 4, 4), Dimension: 4, eps: 4.731197877761641e-07
# Result: True
#
#
# Test: 156
# Input shape: (1, 2, 4, 4), Dimension: 2, eps: 8.049697447381189e-07
# Result: True
#
#
# Test: 157
# Input shape: (5, 3), Dimension: 1, eps: 2.5556319030398316e-07
# Result: True
#
#
# Test: 158
# Input shape: (2,), Dimension: 0, eps: 8.723787047465014e-07
# Result: True
#
#
# Test: 159
# Input shape: (1, 5), Dimension: 1, eps: 2.3849823272920406e-07
# Result: True
#
#
# Test: 160
# Input shape: (5, 3), Dimension: 0, eps: 7.182810683121019e-07
# Result: True
#
#
# Test: 161
# Input shape: (1, 1), Dimension: 1, eps: 8.962985996816358e-07
# Result: True
#
#
# Test: 162
# Input shape: (5, 1), Dimension: 1, eps: 2.870593295939263e-07
# Result: True
#
#
# Test: 163
# Input shape: (1,), Dimension: 0, eps: 5.780801760100453e-07
# Result: True
#
#
# Test: 164
# Input shape: (1, 1, 3, 4, 4, 5), Dimension: 4, eps: 8.369508608825867e-08
# Result: True
#
#
# Test: 165
# Input shape: (5, 2, 4, 2), Dimension: 1, eps: 9.789659472962937e-07
# Result: True
#
#
# Test: 166
# Input shape: (2, 2, 2), Dimension: 0, eps: 3.7216265008129224e-07
# Result: True
#
#
# Test: 167
# Input shape: (4, 3, 5, 1, 1), Dimension: 2, eps: 6.8089118022804e-08
# Result: True
#
#
# Test: 168
# Input shape: (1, 2, 5), Dimension: 1, eps: 3.784579329179564e-07
# Result: True
#
#
# Test: 169
# Input shape: (4, 5, 4, 3, 4, 5), Dimension: 1, eps: 9.480217602644575e-07
# Result: True
#
#
# Test: 170
# Input shape: (4, 3), Dimension: 0, eps: 4.581583649125678e-07
# Result: True
#
#
# Test: 171
# Input shape: (1, 1, 4, 3), Dimension: 2, eps: 6.202574114451185e-07
# Result: True
#
#
# Test: 172
# Input shape: (5, 3, 5, 1), Dimension: 3, eps: 6.349613740805477e-07
# Result: True
#
#
# Test: 173
# Input shape: (5,), Dimension: 0, eps: 7.613730728921228e-07
# Result: True
#
#
# Test: 174
# Input shape: (2, 5, 5, 3, 5), Dimension: 3, eps: 7.578055030644531e-07
# Result: True
#
#
# Test: 175
# Input shape: (4, 4, 2), Dimension: 1, eps: 7.721789651016847e-07
# Result: True
#
#
# Test: 176
# Input shape: (3, 1), Dimension: 1, eps: 8.981751246758926e-07
# Result: True
#
#
# Test: 177
# Input shape: (4,), Dimension: 0, eps: 5.816882028892323e-07
# Result: True
#
#
# Test: 178
# Input shape: (3, 4), Dimension: 1, eps: 4.51041160223233e-07
# Result: True
#
#
# Test: 179
# Input shape: (5,), Dimension: 0, eps: 6.074657816511616e-07
# Result: True
#
#
# Test: 180
# Input shape: (4, 4), Dimension: 0, eps: 6.434513583255299e-07
# Result: True
#
#
# Test: 181
# Input shape: (3, 4, 5, 1, 5), Dimension: 1, eps: 2.3510993375415381e-07
# Result: True
#
#
# Test: 182
# Input shape: (1, 4), Dimension: 1, eps: 8.323185679332723e-07
# Result: True
#
#
# Test: 183
# Input shape: (1, 5, 5, 4, 4), Dimension: 0, eps: 4.300906049614436e-07
# Result: True
#
#
# Test: 184
# Input shape: (5, 4), Dimension: 1, eps: 8.034219709412939e-07
# Result: True
#
#
# Test: 185
# Input shape: (1, 2, 5, 5, 5, 2), Dimension: 5, eps: 6.499952598127987e-07
# Result: True
#
#
# Test: 186
# Input shape: (2,), Dimension: 0, eps: 3.868004553499397e-07
# Result: True
#
#
# Test: 187
# Input shape: (1, 5), Dimension: 0, eps: 4.1658095231937113e-07
# Result: True
#
#
# Test: 188
# Input shape: (4, 2), Dimension: 1, eps: 8.77331962701763e-09
# Result: True
#
#
# Test: 189
# Input shape: (3, 2, 5, 1), Dimension: 2, eps: 4.435420347310966e-07
# Result: True
#
#
# Test: 190
# Input shape: (5, 5, 3, 5, 2), Dimension: 2, eps: 5.514765710841249e-07
# Result: True
#
#
# Test: 191
# Input shape: (5, 5), Dimension: 0, eps: 5.661644720590723e-07
# Result: True
#
#
# Test: 192
# Input shape: (1, 3, 3), Dimension: 1, eps: 6.053552903131753e-07
# Result: True
#
#
# Test: 193
# Input shape: (3, 1, 3), Dimension: 2, eps: 2.3440760034858688e-07
# Result: True
#
#
# Test: 194
# Input shape: (4, 3, 3), Dimension: 1, eps: 5.420665763049156e-07
# Result: True
#
#
# Test: 195
# Input shape: (3, 1, 3, 1), Dimension: 1, eps: 1.8764989271137627e-07
# Result: True
#
#
# Test: 196
# Input shape: (1, 5, 3, 4, 2), Dimension: 2, eps: 4.6758151159838016e-07
# Result: True
#
#
# Test: 197
# Input shape: (3, 4, 5, 1, 4, 3), Dimension: 5, eps: 3.483955636166271e-07
# Result: True
#
#
# Test: 198
# Input shape: (4, 4, 2), Dimension: 0, eps: 5.52100987486524e-08
# Result: True
#
#
# Test: 199
# Input shape: (5, 1, 2, 1, 3), Dimension: 0, eps: 1.2554497662267422e-07
# Result: True
#
#
# Test: 200
# Input shape: (4, 5, 2), Dimension: 1, eps: 8.738991866073089e-07
# Result: True
#
#
# Test: 201
# Input shape: (1,), Dimension: 0, eps: 4.044907699275037e-07
# Result: True
#
#
# Test: 202
# Input shape: (5, 1), Dimension: 1, eps: 2.388437189158071e-07
# Result: True
#
#
# Test: 203
# Input shape: (2, 5, 1, 2), Dimension: 1, eps: 1.7455169111966575e-07
# Result: True
#
#
# Test: 204
# Input shape: (5, 2, 2, 3), Dimension: 3, eps: 2.9227044959262866e-07
# Result: True
#
#
# Test: 205
# Input shape: (1, 1, 1, 5), Dimension: 1, eps: 4.623782860390009e-07
# Result: True
#
#
# Test: 206
# Input shape: (2,), Dimension: 0, eps: 2.9114568115485447e-07
# Result: True
#
#
# Test: 207
# Input shape: (5, 1), Dimension: 1, eps: 7.72038125144466e-07
# Result: True
#
#
# Test: 208
# Input shape: (4,), Dimension: 0, eps: 3.5470142171063824e-07
# Result: True
#
#
# Test: 209
# Input shape: (3, 1), Dimension: 1, eps: 6.616938451953137e-07
# Result: True
#
#
# Test: 210
# Input shape: (2, 1, 1, 3, 3), Dimension: 4, eps: 7.93887411873879e-07
# Result: True
#
#
# Test: 211
# Input shape: (2, 2), Dimension: 0, eps: 4.769424300910475e-07
# Result: True
#
#
# Test: 212
# Input shape: (4, 3, 2, 4, 4, 5), Dimension: 0, eps: 9.526401661071197e-07
# Result: True
#
#
# Test: 213
# Input shape: (3, 1), Dimension: 0, eps: 9.921630396263108e-07
# Result: True
#
#
# Test: 214
# Input shape: (2, 4, 5), Dimension: 2, eps: 5.401172700114612e-07
# Result: True
#
#
# Test: 215
# Input shape: (5,), Dimension: 0, eps: 7.840433380961817e-07
# Result: True
#
#
# Test: 216
# Input shape: (5, 3, 2, 5), Dimension: 1, eps: 7.219224248838426e-07
# Result: True
#
#
# Test: 217
# Input shape: (2,), Dimension: 0, eps: 6.156196360955534e-07
# Result: True
#
#
# Test: 218
# Input shape: (3, 1, 5, 1, 1, 3), Dimension: 4, eps: 1.8083105619950744e-07
# Result: True
#
#
# Test: 219
# Input shape: (2, 3), Dimension: 0, eps: 2.528701971147274e-07
# Result: True
#
#
# Test: 220
# Input shape: (5,), Dimension: 0, eps: 5.294869930647835e-07
# Result: True
#
#
# Test: 221
# Input shape: (2,), Dimension: 0, eps: 9.871626902039514e-07
# Result: True
#
#
# Test: 222
# Input shape: (2, 4, 3, 5, 1), Dimension: 2, eps: 6.902411029774113e-07
# Result: True
#
#
# Test: 223
# Input shape: (3, 3, 3, 2), Dimension: 1, eps: 8.15826757251154e-07
# Result: True
#
#
# Test: 224
# Input shape: (3, 2, 3, 3, 2), Dimension: 2, eps: 1.9242569537071774e-07
# Result: True
#
#
# Test: 225
# Input shape: (5, 2, 4, 4, 1), Dimension: 0, eps: 1.850059161810805e-07
# Result: True
#
#
# Test: 226
# Input shape: (2, 2, 5), Dimension: 0, eps: 6.593743717346862e-08
# Result: True
#
#
# Test: 227
# Input shape: (1,), Dimension: 0, eps: 1.6074765348288066e-07
# Result: True
#
#
# Test: 228
# Input shape: (1, 2, 3), Dimension: 1, eps: 5.1797312854675677e-08
# Result: True
#
#
# Test: 229
# Input shape: (4, 4, 1, 1, 2), Dimension: 2, eps: 1.9900997805423706e-07
# Result: True
#
#
# Test: 230
# Input shape: (4, 3, 4), Dimension: 1, eps: 3.6722092626567024e-07
# Result: True
#
#
# Test: 231
# Input shape: (3, 2, 4, 2), Dimension: 2, eps: 5.305864402298596e-07
# Result: True
#
#
# Test: 232
# Input shape: (3, 3), Dimension: 1, eps: 9.23311839828359e-07
# Result: True
#
#
# Test: 233
# Input shape: (4,), Dimension: 0, eps: 7.739399434763052e-07
# Result: True
#
#
# Test: 234
# Input shape: (4, 1, 2, 5, 5, 2), Dimension: 2, eps: 6.769050224063696e-07
# Result: True
#
#
# Test: 235
# Input shape: (3,), Dimension: 0, eps: 8.181268474351635e-07
# Result: True
#
#
# Test: 236
# Input shape: (5, 3, 2, 2, 1), Dimension: 4, eps: 5.797183752834711e-07
# Result: True
#
#
# Test: 237
# Input shape: (5, 2, 5, 1), Dimension: 2, eps: 6.897261342903604e-07
# Result: True
#
#
# Test: 238
# Input shape: (3, 5, 5, 4, 4), Dimension: 2, eps: 2.680569004487532e-07
# Result: True
#
#
# Test: 239
# Input shape: (5, 5, 3), Dimension: 2, eps: 8.001969005402767e-07
# Result: True
#
#
# Test: 240
# Input shape: (4, 1, 5), Dimension: 2, eps: 6.567787838275813e-07
# Result: True
#
#
# Test: 241
# Input shape: (3,), Dimension: 0, eps: 8.776116704373685e-07
# Result: True
#
#
# Test: 242
# Input shape: (4, 3, 1), Dimension: 2, eps: 1.9443368821808246e-08
# Result: True
#
#
# Test: 243
# Input shape: (5, 5, 1, 5, 3), Dimension: 2, eps: 2.178306148696108e-07
# Result: True
#
#
# Test: 244
# Input shape: (2, 1), Dimension: 0, eps: 8.202143623706609e-07
# Result: True
#
#
# Test: 245
# Input shape: (5,), Dimension: 0, eps: 3.0037183397695776e-07
# Result: True
#
#
# Test: 246
# Input shape: (4,), Dimension: 0, eps: 7.905496853425014e-07
# Result: True
#
#
# Test: 247
# Input shape: (5,), Dimension: 0, eps: 2.5400450204156586e-07
# Result: True
#
#
# Test: 248
# Input shape: (2, 4, 4, 5, 4), Dimension: 0, eps: 4.747435450286278e-07
# Result: True
#
#
# Test: 249
# Input shape: (4, 2, 5), Dimension: 2, eps: 7.23504201471318e-07
# Result: True
#
#
# Test: 250
# Input shape: (5, 1), Dimension: 1, eps: 4.54823769785344e-07
# Result: True
#
#
# Test: 251
# Input shape: (4, 5, 1, 5, 5, 4), Dimension: 2, eps: 9.942525446417138e-07
# Result: True
#
#
# Test: 252
# Input shape: (4, 5, 4, 2), Dimension: 0, eps: 9.041793409626351e-07
# Result: True
#
#
# Test: 253
# Input shape: (5, 4, 4, 3), Dimension: 1, eps: 9.046601730701003e-07
# Result: True
#
#
# Test: 254
# Input shape: (3,), Dimension: 0, eps: 4.634274958312324e-07
# Result: True
#
#
# Test: 255
# Input shape: (2, 3), Dimension: 1, eps: 8.95884419279888e-08
# Result: True
#
#
# Test: 256
# Input shape: (4, 2, 1, 5, 4), Dimension: 1, eps: 1.9852343350353207e-07
# Result: True
#
#
# Test: 257
# Input shape: (3, 3), Dimension: 0, eps: 7.727453320503323e-07
# Result: True
#
#
# Test: 258
# Input shape: (2, 5, 1, 1, 5), Dimension: 4, eps: 9.300623862339542e-07
# Result: True
#
#
# Test: 259
# Input shape: (4, 1, 3, 2), Dimension: 2, eps: 2.3003800306615232e-07
# Result: True
#
#
# Test: 260
# Input shape: (4, 1, 5, 1, 2, 5), Dimension: 5, eps: 6.34307486251706e-08
# Result: True
#
#
# Test: 261
# Input shape: (4, 1, 4), Dimension: 2, eps: 1.6066017804643868e-07
# Result: True
#
#
# Test: 262
# Input shape: (1, 5, 1), Dimension: 2, eps: 1.4344718091099436e-07
# Result: True
#
#
# Test: 263
# Input shape: (3, 1, 1, 1, 2), Dimension: 0, eps: 3.7704713539527125e-07
# Result: True
#
#
# Test: 264
# Input shape: (3, 3, 5, 2), Dimension: 3, eps: 9.892028968759791e-07
# Result: True
#
#
# Test: 265
# Input shape: (2, 3, 2), Dimension: 0, eps: 7.35268695030448e-07
# Result: True
#
#
# Test: 266
# Input shape: (3,), Dimension: 0, eps: 8.174517031292481e-08
# Result: True
#
#
# Test: 267
# Input shape: (5, 3), Dimension: 1, eps: 1.6555094089470197e-07
# Result: True
#
#
# Test: 268
# Input shape: (2, 1, 2, 3), Dimension: 0, eps: 5.688144734878577e-07
# Result: True
#
#
# Test: 269
# Input shape: (1, 4, 3, 3, 5, 1), Dimension: 3, eps: 3.269875189936127e-07
# Result: True
#
#
# Test: 270
# Input shape: (3, 5, 1, 3), Dimension: 1, eps: 5.441517962319834e-07
# Result: True
#
#
# Test: 271
# Input shape: (5, 1, 5, 3, 1), Dimension: 2, eps: 6.224062205072523e-07
# Result: True
#
#
# Test: 272
# Input shape: (5,), Dimension: 0, eps: 2.772401641559682e-07
# Result: True
#
#
# Test: 273
# Input shape: (3, 1, 5), Dimension: 2, eps: 7.975180671013843e-07
# Result: True
#
#
# Test: 274
# Input shape: (3, 1, 2, 2), Dimension: 3, eps: 6.52796874850334e-07
# Result: True
#
#
# Test: 275
# Input shape: (5,), Dimension: 0, eps: 4.1561468528412715e-07
# Result: True
#
#
# Test: 276
# Input shape: (1, 4), Dimension: 1, eps: 2.26779967619186e-07
# Result: True
#
#
# Test: 277
# Input shape: (2, 3, 3, 4), Dimension: 1, eps: 4.860460517318253e-07
# Result: True
#
#
# Test: 278
# Input shape: (3, 2, 4, 4), Dimension: 1, eps: 8.407621244537433e-07
# Result: True
#
#
# Test: 279
# Input shape: (4, 5, 2, 5, 5), Dimension: 4, eps: 2.6172448866904008e-08
# Result: True
#
#
# Test: 280
# Input shape: (5, 5, 4, 2, 5), Dimension: 4, eps: 1.1693884864000637e-07
# Result: True
#
#
# Test: 281
# Input shape: (4,), Dimension: 0, eps: 1.7980427984932117e-07
# Result: True
#
#
# Test: 282
# Input shape: (2, 2, 2, 1, 5), Dimension: 1, eps: 3.6300908434106717e-07
# Result: True
#
#
# Test: 283
# Input shape: (4,), Dimension: 0, eps: 1.3432289583981312e-07
# Result: True
#
#
# Test: 284
# Input shape: (4,), Dimension: 0, eps: 8.432868562620288e-07
# Result: True
#
#
# Test: 285
# Input shape: (2, 4, 3), Dimension: 2, eps: 2.3668110874088947e-07
# Result: True
#
#
# Test: 286
# Input shape: (1, 2, 5, 4, 5, 1), Dimension: 0, eps: 7.011923571762945e-07
# Result: True
#
#
# Test: 287
# Input shape: (5, 1, 3), Dimension: 1, eps: 7.165859679356718e-07
# Result: True
#
#
# Test: 288
# Input shape: (2, 5), Dimension: 0, eps: 3.1528240555433604e-07
# Result: True
#
#
# Test: 289
# Input shape: (3, 1, 3, 4, 5, 1), Dimension: 4, eps: 3.460914028423891e-08
# Result: True
#
#
# Test: 290
# Input shape: (1, 4, 4), Dimension: 1, eps: 9.223874337013129e-08
# Result: True
#
#
# Test: 291
# Input shape: (2, 2, 1), Dimension: 0, eps: 6.700414861817586e-07
# Result: True
#
#
# Test: 292
# Input shape: (5, 4), Dimension: 1, eps: 4.641626674397887e-07
# Result: True
#
#
# Test: 293
# Input shape: (4, 2, 2), Dimension: 1, eps: 2.0411975974895164e-07
# Result: True
#
#
# Test: 294
# Input shape: (2, 1, 3), Dimension: 1, eps: 3.374534763571634e-07
# Result: True
#
#
# Test: 295
# Input shape: (5, 3, 1), Dimension: 1, eps: 2.637689095365901e-07
# Result: True
#
#
# Test: 296
# Input shape: (4, 2, 1, 1, 5, 5), Dimension: 3, eps: 1.6444503997654343e-07
# Result: True
#
#
# Test: 297
# Input shape: (3, 4), Dimension: 1, eps: 4.656328569331275e-07
# Result: True
#
#
# Test: 298
# Input shape: (1, 4, 5, 3, 3, 2), Dimension: 0, eps: 3.624402860513967e-08
# Result: True
#
#
# Test: 299
# Input shape: (5, 3, 2), Dimension: 0, eps: 3.956003310811933e-07
# Result: True
#
#
# Test: 300
# Input shape: (1,), Dimension: 0, eps: 9.736348955757223e-07
# Result: True
#
#
# Test: 301
# Input shape: (4, 5), Dimension: 0, eps: 5.272892300908022e-08
# Result: True
#
#
# Test: 302
# Input shape: (5, 3, 5), Dimension: 1, eps: 3.784122702206693e-08
# Result: True
#
#
# Test: 303
# Input shape: (3, 3, 2, 1), Dimension: 0, eps: 5.732515808852384e-07
# Result: True
#
#
# Test: 304
# Input shape: (1, 3, 5), Dimension: 0, eps: 6.749339862754309e-07
# Result: True
#
#
# Test: 305
# Input shape: (1,), Dimension: 0, eps: 7.452530911239932e-07
# Result: True
#
#
# Test: 306
# Input shape: (4,), Dimension: 0, eps: 5.194432170285481e-07
# Result: True
#
#
# Test: 307
# Input shape: (5,), Dimension: 0, eps: 3.262653816089792e-07
# Result: True
#
#
# Test: 308
# Input shape: (3, 1, 4), Dimension: 2, eps: 2.8067914951286064e-07
# Result: True
#
#
# Test: 309
# Input shape: (4,), Dimension: 0, eps: 5.404119791443616e-07
# Result: True
#
#
# Test: 310
# Input shape: (1,), Dimension: 0, eps: 5.864087474444096e-07
# Result: True
#
#
# Test: 311
# Input shape: (2, 1), Dimension: 1, eps: 6.56921618812513e-07
# Result: True
#
#
# Test: 312
# Input shape: (1, 5, 5, 5, 5), Dimension: 2, eps: 7.365880786971968e-07
# Result: True
#
#
# Test: 313
# Input shape: (1, 2), Dimension: 0, eps: 5.369588124989992e-07
# Result: True
#
#
# Test: 314
# Input shape: (3, 4), Dimension: 0, eps: 5.324221111205977e-07
# Result: True
#
#
# Test: 315
# Input shape: (4, 4, 5, 4), Dimension: 0, eps: 5.785281117392148e-07
# Result: True
#
#
# Test: 316
# Input shape: (3, 1, 2), Dimension: 1, eps: 9.712597918513988e-07
# Result: True
#
#
# Test: 317
# Input shape: (5,), Dimension: 0, eps: 6.665614505475196e-07
# Result: True
#
#
# Test: 318
# Input shape: (2,), Dimension: 0, eps: 9.414741820470408e-07
# Result: True
#
#
# Test: 319
# Input shape: (5,), Dimension: 0, eps: 1.4932359635970817e-07
# Result: True
#
#
# Test: 320
# Input shape: (3,), Dimension: 0, eps: 9.020459209445756e-07
# Result: True
#
#
# Test: 321
# Input shape: (1, 5, 1, 1, 5), Dimension: 3, eps: 6.887285041630151e-07
# Result: True
#
#
# Test: 322
# Input shape: (3,), Dimension: 0, eps: 2.505808280009449e-07
# Result: True
#
#
# Test: 323
# Input shape: (5, 1, 1), Dimension: 1, eps: 6.576061804719285e-07
# Result: True
#
#
# Test: 324
# Input shape: (2, 3, 2, 1, 3), Dimension: 0, eps: 4.5957306629787765e-07
# Result: True
#
#
# Test: 325
# Input shape: (3, 4, 3, 2, 4, 2), Dimension: 3, eps: 9.67903108288826e-07
# Result: True
#
#
# Test: 326
# Input shape: (1, 2, 4), Dimension: 1, eps: 3.506489879261761e-07
# Result: True
#
#
# Test: 327
# Input shape: (5, 2, 4, 2, 1), Dimension: 4, eps: 7.496142472984362e-07
# Result: True
#
#
# Test: 328
# Input shape: (1, 1, 5, 5), Dimension: 1, eps: 8.041685389345109e-07
# Result: True
#
#
# Test: 329
# Input shape: (2, 1, 2, 2, 1), Dimension: 1, eps: 6.763244401885406e-07
# Result: True
#
#
# Test: 330
# Input shape: (4, 3, 3, 5), Dimension: 3, eps: 1.3734602086699946e-07
# Result: True
#
#
# Test: 331
# Input shape: (1, 3), Dimension: 0, eps: 7.737340771912782e-07
# Result: True
#
#
# Test: 332
# Input shape: (1, 3, 1, 1, 5, 3), Dimension: 0, eps: 3.8373410997229783e-07
# Result: True
#
#
# Test: 333
# Input shape: (3, 1, 2), Dimension: 1, eps: 6.836649802816513e-07
# Result: True
#
#
# Test: 334
# Input shape: (4, 3), Dimension: 0, eps: 9.618915204430694e-07
# Result: True
#
#
# Test: 335
# Input shape: (4, 3, 4, 4, 5), Dimension: 4, eps: 3.161988365704791e-07
# Result: True
#
#
# Test: 336
# Input shape: (2, 2, 3, 3, 2), Dimension: 2, eps: 3.412846528329416e-07
# Result: True
#
#
# Test: 337
# Input shape: (1, 2, 5, 5, 2, 2), Dimension: 5, eps: 4.522075329060707e-08
# Result: True
#
#
# Test: 338
# Input shape: (1,), Dimension: 0, eps: 2.439691294607393e-07
# Result: True
#
#
# Test: 339
# Input shape: (4, 1, 5, 5, 2), Dimension: 0, eps: 1.7001676381824991e-07
# Result: True
#
#
# Test: 340
# Input shape: (3, 2), Dimension: 0, eps: 4.996791732693576e-07
# Result: True
#
#
# Test: 341
# Input shape: (3, 1, 5), Dimension: 2, eps: 2.1725547533430958e-07
# Result: True
#
#
# Test: 342
# Input shape: (4,), Dimension: 0, eps: 1.7071035803588055e-07
# Result: True
#
#
# Test: 343
# Input shape: (5,), Dimension: 0, eps: 7.864794174735817e-07
# Result: True
#
#
# Test: 344
# Input shape: (5, 5, 5, 2, 4), Dimension: 3, eps: 6.685541566814177e-08
# Result: True
#
#
# Test: 345
# Input shape: (3, 2, 1, 5), Dimension: 0, eps: 5.560272000597923e-07
# Result: True
#
#
# Test: 346
# Input shape: (3, 3, 2, 4, 4, 2), Dimension: 2, eps: 3.4260728597544983e-07
# Result: True
#
#
# Test: 347
# Input shape: (2,), Dimension: 0, eps: 9.228860495002273e-07
# Result: True
#
#
# Test: 348
# Input shape: (5, 3, 4, 3, 3, 5), Dimension: 3, eps: 8.076310539950099e-07
# Result: True
#
#
# Test: 349
# Input shape: (3, 4), Dimension: 1, eps: 3.685092064913467e-07
# Result: True
#
#
# Test: 350
# Input shape: (1, 5, 3, 3, 2, 3), Dimension: 3, eps: 9.486371396482158e-07
# Result: True
#
#
# Test: 351
# Input shape: (1, 5, 2, 4), Dimension: 2, eps: 4.7109352842246843e-07
# Result: True
#
#
# Test: 352
# Input shape: (5, 4, 4, 2), Dimension: 0, eps: 5.980284489835553e-07
# Result: True
#
#
# Test: 353
# Input shape: (2, 3, 4, 1, 1, 3), Dimension: 0, eps: 6.969771329429754e-07
# Result: True
#
#
# Test: 354
# Input shape: (2, 3), Dimension: 0, eps: 8.345383848308653e-07
# Result: True
#
#
# Test: 355
# Input shape: (5, 5), Dimension: 0, eps: 7.192109440627002e-07
# Result: True
#
#
# Test: 356
# Input shape: (4,), Dimension: 0, eps: 9.299141258911576e-07
# Result: True
#
#
# Test: 357
# Input shape: (4, 5, 2, 2, 3, 3), Dimension: 3, eps: 2.392129747002928e-07
# Result: True
#
#
# Test: 358
# Input shape: (3, 3, 3), Dimension: 1, eps: 6.469588603293111e-07
# Result: True
#
#
# Test: 359
# Input shape: (1, 4, 2, 4, 3), Dimension: 0, eps: 8.34790479633303e-07
# Result: True
#
#
# Test: 360
# Input shape: (2, 1, 2, 4), Dimension: 3, eps: 4.5019686165532566e-07
# Result: True
#
#
# Test: 361
# Input shape: (3, 5, 1, 1, 5, 2), Dimension: 3, eps: 3.0215630040439436e-07
# Result: True
#
#
# Test: 362
# Input shape: (2,), Dimension: 0, eps: 8.855387460727043e-07
# Result: True
#
#
# Test: 363
# Input shape: (1, 5, 1, 5, 2, 5), Dimension: 0, eps: 9.285042145413841e-07
# Result: True
#
#
# Test: 364
# Input shape: (2, 5, 1), Dimension: 1, eps: 2.0323297263591452e-07
# Result: True
#
#
# Test: 365
# Input shape: (1,), Dimension: 0, eps: 8.605769526622227e-10
# Result: True
#
#
# Test: 366
# Input shape: (4, 1, 4), Dimension: 2, eps: 3.466331929484921e-07
# Result: True
#
#
# Test: 367
# Input shape: (4, 3, 3, 2, 2), Dimension: 2, eps: 2.9384879392445825e-08
# Result: True
#
#
# Test: 368
# Input shape: (4, 2, 5, 2), Dimension: 0, eps: 7.250778747072206e-07
# Result: True
#
#
# Test: 369
# Input shape: (5,), Dimension: 0, eps: 8.265980143549743e-07
# Result: True
#
#
# Test: 370
# Input shape: (5, 2, 3, 4, 3), Dimension: 0, eps: 5.293553809475693e-07
# Result: True
#
#
# Test: 371
# Input shape: (2, 2, 3, 5, 4, 3), Dimension: 3, eps: 9.298915932428056e-07
# Result: True
#
#
# Test: 372
# Input shape: (5,), Dimension: 0, eps: 8.420860800451541e-07
# Result: True
#
#
# Test: 373
# Input shape: (4, 3, 5, 2, 2), Dimension: 1, eps: 5.358974304072147e-07
# Result: True
#
#
# Test: 374
# Input shape: (2, 5, 3, 4, 5), Dimension: 2, eps: 2.5940051301107463e-08
# Result: True
#
#
# Test: 375
# Input shape: (3, 1, 2), Dimension: 0, eps: 4.971729033854682e-07
# Result: True
#
#
# Test: 376
# Input shape: (2, 3, 1, 1), Dimension: 2, eps: 6.63686817053366e-08
# Result: True
#
#
# Test: 377
# Input shape: (2, 3), Dimension: 0, eps: 6.842507495601751e-07
# Result: True
#
#
# Test: 378
# Input shape: (1, 4, 3, 2, 2, 4), Dimension: 0, eps: 2.4826952587551513e-07
# Result: True
#
#
# Test: 379
# Input shape: (4, 5, 1, 1), Dimension: 1, eps: 5.908981374129747e-07
# Result: True
#
#
# Test: 380
# Input shape: (4, 2, 5, 3), Dimension: 3, eps: 6.787506873515437e-07
# Result: True
#
#
# Test: 381
# Input shape: (4, 3, 2, 2, 2), Dimension: 1, eps: 7.304681580691001e-07
# Result: True
#
#
# Test: 382
# Input shape: (3, 2, 3), Dimension: 1, eps: 2.509457089560394e-08
# Result: True
#
#
# Test: 383
# Input shape: (4, 2, 1, 2, 2, 1), Dimension: 2, eps: 8.388224428800768e-07
# Result: True
#
#
# Test: 384
# Input shape: (5, 4, 1, 4), Dimension: 3, eps: 1.595061833756846e-07
# Result: True
#
#
# Test: 385
# Input shape: (1, 3, 3), Dimension: 0, eps: 4.829209554005183e-08
# Result: True
#
#
# Test: 386
# Input shape: (3, 3), Dimension: 1, eps: 1.7052032427482617e-07
# Result: True
#
#
# Test: 387
# Input shape: (2, 5), Dimension: 0, eps: 8.663009128912672e-07
# Result: True
#
#
# Test: 388
# Input shape: (4, 4), Dimension: 0, eps: 5.335373803814059e-07
# Result: True
#
#
# Test: 389
# Input shape: (5, 1), Dimension: 1, eps: 2.540124296630406e-07
# Result: True
#
#
# Test: 390
# Input shape: (4, 4, 2, 2), Dimension: 3, eps: 1.8106893338366338e-07
# Result: True
#
#
# Test: 391
# Input shape: (2, 4, 4, 3, 3, 2), Dimension: 1, eps: 9.296378178079528e-07
# Result: True
#
#
# Test: 392
# Input shape: (1,), Dimension: 0, eps: 8.108240101119277e-08
# Result: True
#
#
# Test: 393
# Input shape: (4, 5, 4, 1, 1, 2), Dimension: 3, eps: 1.408397850875432e-08
# Result: True
#
#
# Test: 394
# Input shape: (2, 4, 1, 4), Dimension: 0, eps: 3.735229340237393e-07
# Result: True
#
#
# Test: 395
# Input shape: (5, 1, 3, 4, 5), Dimension: 4, eps: 8.988145244650187e-07
# Result: True
#
#
# Test: 396
# Input shape: (3, 1), Dimension: 1, eps: 7.40999732181105e-07
# Result: True
#
#
# Test: 397
# Input shape: (1, 5, 4), Dimension: 2, eps: 6.425997492404537e-08
# Result: True
#
#
# Test: 398
# Input shape: (1, 3, 3, 5), Dimension: 2, eps: 5.834386637433364e-07
# Result: True
#
#
# Test: 399
# Input shape: (2, 5, 5, 5, 4), Dimension: 3, eps: 6.58975356517316e-07
# Result: True
#
#
# Test: 400
# Input shape: (3,), Dimension: 0, eps: 7.957876509149249e-07
# Result: True
#
#
# Test: 401
# Input shape: (4, 2, 4, 3, 3), Dimension: 2, eps: 5.574507670007951e-07
# Result: True
#
#
# Test: 402
# Input shape: (1, 3, 5, 4, 2, 4), Dimension: 0, eps: 3.7171168441704044e-07
# Result: True
#
#
# Test: 403
# Input shape: (1, 1, 2), Dimension: 0, eps: 6.958871204767356e-07
# Result: True
#
#
# Test: 404
# Input shape: (4, 1, 1), Dimension: 0, eps: 3.7309636470228075e-07
# Result: True
#
#
# Test: 405
# Input shape: (3, 4, 5), Dimension: 1, eps: 5.122870692543576e-07
# Result: True
#
#
# Test: 406
# Input shape: (3, 1, 2), Dimension: 0, eps: 4.6361265428845834e-07
# Result: True
#
#
# Test: 407
# Input shape: (5, 1, 5), Dimension: 1, eps: 7.76814260163691e-07
# Result: True
#
#
# Test: 408
# Input shape: (4, 2), Dimension: 0, eps: 5.858959094711657e-07
# Result: True
#
#
# Test: 409
# Input shape: (2, 5), Dimension: 0, eps: 1.6408543289636434e-07
# Result: True
#
#
# Test: 410
# Input shape: (2, 5, 4), Dimension: 0, eps: 2.7395178296806124e-07
# Result: True
#
#
# Test: 411
# Input shape: (4, 4, 1, 1), Dimension: 3, eps: 8.327034268570841e-07
# Result: True
#
#
# Test: 412
# Input shape: (5, 3, 3, 2, 5, 4), Dimension: 2, eps: 1.3730070680028661e-07
# Result: True
#
#
# Test: 413
# Input shape: (4, 5, 1, 5, 4), Dimension: 1, eps: 1.4981721764603472e-07
# Result: True
#
#
# Test: 414
# Input shape: (2, 4, 5), Dimension: 2, eps: 2.3152158500169553e-07
# Result: True
#
#
# Test: 415
# Input shape: (5, 1, 4), Dimension: 0, eps: 8.056968419490964e-07
# Result: True
#
#
# Test: 416
# Input shape: (5, 4, 1, 5, 4), Dimension: 4, eps: 6.391101887278934e-07
# Result: True
#
#
# Test: 417
# Input shape: (1, 1, 3, 4, 1, 5), Dimension: 1, eps: 6.47456045001257e-07
# Result: True
#
#
# Test: 418
# Input shape: (1, 3, 4), Dimension: 2, eps: 3.677884790531524e-09
# Result: True
#
#
# Test: 419
# Input shape: (3, 2, 5, 4, 1), Dimension: 4, eps: 4.2127209263606494e-08
# Result: True
#
#
# Test: 420
# Input shape: (1, 1), Dimension: 0, eps: 2.8586043030361585e-07
# Result: True
#
#
# Test: 421
# Input shape: (2,), Dimension: 0, eps: 6.928983468898149e-07
# Result: True
#
#
# Test: 422
# Input shape: (5, 3, 5, 2, 4, 2), Dimension: 0, eps: 7.971855547719031e-07
# Result: True
#
#
# Test: 423
# Input shape: (1, 1, 3, 5, 4), Dimension: 4, eps: 3.958718429111546e-07
# Result: True
#
#
# Test: 424
# Input shape: (4, 3, 1, 3, 4, 2), Dimension: 5, eps: 4.800932992342967e-07
# Result: True
#
#
# Test: 425
# Input shape: (2, 2), Dimension: 0, eps: 7.825296733854269e-07
# Result: True
#
#
# Test: 426
# Input shape: (1, 2, 3, 5, 2), Dimension: 0, eps: 3.294493059381825e-07
# Result: True
#
#
# Test: 427
# Input shape: (3, 2, 1, 5), Dimension: 3, eps: 7.582995909228861e-07
# Result: True
#
#
# Test: 428
# Input shape: (4, 5, 3, 3), Dimension: 2, eps: 9.236033507130381e-07
# Result: True
#
#
# Test: 429
# Input shape: (2, 3, 2), Dimension: 0, eps: 1.0854944355356469e-07
# Result: True
#
#
# Test: 430
# Input shape: (5, 1), Dimension: 0, eps: 6.639961842541086e-07
#   4%|█▋                                   | 444/10000 [00:00<00:04, 2378.10it/s]
# Result: True
#
#
# Test: 431
# Input shape: (3,), Dimension: 0, eps: 7.714376263836819e-07
# Result: True
#
#
# Test: 432
# Input shape: (1, 2, 1, 1, 1), Dimension: 1, eps: 7.852499132569867e-07
# Result: True
#
#
# Test: 433
# Input shape: (2, 3, 5, 1, 3, 4), Dimension: 5, eps: 1.3065950454283132e-07
# Result: True
#
#
# Test: 434
# Input shape: (1, 1, 2, 5), Dimension: 0, eps: 6.151448636192945e-07
# Result: True
#
#
# Test: 435
# Input shape: (5, 2), Dimension: 0, eps: 9.279742078251779e-07
# Result: True
#
#
# Test: 436
# Input shape: (4,), Dimension: 0, eps: 5.122902220977197e-07
# Result: True
#
#
# Test: 437
# Input shape: (2, 4, 5), Dimension: 2, eps: 4.685624244722187e-07
# Result: True
#
#
# Test: 438
# Input shape: (1, 4, 3), Dimension: 1, eps: 9.990016418451835e-07
# Result: True
#
#
# Test: 439
# Input shape: (2,), Dimension: 0, eps: 8.471996196427911e-07
# Result: True
#
#
# Test: 440
# Input shape: (1, 2, 3, 1, 1, 1), Dimension: 4, eps: 1.7761989523888628e-07
# Result: True
#
#
# Test: 441
# Input shape: (2, 4, 3, 2, 3), Dimension: 3, eps: 6.655940736054376e-07
# Result: True
#
#
# Test: 442
# Input shape: (5, 5, 3, 1, 5, 2), Dimension: 0, eps: 5.170791419648906e-07
# Result: True
#
#
# Test: 443
# Input shape: (3, 3, 2, 1), Dimension: 1, eps: 2.626241878115365e-07
# Result: True
#
#
# Test: 444
# Input shape: (2, 4, 4, 1, 5), Dimension: 0, eps: 7.532193979749602e-08
# Result: True
#
#
# Test: 445
# Input shape: (5,), Dimension: 0, eps: 8.123033769482824e-07
# Result: True
#
#
# Test: 446
# Input shape: (4, 5, 3), Dimension: 2, eps: 7.81743384497726e-07
# Result: True
#
#
# Test: 447
# Input shape: (4, 1, 5, 5), Dimension: 2, eps: 3.708511371838976e-07
# Result: True
#
#
# Test: 448
# Input shape: (4, 1, 3, 3), Dimension: 0, eps: 9.78744179230163e-07
# Result: True
#
#
# Test: 449
# Input shape: (1, 4, 1), Dimension: 0, eps: 9.990898320414678e-07
# Result: True
#
#
# Test: 450
# Input shape: (3,), Dimension: 0, eps: 5.296817353278727e-07
# Result: True
#
#
# Test: 451
# Input shape: (4, 1, 2, 4, 3, 3), Dimension: 2, eps: 5.463537294113288e-07
# Result: True
#
#
# Test: 452
# Input shape: (5,), Dimension: 0, eps: 1.0313199770267226e-07
# Result: True
#
#
# Test: 453
# Input shape: (3,), Dimension: 0, eps: 7.713487895701468e-07
# Result: True
#
#
# Test: 454
# Input shape: (5, 3, 4), Dimension: 2, eps: 6.351339253867942e-07
# Result: True
#
#
# Test: 455
# Input shape: (1, 2), Dimension: 0, eps: 1.5751044836275543e-07
# Result: True
#
#
# Test: 456
# Input shape: (1,), Dimension: 0, eps: 1.118806953935295e-07
# Result: True
#
#
# Test: 457
# Input shape: (2, 1, 3, 5, 3), Dimension: 3, eps: 4.2805374574425784e-07
# Result: True
#
#
# Test: 458
# Input shape: (3, 4, 4, 4), Dimension: 1, eps: 3.523849554137993e-07
# Result: True
#
#
# Test: 459
# Input shape: (4, 4, 2), Dimension: 2, eps: 9.625648101100346e-07
# Result: True
#
#
# Test: 460
# Input shape: (4,), Dimension: 0, eps: 5.93462943767114e-07
# Result: True
#
#
# Test: 461
# Input shape: (5, 3, 2, 3, 5), Dimension: 3, eps: 1.9752771951397523e-07
# Result: True
#
#
# Test: 462
# Input shape: (5, 1, 5, 1, 4, 5), Dimension: 0, eps: 3.7837490472422965e-07
# Result: True
#
#
# Test: 463
# Input shape: (1, 4, 2), Dimension: 2, eps: 9.421089848867321e-07
# Result: True
#
#
# Test: 464
# Input shape: (1, 5, 4, 3, 3), Dimension: 1, eps: 5.243168595097781e-07
# Result: True
#
#
# Test: 465
# Input shape: (5, 3, 3, 5), Dimension: 0, eps: 4.0531840266000686e-07
# Result: True
#
#
# Test: 466
# Input shape: (1, 4, 4), Dimension: 0, eps: 8.615649327959702e-08
# Result: True
#
#
# Test: 467
# Input shape: (4, 2, 4, 2, 2), Dimension: 0, eps: 6.34421485350095e-07
# Result: True
#
#
# Test: 468
# Input shape: (4,), Dimension: 0, eps: 3.518957631939075e-08
#   7%|██▌                                  | 682/10000 [00:00<00:04, 2267.32it/s]
# Result: True
#
#
# Test: 469
# Input shape: (4, 5, 1, 5), Dimension: 3, eps: 6.354587871384392e-07
# Result: True
#
#
# Test: 470
# Input shape: (2, 3, 1, 2), Dimension: 1, eps: 5.244992264353414e-07
# Result: True
#
#
# Test: 471
# Input shape: (4, 1, 3, 3, 3), Dimension: 2, eps: 6.284975304838036e-07
# Result: True
#
#
# Test: 472
# Input shape: (1, 4, 5), Dimension: 0, eps: 4.3025530837314164e-07
# Result: True
#
#
# Test: 473
# Input shape: (1, 3, 4, 3), Dimension: 0, eps: 4.820990122826709e-07
# Result: True
#
#
# Test: 474
# Input shape: (2,), Dimension: 0, eps: 3.899464313043613e-07
# Result: True
#
#
# Test: 475
# Input shape: (4, 1, 5, 5), Dimension: 2, eps: 5.170056924639048e-07
# Result: True
#
#
# Test: 476
# Input shape: (2, 2, 4, 3), Dimension: 1, eps: 9.226444700731956e-07
# Result: True
#
#
# Test: 477
# Input shape: (1, 5, 3, 1, 5), Dimension: 2, eps: 9.091060903190798e-07
# Result: True
#
#
# Test: 478
# Input shape: (3, 1, 4, 2, 1, 1), Dimension: 5, eps: 6.967617498211062e-07
# Result: True
#
#
# Test: 479
# Input shape: (5, 5, 1), Dimension: 2, eps: 5.625196011987549e-07
# Result: True
#
#
# Test: 480
# Input shape: (4, 5, 3, 2), Dimension: 3, eps: 4.4407251161006853e-07
# Result: True
#
#
# Test: 481
# Input shape: (4, 3, 3, 1, 5, 5), Dimension: 5, eps: 9.61035734328805e-07
# Result: True
#
#
# Test: 482
# Input shape: (2, 5), Dimension: 0, eps: 5.239731872664481e-07
# Result: True
#
#
# Test: 483
# Input shape: (1, 5, 5, 4, 2), Dimension: 4, eps: 6.223601926980344e-07
# Result: True
#
#
# Test: 484
# Input shape: (4, 1, 3), Dimension: 0, eps: 3.9215689736214275e-07
# Result: True
#
#
# Test: 485
# Input shape: (3, 1, 2, 2, 3, 3), Dimension: 3, eps: 5.120426319047773e-07
# Result: True
#
#
# Test: 486
# Input shape: (5,), Dimension: 0, eps: 9.57768326925537e-07
# Result: True
#
#
# Test: 487
# Input shape: (5, 5, 1, 1), Dimension: 1, eps: 6.805191403697429e-07
# Result: True
#
#
# Test: 488
# Input shape: (2, 5, 2, 3), Dimension: 0, eps: 7.416394663127822e-07
# Result: True
#
#
# Test: 489
# Input shape: (4, 2, 3, 1, 1, 2), Dimension: 4, eps: 5.722511066941893e-07
# Result: True
#
#
# Test: 490
# Input shape: (1,), Dimension: 0, eps: 8.976699636111515e-07
# Result: True
#
#
# Test: 491
# Input shape: (4, 2, 3, 5, 5), Dimension: 2, eps: 2.993019311148406e-08
# Result: True
#
#
# Test: 492
# Input shape: (5, 3, 5, 5), Dimension: 0, eps: 1.6503221162571165e-07
# Result: True
#
#
# Test: 493
# Input shape: (2, 5, 5), Dimension: 0, eps: 4.74239389535495e-07
# Result: True
#
#
# Test: 494
# Input shape: (2, 3), Dimension: 1, eps: 7.036376137046464e-07
# Result: True
#
#
# Test: 495
# Input shape: (4, 4, 2, 3, 4), Dimension: 2, eps: 2.794395931211669e-07
# Result: True
#
#
# Test: 496
# Input shape: (3, 1, 1), Dimension: 2, eps: 3.481838252245797e-08
# Result: True
#
#
# Test: 497
# Input shape: (5, 5), Dimension: 1, eps: 8.882935061732072e-07
# Result: True
#
#
# Test: 498
# Input shape: (2, 3, 5), Dimension: 2, eps: 6.368562119282652e-07
# Result: True
#
#
# Test: 499
# Input shape: (4, 1, 2, 4), Dimension: 1, eps: 3.288781895774456e-07
# Result: True
#
#
# Test: 500
# Input shape: (3, 3, 3, 3, 2), Dimension: 1, eps: 9.072947848353202e-08
# Result: True
#
#
# Test: 501
# Input shape: (2, 1), Dimension: 1, eps: 2.1540536485976188e-07
# Result: True
#
#
# Test: 502
# Input shape: (2, 3, 5, 4), Dimension: 1, eps: 5.177870170781461e-07
# Result: True
#
#
# Test: 503
# Input shape: (3,), Dimension: 0, eps: 9.550950860553296e-07
# Result: True
#
#
# Test: 504
# Input shape: (5, 3, 4, 4, 4), Dimension: 1, eps: 9.233028203004245e-09
# Result: True
#
#
# Test: 505
# Input shape: (5, 5, 5, 5, 5, 4), Dimension: 4, eps: 2.4643671288172097e-07
# Result: True
#
#
# Test: 506
# Input shape: (4, 3, 5), Dimension: 1, eps: 9.217808141213974e-07
# Result: True
#
#
# Test: 507
# Input shape: (4, 5, 1, 1, 4), Dimension: 3, eps: 1.1896284300788023e-07
# Result: True
#
#
# Test: 508
# Input shape: (4, 3, 4, 3, 1), Dimension: 0, eps: 2.868591130854727e-07
# Result: True
#
#
# Test: 509
# Input shape: (2, 1, 4), Dimension: 1, eps: 1.9811751467083687e-07
# Result: True
#
#
# Test: 510
# Input shape: (4, 1, 4, 3, 3, 3), Dimension: 2, eps: 2.7532166000159596e-07
# Result: True
#
#
# Test: 511
# Input shape: (3, 5, 1), Dimension: 1, eps: 5.119650148195526e-07
# Result: True
#
#
# Test: 512
# Input shape: (4, 2, 4, 4), Dimension: 1, eps: 6.327600416043339e-07
# Result: True
#
#
# Test: 513
# Input shape: (2, 5, 3, 3), Dimension: 2, eps: 7.310525989142787e-07
# Result: True
#
#
# Test: 514
# Input shape: (2,), Dimension: 0, eps: 5.3731834035836335e-09
# Result: True
#
#
# Test: 515
# Input shape: (5, 1), Dimension: 1, eps: 1.3734796600724745e-07
# Result: True
#
#
# Test: 516
# Input shape: (3,), Dimension: 0, eps: 9.604618725042996e-07
# Result: True
#
#
# Test: 517
# Input shape: (2, 5, 5, 5), Dimension: 2, eps: 4.827569375546903e-07
# Result: True
#
#
# Test: 518
# Input shape: (1,), Dimension: 0, eps: 9.539985013116462e-08
# Result: True
#
#
# Test: 519
# Input shape: (1, 2), Dimension: 1, eps: 9.060638533545802e-07
# Result: True
#
#
# Test: 520
# Input shape: (3, 3, 1), Dimension: 2, eps: 1.9474738459105605e-07
# Result: True
#
#
# Test: 521
# Input shape: (2, 1, 4, 3), Dimension: 0, eps: 5.382892689369089e-07
# Result: True
#
#
# Test: 522
# ...
# Result: True
#
#
# Test: 9829
# Input shape: (2, 3), Dimension: 1, eps: 2.5688885598128364e-07
# Result: True
#
#
# Test: 9830
# Input shape: (1, 3), Dimension: 1, eps: 8.586718388962474e-07
# Result: True
#
#
# Test: 9831
# Input shape: (5, 4, 3, 2, 5), Dimension: 4, eps: 3.130437053134177e-07
# Result: True
#
#
# Test: 9832
# Input shape: (1, 5, 5), Dimension: 0, eps: 8.313669917016106e-07
# Result: True
#
#
# Test: 9833
# Input shape: (3, 1, 5, 2, 5), Dimension: 0, eps: 1.9685011403622846e-07
# Result: True
#
#
# Test: 9834
# Input shape: (5, 3, 4, 1, 4), Dimension: 2, eps: 1.6536822174643247e-07
# Result: True
#
#
# Test: 9835
# Input shape: (3,), Dimension: 0, eps: 1.1613821081417087e-07
# Result: True
#
#
# Test: 9836
# Input shape: (2, 4, 5, 3, 5, 4), Dimension: 2, eps: 2.1067521447748452e-07
# Result: True
#
#
# Test: 9837
# Input shape: (4, 1, 5), Dimension: 2, eps: 6.6019912083425e-07
# Result: True
#
#
# Test: 9838
# Input shape: (1, 3, 3, 5, 2), Dimension: 3, eps: 8.977961034349112e-08
# Result: True
#
#
# Test: 9839
# Input shape: (3, 4, 3, 5, 1), Dimension: 1, eps: 3.370191408449542e-07
# Result: True
#
#
# Test: 9840
# Input shape: (4, 5, 2, 2, 4), Dimension: 3, eps: 8.850400711610274e-07
# Result: True
#
#
# Test: 9841
# Input shape: (1, 5, 2), Dimension: 1, eps: 5.31494388779023e-07
# Result: True
#
#
# Test: 9842
# Input shape: (4, 4, 1), Dimension: 1, eps: 1.242100318943533e-07
# Result: True
#
#
# Test: 9843
# Input shape: (5, 3, 5, 1), Dimension: 3, eps: 1.3162467602059495e-07
# Result: True
#
#
# Test: 9844
# Input shape: (3, 2), Dimension: 1, eps: 9.345586889021803e-07
# Result: True
#
#
# Test: 9845
# Input shape: (5, 2), Dimension: 1, eps: 8.417092215334329e-08
# Result: True
#
#
# Test: 9846
# Input shape: (5, 3, 5, 2, 3, 5), Dimension: 1, eps: 4.117711758550729e-07
# Result: True
#
#
# Test: 9847
# Input shape: (4,), Dimension: 0, eps: 8.327937843629211e-07
# Result: True
#
#
# Test: 9848
# Input shape: (2, 3, 3), Dimension: 0, eps: 3.047987878850327e-07
# Result: True
#
#
# Test: 9849
# Input shape: (1, 2, 4, 3), Dimension: 0, eps: 7.530535668694851e-07
# Result: True
#
#
# Test: 9850
# Input shape: (5, 1, 2, 3, 3), Dimension: 2, eps: 9.208616141933183e-07
# Result: True
#
#
# Test: 9851
# Input shape: (4, 3, 5, 1, 3, 3), Dimension: 3, eps: 8.882837927558811e-07
# Result: True
#
#
# Test: 9852
# Input shape: (5, 4, 3, 3), Dimension: 1, eps: 4.0964267771196076e-07
# Result: True
#
#
# Test: 9853
# Input shape: (3, 4, 5, 2), Dimension: 2, eps: 1.410200813506093e-07
# Result: True
#
#
# Test: 9854
# Input shape: (4, 3, 1, 3, 1, 2), Dimension: 1, eps: 8.143859691384247e-07
# Result: True
#
#
# Test: 9855
# Input shape: (5, 3), Dimension: 0, eps: 2.7169293628750196e-07
# Result: True
#
#
# Test: 9856
# Input shape: (2, 2, 1, 2), Dimension: 0, eps: 2.3774643866025442e-08
# Result: True
#
#
# Test: 9857
# Input shape: (1, 3, 2, 4, 3), Dimension: 0, eps: 1.9992943938652312e-07
# Result: True
#
#
# Test: 9858
# Input shape: (4, 1), Dimension: 1, eps: 1.5724557169741157e-07
# Result: True
#
#
# Test: 9859
# Input shape: (5, 2, 4, 3, 5), Dimension: 4, eps: 1.1297273934605506e-08
# Result: True
#
#
# Test: 9860
# Input shape: (2, 3, 4, 2, 2), Dimension: 1, eps: 5.692717543002509e-07
# Result: True
#
#
# Test: 9861
# Input shape: (1, 4, 2, 1, 1, 2), Dimension: 1, eps: 7.88836963336939e-07
# Result: True
#
#
# Test: 9862
# Input shape: (4,), Dimension: 0, eps: 1.5190242980783294e-08
# Result: True
#
#
# Test: 9863
# Input shape: (5, 5, 1), Dimension: 1, eps: 6.227042033992786e-07
# Result: True
#
#
# Test: 9864
# Input shape: (2,), Dimension: 0, eps: 8.15467375313045e-08
# Result: True
#
#
# Test: 9865
# Input shape: (2, 1, 1, 2, 1), Dimension: 4, eps: 6.994177725566519e-07
# Result: True
#
#
# Test: 9866
# Input shape: (4, 5, 5), Dimension: 1, eps: 3.5757656959355055e-07
# Result: True
#
#
# Test: 9867
# Input shape: (2, 3, 5), Dimension: 2, eps: 4.939269271271314e-07
# Result: True
#
#
# Test: 9868
# Input shape: (2, 1, 4), Dimension: 0, eps: 8.389051305764513e-07
# Result: True
#
#
# Test: 9869
# Input shape: (4, 2), Dimension: 1, eps: 9.013436028285075e-07
# Result: True
#
#
# Test: 9870
# Input shape: (1,), Dimension: 0, eps: 7.383757754269182e-07
# Result: True
#
#
# Test: 9871
# Input shape: (2, 4, 3, 5, 4, 1), Dimension: 1, eps: 2.4036995590288807e-07
# Result: True
#
#
# Test: 9872
# Input shape: (3, 5, 5), Dimension: 2, eps: 3.200233766782965e-07
# Result: True
#
#
# Test: 9873
# Input shape: (5, 4, 3, 1, 3, 1), Dimension: 3, eps: 3.9563963687480437e-07
# Result: True
#
#
# Test: 9874
# Input shape: (1,), Dimension: 0, eps: 7.98519096215108e-07
# Result: True
#
#
# Test: 9875
# Input shape: (5, 5, 4, 2), Dimension: 1, eps: 4.657051113149679e-07
# Result: True
#
#
# Test: 9876
# Input shape: (5, 2, 5), Dimension: 1, eps: 1.941980383288381e-08
# Result: True
#
#
# Test: 9877
# Input shape: (2, 1, 3, 4, 4, 1), Dimension: 5, eps: 3.7963298653999393e-07
# Result: True
#
#
# Test: 9878
# Input shape: (4, 5, 1, 2, 1), Dimension: 3, eps: 7.409242243676814e-07
# Result: True
#
#
# Test: 9879
# Input shape: (2, 5), Dimension: 0, eps: 2.411043142321536e-07
# Result: True
#
#
# Test: 9880
# Input shape: (1, 1, 3, 5, 3, 5), Dimension: 3, eps: 7.616217663307374e-07
# Result: True
#
#
# Test: 9881
# Input shape: (4, 3, 5, 1, 5, 1), Dimension: 3, eps: 3.159200418145012e-07
# Result: True
#
#
# Test: 9882
# Input shape: (3, 3), Dimension: 1, eps: 8.744191819972802e-08
# Result: True
#
#
# Test: 9883
# Input shape: (3, 5, 4), Dimension: 1, eps: 1.224885242085916e-07
# Result: True
#
#
# Test: 9884
# Input shape: (4, 1, 1), Dimension: 2, eps: 4.734449139877874e-07
# Result: True
#
#
# Test: 9885
# Input shape: (3, 4, 4, 1), Dimension: 1, eps: 1.6370869596529217e-07
# Result: True
#
#
# Test: 9886
# Input shape: (2, 2, 4, 5, 2, 2), Dimension: 0, eps: 2.538536305627841e-07
# Result: True
#
#
# Test: 9887
# Input shape: (2, 1, 1, 5, 5, 3), Dimension: 1, eps: 9.296510552212237e-07
# Result: True
#
#
# Test: 9888
# Input shape: (2, 3), Dimension: 0, eps: 9.743970459202665e-07
# Result: True
#
#
# Test: 9889
# Input shape: (2, 2, 3, 5, 3, 1), Dimension: 3, eps: 8.858441522728416e-07
# Result: True
#
#
# Test: 9890
# Input shape: (4, 2, 3), Dimension: 2, eps: 5.691477403719733e-08
# Result: True
#
#
# Test: 9891
# Input shape: (5, 4, 1), Dimension: 1, eps: 1.2827337969609445e-07
# Result: True
#
#
# Test: 9892
# Input shape: (4, 2, 1), Dimension: 2, eps: 5.816566512993167e-07
# Result: True
#
#
# Test: 9893
# Input shape: (3, 2, 4, 1, 3), Dimension: 1, eps: 3.515647344545351e-07
# Result: True
#
#
# Test: 9894
# Input shape: (3, 4, 1, 4), Dimension: 3, eps: 6.508016679236428e-08
# Result: True
#
#
# Test: 9895
# Input shape: (2, 2, 4, 5, 4), Dimension: 3, eps: 1.9904133046670528e-07
# Result: True
#
#
# Test: 9896
# Input shape: (1, 1), Dimension: 1, eps: 7.436047081440476e-07
# Result: True
#
#
# Test: 9897
# Input shape: (1, 4), Dimension: 1, eps: 7.602072099130461e-07
# Result: True
#
#
# Test: 9898
# Input shape: (5, 4, 1, 5), Dimension: 0, eps: 9.185596236255809e-07
# Result: True
#
#
# Test: 9899
# Input shape: (1, 5, 3, 4), Dimension: 2, eps: 8.379071375983428e-07
# Result: True
#
#
# Test: 9900
# Input shape: (1, 2), Dimension: 0, eps: 1.8419878911706718e-07
# Result: True
#
#
# Test: 9901
# Input shape: (5, 4, 2, 3), Dimension: 2, eps: 6.905245761727436e-07
# Result: True
#
#
# Test: 9902
# Input shape: (4, 5, 1, 3, 5, 4), Dimension: 0, eps: 2.245242642710219e-07
# Result: True
#
#
# Test: 9903
# Input shape: (3,), Dimension: 0, eps: 3.0041945801372117e-07
# Result: True
#
#
# Test: 9904
# Input shape: (5, 5, 3, 3, 2), Dimension: 4, eps: 2.697542785747661e-07
# Result: True
#
#
# Test: 9905
# Input shape: (5, 3, 1, 5), Dimension: 2, eps: 1.105471775117593e-07
# Result: True
#
#
# Test: 9906
# Input shape: (5, 5), Dimension: 0, eps: 5.696295458680264e-07
# Result: True
#
#
# Test: 9907
# Input shape: (1, 4, 3, 4, 5), Dimension: 1, eps: 8.969588702918898e-08
# Result: True
#
#
# Test: 9908
# Input shape: (2, 1, 3, 5, 1), Dimension: 2, eps: 4.993205235275176e-07
# Result: True
#
#
# Test: 9909
# Input shape: (5,), Dimension: 0, eps: 8.247363556624874e-07
# Result: True
#
#
# Test: 9910
# Input shape: (2, 2, 1, 2, 1), Dimension: 2, eps: 5.060542003748227e-07
# Result: True
#
#
# Test: 9911
# Input shape: (4, 3), Dimension: 1, eps: 7.195377487110435e-07
# Result: True
#
#
# Test: 9912
# Input shape: (1,), Dimension: 0, eps: 5.642078615381873e-09
# Result: True
#
#
# Test: 9913
# Input shape: (2, 4, 4, 1, 1), Dimension: 4, eps: 9.528567983840684e-07
# Result: True
#
#
# Test: 9914
# Input shape: (1, 5, 2, 3, 3, 3), Dimension: 2, eps: 7.047289493998489e-07
# Result: True
#
#
# Test: 9915
# Input shape: (3, 1, 1, 2, 2, 3), Dimension: 5, eps: 4.357231310704905e-07
# Result: True
#
#
# Test: 9916
# Input shape: (4, 1, 1), Dimension: 2, eps: 2.49476340140927e-07
# Result: True
#
#
# Test: 9917
# Input shape: (3, 3, 5, 5, 1), Dimension: 3, eps: 7.541607545083593e-07
# Result: True
#
#
# Test: 9918
# Input shape: (2,), Dimension: 0, eps: 1.0511675872411438e-07
# Result: True
#
#
# Test: 9919
# Input shape: (4, 5, 1), Dimension: 1, eps: 1.163457811937937e-07
# Result: True
#
#
# Test: 9920
# Input shape: (5,), Dimension: 0, eps: 9.416530223685936e-08
# Result: True
#
#
# Test: 9921
# Input shape: (2, 1), Dimension: 1, eps: 2.1118771255577872e-07
# Result: True
#
#
# Test: 9922
# Input shape: (4, 5, 2), Dimension: 0, eps: 7.20664160061209e-07
# Result: True
#
#
# Test: 9923
# Input shape: (4, 2, 1), Dimension: 0, eps: 5.278064818827627e-08
# Result: True
#
#
# Test: 9924
# Input shape: (5, 4), Dimension: 0, eps: 4.4959770737380247e-07
# Result: True
#
#
# Test: 9925
# Input shape: (4, 1, 2, 1, 5), Dimension: 1, eps: 2.4668478229054937e-07
# Result: True
#
#
# Test: 9926
# Input shape: (1, 1, 4, 2), Dimension: 3, eps: 4.464815635198163e-07
# Result: True
#
#
# Test: 9927
# Input shape: (5, 1, 1, 3), Dimension: 3, eps: 1.224569471397938e-07
# Result: True
#
#
# Test: 9928
# Input shape: (2, 1, 1, 2, 5, 3), Dimension: 4, eps: 3.120356700090519e-07
# Result: True
#
#
# Test: 9929
# Input shape: (1, 2, 4, 1, 4), Dimension: 4, eps: 8.449197432178989e-07
# Result: True
#
#
# Test: 9930
# Input shape: (1, 4, 5), Dimension: 1, eps: 4.6762019867296093e-07
# Result: True
#
#
# Test: 9931
# Input shape: (4, 4, 5, 3, 4, 1), Dimension: 5, eps: 8.79287850222711e-07
# Result: True
#
#
# Test: 9932
# Input shape: (4, 1), Dimension: 1, eps: 8.841940963977541e-07
# Result: True
#
#
# Test: 9933
# Input shape: (5, 3, 4, 2), Dimension: 1, eps: 5.525235317315955e-07
# Result: True
#
#
# Test: 9934
# Input shape: (1,), Dimension: 0, eps: 3.2411630233053677e-07
# Result: True
#
#
# Test: 9935
# Input shape: (4, 3, 1, 3, 3), Dimension: 1, eps: 5.727452427909159e-07
# Result: True
#
#
# Test: 9936
# Input shape: (1, 1), Dimension: 1, eps: 3.6016249577410957e-07
# Result: True
#
#
# Test: 9937
# Input shape: (3, 1), Dimension: 1, eps: 4.1488027714316336e-07
# Result: True
#
#
# Test: 9938
# Input shape: (5, 4, 1, 2, 4, 4), Dimension: 1, eps: 9.087772665513728e-08
# Result: True
#
#
# Test: 9939
# Input shape: (3, 3, 1), Dimension: 1, eps: 4.7142958753133575e-08
# Result: True
#
#
# Test: 9940
# Input shape: (3,), Dimension: 0, eps: 2.235743643047998e-07
# Result: True
#
#
# Test: 9941
# Input shape: (3, 2), Dimension: 0, eps: 7.870589331384077e-07
# Result: True
#
#
# Test: 9942
# Input shape: (4, 2, 2, 5), Dimension: 2, eps: 1.1487674276124517e-07
# Result: True
#
#
# Test: 9943
# Input shape: (4, 1, 3, 1, 3, 3), Dimension: 5, eps: 3.369392965990453e-07
# Result: True
#
#
# Test: 9944
# Input shape: (3, 1, 3, 2, 5), Dimension: 0, eps: 2.646003775200145e-07
# Result: True
#
#
# Test: 9945
# Input shape: (1, 3, 4), Dimension: 0, eps: 8.943269933144785e-07
# Result: True
#
#
# Test: 9946
# Input shape: (1, 4, 1), Dimension: 1, eps: 1.331155050164302e-07
# Result: True
#
#
# Test: 9947
# Input shape: (1, 2, 5, 4, 3), Dimension: 4, eps: 3.1294739143829705e-09
# Result: True
#
#
# Test: 9948
# Input shape: (5, 2), Dimension: 0, eps: 6.417591232264901e-07
# Result: True
#
#
# Test: 9949
# Input shape: (5, 1, 4), Dimension: 1, eps: 5.820841633147963e-07
# Result: True
#
#
# Test: 9950
# Input shape: (3, 3, 2), Dimension: 0, eps: 2.0640248021307857e-07
# Result: True
#
#
# Test: 9951
# Input shape: (4, 2, 3), Dimension: 1, eps: 6.970496357606047e-07
# Result: True
#
#
# Test: 9952
# Input shape: (3, 5), Dimension: 1, eps: 9.365196062808764e-07
# Result: True
#
#
# Test: 9953
# Input shape: (5, 4, 3, 5, 3), Dimension: 3, eps: 8.454885310136979e-07
# Result: True
#
#
# Test: 9954
# Input shape: (2, 1, 4), Dimension: 0, eps: 5.234631304914818e-07
# Result: True
#
#
# Test: 9955
# Input shape: (2,), Dimension: 0, eps: 6.958876830849531e-07
# Result: True
#
#
# Test: 9956
# Input shape: (4, 1, 3, 1, 3, 5), Dimension: 5, eps: 7.851251259280404e-07
# Result: True
#
#
# Test: 9957
# Input shape: (3,), Dimension: 0, eps: 6.008590519749064e-07
# Result: True
#
#
# Test: 9958
# Input shape: (2, 5, 3, 4), Dimension: 2, eps: 5.209202329239316e-07
# Result: True
#
#
# Test: 9959
# Input shape: (1, 4), Dimension: 1, eps: 8.031352737601397e-07
# Result: True
#
#
# Test: 9960
# Input shape: (4, 4, 1, 5), Dimension: 1, eps: 2.589397820334106e-07
# Result: True
#
#
# Test: 9961
# Input shape: (4,), Dimension: 0, eps: 5.754587489351953e-07
# Result: True
#
#
# Test: 9962
# Input shape: (3, 1, 1, 2, 1, 5), Dimension: 5, eps: 3.0386568186599413e-07
# Result: True
#
#
# Test: 9963
# Input shape: (2,), Dimension: 0, eps: 4.049679024814508e-07
# Result: True
#
#
# Test: 9964
# Input shape: (4,), Dimension: 0, eps: 5.224195432035967e-07
# Result: True
#
#
# Test: 9965
# Input shape: (5,), Dimension: 0, eps: 3.7299523337310423e-07
# Result: True
#
#
# Test: 9966
# Input shape: (5,), Dimension: 0, eps: 4.5213675596702275e-08
# Result: True
#
#
# Test: 9967
# Input shape: (1, 5, 2, 2, 2, 1), Dimension: 0, eps: 7.389260025476805e-07
# Result: True
#
#
# Test: 9968
# Input shape: (3, 2, 1, 3, 1), Dimension: 1, eps: 1.2207794842533885e-07
# Result: True
#
#
# Test: 9969
# Input shape: (5,), Dimension: 0, eps: 9.57889714936729e-07
# Result: True
#
#
# Test: 9970
# Input shape: (5, 3, 4, 4), Dimension: 2, eps: 4.6428987041304724e-07
# Result: True
#
#
# Test: 9971
# Input shape: (4, 3, 5), Dimension: 2, eps: 6.847527875031806e-07
# Result: True
#
#
# Test: 9972
# Input shape: (2, 5, 1, 5), Dimension: 1, eps: 5.79711101333668e-07
# Result: True
#
#
# Test: 9973
# Input shape: (1, 2, 5, 2, 4), Dimension: 3, eps: 4.251516118572551e-07
# Result: True
#
#
# Test: 9974
# Input shape: (4, 2, 4), Dimension: 1, eps: 5.035478566781333e-07
# Result: True
#
#
# Test: 9975
# Input shape: (4, 3, 4, 5), Dimension: 1, eps: 3.601524377011114e-07
# Result: True
#
#
# Test: 9976
# Input shape: (4, 4), Dimension: 1, eps: 3.5370817591539375e-07
# Result: True
#
#
# Test: 9977
# Input shape: (3, 5, 5, 2), Dimension: 0, eps: 4.3469191793422075e-07
# Result: True
#
#
# Test: 9978
# Input shape: (1, 1, 2), Dimension: 1, eps: 2.2294427160939409e-07
# Result: True
#
#
# Test: 9979
# Input shape: (4, 5, 1, 1, 1), Dimension: 1, eps: 2.3490881545822105e-07
# Result: True
#
#
# Test: 9980
# Input shape: (1, 1, 4), Dimension: 2, eps: 4.7146864559699404e-07
# Result: True
#
#
# Test: 9981
# Input shape: (1, 1, 5, 1, 5), Dimension: 1, eps: 8.944524537743934e-07
# Result: True
#
#
# Test: 9982
# Input shape: (1, 5, 1, 2), Dimension: 3, eps: 7.077051927655342e-08
# Result: True
#
#
# Test: 9983
# Input shape: (4, 4, 3), Dimension: 0, eps: 9.144054327338927e-07
# Result: True
#
#
# Test: 9984
# Input shape: (3, 1, 2), Dimension: 2, eps: 7.294815586804489e-07
# Result: True
#
#
# Test: 9985
# Input shape: (1, 3), Dimension: 0, eps: 7.954199904612723e-07
# Result: True
#
#
# Test: 9986
# Input shape: (3, 4), Dimension: 0, eps: 8.689587857999398e-07
# Result: True
#
#
# Test: 9987
# Input shape: (1, 4, 5), Dimension: 2, eps: 9.153519672096819e-07
# Result: True
#
#
# Test: 9988
# Input shape: (5, 2, 4), Dimension: 0, eps: 1.4510651247316156e-07
# Result: True
#
#
# Test: 9989
# Input shape: (2, 1, 2, 1), Dimension: 3, eps: 5.980278498356736e-07
# Result: True
#
#
# Test: 9990
# Input shape: (5, 2, 1, 5, 1), Dimension: 3, eps: 1.5361373936714182e-07
# Result: True
#
#
# Test: 9991
# Input shape: (2, 4, 1, 4, 1), Dimension: 1, eps: 4.871311207686806e-07
# Result: True
#
#
# Test: 9992
# Input shape: (5, 1, 4, 5), Dimension: 3, eps: 1.2524326921981532e-07
# Result: True
#
#
# Test: 9993
# Input shape: (5, 4, 1), Dimension: 0, eps: 2.1695538765948003e-07
# Result: True
#
#
# Test: 9994
# Input shape: (2, 5, 2, 2, 5, 5), Dimension: 2, eps: 7.877636225915031e-07
# Result: True
#
#
# Test: 9995
# Input shape: (5, 2, 2, 1, 3, 5), Dimension: 1, eps: 4.123240215024497e-07
# Result: True
#
#
# Test: 9996
# Input shape: (5, 3, 3, 5, 1), Dimension: 3, eps: 8.97884462798866e-07
# Result: True
#
#
# Test: 9997
# Input shape: (1,), Dimension: 0, eps: 5.646663816101568e-07
# Result: True
#
#
# Test: 9998
# Input shape: (3, 3, 3, 5, 2, 1), Dimension: 1, eps: 5.590501738079844e-07
# Result: True
#
#
# Test: 9999
# Input shape: (1, 3, 5), Dimension: 1, eps: 2.1089716832267896e-07
# Result: True
#
#
# 10000 out of 10000 (100.0%) tests passed
