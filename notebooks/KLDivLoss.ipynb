# %% [markdown]
# ### `KLDivLoss` code

# %%
import numpy as np
import random
import torch # needed for tests
from tqdm import tqdm # needed for tests

# %%
class KLDivLoss:
    ''' Computes Kullback-Leibler (KL) Divergence Loss given the input and target '''
    
    ''' * The class implementation will be along the lines of torch.nn.MSELoss in order to 
          enable comparison of this NumPy only implementation and seamless testing
        * Can expect extensive refactoring of the existing code in the days to come
        * As part of refactoring, some code will be de-modularized
        * Old code will be retained at the end of the notebook for reference
    '''
    '''
        TODO:
        * Replace `torch.round()` with `np.allclose()` for tests
        * Optimizing code
    '''
    
    def __init__(
        self,
        size_average = None,
        reduce = None,
        reduction = 'mean',
        log_target = False,
        verbose = False
        ):
        super(KLDivLoss, self).__init__()
        
        ''' mandatory parameters '''
        # None
        
        ''' optional parameters '''
        self.reduction = reduction
        self.log_target = log_target
        
        ''' optional parameters (dummy, yet to be implemented)'''
        self.size_average = size_average
        self.reduce = reduce
        
        ''' additional parameters (different from torch.nn.Conv2D)'''
        self.verbose = verbose
        self.verboseprint = print if self.verbose else lambda *a, **k: None
        self.verboseprint('*** parameters ***')
        self.verboseprint('size_average: {}, reduce: {}, reduction: {}, log_target: {}'.format(self.size_average, self.reduce, self.reduction, self.log_target))
        self.verboseprint('\n')
    
    def forward(self, _input, _target):
        ''' forward pass to compute KL Divergence Loss'''
        
        ''' error checking '''
        if not (isinstance(_input, int) or isinstance(_input, float) or isinstance(_input, np.ndarray)):
            raise Exception('invalid input: `input` should either be an int, a float, or a NumPy ndarray')
        
        if not (isinstance(_target, int) or isinstance(_target, float) or isinstance(_target, np.ndarray)):
            raise Exception('invalid input: `target` should either be an int, a float, or a NumPy ndarray')
            
        if (isinstance(_input, np.ndarray) and not isinstance(_target, np.ndarray))  or (not isinstance(_input, np.ndarray) and isinstance(_target, np.ndarray)):
            raise Exception('invalid input: `input` and `target` should both be a NumPy ndarray, or can be a mix of `int` and `float`')
            
        ''' compute KL Divergence Loss '''
        if not self.log_target:
            output = _target * (np.log(_target) - _input)
        else:
            output = np.exp(_target) * (_target - _input)
        if self.reduction == 'mean':
            output = np.mean(output)
        # elif self.reduction == 'batchmean':
            # if isinstance(_input, np.ndarray):
                # print(_input.size())
        elif self.reduction == 'sum':
            output = np.sum(output)
        elif self.reduction == 'none':
            pass
        else:
            raise Exception("invalid input: `reduction` flag should be one of `'mean'`, `'sum'`, `'batchmean'` or `'none'`")
        self.verboseprint("*** KLDivLoss output ***")
        self.verboseprint(output)
        self.verboseprint('\n')
        return output

# %% [markdown]
# ### Standalone test (random input, target)

# %%
_reduction = 'none'
dimension = np.random.randint(500) # dimension of the input and target
_input = np.random.rand(dimension) # define a random input of the above dimension
_target= np.random.rand(dimension) # define a random target of the above dimension
print(_input.shape, _target.shape)
# Out:
# (267,) (267,)

# %%
# compute KL Divergence loss using the random input and target
kldivloss = KLDivLoss(reduction = _reduction) # call an instance of the class
_output = kldivloss.forward(_input, _target) # compute KL Divergence loss
print("*** KLDivLoss output ***")
print(_output)
# Out:
# *** KLDivLoss output ***
# [-0.54292885 -0.44163028 -0.66802759 -0.56537674 -0.62067917 -0.5053377
#  -0.37064588 -0.23143806 -0.52237298 -0.43647289 -0.72591047 -0.83611497
#  -0.3475422  -0.15199753 -0.42713198 -0.49954143 -0.32027984 -0.69700723
#  -0.94070492 -0.25914293 -0.27434056 -0.6805685  -0.51798175 -0.49841353
#  -0.16204999 -0.45188463 -0.86997938 -0.19119411 -0.53651524 -0.44795948
#  -0.71524566 -0.33983374 -0.35781834 -0.52595303 -0.3036892  -0.24807413
#  -0.45341386 -0.77778761 -0.30645936 -0.45547583 -0.61908811 -0.21223905
#  -0.7564861  -0.50139352 -0.38916817 -0.4156423  -0.15651301 -0.38371029
#  -0.5795809  -0.86576243 -0.60170934 -0.36968798 -0.33256914 -0.8247489
#  -0.26294193 -0.42483604 -0.62568457 -0.49002295 -0.30032501 -0.39327929
#  -0.39735634 -0.62828196 -0.46792439 -0.40812607 -0.35300499 -0.29468643
#  -0.76068107 -0.43181656 -0.43230562 -0.44592589 -0.53818907 -0.55374056
#  -0.12349909 -0.79308063 -0.43761295 -0.73648793 -0.43780844 -0.82764716
#  -0.62596082 -0.64339476 -0.58490975 -0.50653619 -0.55693552 -0.27457949
#  -0.33908257 -0.49940674 -0.31413377 -0.50219109 -0.83617286 -0.39794997
#  -0.43586006 -0.97639128 -0.60425726 -0.08500939 -0.23710868 -0.45869573
#  -0.53247481 -0.88464512 -0.53385202 -0.78167043 -0.39658297 -0.55068601
#  -0.61083491 -0.3680136  -0.54011544 -0.44704568 -0.59166636 -0.44005193
#  -0.4444743  -0.61222416 -0.3783476  -0.47960144 -0.44629072 -0.32901646
#  -0.19220781 -0.42526876 -0.43007623 -0.44489129 -0.42686125 -0.57318072
#  -0.39477469 -0.18249177 -0.73830297 -0.91589818 -0.93920376 -0.5357132
#  -0.67905786 -0.36890461 -0.46100506 -0.24560965 -0.44291741 -0.3571008
#  -0.34467601 -0.71140168 -0.19330783 -0.51843148 -0.74130926 -0.48600133
#  -0.51372069 -0.20859067 -0.17755207 -0.59607241 -0.69361689 -0.32037961
#  -0.7990788  -0.33893419 -0.60497608 -0.49502377 -0.17746969 -0.92740891
#  -0.1150765  -0.15926152 -0.68726715 -0.05248943 -0.96926311 -0.3744736
#  -0.68369887 -0.53524711 -0.58953908 -0.57990382 -0.55209356 -0.09772639
#  -0.67042201 -0.55470477 -0.7122776  -0.68219249 -0.43731701 -0.79695313
#  -0.46294671 -0.53394523 -0.11404677 -0.51726365 -0.72836017 -0.52412367
#  -0.82372711 -0.56212059 -0.46867565 -0.49845942 -0.35239223 -0.27877523
#  -0.57559353 -0.6581049  -0.65661103 -0.32543328 -0.41511983 -0.52620253
#  -0.33204668 -0.33554496 -0.79828061 -0.45349728 -0.77434042 -0.58792684
#  -0.37605001 -0.54694955 -0.82071102 -0.29045775 -0.80131392 -0.14178328
#  -0.40529018 -0.26408138 -0.46772475 -0.58694966 -0.87358336 -0.29579947
#  -0.34805112 -0.59200898 -0.10710583 -0.61203518 -0.18386071 -0.22996735
#  -0.38442545 -0.47083536 -0.4689957  -0.10416362 -0.57666641 -0.34711911
#  -0.41174824 -0.41267127 -0.60950191 -0.4648519  -0.32463256 -0.56345555
#  -0.64264687 -0.47059754 -0.35308778 -0.77212996 -0.79236674 -0.19828854
#  -0.27159508 -0.53305344 -0.90331824 -0.47607871 -0.40319469 -0.50022535
#  -0.63890977 -0.44207202 -0.76641275 -0.90479752 -0.66557688 -0.39110486
#  -0.42401413 -0.87884503 -0.82867482 -0.77173443 -0.68757574 -0.44215947
#  -0.75764261 -0.40574302 -0.48349693 -0.48691463 -0.34075854 -0.32934727
#  -0.42214916 -0.50585777 -0.93611277 -0.08941462 -0.67899111 -0.04025652
#  -0.91631999 -0.80676133 -0.45806139 -0.98511336 -0.4748054  -0.74994059
#  -0.68710213 -0.73933586 -0.35991019]

# %%
# get PyTorch output with the same random inputs as above

x = torch.DoubleTensor(_input)
y = torch.DoubleTensor(_target)
loss = torch.nn.KLDivLoss(reduction = _reduction)
output = loss(x, y)
print("*** PyTorch output ***")
print(output)
# Out:
# *** PyTorch output ***
# tensor([-0.5429, -0.4416, -0.6680, -0.5654, -0.6207, -0.5053, -0.3706, -0.2314,
#         -0.5224, -0.4365, -0.7259, -0.8361, -0.3475, -0.1520, -0.4271, -0.4995,
#         -0.3203, -0.6970, -0.9407, -0.2591, -0.2743, -0.6806, -0.5180, -0.4984,
#         -0.1620, -0.4519, -0.8700, -0.1912, -0.5365, -0.4480, -0.7152, -0.3398,
#         -0.3578, -0.5260, -0.3037, -0.2481, -0.4534, -0.7778, -0.3065, -0.4555,
#         -0.6191, -0.2122, -0.7565, -0.5014, -0.3892, -0.4156, -0.1565, -0.3837,
#         -0.5796, -0.8658, -0.6017, -0.3697, -0.3326, -0.8247, -0.2629, -0.4248,
#         -0.6257, -0.4900, -0.3003, -0.3933, -0.3974, -0.6283, -0.4679, -0.4081,
#         -0.3530, -0.2947, -0.7607, -0.4318, -0.4323, -0.4459, -0.5382, -0.5537,
#         -0.1235, -0.7931, -0.4376, -0.7365, -0.4378, -0.8276, -0.6260, -0.6434,
#         -0.5849, -0.5065, -0.5569, -0.2746, -0.3391, -0.4994, -0.3141, -0.5022,
#         -0.8362, -0.3979, -0.4359, -0.9764, -0.6043, -0.0850, -0.2371, -0.4587,
#         -0.5325, -0.8846, -0.5339, -0.7817, -0.3966, -0.5507, -0.6108, -0.3680,
#         -0.5401, -0.4470, -0.5917, -0.4401, -0.4445, -0.6122, -0.3783, -0.4796,
#         -0.4463, -0.3290, -0.1922, -0.4253, -0.4301, -0.4449, -0.4269, -0.5732,
#         -0.3948, -0.1825, -0.7383, -0.9159, -0.9392, -0.5357, -0.6791, -0.3689,
#         -0.4610, -0.2456, -0.4429, -0.3571, -0.3447, -0.7114, -0.1933, -0.5184,
#         -0.7413, -0.4860, -0.5137, -0.2086, -0.1776, -0.5961, -0.6936, -0.3204,
#         -0.7991, -0.3389, -0.6050, -0.4950, -0.1775, -0.9274, -0.1151, -0.1593,
#         -0.6873, -0.0525, -0.9693, -0.3745, -0.6837, -0.5352, -0.5895, -0.5799,
#         -0.5521, -0.0977, -0.6704, -0.5547, -0.7123, -0.6822, -0.4373, -0.7970,
#         -0.4629, -0.5339, -0.1140, -0.5173, -0.7284, -0.5241, -0.8237, -0.5621,
#         -0.4687, -0.4985, -0.3524, -0.2788, -0.5756, -0.6581, -0.6566, -0.3254,
#         -0.4151, -0.5262, -0.3320, -0.3355, -0.7983, -0.4535, -0.7743, -0.5879,
#         -0.3761, -0.5469, -0.8207, -0.2905, -0.8013, -0.1418, -0.4053, -0.2641,
#         -0.4677, -0.5869, -0.8736, -0.2958, -0.3481, -0.5920, -0.1071, -0.6120,
#         -0.1839, -0.2300, -0.3844, -0.4708, -0.4690, -0.1042, -0.5767, -0.3471,
#         -0.4117, -0.4127, -0.6095, -0.4649, -0.3246, -0.5635, -0.6426, -0.4706,
#         -0.3531, -0.7721, -0.7924, -0.1983, -0.2716, -0.5331, -0.9033, -0.4761,
#         -0.4032, -0.5002, -0.6389, -0.4421, -0.7664, -0.9048, -0.6656, -0.3911,
#         -0.4240, -0.8788, -0.8287, -0.7717, -0.6876, -0.4422, -0.7576, -0.4057,
#         -0.4835, -0.4869, -0.3408, -0.3293, -0.4221, -0.5059, -0.9361, -0.0894,
#         -0.6790, -0.0403, -0.9163, -0.8068, -0.4581, -0.9851, -0.4748, -0.7499,
#         -0.6871, -0.7393, -0.3599], dtype=torch.float64)

# %%
# compare outputs of MSELoss and PyTorch
if not isinstance(_output, np.ndarray): # if a singleton, convert PyTorch tensor to NumPy float, round, and compare
    output = output.numpy()
    print(np.equal(np.round(_output), np.round(output)))  
else:
    print(torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output))) # need to round the output due to precision difference
# Out:
# True

# %% [markdown]
# ### Extensive tests (random input, target)

# %%
def run_tests(num_tests):
    ''' sweep different input parameters and test by comparing outputs of KLDivLoss and PyTorch '''
    
    num_passed = 0
    print('Number of tests: {}\n\n'.format(num_tests))
    
    for i in tqdm(range(num_tests)):
        _reduction = np.random.choice(['mean', 'sum', 'none'])
        _log_target = bool(random.getrandbits(1))
        dimension = np.random.randint(500) + 1 # dimension of the input and target
        _input = np.random.rand(dimension) # define a random input of the above dimension
        _target= np.random.rand(dimension) # define a random target of the above dimension
        print('Test: {}\nDimension : {}, `reduction`: {}'.format(i, dimension, _reduction))
        
        try:
            # compute MSE loss using the random input and target
            kldivloss = KLDivLoss(reduction = _reduction, log_target = _log_target) # call an instance of the class
            _output = kldivloss.forward(_input, _target) # compute KL Divergence loss


            # get PyTorch output with the same random inputs as above
            x = torch.DoubleTensor(_input)
            y = torch.DoubleTensor(_target)
            loss = torch.nn.KLDivLoss(reduction = _reduction, log_target = _log_target)
            output = loss(x, y)

            
        except Exception as e:
            print(e)
            print('Result: False\n\n') # treating exception as a failed test
            continue

        # compare outputs of MSELoss and PyTorch
        if not isinstance(_output, np.ndarray): # if a singleton, convert PyTorch tensor to NumPy float, round, and compare
            output = output.numpy()
            result = np.equal(np.round(_output), np.round(output)) 
        else:
            result = torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output)) # need to round the output due to precision difference
        print('Result: {}\n\n'.format(result))
        if result:
            num_passed += 1

    print('{} out of {} ({}%) tests passed'.format(num_passed, num_tests, float(100 * num_passed / num_tests)))

# %%
num_tests = 1000
run_tests(num_tests)
# Out:
# Number of tests: 1000
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/home/degirum/anaconda3/lib/python3.10/site-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 6457.42it/s]
# Test: 0
# Dimension : 359, `reduction`: none
# Result: True
#
#
# Test: 1
# Dimension : 164, `reduction`: sum
# Result: True
#
#
# Test: 2
# Dimension : 149, `reduction`: mean
# Result: True
#
#
# Test: 3
# Dimension : 414, `reduction`: none
# Result: True
#
#
# Test: 4
# Dimension : 166, `reduction`: sum
# Result: True
#
#
# Test: 5
# Dimension : 370, `reduction`: mean
# Result: True
#
#
# Test: 6
# Dimension : 364, `reduction`: mean
# Result: True
#
#
# Test: 7
# Dimension : 67, `reduction`: none
# Result: True
#
#
# Test: 8
# Dimension : 90, `reduction`: none
# Result: True
#
#
# Test: 9
# Dimension : 191, `reduction`: sum
# Result: True
#
#
# Test: 10
# Dimension : 12, `reduction`: mean
# Result: True
#
#
# Test: 11
# Dimension : 317, `reduction`: sum
# Result: True
#
#
# Test: 12
# Dimension : 1, `reduction`: none
# Result: True
#
#
# Test: 13
# Dimension : 411, `reduction`: sum
# Result: True
#
#
# Test: 14
# Dimension : 63, `reduction`: none
# Result: True
#
#
# Test: 15
# Dimension : 90, `reduction`: sum
# Result: True
#
#
# Test: 16
# Dimension : 499, `reduction`: mean
# Result: True
#
#
# Test: 17
# Dimension : 410, `reduction`: sum
# Result: True
#
#
# Test: 18
# Dimension : 478, `reduction`: none
# Result: True
#
#
# Test: 19
# Dimension : 196, `reduction`: mean
# Result: True
#
#
# Test: 20
# Dimension : 301, `reduction`: mean
# Result: True
#
#
# Test: 21
# Dimension : 132, `reduction`: mean
# Result: True
#
#
# Test: 22
# Dimension : 313, `reduction`: sum
# Result: True
#
#
# Test: 23
# Dimension : 38, `reduction`: sum
# Result: True
#
#
# Test: 24
# Dimension : 132, `reduction`: none
# Result: True
#
#
# Test: 25
# Dimension : 23, `reduction`: mean
# Result: True
#
#
# Test: 26
# Dimension : 241, `reduction`: mean
# Result: True
#
#
# Test: 27
# Dimension : 59, `reduction`: mean
# Result: True
#
#
# Test: 28
# Dimension : 41, `reduction`: sum
# Result: True
#
#
# Test: 29
# Dimension : 360, `reduction`: mean
# Result: True
#
#
# Test: 30
# Dimension : 185, `reduction`: none
# Result: True
#
#
# Test: 31
# Dimension : 306, `reduction`: none
# Result: True
#
#
# Test: 32
# Dimension : 329, `reduction`: none
# Result: True
#
#
# Test: 33
# Dimension : 456, `reduction`: sum
# Result: True
#
#
# Test: 34
# Dimension : 470, `reduction`: none
# Result: True
#
#
# Test: 35
# Dimension : 2, `reduction`: mean
# Result: True
#
#
# Test: 36
# Dimension : 496, `reduction`: none
# Result: True
#
#
# Test: 37
# Dimension : 115, `reduction`: mean
# Result: True
#
#
# Test: 38
# Dimension : 400, `reduction`: sum
# Result: True
#
#
# Test: 39
# Dimension : 31, `reduction`: none
# Result: True
#
#
# Test: 40
# Dimension : 76, `reduction`: sum
# Result: True
#
#
# Test: 41
# Dimension : 421, `reduction`: none
# Result: True
#
#
# Test: 42
# Dimension : 91, `reduction`: none
# Result: True
#
#
# Test: 43
# Dimension : 165, `reduction`: sum
# Result: True
#
#
# Test: 44
# Dimension : 306, `reduction`: mean
# Result: True
#
#
# Test: 45
# Dimension : 48, `reduction`: none
# Result: True
#
#
# Test: 46
# Dimension : 271, `reduction`: sum
# Result: True
#
#
# Test: 47
# Dimension : 67, `reduction`: mean
# Result: True
#
#
# Test: 48
# Dimension : 341, `reduction`: mean
# Result: True
#
#
# Test: 49
# Dimension : 293, `reduction`: sum
# Result: True
#
#
# Test: 50
# Dimension : 381, `reduction`: none
# Result: True
#
#
# Test: 51
# Dimension : 79, `reduction`: sum
# Result: True
#
#
# Test: 52
# Dimension : 286, `reduction`: none
# Result: True
#
#
# Test: 53
# Dimension : 409, `reduction`: mean
# Result: True
#
#
# Test: 54
# Dimension : 148, `reduction`: mean
# Result: True
#
#
# Test: 55
# Dimension : 112, `reduction`: mean
# Result: True
#
#
# Test: 56
# Dimension : 16, `reduction`: mean
# Result: True
#
#
# Test: 57
# Dimension : 4, `reduction`: none
# Result: True
#
#
# Test: 58
# Dimension : 402, `reduction`: sum
# Result: True
#
#
# Test: 59
# Dimension : 98, `reduction`: sum
# Result: True
#
#
# Test: 60
# Dimension : 308, `reduction`: none
# Result: True
#
#
# Test: 61
# Dimension : 252, `reduction`: none
# Result: True
#
#
# Test: 62
# Dimension : 450, `reduction`: mean
# Result: True
#
#
# Test: 63
# Dimension : 126, `reduction`: mean
# Result: True
#
#
# Test: 64
# Dimension : 319, `reduction`: sum
# Result: True
#
#
# Test: 65
# Dimension : 146, `reduction`: none
# Result: True
#
#
# Test: 66
# Dimension : 215, `reduction`: none
# Result: True
#
#
# Test: 67
# Dimension : 320, `reduction`: sum
# Result: True
#
#
# Test: 68
# Dimension : 39, `reduction`: sum
# Result: True
#
#
# Test: 69
# Dimension : 325, `reduction`: sum
# Result: True
#
#
# Test: 70
# Dimension : 373, `reduction`: none
# Result: True
#
#
# Test: 71
# Dimension : 315, `reduction`: mean
# Result: True
#
#
# Test: 72
# Dimension : 28, `reduction`: none
# Result: True
#
#
# Test: 73
# Dimension : 161, `reduction`: sum
# Result: True
#
#
# Test: 74
# Dimension : 495, `reduction`: mean
# Result: True
#
#
# Test: 75
# Dimension : 41, `reduction`: none
# Result: True
#
#
# Test: 76
# Dimension : 468, `reduction`: mean
# Result: True
#
#
# Test: 77
# Dimension : 307, `reduction`: sum
# Result: True
#
#
# Test: 78
# Dimension : 276, `reduction`: none
# Result: True
#
#
# Test: 79
# Dimension : 347, `reduction`: none
# Result: True
#
#
# Test: 80
# Dimension : 144, `reduction`: sum
# Result: True
#
#
# Test: 81
# Dimension : 209, `reduction`: sum
# Result: True
#
#
# Test: 82
# Dimension : 263, `reduction`: mean
# Result: True
#
#
# Test: 83
# Dimension : 19, `reduction`: mean
# Result: True
#
#
# Test: 84
# Dimension : 453, `reduction`: sum
# Result: True
#
#
# Test: 85
# Dimension : 180, `reduction`: mean
# Result: True
#
#
# Test: 86
# Dimension : 96, `reduction`: sum
# Result: True
#
#
# Test: 87
# Dimension : 458, `reduction`: none
# Result: True
#
#
# Test: 88
# Dimension : 148, `reduction`: none
# Result: True
#
#
# Test: 89
# Dimension : 95, `reduction`: sum
# Result: True
#
#
# Test: 90
# Dimension : 161, `reduction`: none
# Result: True
#
#
# Test: 91
# Dimension : 288, `reduction`: sum
# Result: True
#
#
# Test: 92
# Dimension : 433, `reduction`: sum
# Result: True
#
#
# Test: 93
# Dimension : 274, `reduction`: none
# Result: True
#
#
# Test: 94
# Dimension : 393, `reduction`: none
# Result: True
#
#
# Test: 95
# Dimension : 57, `reduction`: sum
# Result: True
#
#
# Test: 96
# Dimension : 432, `reduction`: mean
# Result: True
#
#
# Test: 97
# Dimension : 36, `reduction`: mean
# Result: True
#
#
# Test: 98
# Dimension : 14, `reduction`: mean
# Result: True
#
#
# Test: 99
# Dimension : 443, `reduction`: sum
# Result: True
#
#
# Test: 100
# Dimension : 376, `reduction`: sum
# Result: True
#
#
# Test: 101
# Dimension : 63, `reduction`: mean
# Result: True
#
#
# Test: 102
# Dimension : 159, `reduction`: none
# Result: True
#
#
# Test: 103
# Dimension : 128, `reduction`: sum
# Result: True
#
#
# Test: 104
# Dimension : 281, `reduction`: sum
# Result: True
#
#
# Test: 105
# Dimension : 241, `reduction`: mean
# Result: True
#
#
# Test: 106
# Dimension : 399, `reduction`: mean
# Result: True
#
#
# Test: 107
# Dimension : 165, `reduction`: none
# Result: True
#
#
# Test: 108
# Dimension : 147, `reduction`: mean
# Result: True
#
#
# Test: 109
# Dimension : 49, `reduction`: mean
# Result: True
#
#
# Test: 110
# Dimension : 119, `reduction`: sum
# Result: True
#
#
# Test: 111
# Dimension : 117, `reduction`: mean
# Result: True
#
#
# Test: 112
# Dimension : 334, `reduction`: sum
# Result: True
#
#
# Test: 113
# Dimension : 187, `reduction`: mean
# Result: True
#
#
# Test: 114
# Dimension : 49, `reduction`: sum
# Result: True
#
#
# Test: 115
# Dimension : 470, `reduction`: mean
# Result: True
#
#
# Test: 116
# Dimension : 339, `reduction`: none
# Result: True
#
#
# Test: 117
# Dimension : 300, `reduction`: sum
# Result: True
#
#
# Test: 118
# Dimension : 13, `reduction`: sum
# Result: True
#
#
# Test: 119
# Dimension : 465, `reduction`: sum
# Result: True
#
#
# Test: 120
# Dimension : 255, `reduction`: sum
# Result: True
#
#
# Test: 121
# Dimension : 174, `reduction`: sum
# Result: True
#
#
# Test: 122
# Dimension : 38, `reduction`: none
# Result: True
#
#
# Test: 123
# Dimension : 51, `reduction`: sum
# Result: True
#
#
# Test: 124
# Dimension : 280, `reduction`: none
# Result: True
#
#
# Test: 125
# Dimension : 471, `reduction`: none
# Result: True
#
#
# Test: 126
# Dimension : 201, `reduction`: sum
# Result: True
#
#
# Test: 127
# Dimension : 433, `reduction`: sum
# Result: True
#
#
# Test: 128
# Dimension : 273, `reduction`: none
# Result: True
#
#
# Test: 129
# Dimension : 488, `reduction`: none
# Result: True
#
#
# Test: 130
# Dimension : 304, `reduction`: mean
# Result: True
#
#
# Test: 131
# Dimension : 293, `reduction`: sum
# Result: True
#
#
# Test: 132
# Dimension : 338, `reduction`: none
# Result: True
#
#
# Test: 133
# Dimension : 155, `reduction`: none
# Result: True
#
#
# Test: 134
# Dimension : 375, `reduction`: mean
# Result: True
#
#
# Test: 135
# Dimension : 256, `reduction`: none
# Result: True
#
#
# Test: 136
# Dimension : 173, `reduction`: mean
# Result: True
#
#
# Test: 137
# Dimension : 254, `reduction`: sum
# Result: True
#
#
# Test: 138
# Dimension : 413, `reduction`: sum
# Result: True
#
#
# Test: 139
# Dimension : 314, `reduction`: mean
# Result: True
#
#
# Test: 140
# Dimension : 444, `reduction`: sum
# Result: True
#
#
# Test: 141
# Dimension : 329, `reduction`: sum
# Result: True
#
#
# Test: 142
# Dimension : 188, `reduction`: sum
# Result: True
#
#
# Test: 143
# Dimension : 15, `reduction`: mean
# Result: True
#
#
# Test: 144
# Dimension : 141, `reduction`: sum
# Result: True
#
#
# Test: 145
# Dimension : 66, `reduction`: sum
# Result: True
#
#
# Test: 146
# Dimension : 320, `reduction`: sum
# Result: True
#
#
# Test: 147
# Dimension : 4, `reduction`: none
# Result: True
#
#
# Test: 148
# Dimension : 53, `reduction`: sum
# Result: True
#
#
# Test: 149
# Dimension : 291, `reduction`: none
# Result: True
#
#
# Test: 150
# Dimension : 128, `reduction`: mean
# Result: True
#
#
# Test: 151
# Dimension : 402, `reduction`: sum
# Result: True
#
#
# Test: 152
# Dimension : 483, `reduction`: none
# Result: True
#
#
# Test: 153
# Dimension : 78, `reduction`: mean
# Result: True
#
#
# Test: 154
# Dimension : 108, `reduction`: none
# Result: True
#
#
# Test: 155
# Dimension : 307, `reduction`: sum
# Result: True
#
#
# Test: 156
# Dimension : 276, `reduction`: none
# Result: True
#
#
# Test: 157
# Dimension : 53, `reduction`: sum
# Result: True
#
#
# Test: 158
# Dimension : 63, `reduction`: none
# Result: True
#
#
# Test: 159
# Dimension : 86, `reduction`: mean
# Result: True
#
#
# Test: 160
# Dimension : 448, `reduction`: none
# Result: True
#
#
# Test: 161
# Dimension : 473, `reduction`: none
# Result: True
#
#
# Test: 162
# Dimension : 326, `reduction`: sum
# Result: True
#
#
# Test: 163
# Dimension : 48, `reduction`: mean
# Result: True
#
#
# Test: 164
# Dimension : 430, `reduction`: mean
# Result: True
#
#
# Test: 165
# Dimension : 179, `reduction`: mean
# Result: True
#
#
# Test: 166
# Dimension : 177, `reduction`: none
# Result: True
#
#
# Test: 167
# Dimension : 110, `reduction`: none
# Result: True
#
#
# Test: 168
# Dimension : 443, `reduction`: none
# Result: True
#
#
# Test: 169
# Dimension : 379, `reduction`: none
# Result: True
#
#
# Test: 170
# Dimension : 270, `reduction`: none
# Result: True
#
#
# Test: 171
# Dimension : 407, `reduction`: mean
# Result: True
#
#
# Test: 172
# Dimension : 325, `reduction`: sum
# Result: True
#
#
# Test: 173
# Dimension : 199, `reduction`: sum
# Result: True
#
#
# Test: 174
# Dimension : 133, `reduction`: mean
# Result: True
#
#
# Test: 175
# Dimension : 132, `reduction`: mean
# Result: True
#
#
# Test: 176
# Dimension : 134, `reduction`: sum
# Result: True
#
#
# Test: 177
# Dimension : 50, `reduction`: none
# Result: True
#
#
# Test: 178
# Dimension : 195, `reduction`: none
# Result: True
#
#
# Test: 179
# Dimension : 9, `reduction`: sum
# Result: True
#
#
# Test: 180
# Dimension : 36, `reduction`: sum
# Result: True
#
#
# Test: 181
# Dimension : 440, `reduction`: mean
# Result: True
#
#
# Test: 182
# Dimension : 385, `reduction`: sum
# Result: True
#
#
# Test: 183
# Dimension : 326, `reduction`: sum
# Result: True
#
#
# Test: 184
# Dimension : 229, `reduction`: none
# Result: True
#
#
# Test: 185
# Dimension : 411, `reduction`: mean
# Result: True
#
#
# Test: 186
# Dimension : 361, `reduction`: none
# Result: True
#
#
# Test: 187
# Dimension : 177, `reduction`: mean
# Result: True
#
#
# Test: 188
# Dimension : 263, `reduction`: sum
# Result: True
#
#
# Test: 189
# Dimension : 280, `reduction`: sum
# Result: True
#
#
# Test: 190
# Dimension : 1, `reduction`: sum
# Result: True
#
#
# Test: 191
# Dimension : 390, `reduction`: mean
# Result: True
#
#
# Test: 192
# Dimension : 129, `reduction`: none
# Result: True
#
#
# Test: 193
# Dimension : 15, `reduction`: none
# Result: True
#
#
# Test: 194
# Dimension : 5, `reduction`: sum
# Result: True
#
#
# Test: 195
# Dimension : 481, `reduction`: mean
# Result: True
#
#
# Test: 196
# Dimension : 23, `reduction`: mean
# Result: True
#
#
# Test: 197
# Dimension : 291, `reduction`: mean
# Result: True
#
#
# Test: 198
# Dimension : 498, `reduction`: sum
# Result: True
#
#
# Test: 199
# Dimension : 497, `reduction`: none
# Result: True
#
#
# Test: 200
# Dimension : 483, `reduction`: none
# Result: True
#
#
# Test: 201
# Dimension : 255, `reduction`: sum
# Result: True
#
#
# Test: 202
# Dimension : 175, `reduction`: mean
# Result: True
#
#
# Test: 203
# Dimension : 183, `reduction`: mean
# Result: True
#
#
# Test: 204
# Dimension : 192, `reduction`: none
# Result: True
#
#
# Test: 205
# Dimension : 408, `reduction`: none
# Result: True
#
#
# Test: 206
# Dimension : 355, `reduction`: sum
# Result: True
#
#
# Test: 207
# Dimension : 226, `reduction`: mean
# Result: True
#
#
# Test: 208
# Dimension : 411, `reduction`: none
# Result: True
#
#
# Test: 209
# Dimension : 471, `reduction`: none
# Result: True
#
#
# Test: 210
# Dimension : 480, `reduction`: sum
# Result: True
#
#
# Test: 211
# Dimension : 335, `reduction`: mean
# Result: True
#
#
# Test: 212
# Dimension : 11, `reduction`: none
# Result: True
#
#
# Test: 213
# Dimension : 147, `reduction`: none
# Result: True
#
#
# Test: 214
# Dimension : 181, `reduction`: mean
# Result: True
#
#
# Test: 215
# Dimension : 458, `reduction`: none
# Result: True
#
#
# Test: 216
# Dimension : 149, `reduction`: sum
# Result: True
#
#
# Test: 217
# Dimension : 222, `reduction`: none
# Result: True
#
#
# Test: 218
# Dimension : 342, `reduction`: mean
# Result: True
#
#
# Test: 219
# Dimension : 21, `reduction`: sum
# Result: True
#
#
# Test: 220
# Dimension : 111, `reduction`: none
# Result: True
#
#
# Test: 221
# Dimension : 480, `reduction`: mean
# Result: True
#
#
# Test: 222
# Dimension : 300, `reduction`: sum
# Result: True
#
#
# Test: 223
# Dimension : 429, `reduction`: none
# Result: True
#
#
# Test: 224
# Dimension : 305, `reduction`: none
# Result: True
#
#
# Test: 225
# Dimension : 10, `reduction`: mean
# Result: True
#
#
# Test: 226
# Dimension : 97, `reduction`: mean
# Result: True
#
#
# Test: 227
# Dimension : 379, `reduction`: none
# Result: True
#
#
# Test: 228
# Dimension : 391, `reduction`: sum
# Result: True
#
#
# Test: 229
# Dimension : 269, `reduction`: none
# Result: True
#
#
# Test: 230
# Dimension : 27, `reduction`: sum
# Result: True
#
#
# Test: 231
# Dimension : 294, `reduction`: sum
# Result: True
#
#
# Test: 232
# Dimension : 217, `reduction`: mean
# Result: True
#
#
# Test: 233
# Dimension : 431, `reduction`: none
# Result: True
#
#
# Test: 234
# Dimension : 272, `reduction`: sum
# Result: True
#
#
# Test: 235
# Dimension : 177, `reduction`: none
# Result: True
#
#
# Test: 236
# Dimension : 246, `reduction`: mean
# Result: True
#
#
# Test: 237
# Dimension : 355, `reduction`: none
# Result: True
#
#
# Test: 238
# Dimension : 77, `reduction`: mean
# Result: True
#
#
# Test: 239
# Dimension : 227, `reduction`: mean
# Result: True
#
#
# Test: 240
# Dimension : 202, `reduction`: none
# Result: True
#
#
# Test: 241
# Dimension : 432, `reduction`: mean
# Result: True
#
#
# Test: 242
# Dimension : 291, `reduction`: sum
# Result: True
#
#
# Test: 243
# Dimension : 172, `reduction`: mean
# Result: True
#
#
# Test: 244
# Dimension : 372, `reduction`: sum
# Result: True
#
#
# Test: 245
# Dimension : 221, `reduction`: sum
# Result: True
#
#
# Test: 246
# Dimension : 53, `reduction`: mean
# Result: True
#
#
# Test: 247
# Dimension : 7, `reduction`: sum
# Result: True
#
#
# Test: 248
# Dimension : 352, `reduction`: mean
# Result: True
#
#
# Test: 249
# Dimension : 260, `reduction`: sum
# Result: True
#
#
# Test: 250
# Dimension : 488, `reduction`: none
# Result: True
#
#
# Test: 251
# Dimension : 179, `reduction`: sum
# Result: True
#
#
# Test: 252
# Dimension : 417, `reduction`: mean
# Result: True
#
#
# Test: 253
# Dimension : 337, `reduction`: sum
# Result: True
#
#
# Test: 254
# Dimension : 243, `reduction`: sum
# Result: True
#
#
# Test: 255
# Dimension : 450, `reduction`: sum
# Result: True
#
#
# Test: 256
# Dimension : 413, `reduction`: mean
# Result: True
#
#
# Test: 257
# Dimension : 440, `reduction`: mean
# Result: True
#
#
# Test: 258
# Dimension : 391, `reduction`: mean
# Result: True
#
#
# Test: 259
# Dimension : 139, `reduction`: mean
# Result: True
#
#
# Test: 260
# Dimension : 490, `reduction`: none
# Result: True
#
#
# Test: 261
# Dimension : 236, `reduction`: none
# Result: True
#
#
# Test: 262
# Dimension : 391, `reduction`: sum
# Result: True
#
#
# Test: 263
# Dimension : 139, `reduction`: none
# Result: True
#
#
# Test: 264
# Dimension : 133, `reduction`: sum
# Result: True
#
#
# Test: 265
# Dimension : 414, `reduction`: sum
# Result: True
#
#
# Test: 266
# Dimension : 43, `reduction`: none
# Result: True
#
#
# Test: 267
# Dimension : 284, `reduction`: mean
# Result: True
#
#
# Test: 268
# Dimension : 349, `reduction`: mean
# Result: True
#
#
# Test: 269
# Dimension : 366, `reduction`: none
# Result: True
#
#
# Test: 270
# Dimension : 346, `reduction`: sum
# Result: True
#
#
# Test: 271
# Dimension : 230, `reduction`: mean
# Result: True
#
#
# Test: 272
# Dimension : 308, `reduction`: sum
# Result: True
#
#
# Test: 273
# Dimension : 493, `reduction`: sum
# Result: True
#
#
# Test: 274
# Dimension : 296, `reduction`: mean
# Result: True
#
#
# Test: 275
# Dimension : 114, `reduction`: sum
# Result: True
#
#
# Test: 276
# Dimension : 425, `reduction`: mean
# Result: True
#
#
# Test: 277
# Dimension : 433, `reduction`: none
# Result: True
#
#
# Test: 278
# Dimension : 255, `reduction`: sum
# Result: True
#
#
# Test: 279
# Dimension : 194, `reduction`: sum
# Result: True
#
#
# Test: 280
# Dimension : 334, `reduction`: sum
# Result: True
#
#
# Test: 281
# Dimension : 388, `reduction`: sum
# Result: True
#
#
# Test: 282
# Dimension : 52, `reduction`: sum
# Result: True
#
#
# Test: 283
# Dimension : 206, `reduction`: none
# Result: True
#
#
# Test: 284
# Dimension : 452, `reduction`: none
# Result: True
#
#
# Test: 285
# Dimension : 187, `reduction`: none
# Result: True
#
#
# Test: 286
# Dimension : 132, `reduction`: mean
# Result: True
#
#
# Test: 287
# Dimension : 393, `reduction`: mean
# Result: True
#
#
# Test: 288
# Dimension : 44, `reduction`: sum
# Result: True
#
#
# Test: 289
# Dimension : 230, `reduction`: sum
# Result: True
#
#
# Test: 290
# Dimension : 130, `reduction`: sum
# Result: True
#
#
# Test: 291
# Dimension : 285, `reduction`: sum
# Result: True
#
#
# Test: 292
# Dimension : 357, `reduction`: none
# Result: True
#
#
# Test: 293
# Dimension : 452, `reduction`: none
# Result: True
#
#
# Test: 294
# Dimension : 486, `reduction`: sum
# Result: True
#
#
# Test: 295
# Dimension : 327, `reduction`: sum
# Result: True
#
#
# Test: 296
# Dimension : 132, `reduction`: sum
# Result: True
#
#
# Test: 297
# Dimension : 389, `reduction`: none
# Result: True
#
#
# Test: 298
# Dimension : 231, `reduction`: sum
# Result: True
#
#
# Test: 299
# Dimension : 291, `reduction`: mean
# Result: True
#
#
# Test: 300
# Dimension : 450, `reduction`: none
# Result: True
#
#
# Test: 301
# Dimension : 274, `reduction`: mean
# Result: True
#
#
# Test: 302
# Dimension : 75, `reduction`: sum
# Result: True
#
#
# Test: 303
# Dimension : 376, `reduction`: none
# Result: True
#
#
# Test: 304
# Dimension : 278, `reduction`: sum
# Result: True
#
#
# Test: 305
# Dimension : 177, `reduction`: sum
# Result: True
#
#
# Test: 306
# Dimension : 447, `reduction`: mean
# Result: True
#
#
# Test: 307
# Dimension : 426, `reduction`: sum
# Result: True
#
#
# Test: 308
# Dimension : 132, `reduction`: sum
# Result: True
#
#
# Test: 309
# Dimension : 432, `reduction`: sum
# Result: True
#
#
# Test: 310
# Dimension : 300, `reduction`: none
# Result: True
#
#
# Test: 311
# Dimension : 51, `reduction`: sum
# Result: True
#
#
# Test: 312
# Dimension : 281, `reduction`: none
# Result: True
#
#
# Test: 313
# Dimension : 265, `reduction`: mean
# Result: True
#
#
# Test: 314
# Dimension : 63, `reduction`: none
# Result: True
#
#
# Test: 315
# Dimension : 24, `reduction`: none
# Result: True
#
#
# Test: 316
# Dimension : 25, `reduction`: none
# Result: True
#
#
# Test: 317
# Dimension : 416, `reduction`: mean
# Result: True
#
#
# Test: 318
# Dimension : 119, `reduction`: none
# Result: True
#
#
# Test: 319
# Dimension : 178, `reduction`: mean
# Result: True
#
#
# Test: 320
# Dimension : 334, `reduction`: sum
# Result: True
#
#
# Test: 321
# Dimension : 95, `reduction`: none
# Result: True
#
#
# Test: 322
# Dimension : 414, `reduction`: none
# Result: True
#
#
# Test: 323
# Dimension : 199, `reduction`: mean
# Result: True
#
#
# Test: 324
# Dimension : 254, `reduction`: mean
# Result: True
#
#
# Test: 325
# Dimension : 272, `reduction`: none
# Result: True
#
#
# Test: 326
# Dimension : 32, `reduction`: none
# Result: True
#
#
# Test: 327
# Dimension : 496, `reduction`: mean
# Result: True
#
#
# Test: 328
# Dimension : 158, `reduction`: mean
# Result: True
#
#
# Test: 329
# Dimension : 488, `reduction`: none
# Result: True
#
#
# Test: 330
# Dimension : 77, `reduction`: mean
# Result: True
#
#
# Test: 331
# Dimension : 340, `reduction`: sum
# Result: True
#
#
# Test: 332
# Dimension : 476, `reduction`: none
# Result: True
#
#
# Test: 333
# Dimension : 477, `reduction`: sum
# Result: True
#
#
# Test: 334
# Dimension : 5, `reduction`: mean
# Result: True
#
#
# Test: 335
# Dimension : 111, `reduction`: mean
# Result: True
#
#
# Test: 336
# Dimension : 432, `reduction`: sum
# Result: True
#
#
# Test: 337
# Dimension : 332, `reduction`: none
# Result: True
#
#
# Test: 338
# Dimension : 161, `reduction`: none
# Result: True
#
#
# Test: 339
# Dimension : 147, `reduction`: mean
# Result: True
#
#
# Test: 340
# Dimension : 358, `reduction`: sum
# Result: True
#
#
# Test: 341
# Dimension : 384, `reduction`: sum
# Result: True
#
#
# Test: 342
# Dimension : 82, `reduction`: none
# Result: True
#
#
# Test: 343
# Dimension : 412, `reduction`: sum
# Result: True
#
#
# Test: 344
# Dimension : 158, `reduction`: sum
# Result: True
#
#
# Test: 345
# Dimension : 370, `reduction`: sum
# Result: True
#
#
# Test: 346
# Dimension : 168, `reduction`: sum
# Result: True
#
#
# Test: 347
# Dimension : 172, `reduction`: none
# Result: True
#
#
# Test: 348
# Dimension : 296, `reduction`: sum
# Result: True
#
#
# Test: 349
# Dimension : 482, `reduction`: none
# Result: True
#
#
# Test: 350
# Dimension : 69, `reduction`: none
# Result: True
#
#
# Test: 351
# Dimension : 195, `reduction`: sum
# Result: True
#
#
# Test: 352
# Dimension : 257, `reduction`: sum
# Result: True
#
#
# Test: 353
# Dimension : 332, `reduction`: mean
# Result: True
#
#
# Test: 354
# Dimension : 108, `reduction`: none
# Result: True
#
#
# Test: 355
# Dimension : 29, `reduction`: sum
# Result: True
#
#
# Test: 356
# Dimension : 83, `reduction`: sum
# Result: True
#
#
# Test: 357
# Dimension : 39, `reduction`: mean
# Result: True
#
#
# Test: 358
# Dimension : 410, `reduction`: mean
# Result: True
#
#
# Test: 359
# Dimension : 338, `reduction`: sum
# Result: True
#
#
# Test: 360
# Dimension : 494, `reduction`: sum
# Result: True
#
#
# Test: 361
# Dimension : 259, `reduction`: none
# Result: True
#
#
# Test: 362
# Dimension : 393, `reduction`: sum
# Result: True
#
#
# Test: 363
# Dimension : 490, `reduction`: none
# Result: True
#
#
# Test: 364
# Dimension : 142, `reduction`: none
# Result: True
#
#
# Test: 365
# Dimension : 466, `reduction`: sum
# Result: True
#
#
# Test: 366
# Dimension : 118, `reduction`: mean
# Result: True
#
#
# Test: 367
# Dimension : 292, `reduction`: sum
# Result: True
#
#
# Test: 368
# Dimension : 421, `reduction`: none
# Result: True
#
#
# Test: 369
# Dimension : 421, `reduction`: mean
# Result: True
#
#
# Test: 370
# Dimension : 325, `reduction`: none
# Result: True
#
#
# Test: 371
# Dimension : 409, `reduction`: mean
# Result: True
#
#
# Test: 372
# Dimension : 192, `reduction`: none
# Result: True
#
#
# Test: 373
# Dimension : 42, `reduction`: mean
# Result: True
#
#
# Test: 374
# Dimension : 60, `reduction`: none
# Result: True
#
#
# Test: 375
# Dimension : 375, `reduction`: sum
# Result: True
#
#
# Test: 376
# Dimension : 407, `reduction`: mean
# Result: True
#
#
# Test: 377
# Dimension : 151, `reduction`: none
# Result: True
#
#
# Test: 378
# Dimension : 168, `reduction`: none
# Result: True
#
#
# Test: 379
# Dimension : 195, `reduction`: sum
# Result: True
#
#
# Test: 380
# Dimension : 186, `reduction`: none
# Result: True
#
#
# Test: 381
# Dimension : 329, `reduction`: mean
# Result: True
#
#
# Test: 382
# Dimension : 316, `reduction`: mean
# Result: True
#
#
# Test: 383
# Dimension : 342, `reduction`: sum
# Result: True
#
#
# Test: 384
# Dimension : 337, `reduction`: mean
# Result: True
#
#
# Test: 385
# Dimension : 407, `reduction`: none
# Result: True
#
#
# Test: 386
# Dimension : 39, `reduction`: sum
# Result: True
#
#
# Test: 387
# Dimension : 202, `reduction`: none
# Result: True
#
#
# Test: 388
# Dimension : 11, `reduction`: none
# Result: True
#
#
# Test: 389
# Dimension : 378, `reduction`: sum
# Result: True
#
#
# Test: 390
# Dimension : 340, `reduction`: none
# Result: True
#
#
# Test: 391
# Dimension : 149, `reduction`: none
# Result: True
#
#
# Test: 392
# Dimension : 167, `reduction`: mean
# Result: True
#
#
# Test: 393
# Dimension : 409, `reduction`: mean
# Result: True
#
#
# Test: 394
# Dimension : 340, `reduction`: none
# Result: True
#
#
# Test: 395
# Dimension : 419, `reduction`: mean
# Result: True
#
#
# Test: 396
# Dimension : 207, `reduction`: mean
# Result: True
#
#
# Test: 397
# Dimension : 363, `reduction`: mean
# Result: True
#
#
# Test: 398
# Dimension : 239, `reduction`: none
# Result: True
#
#
# Test: 399
# Dimension : 307, `reduction`: mean
# Result: True
#
#
# Test: 400
# Dimension : 299, `reduction`: mean
# Result: True
#
#
# Test: 401
# Dimension : 254, `reduction`: mean
# Result: True
#
#
# Test: 402
# Dimension : 26, `reduction`: none
# Result: True
#
#
# Test: 403
# Dimension : 430, `reduction`: sum
# Result: True
#
#
# Test: 404
# Dimension : 257, `reduction`: sum
# Result: True
#
#
# Test: 405
# Dimension : 4, `reduction`: mean
# Result: True
#
#
# Test: 406
# Dimension : 231, `reduction`: mean
# Result: True
#
#
# Test: 407
# Dimension : 162, `reduction`: sum
# Result: True
#
#
# Test: 408
# Dimension : 199, `reduction`: sum
# Result: True
#
#
# Test: 409
# Dimension : 149, `reduction`: none
# Result: True
#
#
# Test: 410
# Dimension : 255, `reduction`: mean
# Result: True
#
#
# Test: 411
# Dimension : 285, `reduction`: mean
# Result: True
#
#
# Test: 412
# Dimension : 299, `reduction`: mean
# Result: True
#
#
# Test: 413
# Dimension : 315, `reduction`: none
# Result: True
#
#
# Test: 414
# Dimension : 273, `reduction`: none
# Result: True
#
#
# Test: 415
# Dimension : 205, `reduction`: mean
# Result: True
#
#
# Test: 416
# Dimension : 27, `reduction`: mean
# Result: True
#
#
# Test: 417
# Dimension : 46, `reduction`: mean
# Result: True
#
#
# Test: 418
# Dimension : 460, `reduction`: mean
# Result: True
#
#
# Test: 419
# Dimension : 339, `reduction`: sum
# Result: True
#
#
# Test: 420
# Dimension : 131, `reduction`: sum
# Result: True
#
#
# Test: 421
# Dimension : 431, `reduction`: mean
# Result: True
#
#
# Test: 422
# Dimension : 182, `reduction`: sum
# Result: True
#
#
# Test: 423
# Dimension : 297, `reduction`: none
# Result: True
#
#
# Test: 424
# Dimension : 459, `reduction`: none
# Result: True
#
#
# Test: 425
# Dimension : 8, `reduction`: none
# Result: True
#
#
# Test: 426
# Dimension : 52, `reduction`: mean
# Result: True
#
#
# Test: 427
# Dimension : 36, `reduction`: mean
# Result: True
#
#
# Test: 428
# Dimension : 461, `reduction`: sum
# Result: True
#
#
# Test: 429
# Dimension : 453, `reduction`: none
# Result: True
#
#
# Test: 430
# Dimension : 84, `reduction`: mean
# Result: True
#
#
# Test: 431
# Dimension : 476, `reduction`: sum
# Result: True
#
#
# Test: 432
# Dimension : 300, `reduction`: none
# Result: True
#
#
# Test: 433
# Dimension : 37, `reduction`: sum
# Result: True
#
#
# Test: 434
# Dimension : 328, `reduction`: mean
# Result: True
#
#
# Test: 435
# Dimension : 45, `reduction`: none
# Result: True
#
#
# Test: 436
# Dimension : 430, `reduction`: mean
# Result: True
#
#
# Test: 437
# Dimension : 230, `reduction`: sum
# Result: True
#
#
# Test: 438
# Dimension : 78, `reduction`: none
# Result: True
#
#
# Test: 439
# Dimension : 231, `reduction`: sum
# Result: True
#
#
# Test: 440
# Dimension : 404, `reduction`: none
# Result: True
#
#
# Test: 441
# Dimension : 290, `reduction`: none
# Result: True
#
#
# Test: 442
# Dimension : 65, `reduction`: none
# Result: True
#
#
# Test: 443
# Dimension : 445, `reduction`: none
# Result: True
#
#
# Test: 444
# Dimension : 448, `reduction`: sum
# Result: True
#
#
# Test: 445
# Dimension : 129, `reduction`: sum
# Result: True
#
#
# Test: 446
# Dimension : 117, `reduction`: sum
# Result: True
#
#
# Test: 447
# Dimension : 327, `reduction`: none
# Result: True
#
#
# Test: 448
# Dimension : 210, `reduction`: mean
# Result: True
#
#
# Test: 449
# Dimension : 304, `reduction`: sum
# Result: True
#
#
# Test: 450
# Dimension : 111, `reduction`: sum
# Result: True
#
#
# Test: 451
# Dimension : 330, `reduction`: mean
# Result: True
#
#
# Test: 452
# Dimension : 32, `reduction`: none
# Result: True
#
#
# Test: 453
# Dimension : 393, `reduction`: mean
# Result: True
#
#
# Test: 454
# Dimension : 464, `reduction`: none
# Result: True
#
#
# Test: 455
# Dimension : 46, `reduction`: mean
# Result: True
#
#
# Test: 456
# Dimension : 29, `reduction`: none
# Result: True
#
#
# Test: 457
# Dimension : 298, `reduction`: none
# Result: True
#
#
# Test: 458
# Dimension : 106, `reduction`: sum
# Result: True
#
#
# Test: 459
# Dimension : 186, `reduction`: sum
# Result: True
#
#
# Test: 460
# Dimension : 29, `reduction`: mean
# Result: True
#
#
# Test: 461
# Dimension : 169, `reduction`: sum
# Result: True
#
#
# Test: 462
# Dimension : 485, `reduction`: sum
# Result: True
#
#
# Test: 463
# Dimension : 52, `reduction`: sum
# Result: True
#
#
# Test: 464
# Dimension : 256, `reduction`: none
# Result: True
#
#
# Test: 465
# Dimension : 428, `reduction`: sum
# Result: True
#
#
# Test: 466
# Dimension : 101, `reduction`: mean
# Result: True
#
#
# Test: 467
# Dimension : 150, `reduction`: mean
# Result: True
#
#
# Test: 468
# Dimension : 88, `reduction`: none
# Result: True
#
#
# Test: 469
# Dimension : 12, `reduction`: none
# Result: True
#
#
# Test: 470
# Dimension : 243, `reduction`: none
# Result: True
#
#
# Test: 471
# Dimension : 399, `reduction`: sum
# Result: True
#
#
# Test: 472
# Dimension : 486, `reduction`: sum
# Result: True
#
#
# Test: 473
# Dimension : 143, `reduction`: none
# Result: True
#
#
# Test: 474
# Dimension : 398, `reduction`: mean
# Result: True
#
#
# Test: 475
# Dimension : 391, `reduction`: none
# Result: True
#
#
# Test: 476
# Dimension : 36, `reduction`: mean
# Result: True
#
#
# Test: 477
# Dimension : 437, `reduction`: sum
# Result: True
#
#
# Test: 478
# Dimension : 338, `reduction`: mean
# Result: True
#
#
# Test: 479
# Dimension : 448, `reduction`: sum
# Result: True
#
#
# Test: 480
# Dimension : 120, `reduction`: mean
# Result: True
#
#
# Test: 481
# Dimension : 277, `reduction`: sum
# Result: True
#
#
# Test: 482
# Dimension : 204, `reduction`: sum
# Result: True
#
#
# Test: 483
# Dimension : 160, `reduction`: none
# Result: True
#
#
# Test: 484
# Dimension : 309, `reduction`: mean
# Result: True
#
#
# Test: 485
# Dimension : 38, `reduction`: sum
# Result: True
#
#
# Test: 486
# Dimension : 303, `reduction`: mean
# Result: True
#
#
# Test: 487
# Dimension : 485, `reduction`: mean
# Result: True
#
#
# Test: 488
# Dimension : 154, `reduction`: sum
# Result: True
#
#
# Test: 489
# Dimension : 243, `reduction`: mean
# Result: True
#
#
# Test: 490
# Dimension : 91, `reduction`: none
# Result: True
#
#
# Test: 491
# Dimension : 356, `reduction`: sum
# Result: True
#
#
# Test: 492
# Dimension : 38, `reduction`: none
# Result: True
#
#
# Test: 493
# Dimension : 496, `reduction`: none
# Result: True
#
#
# Test: 494
# Dimension : 478, `reduction`: none
# Result: True
#
#
# Test: 495
# Dimension : 399, `reduction`: sum
# Result: True
#
#
# Test: 496
# Dimension : 302, `reduction`: none
# Result: True
#
#
# Test: 497
# Dimension : 9, `reduction`: sum
# Result: True
#
#
# Test: 498
# Dimension : 251, `reduction`: sum
# Result: True
#
#
# Test: 499
# Dimension : 138, `reduction`: none
# Result: True
#
#
# Test: 500
# Dimension : 287, `reduction`: sum
# Result: True
#
#
# Test: 501
# Dimension : 374, `reduction`: mean
# Result: True
#
#
# Test: 502
# Dimension : 180, `reduction`: none
# Result: True
#
#
# Test: 503
# Dimension : 142, `reduction`: mean
# Result: True
#
#
# Test: 504
# Dimension : 273, `reduction`: mean
# Result: True
#
#
# Test: 505
# Dimension : 168, `reduction`: none
# Result: True
#
#
# Test: 506
# Dimension : 484, `reduction`: none
# Result: True
#
#
# Test: 507
# Dimension : 49, `reduction`: none
# Result: True
#
#
# Test: 508
# Dimension : 436, `reduction`: none
# Result: True
#
#
# Test: 509
# Dimension : 228, `reduction`: none
# Result: True
#
#
# Test: 510
# Dimension : 57, `reduction`: none
# Result: True
#
#
# Test: 511
# Dimension : 148, `reduction`: none
# Result: True
#
#
# Test: 512
# Dimension : 141, `reduction`: sum
# Result: True
#
#
# Test: 513
# Dimension : 86, `reduction`: sum
# Result: True
#
#
# Test: 514
# Dimension : 212, `reduction`: none
# Result: True
#
#
# Test: 515
# Dimension : 410, `reduction`: mean
# Result: True
#
#
# Test: 516
# Dimension : 325, `reduction`: mean
# Result: True
#
#
# Test: 517
# Dimension : 170, `reduction`: sum
# Result: True
#
#
# Test: 518
# Dimension : 57, `reduction`: mean
# Result: True
#
#
# Test: 519
# Dimension : 391, `reduction`: none
# Result: True
#
#
# Test: 520
# Dimension : 20, `reduction`: sum
# Result: True
#
#
# Test: 521
# Dimension : 102, `reduction`: mean
# Result: True
#
#
# Test: 522
# Dimension : 180, `reduction`: none
# Result: True
#
#
# Test: 523
# Dimension : 30, `reduction`: mean
# Result: True
#
#
# Test: 524
# Dimension : 497, `reduction`: none
# Result: True
#
#
# Test: 525
# Dimension : 289, `reduction`: mean
# Result: True
#
#
# Test: 526
# Dimension : 410, `reduction`: mean
# Result: True
#
#
# Test: 527
# Dimension : 214, `reduction`: none
# Result: True
#
#
# Test: 528
# Dimension : 268, `reduction`: sum
# Result: True
#
#
# Test: 529
# Dimension : 23, `reduction`: none
# Result: True
#
#
# Test: 530
# Dimension : 22, `reduction`: none
# Result: True
#
#
# Test: 531
# Dimension : 417, `reduction`: sum
# Result: True
#
#
# Test: 532
# Dimension : 251, `reduction`: none
# Result: True
#
#
# Test: 533
# Dimension : 424, `reduction`: none
# Result: True
#
#
# Test: 534
# Dimension : 312, `reduction`: sum
# Result: True
#
#
# Test: 535
# Dimension : 190, `reduction`: sum
# Result: True
#
#
# Test: 536
# Dimension : 380, `reduction`: mean
# Result: True
#
#
# Test: 537
# Dimension : 54, `reduction`: none
# Result: True
#
#
# Test: 538
# Dimension : 60, `reduction`: none
# Result: True
#
#
# Test: 539
# Dimension : 65, `reduction`: sum
# Result: True
#
#
# Test: 540
# Dimension : 317, `reduction`: none
# Result: True
#
#
# Test: 541
# Dimension : 299, `reduction`: mean
# Result: True
#
#
# Test: 542
# Dimension : 302, `reduction`: mean
# Result: True
#
#
# Test: 543
# Dimension : 482, `reduction`: mean
# Result: True
#
#
# Test: 544
# Dimension : 391, `reduction`: none
# Result: True
#
#
# Test: 545
# Dimension : 204, `reduction`: sum
# Result: True
#
#
# Test: 546
# Dimension : 135, `reduction`: none
# Result: True
#
#
# Test: 547
# Dimension : 314, `reduction`: mean
# Result: True
#
#
# Test: 548
# Dimension : 215, `reduction`: mean
# Result: True
#
#
# Test: 549
# Dimension : 304, `reduction`: mean
# Result: True
#
#
# Test: 550
# Dimension : 307, `reduction`: mean
# Result: True
#
#
# Test: 551
# Dimension : 486, `reduction`: sum
# Result: True
#
#
# Test: 552
# Dimension : 499, `reduction`: sum
# Result: True
#
#
# Test: 553
# Dimension : 112, `reduction`: mean
# Result: True
#
#
# Test: 554
# Dimension : 116, `reduction`: mean
# Result: True
#
#
# Test: 555
# Dimension : 131, `reduction`: none
# Result: True
#
#
# Test: 556
# Dimension : 261, `reduction`: mean
# Result: True
#
#
# Test: 557
# Dimension : 92, `reduction`: mean
# Result: True
#
#
# Test: 558
# Dimension : 482, `reduction`: sum
# Result: True
#
#
# Test: 559
# Dimension : 243, `reduction`: none
# Result: True
#
#
# Test: 560
# Dimension : 473, `reduction`: mean
# Result: True
#
#
# Test: 561
# Dimension : 229, `reduction`: mean
# Result: True
#
#
# Test: 562
# Dimension : 416, `reduction`: none
# Result: True
#
#
# Test: 563
# Dimension : 262, `reduction`: mean
# Result: True
#
#
# Test: 564
# Dimension : 363, `reduction`: sum
# Result: True
#
#
# Test: 565
# Dimension : 493, `reduction`: mean
# Result: True
#
#
# Test: 566
# Dimension : 465, `reduction`: none
# Result: True
#
#
# Test: 567
# Dimension : 76, `reduction`: mean
# Result: True
#
#
# Test: 568
# Dimension : 145, `reduction`: sum
# Result: True
#
#
# Test: 569
# Dimension : 110, `reduction`: mean
# Result: True
#
#
# Test: 570
# Dimension : 432, `reduction`: none
# Result: True
#
#
# Test: 571
# Dimension : 207, `reduction`: none
# Result: True
#
#
# Test: 572
# Dimension : 355, `reduction`: sum
# Result: True
#
#
# Test: 573
# Dimension : 182, `reduction`: mean
# Result: True
#
#
# Test: 574
# Dimension : 134, `reduction`: mean
# Result: True
#
#
# Test: 575
# Dimension : 84, `reduction`: none
# Result: True
#
#
# Test: 576
# Dimension : 446, `reduction`: sum
# Result: True
#
#
# Test: 577
# Dimension : 63, `reduction`: mean
# Result: True
#
#
# Test: 578
# Dimension : 391, `reduction`: sum
# Result: True
#
#
# Test: 579
# Dimension : 88, `reduction`: mean
# Result: True
#
#
# Test: 580
# Dimension : 301, `reduction`: sum
# Result: True
#
#
# Test: 581
# Dimension : 328, `reduction`: mean
# Result: True
#
#
# Test: 582
# Dimension : 118, `reduction`: none
# Result: True
#
#
# Test: 583
# Dimension : 500, `reduction`: sum
# Result: True
#
#
# Test: 584
# Dimension : 76, `reduction`: none
# Result: True
#
#
# Test: 585
# Dimension : 35, `reduction`: sum
# Result: True
#
#
# Test: 586
# Dimension : 194, `reduction`: sum
# Result: True
#
#
# Test: 587
# Dimension : 262, `reduction`: sum
# Result: True
#
#
# Test: 588
# Dimension : 128, `reduction`: mean
# Result: True
#
#
# Test: 589
# Dimension : 227, `reduction`: none
# Result: True
#
#
# Test: 590
# Dimension : 166, `reduction`: none
# Result: True
#
#
# Test: 591
# Dimension : 118, `reduction`: sum
# Result: True
#
#
# Test: 592
# Dimension : 404, `reduction`: mean
# Result: True
#
#
# Test: 593
# Dimension : 340, `reduction`: none
# Result: True
#
#
# Test: 594
# Dimension : 381, `reduction`: sum
# Result: True
#
#
# Test: 595
# Dimension : 215, `reduction`: sum
# Result: True
#
#
# Test: 596
# Dimension : 290, `reduction`: sum
# Result: True
#
#
# Test: 597
# Dimension : 418, `reduction`: mean
# Result: True
#
#
# Test: 598
# Dimension : 142, `reduction`: none
# Result: True
#
#
# Test: 599
# Dimension : 384, `reduction`: none
# Result: True
#
#
# Test: 600
# Dimension : 287, `reduction`: none
# Result: True
#
#
# Test: 601
# Dimension : 401, `reduction`: none
# Result: True
#
#
# Test: 602
# Dimension : 66, `reduction`: mean
# Result: True
#
#
# Test: 603
# Dimension : 400, `reduction`: mean
# Result: True
#
#
# Test: 604
# Dimension : 247, `reduction`: mean
# Result: True
#
#
# Test: 605
# Dimension : 404, `reduction`: sum
# Result: True
#
#
# Test: 606
# Dimension : 124, `reduction`: sum
# Result: True
#
#
# Test: 607
# Dimension : 325, `reduction`: sum
# Result: True
#
#
# Test: 608
# Dimension : 85, `reduction`: none
# Result: True
#
#
# Test: 609
# Dimension : 368, `reduction`: sum
# Result: True
#
#
# Test: 610
# Dimension : 280, `reduction`: sum
# Result: True
#
#
# Test: 611
# Dimension : 376, `reduction`: sum
# Result: True
#
#
# Test: 612
# Dimension : 76, `reduction`: mean
# Result: True
#
#
# Test: 613
# Dimension : 183, `reduction`: sum
# Result: True
#
#
# Test: 614
# Dimension : 30, `reduction`: mean
# Result: True
#
#
# Test: 615
# Dimension : 429, `reduction`: sum
# Result: True
#
#
# Test: 616
# Dimension : 331, `reduction`: none
# Result: True
#
#
# Test: 617
# Dimension : 290, `reduction`: none
# Result: True
#
#
# Test: 618
# Dimension : 28, `reduction`: none
# Result: True
#
#
# Test: 619
# Dimension : 342, `reduction`: mean
# Result: True
#
#
# Test: 620
# Dimension : 136, `reduction`: sum
# Result: True
#
#
# Test: 621
# Dimension : 457, `reduction`: mean
# Result: True
#
#
# Test: 622
# Dimension : 281, `reduction`: none
# Result: True
#
#
# Test: 623
# Dimension : 383, `reduction`: none
# Result: True
#
#
# Test: 624
# Dimension : 483, `reduction`: none
# Result: True
#
#
# Test: 625
# Dimension : 250, `reduction`: mean
# Result: True
#
#
# Test: 626
# Dimension : 149, `reduction`: mean
# Result: True
#
#
# Test: 627
# Dimension : 284, `reduction`: sum
# Result: True
#
#
# Test: 628
# Dimension : 332, `reduction`: none
# Result: True
#
#
# Test: 629
# Dimension : 55, `reduction`: sum
# Result: True
#
#
# Test: 630
# Dimension : 436, `reduction`: sum
# Result: True
#
#
# Test: 631
# Dimension : 481, `reduction`: none
# Result: True
#
#
# Test: 632
# Dimension : 21, `reduction`: sum
# Result: True
#
#
# Test: 633
# Dimension : 328, `reduction`: none
# Result: True
#
#
# Test: 634
# Dimension : 238, `reduction`: sum
# Result: True
#
#
# Test: 635
# Dimension : 287, `reduction`: sum
# Result: True
#
#
# Test: 636
# Dimension : 262, `reduction`: sum
# Result: True
#
#
# Test: 637
# Dimension : 275, `reduction`: none
# Result: True
#
#
# Test: 638
# Dimension : 85, `reduction`: sum
# Result: True
#
#
# Test: 639
# Dimension : 149, `reduction`: mean
# Result: True
#
#
# Test: 640
# Dimension : 39, `reduction`: sum
# Result: True
#
#
# Test: 641
# Dimension : 429, `reduction`: none
# Result: True
#
#
# Test: 642
# Dimension : 335, `reduction`: sum
# Result: True
#
#
# Test: 643
# Dimension : 31, `reduction`: mean
# Result: True
#
#
# Test: 644
# Dimension : 377, `reduction`: mean
# Result: True
#
#
# Test: 645
# Dimension : 119, `reduction`: mean
# Result: True
#
#
# Test: 646
# Dimension : 393, `reduction`: sum
# Result: True
#
#
# Test: 647
# Dimension : 208, `reduction`: mean
# Result: True
#
#
# Test: 648
# Dimension : 330, `reduction`: mean
# Result: True
#
#
# Test: 649
# Dimension : 262, `reduction`: none
# Result: True
#
#
# Test: 650
# Dimension : 320, `reduction`: none
# Result: True
#
#
# Test: 651
# Dimension : 250, `reduction`: mean
# Result: True
#
#
# Test: 652
# Dimension : 392, `reduction`: sum
# Result: True
#
#
# Test: 653
# Dimension : 231, `reduction`: sum
# Result: True
#
#
# Test: 654
# Dimension : 383, `reduction`: none
# Result: True
#
#
# Test: 655
# Dimension : 117, `reduction`: sum
# Result: True
#
#
# Test: 656
# Dimension : 410, `reduction`: none
# Result: True
#
#
# Test: 657
# Dimension : 287, `reduction`: mean
# Result: True
#
#
# Test: 658
# Dimension : 200, `reduction`: none
# Result: True
#
#
# Test: 659
# Dimension : 170, `reduction`: none
# Result: True
#
#
# Test: 660
# Dimension : 385, `reduction`: mean
# Result: True
#
#
# Test: 661
# Dimension : 45, `reduction`: mean
# Result: True
#
#
# Test: 662
# Dimension : 311, `reduction`: none
# Result: True
#
#
# Test: 663
# Dimension : 350, `reduction`: mean
# Result: True
#
#
# Test: 664
# Dimension : 377, `reduction`: none
# Result: True
#
#
# Test: 665
# Dimension : 32, `reduction`: sum
# Result: True
#
#
# Test: 666
# Dimension : 291, `reduction`: mean
# Result: True
#
#
# Test: 667
# Dimension : 206, `reduction`: sum
# Result: True
#
#
# Test: 668
# Dimension : 434, `reduction`: sum
# Result: True
#
#
# Test: 669
# Dimension : 335, `reduction`: sum
# Result: True
#
#
# Test: 670
# Dimension : 116, `reduction`: sum
# Result: True
#
#
# Test: 671
# Dimension : 120, `reduction`: mean
# Result: True
#
#
# Test: 672
# Dimension : 295, `reduction`: mean
# Result: True
#
#
# Test: 673
# Dimension : 159, `reduction`: sum
# Result: True
#
#
# Test: 674
# Dimension : 149, `reduction`: mean
# Result: True
#
#
# Test: 675
# Dimension : 464, `reduction`: none
# Result: True
#
#
# Test: 676
# Dimension : 198, `reduction`: none
# Result: True
#
#
# Test: 677
# Dimension : 91, `reduction`: sum
# Result: True
#
#
# Test: 678
# Dimension : 340, `reduction`: sum
# Result: True
#
#
# Test: 679
# Dimension : 426, `reduction`: sum
# Result: True
#
#
# Test: 680
# Dimension : 475, `reduction`: mean
# Result: True
#
#
# Test: 681
# Dimension : 413, `reduction`: mean
# Result: True
#
#
# Test: 682
# Dimension : 359, `reduction`: sum
# Result: True
#
#
# Test: 683
# Dimension : 31, `reduction`: none
# Result: True
#
#
# Test: 684
# Dimension : 185, `reduction`: mean
# Result: True
#
#
# Test: 685
# Dimension : 245, `reduction`: none
# Result: True
#
#
# Test: 686
# Dimension : 291, `reduction`: sum
# Result: True
#
#
# Test: 687
# Dimension : 224, `reduction`: none
# Result: True
#
#
# Test: 688
# Dimension : 219, `reduction`: mean
# Result: True
#
#
# Test: 689
# Dimension : 13, `reduction`: none
# Result: True
#
#
# Test: 690
# Dimension : 471, `reduction`: none
# Result: True
#
#
# Test: 691
# Dimension : 328, `reduction`: none
# Result: True
#
#
# Test: 692
# Dimension : 145, `reduction`: sum
# Result: True
#
#
# Test: 693
# Dimension : 444, `reduction`: mean
# Result: True
#
#
# Test: 694
# Dimension : 473, `reduction`: none
# Result: True
#
#
# Test: 695
# Dimension : 435, `reduction`: none
# Result: True
#
#
# Test: 696
# Dimension : 80, `reduction`: sum
# Result: True
#
#
# Test: 697
# Dimension : 3, `reduction`: mean
# Result: True
#
#
# Test: 698
# Dimension : 177, `reduction`: sum
# Result: True
#
#
# Test: 699
# Dimension : 72, `reduction`: sum
# Result: True
#
#
# Test: 700
# Dimension : 342, `reduction`: none
# Result: True
#
#
# Test: 701
# Dimension : 59, `reduction`: none
# Result: True
#
#
# Test: 702
# Dimension : 225, `reduction`: sum
# Result: True
#
#
# Test: 703
# Dimension : 237, `reduction`: none
# Result: True
#
#
# Test: 704
# Dimension : 13, `reduction`: mean
# Result: True
#
#
# Test: 705
# Dimension : 147, `reduction`: sum
# Result: True
#
#
# Test: 706
# Dimension : 348, `reduction`: none
# Result: True
#
#
# Test: 707
# Dimension : 398, `reduction`: sum
# Result: True
#
#
# Test: 708
# Dimension : 219, `reduction`: sum
# Result: True
#
#
# Test: 709
# Dimension : 493, `reduction`: sum
# Result: True
#
#
# Test: 710
# Dimension : 59, `reduction`: none
# Result: True
#
#
# Test: 711
# Dimension : 289, `reduction`: none
# Result: True
#
#
# Test: 712
# Dimension : 385, `reduction`: none
# Result: True
#
#
# Test: 713
# Dimension : 435, `reduction`: sum
# Result: True
#
#
# Test: 714
# Dimension : 110, `reduction`: mean
# Result: True
#
#
# Test: 715
# Dimension : 389, `reduction`: sum
# Result: True
#
#
# Test: 716
# Dimension : 467, `reduction`: mean
# Result: True
#
#
# Test: 717
# Dimension : 425, `reduction`: none
# Result: True
#
#
# Test: 718
# Dimension : 388, `reduction`: none
# Result: True
#
#
# Test: 719
# Dimension : 449, `reduction`: mean
# Result: True
#
#
# Test: 720
# Dimension : 79, `reduction`: mean
# Result: True
#
#
# Test: 721
# Dimension : 94, `reduction`: none
# Result: True
#
#
# Test: 722
# Dimension : 313, `reduction`: mean
# Result: True
#
#
# Test: 723
# Dimension : 223, `reduction`: none
# Result: True
#
#
# Test: 724
# Dimension : 175, `reduction`: mean
# Result: True
#
#
# Test: 725
# Dimension : 112, `reduction`: sum
# Result: True
#
#
# Test: 726
# Dimension : 61, `reduction`: sum
# Result: True
#
#
# Test: 727
# Dimension : 245, `reduction`: sum
# Result: True
#
#
# Test: 728
# Dimension : 37, `reduction`: sum
# Result: True
#
#
# Test: 729
# Dimension : 76, `reduction`: none
# Result: True
#
#
# Test: 730
# Dimension : 350, `reduction`: none
# Result: True
#
#
# Test: 731
# Dimension : 367, `reduction`: mean
# Result: True
#
#
# Test: 732
# Dimension : 123, `reduction`: mean
# Result: True
#
#
# Test: 733
# Dimension : 12, `reduction`: mean
# Result: True
#
#
# Test: 734
# Dimension : 328, `reduction`: none
# Result: True
#
#
# Test: 735
# Dimension : 68, `reduction`: none
# Result: True
#
#
# Test: 736
# Dimension : 432, `reduction`: none
# Result: True
#
#
# Test: 737
# Dimension : 326, `reduction`: none
# Result: True
#
#
# Test: 738
# Dimension : 79, `reduction`: none
# Result: True
#
#
# Test: 739
# Dimension : 379, `reduction`: sum
# Result: True
#
#
# Test: 740
# Dimension : 4, `reduction`: sum
# Result: True
#
#
# Test: 741
# Dimension : 363, `reduction`: none
# Result: True
#
#
# Test: 742
# Dimension : 445, `reduction`: mean
# Result: True
#
#
# Test: 743
# Dimension : 132, `reduction`: mean
# Result: True
#
#
# Test: 744
# Dimension : 44, `reduction`: mean
# Result: True
#
#
# Test: 745
# Dimension : 200, `reduction`: mean
# Result: True
#
#
# Test: 746
# Dimension : 242, `reduction`: mean
# Result: True
#
#
# Test: 747
# Dimension : 107, `reduction`: mean
# Result: True
#
#
# Test: 748
# Dimension : 395, `reduction`: mean
# Result: True
#
#
# Test: 749
# Dimension : 295, `reduction`: sum
# Result: True
#
#
# Test: 750
# Dimension : 195, `reduction`: mean
# Result: True
#
#
# Test: 751
# Dimension : 353, `reduction`: mean
# Result: True
#
#
# Test: 752
# Dimension : 75, `reduction`: none
# Result: True
#
#
# Test: 753
# Dimension : 438, `reduction`: mean
# Result: True
#
#
# Test: 754
# Dimension : 414, `reduction`: sum
# Result: True
#
#
# Test: 755
# Dimension : 79, `reduction`: mean
# Result: True
#
#
# Test: 756
# Dimension : 253, `reduction`: sum
# Result: True
#
#
# Test: 757
# Dimension : 191, `reduction`: none
# Result: True
#
#
# Test: 758
# Dimension : 115, `reduction`: none
# Result: True
#
#
# Test: 759
# Dimension : 411, `reduction`: mean
# Result: True
#
#
# Test: 760
# Dimension : 369, `reduction`: sum
# Result: True
#
#
# Test: 761
# Dimension : 330, `reduction`: none
# Result: True
#
#
# Test: 762
# Dimension : 81, `reduction`: none
# Result: True
#
#
# Test: 763
# Dimension : 381, `reduction`: mean
# Result: True
#
#
# Test: 764
# Dimension : 283, `reduction`: sum
# Result: True
#
#
# Test: 765
# Dimension : 83, `reduction`: sum
# Result: True
#
#
# Test: 766
# Dimension : 377, `reduction`: mean
# Result: True
#
#
# Test: 767
# Dimension : 25, `reduction`: none
# Result: True
#
#
# Test: 768
# Dimension : 205, `reduction`: mean
# Result: True
#
#
# Test: 769
# Dimension : 134, `reduction`: mean
# Result: True
#
#
# Test: 770
# Dimension : 147, `reduction`: mean
# Result: True
#
#
# Test: 771
# Dimension : 266, `reduction`: sum
# Result: True
#
#
# Test: 772
# Dimension : 147, `reduction`: none
# Result: True
#
#
# Test: 773
# Dimension : 418, `reduction`: sum
# Result: True
#
#
# Test: 774
# Dimension : 262, `reduction`: sum
# Result: True
#
#
# Test: 775
# Dimension : 284, `reduction`: none
# Result: True
#
#
# Test: 776
# Dimension : 431, `reduction`: none
# Result: True
#
#
# Test: 777
# Dimension : 369, `reduction`: none
# Result: True
#
#
# Test: 778
# Dimension : 211, `reduction`: none
# Result: True
#
#
# Test: 779
# Dimension : 380, `reduction`: none
# Result: True
#
#
# Test: 780
# Dimension : 237, `reduction`: none
# Result: True
#
#
# Test: 781
# Dimension : 476, `reduction`: sum
# Result: True
#
#
# Test: 782
# Dimension : 398, `reduction`: sum
# Result: True
#
#
# Test: 783
# Dimension : 183, `reduction`: none
# Result: True
#
#
# Test: 784
# Dimension : 12, `reduction`: none
# Result: True
#
#
# Test: 785
# Dimension : 108, `reduction`: none
# Result: True
#
#
# Test: 786
# Dimension : 69, `reduction`: sum
# Result: True
#
#
# Test: 787
# Dimension : 88, `reduction`: mean
# Result: True
#
#
# Test: 788
# Dimension : 409, `reduction`: none
# Result: True
#
#
# Test: 789
# Dimension : 290, `reduction`: sum
# Result: True
#
#
# Test: 790
# Dimension : 338, `reduction`: none
# Result: True
#
#
# Test: 791
# Dimension : 164, `reduction`: none
# Result: True
#
#
# Test: 792
# Dimension : 112, `reduction`: mean
# Result: True
#
#
# Test: 793
# Dimension : 138, `reduction`: sum
# Result: True
#
#
# Test: 794
# Dimension : 386, `reduction`: none
# Result: True
#
#
# Test: 795
# Dimension : 27, `reduction`: none
# Result: True
#
#
# Test: 796
# Dimension : 102, `reduction`: none
# Result: True
#
#
# Test: 797
# Dimension : 422, `reduction`: sum
# Result: True
#
#
# Test: 798
# Dimension : 216, `reduction`: sum
# Result: True
#
#
# Test: 799
# Dimension : 351, `reduction`: mean
# Result: True
#
#
# Test: 800
# Dimension : 347, `reduction`: sum
# Result: True
#
#
# Test: 801
# Dimension : 478, `reduction`: none
# Result: True
#
#
# Test: 802
# Dimension : 142, `reduction`: sum
# Result: True
#
#
# Test: 803
# Dimension : 47, `reduction`: sum
# Result: True
#
#
# Test: 804
# Dimension : 63, `reduction`: mean
# Result: True
#
#
# Test: 805
# Dimension : 95, `reduction`: sum
# Result: True
#
#
# Test: 806
# Dimension : 255, `reduction`: none
# Result: True
#
#
# Test: 807
# Dimension : 288, `reduction`: sum
# Result: True
#
#
# Test: 808
# Dimension : 160, `reduction`: sum
# Result: True
#
#
# Test: 809
# Dimension : 440, `reduction`: mean
# Result: True
#
#
# Test: 810
# Dimension : 443, `reduction`: mean
# Result: True
#
#
# Test: 811
# Dimension : 394, `reduction`: mean
# Result: True
#
#
# Test: 812
# Dimension : 28, `reduction`: mean
# Result: True
#
#
# Test: 813
# Dimension : 318, `reduction`: sum
# Result: True
#
#
# Test: 814
# Dimension : 142, `reduction`: none
# Result: True
#
#
# Test: 815
# Dimension : 315, `reduction`: none
# Result: True
#
#
# Test: 816
# Dimension : 119, `reduction`: sum
# Result: True
#
#
# Test: 817
# Dimension : 458, `reduction`: sum
# Result: True
#
#
# Test: 818
# Dimension : 296, `reduction`: mean
# Result: True
#
#
# Test: 819
# Dimension : 409, `reduction`: sum
# Result: True
#
#
# Test: 820
# Dimension : 304, `reduction`: sum
# Result: True
#
#
# Test: 821
# Dimension : 430, `reduction`: none
# Result: True
#
#
# Test: 822
# Dimension : 380, `reduction`: sum
# Result: True
#
#
# Test: 823
# Dimension : 106, `reduction`: mean
# Result: True
#
#
# Test: 824
# Dimension : 23, `reduction`: mean
# Result: True
#
#
# Test: 825
# Dimension : 19, `reduction`: mean
# Result: True
#
#
# Test: 826
# Dimension : 358, `reduction`: none
# Result: True
#
#
# Test: 827
# Dimension : 28, `reduction`: mean
# Result: True
#
#
# Test: 828
# Dimension : 206, `reduction`: none
# Result: True
#
#
# Test: 829
# Dimension : 107, `reduction`: none
# Result: True
#
#
# Test: 830
# Dimension : 144, `reduction`: none
# Result: True
#
#
# Test: 831
# Dimension : 234, `reduction`: none
# Result: True
#
#
# Test: 832
# Dimension : 185, `reduction`: sum
# Result: True
#
#
# Test: 833
# Dimension : 320, `reduction`: none
# Result: True
#
#
# Test: 834
# Dimension : 214, `reduction`: sum
# Result: True
#
#
# Test: 835
# Dimension : 272, `reduction`: sum
# Result: True
#
#
# Test: 836
# Dimension : 440, `reduction`: mean
# Result: True
#
#
# Test: 837
# Dimension : 51, `reduction`: sum
# Result: True
#
#
# Test: 838
# Dimension : 115, `reduction`: none
# Result: True
#
#
# Test: 839
# Dimension : 228, `reduction`: mean
# Result: True
#
#
# Test: 840
# Dimension : 373, `reduction`: sum
# Result: True
#
#
# Test: 841
# Dimension : 394, `reduction`: sum
# Result: True
#
#
# Test: 842
# Dimension : 287, `reduction`: sum
# Result: True
#
#
# Test: 843
# Dimension : 413, `reduction`: none
# Result: True
#
#
# Test: 844
# Dimension : 225, `reduction`: mean
# Result: True
#
#
# Test: 845
# Dimension : 218, `reduction`: sum
# Result: True
#
#
# Test: 846
# Dimension : 256, `reduction`: mean
# Result: True
#
#
# Test: 847
# Dimension : 287, `reduction`: mean
# Result: True
#
#
# Test: 848
# Dimension : 72, `reduction`: mean
# Result: True
#
#
# Test: 849
# Dimension : 133, `reduction`: none
# Result: True
#
#
# Test: 850
# Dimension : 309, `reduction`: none
# Result: True
#
#
# Test: 851
# Dimension : 441, `reduction`: none
# Result: True
#
#
# Test: 852
# Dimension : 458, `reduction`: sum
# Result: True
#
#
# Test: 853
# Dimension : 4, `reduction`: sum
# Result: True
#
#
# Test: 854
# Dimension : 171, `reduction`: sum
# Result: True
#
#
# Test: 855
# Dimension : 390, `reduction`: mean
# Result: True
#
#
# Test: 856
# Dimension : 81, `reduction`: none
# Result: True
#
#
# Test: 857
# Dimension : 362, `reduction`: mean
# Result: True
#
#
# Test: 858
# Dimension : 172, `reduction`: none
# Result: True
#
#
# Test: 859
# Dimension : 349, `reduction`: mean
# Result: True
#
#
# Test: 860
# Dimension : 122, `reduction`: mean
# Result: True
#
#
# Test: 861
# Dimension : 389, `reduction`: sum
# Result: True
#
#
# Test: 862
# Dimension : 241, `reduction`: mean
# Result: True
#
#
# Test: 863
# Dimension : 322, `reduction`: sum
# Result: True
#
#
# Test: 864
# Dimension : 458, `reduction`: none
# Result: True
#
#
# Test: 865
# Dimension : 183, `reduction`: sum
# Result: True
#
#
# Test: 866
# Dimension : 137, `reduction`: mean
# Result: True
#
#
# Test: 867
# Dimension : 299, `reduction`: mean
# Result: True
#
#
# Test: 868
# Dimension : 463, `reduction`: none
# Result: True
#
#
# Test: 869
# Dimension : 175, `reduction`: sum
# Result: True
#
#
# Test: 870
# Dimension : 14, `reduction`: mean
# Result: True
#
#
# Test: 871
# Dimension : 322, `reduction`: mean
# Result: True
#
#
# Test: 872
# Dimension : 334, `reduction`: none
# Result: True
#
#
# Test: 873
# Dimension : 60, `reduction`: mean
# Result: True
#
#
# Test: 874
# Dimension : 363, `reduction`: sum
# Result: True
#
#
# Test: 875
# Dimension : 313, `reduction`: sum
# Result: True
#
#
# Test: 876
# Dimension : 89, `reduction`: none
# Result: True
#
#
# Test: 877
# Dimension : 136, `reduction`: none
# Result: True
#
#
# Test: 878
# Dimension : 440, `reduction`: none
# Result: True
#
#
# Test: 879
# Dimension : 3, `reduction`: sum
# Result: True
#
#
# Test: 880
# Dimension : 122, `reduction`: sum
# Result: True
#
#
# Test: 881
# Dimension : 5, `reduction`: mean
# Result: True
#
#
# Test: 882
# Dimension : 329, `reduction`: mean
# Result: True
#
#
# Test: 883
# Dimension : 12, `reduction`: sum
# Result: True
#
#
# Test: 884
# Dimension : 211, `reduction`: mean
# Result: True
#
#
# Test: 885
# Dimension : 219, `reduction`: none
# Result: True
#
#
# Test: 886
# Dimension : 432, `reduction`: sum
# Result: True
#
#
# Test: 887
# Dimension : 493, `reduction`: mean
# Result: True
#
#
# Test: 888
# Dimension : 194, `reduction`: none
# Result: True
#
#
# Test: 889
# Dimension : 125, `reduction`: mean
# Result: True
#
#
# Test: 890
# Dimension : 247, `reduction`: sum
# Result: True
#
#
# Test: 891
# Dimension : 353, `reduction`: none
# Result: True
#
#
# Test: 892
# Dimension : 250, `reduction`: sum
# Result: True
#
#
# Test: 893
# Dimension : 35, `reduction`: mean
# Result: True
#
#
# Test: 894
# Dimension : 177, `reduction`: none
# Result: True
#
#
# Test: 895
# Dimension : 429, `reduction`: mean
# Result: True
#
#
# Test: 896
# Dimension : 258, `reduction`: none
# Result: True
#
#
# Test: 897
# Dimension : 45, `reduction`: none
# Result: True
#
#
# Test: 898
# Dimension : 99, `reduction`: none
# Result: True
#
#
# Test: 899
# Dimension : 189, `reduction`: mean
# Result: True
#
#
# Test: 900
# Dimension : 161, `reduction`: mean
# Result: True
#
#
# Test: 901
# Dimension : 335, `reduction`: none
# Result: True
#
#
# Test: 902
# Dimension : 499, `reduction`: mean
# Result: True
#
#
# Test: 903
# Dimension : 450, `reduction`: sum
# Result: True
#
#
# Test: 904
# Dimension : 491, `reduction`: none
# Result: True
#
#
# Test: 905
# Dimension : 443, `reduction`: sum
# Result: True
#
#
# Test: 906
# Dimension : 55, `reduction`: mean
# Result: True
#
#
# Test: 907
# Dimension : 435, `reduction`: mean
# Result: True
#
#
# Test: 908
# Dimension : 116, `reduction`: none
# Result: True
#
#
# Test: 909
# Dimension : 432, `reduction`: sum
# Result: True
#
#
# Test: 910
# Dimension : 121, `reduction`: sum
# Result: True
#
#
# Test: 911
# Dimension : 457, `reduction`: sum
# Result: True
#
#
# Test: 912
# Dimension : 400, `reduction`: mean
# Result: True
#
#
# Test: 913
# Dimension : 326, `reduction`: none
# Result: True
#
#
# Test: 914
# Dimension : 271, `reduction`: none
# Result: True
#
#
# Test: 915
# Dimension : 392, `reduction`: sum
# Result: True
#
#
# Test: 916
# Dimension : 302, `reduction`: mean
# Result: True
#
#
# Test: 917
# Dimension : 226, `reduction`: sum
# Result: True
#
#
# Test: 918
# Dimension : 84, `reduction`: none
# Result: True
#
#
# Test: 919
# Dimension : 166, `reduction`: sum
# Result: True
#
#
# Test: 920
# Dimension : 126, `reduction`: sum
# Result: True
#
#
# Test: 921
# Dimension : 156, `reduction`: none
# Result: True
#
#
# Test: 922
# Dimension : 172, `reduction`: mean
# Result: True
#
#
# Test: 923
# Dimension : 314, `reduction`: none
# Result: True
#
#
# Test: 924
# Dimension : 367, `reduction`: sum
# Result: True
#
#
# Test: 925
# Dimension : 170, `reduction`: sum
# Result: True
#
#
# Test: 926
# Dimension : 345, `reduction`: none
# Result: True
#
#
# Test: 927
# Dimension : 87, `reduction`: sum
# Result: True
#
#
# Test: 928
# Dimension : 125, `reduction`: mean
# Result: True
#
#
# Test: 929
# Dimension : 460, `reduction`: sum
# Result: True
#
#
# Test: 930
# Dimension : 457, `reduction`: none
# Result: True
#
#
# Test: 931
# Dimension : 414, `reduction`: none
# Result: True
#
#
# Test: 932
# Dimension : 347, `reduction`: sum
# Result: True
#
#
# Test: 933
# Dimension : 9, `reduction`: mean
# Result: True
#
#
# Test: 934
# Dimension : 53, `reduction`: sum
# Result: True
#
#
# Test: 935
# Dimension : 272, `reduction`: mean
# Result: True
#
#
# Test: 936
# Dimension : 205, `reduction`: sum
# Result: True
#
#
# Test: 937
# Dimension : 310, `reduction`: none
# Result: True
#
#
# Test: 938
# Dimension : 422, `reduction`: sum
# Result: True
#
#
# Test: 939
# Dimension : 161, `reduction`: sum
# Result: True
#
#
# Test: 940
# Dimension : 339, `reduction`: sum
# Result: True
#
#
# Test: 941
# Dimension : 113, `reduction`: none
# Result: True
#
#
# Test: 942
# Dimension : 23, `reduction`: none
# Result: True
#
#
# Test: 943
# Dimension : 282, `reduction`: sum
# Result: True
#
#
# Test: 944
# Dimension : 317, `reduction`: sum
# Result: True
#
#
# Test: 945
# Dimension : 79, `reduction`: none
# Result: True
#
#
# Test: 946
# Dimension : 268, `reduction`: none
# Result: True
#
#
# Test: 947
# Dimension : 457, `reduction`: mean
# Result: True
#
#
# Test: 948
# Dimension : 166, `reduction`: mean
# Result: True
#
#
# Test: 949
# Dimension : 427, `reduction`: mean
# Result: True
#
#
# Test: 950
# Dimension : 217, `reduction`: none
# Result: True
#
#
# Test: 951
# Dimension : 150, `reduction`: none
# Result: True
#
#
# Test: 952
# Dimension : 364, `reduction`: none
# Result: True
#
#
# Test: 953
# Dimension : 7, `reduction`: mean
# Result: True
#
#
# Test: 954
# Dimension : 42, `reduction`: none
# Result: True
#
#
# Test: 955
# Dimension : 489, `reduction`: none
# Result: True
#
#
# Test: 956
# Dimension : 218, `reduction`: none
# Result: True
#
#
# Test: 957
# Dimension : 170, `reduction`: mean
# Result: True
#
#
# Test: 958
# Dimension : 407, `reduction`: sum
# Result: True
#
#
# Test: 959
# Dimension : 307, `reduction`: mean
# Result: True
#
#
# Test: 960
# Dimension : 103, `reduction`: sum
# Result: True
#
#
# Test: 961
# Dimension : 454, `reduction`: none
# Result: True
#
#
# Test: 962
# Dimension : 59, `reduction`: none
# Result: True
#
#
# Test: 963
# Dimension : 432, `reduction`: mean
# Result: True
#
#
# Test: 964
# Dimension : 258, `reduction`: sum
# Result: True
#
#
# Test: 965
# Dimension : 263, `reduction`: none
# Result: True
#
#
# Test: 966
# Dimension : 414, `reduction`: none
# Result: True
#
#
# Test: 967
# Dimension : 178, `reduction`: mean
# Result: True
#
#
# Test: 968
# Dimension : 137, `reduction`: sum
# Result: True
#
#
# Test: 969
# Dimension : 21, `reduction`: none
# Result: True
#
#
# Test: 970
# Dimension : 64, `reduction`: sum
# Result: True
#
#
# Test: 971
# Dimension : 110, `reduction`: sum
# Result: True
#
#
# Test: 972
# Dimension : 310, `reduction`: mean
# Result: True
#
#
# Test: 973
# Dimension : 470, `reduction`: mean
# Result: True
#
#
# Test: 974
# Dimension : 112, `reduction`: none
# Result: True
#
#
# Test: 975
# Dimension : 333, `reduction`: none
# Result: True
#
#
# Test: 976
# Dimension : 221, `reduction`: mean
# Result: True
#
#
# Test: 977
# Dimension : 268, `reduction`: mean
# Result: True
#
#
# Test: 978
# Dimension : 45, `reduction`: none
# Result: True
#
#
# Test: 979
# Dimension : 331, `reduction`: none
# Result: True
#
#
# Test: 980
# Dimension : 379, `reduction`: sum
# Result: True
#
#
# Test: 981
# Dimension : 24, `reduction`: none
# Result: True
#
#
# Test: 982
# Dimension : 395, `reduction`: none
# Result: True
#
#
# Test: 983
# Dimension : 125, `reduction`: none
# Result: True
#
#
# Test: 984
# Dimension : 452, `reduction`: sum
# Result: True
#
#
# Test: 985
# Dimension : 463, `reduction`: sum
# Result: True
#
#
# Test: 986
# Dimension : 335, `reduction`: mean
# Result: True
#
#
# Test: 987
# Dimension : 167, `reduction`: mean
# Result: True
#
#
# Test: 988
# Dimension : 115, `reduction`: sum
# Result: True
#
#
# Test: 989
# Dimension : 223, `reduction`: mean
# Result: True
#
#
# Test: 990
# Dimension : 465, `reduction`: mean
# Result: True
#
#
# Test: 991
# Dimension : 28, `reduction`: mean
# Result: True
#
#
# Test: 992
# Dimension : 57, `reduction`: mean
# Result: True
#
#
# Test: 993
# Dimension : 100, `reduction`: sum
# Result: True
#
#
# Test: 994
# Dimension : 274, `reduction`: mean
# Result: True
#
#
# Test: 995
# Dimension : 61, `reduction`: none
# Result: True
#
#
# Test: 996
# Dimension : 319, `reduction`: none
# Result: True
#
#
# Test: 997
# Dimension : 209, `reduction`: sum
# Result: True
#
#
# Test: 998
# Dimension : 3, `reduction`: mean
# Result: True
#
#
# Test: 999
# Dimension : 392, `reduction`: none
# Result: True
#
#
# 1000 out of 1000 (100.0%) tests passed
