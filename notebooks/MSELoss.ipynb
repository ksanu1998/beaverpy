# %% [markdown]
# ### `MSELoss` code

# %%
import numpy as np
import torch # needed for tests
from tqdm import tqdm # needed for tests

# %%
class MSELoss:
    ''' Computes MSE Loss given the input and target '''
    
    ''' * The class implementation will be along the lines of torch.nn.MSELoss in order to 
          enable comparison of this NumPy only implementation and seamless testing
        * Can expect extensive refactoring of the existing code in the days to come
        * As part of refactoring, some code will be de-modularized
        * Old code will be retained at the end of the notebook for reference
    '''
    '''
        TODO:
        * Replace `torch.round()` with `np.allclose()` for tests
        * Optimizing code
    '''
    
    def __init__(
        self,
        size_average = None,
        reduce = None,
        reduction = 'mean',
        verbose = False
        ):
        super(MSELoss, self).__init__()
        
        ''' mandatory parameters '''
        # None
        
        ''' optional parameters '''
        self.reduction = reduction
        
        ''' optional parameters (dummy, yet to be implemented)'''
        self.size_average = size_average
        self.reduce = reduce
        
        ''' additional parameters (different from torch.nn.Conv2D)'''
        self.verbose = verbose
        self.verboseprint = print if self.verbose else lambda *a, **k: None
        self.verboseprint('*** parameters ***')
        self.verboseprint('size_average: {}, reduce: {}, reduction: {}'.format(self.size_average, self.reduce, self.reduction))
        self.verboseprint('\n')
    
    def forward(self, _input, _target):
        ''' forward pass to compute MSE Loss'''
        
        ''' error checking '''
        if not (isinstance(_input, int) or isinstance(_input, float) or isinstance(_input, np.ndarray)):
            raise Exception('invalid input: `input` should either be an int, a float, or a NumPy ndarray')
        
        if not (isinstance(_target, int) or isinstance(_target, float) or isinstance(_target, np.ndarray)):
            raise Exception('invalid input: `target` should either be an int, a float, or a NumPy ndarray')
            
        if (isinstance(_input, np.ndarray) and not isinstance(_target, np.ndarray))  or (not isinstance(_input, np.ndarray) and isinstance(_target, np.ndarray)):
            raise Exception('invalid input: `input` and `target` should both be a NumPy ndarray, or can be a mix of `int` and `float`')
            
        ''' compute MSE LOSS '''
        output = np.square(_input - _target)
        if self.reduction == 'mean':
            output = np.mean(output)
        elif self.reduction == 'sum':
            output = np.sum(output)
        elif self.reduction == 'none':
            pass
        else:
            raise Exception("invalid input: `reduction` flag should be one of `'mean'`, `'sum'`, or `'none'`")
        self.verboseprint("*** MSELoss output ***")
        self.verboseprint(output)
        self.verboseprint('\n')
        return output

# %% [markdown]
# ### Standalone test (random input, target)

# %%
_reduction = 'none'
dimension = np.random.randint(500) # dimension of the input and target
_input = np.random.rand(dimension) # define a random input of the above dimension
_target= np.random.rand(dimension) # define a random target of the above dimension
print(_input.shape, _target.shape)
# Out:
# (244,) (244,)

# %%
# compute MSE loss using the random input and target
mseloss = MSELoss(reduction = _reduction) # call an instance of the class
_output = mseloss.forward(_input, _target) # compute MSE loss
print("*** MSELoss output ***")
print(_output)
# Out:
# *** MSELoss output ***
# [7.52263374e-02 2.66034286e-02 5.25515480e-01 9.87119059e-02
#  8.33585364e-02 4.18327745e-01 1.84992698e-06 9.74517356e-01
#  3.98327458e-01 1.39912483e-01 2.69961219e-02 4.39104569e-02
#  4.89134768e-02 3.88983294e-01 1.05146622e-03 4.01029740e-01
#  6.09867556e-03 3.68023635e-02 6.25829083e-02 2.09861058e-01
#  2.27983150e-04 4.37267503e-01 8.88976258e-02 3.54032138e-03
#  4.95932193e-03 5.17305908e-03 1.75910391e-01 3.04397912e-02
#  1.12098897e-01 3.88308090e-04 2.42028486e-01 6.31262333e-02
#  2.06443861e-02 6.22225594e-04 1.80168915e-01 9.85553417e-02
#  7.16315846e-02 2.96071212e-03 2.11854356e-01 6.63384047e-01
#  3.73060450e-03 5.59403026e-04 4.47219495e-01 1.57068758e-01
#  5.61935341e-02 3.34822468e-02 4.01398101e-01 2.53030177e-01
#  1.08897697e-01 2.41723776e-02 1.14732396e-03 2.96601148e-02
#  6.40942056e-02 2.15059576e-01 1.16505457e-01 2.08052736e-01
#  8.43765536e-04 2.99385788e-01 7.53471683e-03 4.26070722e-05
#  2.51472459e-01 1.43248550e-02 1.85404384e-01 1.77430235e-02
#  5.12965252e-01 5.71493831e-01 1.30759085e-02 1.89200590e-02
#  4.07851247e-01 4.71169171e-02 1.09093908e-01 1.33682809e-01
#  1.75217754e-01 2.70038739e-01 1.41628638e-01 7.13070808e-04
#  1.63106803e-02 3.45134117e-01 4.79115846e-03 1.23066733e-01
#  7.06211010e-01 2.32796401e-03 3.11680371e-01 2.16865410e-03
#  7.94433753e-03 6.85238432e-01 1.54175633e-02 9.75448121e-02
#  4.64729779e-04 1.78401454e-02 3.56890711e-02 3.16381586e-01
#  3.95466165e-01 8.57194834e-01 4.98338378e-06 1.35744202e-02
#  2.62656606e-02 1.17557780e-01 6.54016999e-02 9.04197380e-02
#  9.14554838e-02 4.92749936e-02 3.39441296e-01 1.79100779e-02
#  1.12463924e-01 3.69679178e-01 7.01771791e-03 2.43076391e-01
#  1.03391702e-01 2.78944258e-02 2.43326635e-01 7.68503730e-03
#  6.66356078e-03 1.25993036e-01 9.17965680e-02 4.80964140e-01
#  5.17398205e-03 2.07498575e-01 1.00914133e-01 1.31997296e-01
#  1.50061161e-01 1.50877536e-01 6.48130404e-01 4.24682182e-02
#  2.51738376e-01 5.25258142e-02 8.45744252e-03 1.15235085e-01
#  5.97334108e-02 7.55715360e-02 4.34552763e-01 1.34476905e-02
#  6.73437562e-02 2.04187154e-01 8.95609996e-02 4.42302701e-02
#  4.91739859e-02 2.83208946e-01 3.75415264e-03 1.56491276e-01
#  2.50960232e-01 2.34748760e-01 1.77948116e-01 3.40321491e-03
#  7.15547400e-03 1.07155641e-01 1.04667123e-01 1.98032277e-01
#  3.37514699e-02 8.03348032e-01 1.42921837e-02 7.21802424e-03
#  6.22443364e-03 1.14394613e-01 7.76971851e-03 1.49069093e-02
#  3.28957585e-01 1.68559485e-03 3.94083730e-01 4.17157559e-01
#  1.52544572e-02 6.04149184e-01 1.99589949e-01 1.16766580e-05
#  2.90986777e-02 9.25892711e-03 7.79166278e-02 5.79314614e-02
#  1.22143417e-01 2.99813390e-01 5.86708308e-02 1.31175272e-01
#  7.29069458e-01 7.60483254e-02 3.38958540e-01 1.13434881e-02
#  1.55746105e-02 7.46249983e-03 3.39715110e-02 4.58883841e-01
#  1.05981793e-01 1.35972150e-02 8.65952606e-04 1.54487078e-01
#  7.36356949e-02 2.00284930e-02 6.56143505e-02 6.56798554e-01
#  1.37936414e-01 6.75469766e-01 2.62699180e-01 8.64926490e-02
#  7.35260203e-02 4.60670005e-01 5.66940147e-01 1.20431429e-01
#  8.75668558e-03 3.17132715e-03 2.30906105e-01 1.90252072e-01
#  4.41465082e-05 1.77456367e-01 2.75679212e-01 3.24985089e-01
#  4.35607944e-02 6.10430791e-02 1.97006783e-02 2.65936858e-02
#  1.41158500e-02 1.53415429e-02 1.29572719e-01 1.93950000e-01
#  2.52094696e-01 9.40637405e-02 3.66282878e-01 6.63075503e-02
#  8.85289296e-02 6.00285409e-01 3.38369714e-03 1.76900518e-01
#  4.71497900e-01 3.77548043e-03 2.71931286e-01 3.86158408e-03
#  8.77261213e-03 3.17851721e-01 5.89414668e-03 1.81932857e-02
#  1.15327911e-02 4.31305417e-02 1.85979409e-01 9.97086508e-03
#  3.47924507e-02 7.23586616e-02 5.81759874e-01 4.52239500e-01
#  3.98314203e-01 1.47078653e-01 2.51232424e-05 4.95795547e-01
#  2.69034608e-01 5.26501878e-02 7.69249600e-02 2.21645213e-01]

# %%
# get PyTorch output with the same random inputs as above

x = torch.DoubleTensor(_input)
y = torch.DoubleTensor(_target)
loss = torch.nn.MSELoss(reduction = _reduction)
output = loss(x, y)
print("*** PyTorch output ***")
print(output)
# Out:
# *** PyTorch output ***
# tensor([7.5226e-02, 2.6603e-02, 5.2552e-01, 9.8712e-02, 8.3359e-02, 4.1833e-01,
#         1.8499e-06, 9.7452e-01, 3.9833e-01, 1.3991e-01, 2.6996e-02, 4.3910e-02,
#         4.8913e-02, 3.8898e-01, 1.0515e-03, 4.0103e-01, 6.0987e-03, 3.6802e-02,
#         6.2583e-02, 2.0986e-01, 2.2798e-04, 4.3727e-01, 8.8898e-02, 3.5403e-03,
#         4.9593e-03, 5.1731e-03, 1.7591e-01, 3.0440e-02, 1.1210e-01, 3.8831e-04,
#         2.4203e-01, 6.3126e-02, 2.0644e-02, 6.2223e-04, 1.8017e-01, 9.8555e-02,
#         7.1632e-02, 2.9607e-03, 2.1185e-01, 6.6338e-01, 3.7306e-03, 5.5940e-04,
#         4.4722e-01, 1.5707e-01, 5.6194e-02, 3.3482e-02, 4.0140e-01, 2.5303e-01,
#         1.0890e-01, 2.4172e-02, 1.1473e-03, 2.9660e-02, 6.4094e-02, 2.1506e-01,
#         1.1651e-01, 2.0805e-01, 8.4377e-04, 2.9939e-01, 7.5347e-03, 4.2607e-05,
#         2.5147e-01, 1.4325e-02, 1.8540e-01, 1.7743e-02, 5.1297e-01, 5.7149e-01,
#         1.3076e-02, 1.8920e-02, 4.0785e-01, 4.7117e-02, 1.0909e-01, 1.3368e-01,
#         1.7522e-01, 2.7004e-01, 1.4163e-01, 7.1307e-04, 1.6311e-02, 3.4513e-01,
#         4.7912e-03, 1.2307e-01, 7.0621e-01, 2.3280e-03, 3.1168e-01, 2.1687e-03,
#         7.9443e-03, 6.8524e-01, 1.5418e-02, 9.7545e-02, 4.6473e-04, 1.7840e-02,
#         3.5689e-02, 3.1638e-01, 3.9547e-01, 8.5719e-01, 4.9834e-06, 1.3574e-02,
#         2.6266e-02, 1.1756e-01, 6.5402e-02, 9.0420e-02, 9.1455e-02, 4.9275e-02,
#         3.3944e-01, 1.7910e-02, 1.1246e-01, 3.6968e-01, 7.0177e-03, 2.4308e-01,
#         1.0339e-01, 2.7894e-02, 2.4333e-01, 7.6850e-03, 6.6636e-03, 1.2599e-01,
#         9.1797e-02, 4.8096e-01, 5.1740e-03, 2.0750e-01, 1.0091e-01, 1.3200e-01,
#         1.5006e-01, 1.5088e-01, 6.4813e-01, 4.2468e-02, 2.5174e-01, 5.2526e-02,
#         8.4574e-03, 1.1524e-01, 5.9733e-02, 7.5572e-02, 4.3455e-01, 1.3448e-02,
#         6.7344e-02, 2.0419e-01, 8.9561e-02, 4.4230e-02, 4.9174e-02, 2.8321e-01,
#         3.7542e-03, 1.5649e-01, 2.5096e-01, 2.3475e-01, 1.7795e-01, 3.4032e-03,
#         7.1555e-03, 1.0716e-01, 1.0467e-01, 1.9803e-01, 3.3751e-02, 8.0335e-01,
#         1.4292e-02, 7.2180e-03, 6.2244e-03, 1.1439e-01, 7.7697e-03, 1.4907e-02,
#         3.2896e-01, 1.6856e-03, 3.9408e-01, 4.1716e-01, 1.5254e-02, 6.0415e-01,
#         1.9959e-01, 1.1677e-05, 2.9099e-02, 9.2589e-03, 7.7917e-02, 5.7931e-02,
#         1.2214e-01, 2.9981e-01, 5.8671e-02, 1.3118e-01, 7.2907e-01, 7.6048e-02,
#         3.3896e-01, 1.1343e-02, 1.5575e-02, 7.4625e-03, 3.3972e-02, 4.5888e-01,
#         1.0598e-01, 1.3597e-02, 8.6595e-04, 1.5449e-01, 7.3636e-02, 2.0028e-02,
#         6.5614e-02, 6.5680e-01, 1.3794e-01, 6.7547e-01, 2.6270e-01, 8.6493e-02,
#         7.3526e-02, 4.6067e-01, 5.6694e-01, 1.2043e-01, 8.7567e-03, 3.1713e-03,
#         2.3091e-01, 1.9025e-01, 4.4147e-05, 1.7746e-01, 2.7568e-01, 3.2499e-01,
#         4.3561e-02, 6.1043e-02, 1.9701e-02, 2.6594e-02, 1.4116e-02, 1.5342e-02,
#         1.2957e-01, 1.9395e-01, 2.5209e-01, 9.4064e-02, 3.6628e-01, 6.6308e-02,
#         8.8529e-02, 6.0029e-01, 3.3837e-03, 1.7690e-01, 4.7150e-01, 3.7755e-03,
#         2.7193e-01, 3.8616e-03, 8.7726e-03, 3.1785e-01, 5.8941e-03, 1.8193e-02,
#         1.1533e-02, 4.3131e-02, 1.8598e-01, 9.9709e-03, 3.4792e-02, 7.2359e-02,
#         5.8176e-01, 4.5224e-01, 3.9831e-01, 1.4708e-01, 2.5123e-05, 4.9580e-01,
#         2.6903e-01, 5.2650e-02, 7.6925e-02, 2.2165e-01], dtype=torch.float64)

# %%
# compare outputs of MSELoss and PyTorch
if not isinstance(_output, np.ndarray): # if a singleton, convert PyTorch tensor to NumPy float, round, and compare
    output = output.numpy()
    print(np.equal(np.round(_output), np.round(output)))  
else:
    print(torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output))) # need to round the output due to precision difference
# Out:
# True

# %% [markdown]
# ### Extensive tests (random input, target)

# %%
def run_tests(num_tests):
    ''' sweep different input parameters and test by comparing outputs of ReLU and PyTorch '''
    
    num_passed = 0
    print('Number of tests: {}\n\n'.format(num_tests))
    
    for i in tqdm(range(num_tests)):
        _reduction = np.random.choice(['mean', 'sum', 'none'])
        dimension = np.random.randint(500) # dimension of the input and target
        _input = np.random.rand(dimension) # define a random input of the above dimension
        _target= np.random.rand(dimension) # define a random target of the above dimension
        print('Test: {}\nDimension : {}, `reduction`: {}'.format(i, dimension, _reduction))
        
        try:
            # compute MSE loss using the random input and target
            mseloss = MSELoss(reduction = _reduction) # call an instance of the class
            _output = mseloss.forward(_input, _target) # compute MSE loss


            # get PyTorch output with the same random inputs as above
            x = torch.DoubleTensor(_input)
            y = torch.DoubleTensor(_target)
            loss = torch.nn.MSELoss(reduction = _reduction)
            output = loss(x, y)

            
        except Exception as e:
            print(e)
            print('Result: False\n\n') # treating exception as a failed test
            continue

        # compare outputs of MSELoss and PyTorch
        if not isinstance(_output, np.ndarray): # if a singleton, convert PyTorch tensor to NumPy float, round, and compare
            output = output.numpy()
            result = np.equal(np.round(_output), np.round(output)) 
        else:
            result = torch.equal(torch.round(torch.DoubleTensor(_output)), torch.round(output)) # need to round the output due to precision difference
        print('Result: {}\n\n'.format(result))
        if result:
            num_passed += 1

    print('{} out of {} ({}%) tests passed'.format(num_passed, num_tests, float(100 * num_passed / num_tests)))

# %%
num_tests = 1000
run_tests(num_tests)
# Out:
# Number of tests: 1000
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 7487.11it/s]
# Test: 0
# Dimension : 145, `reduction`: sum
# Result: True
#
#
# Test: 1
# Dimension : 21, `reduction`: sum
# Result: True
#
#
# Test: 2
# Dimension : 118, `reduction`: sum
# Result: True
#
#
# Test: 3
# Dimension : 355, `reduction`: sum
# Result: True
#
#
# Test: 4
# Dimension : 359, `reduction`: sum
# Result: True
#
#
# Test: 5
# Dimension : 396, `reduction`: mean
# Result: True
#
#
# Test: 6
# Dimension : 167, `reduction`: sum
# Result: True
#
#
# Test: 7
# Dimension : 86, `reduction`: sum
# Result: True
#
#
# Test: 8
# Dimension : 346, `reduction`: mean
# Result: True
#
#
# Test: 9
# Dimension : 57, `reduction`: none
# Result: True
#
#
# Test: 10
# Dimension : 448, `reduction`: mean
# Result: True
#
#
# Test: 11
# Dimension : 360, `reduction`: none
# Result: True
#
#
# Test: 12
# Dimension : 122, `reduction`: sum
# Result: True
#
#
# Test: 13
# Dimension : 110, `reduction`: mean
# Result: True
#
#
# Test: 14
# Dimension : 321, `reduction`: mean
# Result: True
#
#
# Test: 15
# Dimension : 247, `reduction`: none
# Result: True
#
#
# Test: 16
# Dimension : 32, `reduction`: sum
# Result: True
#
#
# Test: 17
# Dimension : 278, `reduction`: mean
# Result: True
#
#
# Test: 18
# Dimension : 67, `reduction`: none
# Result: True
#
#
# Test: 19
# Dimension : 353, `reduction`: mean
# Result: True
#
#
# Test: 20
# Dimension : 201, `reduction`: none
# Result: True
#
#
# Test: 21
# Dimension : 228, `reduction`: mean
# Result: True
#
#
# Test: 22
# Dimension : 358, `reduction`: sum
# Result: True
#
#
# Test: 23
# Dimension : 386, `reduction`: sum
# Result: True
#
#
# Test: 24
# Dimension : 37, `reduction`: none
# Result: True
#
#
# Test: 25
# Dimension : 434, `reduction`: none
# Result: True
#
#
# Test: 26
# Dimension : 265, `reduction`: sum
# Result: True
#
#
# Test: 27
# Dimension : 205, `reduction`: none
# Result: True
#
#
# Test: 28
# Dimension : 163, `reduction`: none
# Result: True
#
#
# Test: 29
# Dimension : 131, `reduction`: mean
# Result: True
#
#
# Test: 30
# Dimension : 108, `reduction`: none
# Result: True
#
#
# Test: 31
# Dimension : 331, `reduction`: mean
# Result: True
#
#
# Test: 32
# Dimension : 86, `reduction`: none
# Result: True
#
#
# Test: 33
# Dimension : 154, `reduction`: sum
# Result: True
#
#
# Test: 34
# Dimension : 35, `reduction`: none
# Result: True
#
#
# Test: 35
# Dimension : 105, `reduction`: sum
# Result: True
#
#
# Test: 36
# Dimension : 120, `reduction`: sum
# Result: True
#
#
# Test: 37
# Dimension : 143, `reduction`: mean
# Result: True
#
#
# Test: 38
# Dimension : 470, `reduction`: none
# Result: True
#
#
# Test: 39
# Dimension : 341, `reduction`: mean
# Result: True
#
#
# Test: 40
# Dimension : 25, `reduction`: mean
# Result: True
#
#
# Test: 41
# Dimension : 250, `reduction`: mean
# Result: True
#
#
# Test: 42
# Dimension : 198, `reduction`: none
# Result: True
#
#
# Test: 43
# Dimension : 239, `reduction`: mean
# Result: True
#
#
# Test: 44
# Dimension : 262, `reduction`: none
# Result: True
#
#
# Test: 45
# Dimension : 139, `reduction`: none
# Result: True
#
#
# Test: 46
# Dimension : 47, `reduction`: mean
# Result: True
#
#
# Test: 47
# Dimension : 265, `reduction`: mean
# Result: True
#
#
# Test: 48
# Dimension : 481, `reduction`: none
# Result: True
#
#
# Test: 49
# Dimension : 353, `reduction`: none
# Result: True
#
#
# Test: 50
# Dimension : 386, `reduction`: none
# Result: True
#
#
# Test: 51
# Dimension : 52, `reduction`: none
# Result: True
#
#
# Test: 52
# Dimension : 253, `reduction`: sum
# Result: True
#
#
# Test: 53
# Dimension : 123, `reduction`: sum
# Result: True
#
#
# Test: 54
# Dimension : 80, `reduction`: mean
# Result: True
#
#
# Test: 55
# Dimension : 56, `reduction`: sum
# Result: True
#
#
# Test: 56
# Dimension : 377, `reduction`: none
# Result: True
#
#
# Test: 57
# Dimension : 101, `reduction`: mean
# Result: True
#
#
# Test: 58
# Dimension : 318, `reduction`: sum
# Result: True
#
#
# Test: 59
# Dimension : 61, `reduction`: mean
# Result: True
#
#
# Test: 60
# Dimension : 142, `reduction`: sum
# Result: True
#
#
# Test: 61
# Dimension : 452, `reduction`: none
# Result: True
#
#
# Test: 62
# Dimension : 287, `reduction`: mean
# Result: True
#
#
# Test: 63
# Dimension : 167, `reduction`: none
# Result: True
#
#
# Test: 64
# Dimension : 422, `reduction`: sum
# Result: True
#
#
# Test: 65
# Dimension : 52, `reduction`: none
# Result: True
#
#
# Test: 66
# Dimension : 219, `reduction`: mean
# Result: True
#
#
# Test: 67
# Dimension : 143, `reduction`: mean
# Result: True
#
#
# Test: 68
# Dimension : 304, `reduction`: mean
# Result: True
#
#
# Test: 69
# Dimension : 295, `reduction`: mean
# Result: True
#
#
# Test: 70
# Dimension : 76, `reduction`: none
# Result: True
#
#
# Test: 71
# Dimension : 163, `reduction`: sum
# Result: True
#
#
# Test: 72
# Dimension : 50, `reduction`: none
# Result: True
#
#
# Test: 73
# Dimension : 60, `reduction`: none
# Result: True
#
#
# Test: 74
# Dimension : 459, `reduction`: sum
# Result: True
#
#
# Test: 75
# Dimension : 15, `reduction`: sum
# Result: True
#
#
# Test: 76
# Dimension : 53, `reduction`: mean
# Result: True
#
#
# Test: 77
# Dimension : 255, `reduction`: none
# Result: True
#
#
# Test: 78
# Dimension : 496, `reduction`: none
# Result: True
#
#
# Test: 79
# Dimension : 343, `reduction`: mean
# Result: True
#
#
# Test: 80
# Dimension : 441, `reduction`: sum
# Result: True
#
#
# Test: 81
# Dimension : 319, `reduction`: none
# Result: True
#
#
# Test: 82
# Dimension : 260, `reduction`: sum
# Result: True
#
#
# Test: 83
# Dimension : 245, `reduction`: none
# Result: True
#
#
# Test: 84
# Dimension : 170, `reduction`: mean
# Result: True
#
#
# Test: 85
# Dimension : 466, `reduction`: mean
# Result: True
#
#
# Test: 86
# Dimension : 469, `reduction`: mean
# Result: True
#
#
# Test: 87
# Dimension : 30, `reduction`: none
# Result: True
#
#
# Test: 88
# Dimension : 370, `reduction`: none
# Result: True
#
#
# Test: 89
# Dimension : 400, `reduction`: mean
# Result: True
#
#
# Test: 90
# Dimension : 267, `reduction`: sum
# Result: True
#
#
# Test: 91
# Dimension : 454, `reduction`: none
# Result: True
#
#
# Test: 92
# Dimension : 374, `reduction`: sum
# Result: True
#
#
# Test: 93
# Dimension : 348, `reduction`: mean
# Result: True
#
#
# Test: 94
# Dimension : 250, `reduction`: sum
# Result: True
#
#
# Test: 95
# Dimension : 248, `reduction`: none
# Result: True
#
#
# Test: 96
# Dimension : 419, `reduction`: sum
# Result: True
#
#
# Test: 97
# Dimension : 143, `reduction`: none
# Result: True
#
#
# Test: 98
# Dimension : 490, `reduction`: mean
# Result: True
#
#
# Test: 99
# Dimension : 497, `reduction`: none
# Result: True
#
#
# Test: 100
# Dimension : 204, `reduction`: sum
# Result: True
#
#
# Test: 101
# Dimension : 157, `reduction`: mean
# Result: True
#
#
# Test: 102
# Dimension : 37, `reduction`: sum
# Result: True
#
#
# Test: 103
# Dimension : 402, `reduction`: sum
# Result: True
#
#
# Test: 104
# Dimension : 72, `reduction`: mean
# Result: True
#
#
# Test: 105
# Dimension : 100, `reduction`: mean
# Result: True
#
#
# Test: 106
# Dimension : 48, `reduction`: sum
# Result: True
#
#
# Test: 107
# Dimension : 125, `reduction`: mean
# Result: True
#
#
# Test: 108
# Dimension : 209, `reduction`: none
# Result: True
#
#
# Test: 109
# Dimension : 367, `reduction`: sum
# Result: True
#
#
# Test: 110
# Dimension : 134, `reduction`: mean
# Result: True
#
#
# Test: 111
# Dimension : 403, `reduction`: sum
# Result: True
#
#
# Test: 112
# Dimension : 472, `reduction`: mean
# Result: True
#
#
# Test: 113
# Dimension : 74, `reduction`: sum
# Result: True
#
#
# Test: 114
# Dimension : 246, `reduction`: none
# Result: True
#
#
# Test: 115
# Dimension : 7, `reduction`: mean
# Result: True
#
#
# Test: 116
# Dimension : 256, `reduction`: sum
# Result: True
#
#
# Test: 117
# Dimension : 410, `reduction`: sum
# Result: True
#
#
# Test: 118
# Dimension : 293, `reduction`: mean
# Result: True
#
#
# Test: 119
# Dimension : 95, `reduction`: none
# Result: True
#
#
# Test: 120
# Dimension : 224, `reduction`: none
# Result: True
#
#
# Test: 121
# Dimension : 474, `reduction`: none
# Result: True
#
#
# Test: 122
# Dimension : 28, `reduction`: sum
# Result: True
#
#
# Test: 123
# Dimension : 54, `reduction`: sum
# Result: True
#
#
# Test: 124
# Dimension : 177, `reduction`: mean
# Result: True
#
#
# Test: 125
# Dimension : 379, `reduction`: sum
# Result: True
#
#
# Test: 126
# Dimension : 409, `reduction`: mean
# Result: True
#
#
# Test: 127
# Dimension : 429, `reduction`: none
# Result: True
#
#
# Test: 128
# Dimension : 99, `reduction`: mean
# Result: True
#
#
# Test: 129
# Dimension : 97, `reduction`: none
# Result: True
#
#
# Test: 130
# Dimension : 381, `reduction`: sum
# Result: True
#
#
# Test: 131
# Dimension : 138, `reduction`: mean
# Result: True
#
#
# Test: 132
# Dimension : 142, `reduction`: none
# Result: True
#
#
# Test: 133
# Dimension : 317, `reduction`: sum
# Result: True
#
#
# Test: 134
# Dimension : 442, `reduction`: none
# Result: True
#
#
# Test: 135
# Dimension : 212, `reduction`: none
# Result: True
#
#
# Test: 136
# Dimension : 424, `reduction`: mean
# Result: True
#
#
# Test: 137
# Dimension : 203, `reduction`: mean
# Result: True
#
#
# Test: 138
# Dimension : 48, `reduction`: none
# Result: True
#
#
# Test: 139
# Dimension : 72, `reduction`: none
# Result: True
#
#
# Test: 140
# Dimension : 451, `reduction`: none
# Result: True
#
#
# Test: 141
# Dimension : 460, `reduction`: mean
# Result: True
#
#
# Test: 142
# Dimension : 399, `reduction`: sum
# Result: True
#
#
# Test: 143
# Dimension : 349, `reduction`: none
# Result: True
#
#
# Test: 144
# Dimension : 429, `reduction`: none
# Result: True
#
#
# Test: 145
# Dimension : 337, `reduction`: mean
# Result: True
#
#
# Test: 146
# Dimension : 89, `reduction`: none
# Result: True
#
#
# Test: 147
# Dimension : 241, `reduction`: sum
# Result: True
#
#
# Test: 148
# Dimension : 189, `reduction`: none
# Result: True
#
#
# Test: 149
# Dimension : 320, `reduction`: none
# Result: True
#
#
# Test: 150
# Dimension : 379, `reduction`: sum
# Result: True
#
#
# Test: 151
# Dimension : 81, `reduction`: sum
# Result: True
#
#
# Test: 152
# Dimension : 379, `reduction`: sum
# Result: True
#
#
# Test: 153
# Dimension : 232, `reduction`: sum
# Result: True
#
#
# Test: 154
# Dimension : 144, `reduction`: mean
# Result: True
#
#
# Test: 155
# Dimension : 148, `reduction`: mean
# Result: True
#
#
# Test: 156
# Dimension : 141, `reduction`: none
# Result: True
#
#
# Test: 157
# Dimension : 359, `reduction`: mean
# Result: True
#
#
# Test: 158
# Dimension : 142, `reduction`: mean
# Result: True
#
#
# Test: 159
# Dimension : 378, `reduction`: none
# Result: True
#
#
# Test: 160
# Dimension : 78, `reduction`: mean
# Result: True
#
#
# Test: 161
# Dimension : 386, `reduction`: mean
# Result: True
#
#
# Test: 162
# Dimension : 232, `reduction`: sum
# Result: True
#
#
# Test: 163
# Dimension : 486, `reduction`: sum
# Result: True
#
#
# Test: 164
# Dimension : 95, `reduction`: none
# Result: True
#
#
# Test: 165
# Dimension : 298, `reduction`: sum
# Result: True
#
#
# Test: 166
# Dimension : 178, `reduction`: mean
# Result: True
#
#
# Test: 167
# Dimension : 198, `reduction`: none
# Result: True
#
#
# Test: 168
# Dimension : 225, `reduction`: mean
# Result: True
#
#
# Test: 169
# Dimension : 108, `reduction`: sum
# Result: True
#
#
# Test: 170
# Dimension : 221, `reduction`: none
# Result: True
#
#
# Test: 171
# Dimension : 168, `reduction`: none
# Result: True
#
#
# Test: 172
# Dimension : 132, `reduction`: none
# Result: True
#
#
# Test: 173
# Dimension : 84, `reduction`: mean
# Result: True
#
#
# Test: 174
# Dimension : 175, `reduction`: mean
# Result: True
#
#
# Test: 175
# Dimension : 193, `reduction`: none
# Result: True
#
#
# Test: 176
# Dimension : 261, `reduction`: sum
# Result: True
#
#
# Test: 177
# Dimension : 293, `reduction`: sum
# Result: True
#
#
# Test: 178
# Dimension : 249, `reduction`: mean
# Result: True
#
#
# Test: 179
# Dimension : 19, `reduction`: mean
# Result: True
#
#
# Test: 180
# Dimension : 235, `reduction`: sum
# Result: True
#
#
# Test: 181
# Dimension : 296, `reduction`: none
# Result: True
#
#
# Test: 182
# Dimension : 288, `reduction`: none
# Result: True
#
#
# Test: 183
# Dimension : 45, `reduction`: mean
# Result: True
#
#
# Test: 184
# Dimension : 355, `reduction`: sum
# Result: True
#
#
# Test: 185
# Dimension : 153, `reduction`: sum
# Result: True
#
#
# Test: 186
# Dimension : 219, `reduction`: sum
# Result: True
#
#
# Test: 187
# Dimension : 366, `reduction`: none
# Result: True
#
#
# Test: 188
# Dimension : 303, `reduction`: mean
# Result: True
#
#
# Test: 189
# Dimension : 62, `reduction`: mean
# Result: True
#
#
# Test: 190
# Dimension : 231, `reduction`: sum
# Result: True
#
#
# Test: 191
# Dimension : 214, `reduction`: none
# Result: True
#
#
# Test: 192
# Dimension : 102, `reduction`: sum
# Result: True
#
#
# Test: 193
# Dimension : 234, `reduction`: mean
# Result: True
#
#
# Test: 194
# Dimension : 16, `reduction`: sum
# Result: True
#
#
# Test: 195
# Dimension : 113, `reduction`: none
# Result: True
#
#
# Test: 196
# Dimension : 245, `reduction`: mean
# Result: True
#
#
# Test: 197
# Dimension : 433, `reduction`: mean
# Result: True
#
#
# Test: 198
# Dimension : 446, `reduction`: none
# Result: True
#
#
# Test: 199
# Dimension : 428, `reduction`: sum
# Result: True
#
#
# Test: 200
# Dimension : 284, `reduction`: mean
# Result: True
#
#
# Test: 201
# Dimension : 310, `reduction`: sum
# Result: True
#
#
# Test: 202
# Dimension : 296, `reduction`: none
# Result: True
#
#
# Test: 203
# Dimension : 469, `reduction`: mean
# Result: True
#
#
# Test: 204
# Dimension : 439, `reduction`: mean
# Result: True
#
#
# Test: 205
# Dimension : 412, `reduction`: none
# Result: True
#
#
# Test: 206
# Dimension : 8, `reduction`: none
# Result: True
#
#
# Test: 207
# Dimension : 366, `reduction`: none
# Result: True
#
#
# Test: 208
# Dimension : 230, `reduction`: sum
# Result: True
#
#
# Test: 209
# Dimension : 372, `reduction`: mean
# Result: True
#
#
# Test: 210
# Dimension : 379, `reduction`: none
# Result: True
#
#
# Test: 211
# Dimension : 39, `reduction`: sum
# Result: True
#
#
# Test: 212
# Dimension : 307, `reduction`: none
# Result: True
#
#
# Test: 213
# Dimension : 47, `reduction`: mean
# Result: True
#
#
# Test: 214
# Dimension : 367, `reduction`: none
# Result: True
#
#
# Test: 215
# Dimension : 14, `reduction`: sum
# Result: True
#
#
# Test: 216
# Dimension : 143, `reduction`: mean
# Result: True
#
#
# Test: 217
# Dimension : 71, `reduction`: sum
# Result: True
#
#
# Test: 218
# Dimension : 209, `reduction`: none
# Result: True
#
#
# Test: 219
# Dimension : 468, `reduction`: sum
# Result: True
#
#
# Test: 220
# Dimension : 69, `reduction`: mean
# Result: True
#
#
# Test: 221
# Dimension : 135, `reduction`: none
# Result: True
#
#
# Test: 222
# Dimension : 143, `reduction`: sum
# Result: True
#
#
# Test: 223
# Dimension : 203, `reduction`: none
# Result: True
#
#
# Test: 224
# Dimension : 233, `reduction`: none
# Result: True
#
#
# Test: 225
# Dimension : 346, `reduction`: sum
# Result: True
#
#
# Test: 226
# Dimension : 476, `reduction`: mean
# Result: True
#
#
# Test: 227
# Dimension : 346, `reduction`: sum
# Result: True
#
#
# Test: 228
# Dimension : 389, `reduction`: sum
# Result: True
#
#
# Test: 229
# Dimension : 15, `reduction`: none
# Result: True
#
#
# Test: 230
# Dimension : 337, `reduction`: sum
# Result: True
#
#
# Test: 231
# Dimension : 304, `reduction`: none
# Result: True
#
#
# Test: 232
# Dimension : 392, `reduction`: none
# Result: True
#
#
# Test: 233
# Dimension : 382, `reduction`: none
# Result: True
#
#
# Test: 234
# Dimension : 445, `reduction`: sum
# Result: True
#
#
# Test: 235
# Dimension : 433, `reduction`: sum
# Result: True
#
#
# Test: 236
# Dimension : 165, `reduction`: none
# Result: True
#
#
# Test: 237
# Dimension : 100, `reduction`: sum
# Result: True
#
#
# Test: 238
# Dimension : 495, `reduction`: mean
# Result: True
#
#
# Test: 239
# Dimension : 409, `reduction`: sum
# Result: True
#
#
# Test: 240
# Dimension : 144, `reduction`: none
# Result: True
#
#
# Test: 241
# Dimension : 224, `reduction`: sum
# Result: True
#
#
# Test: 242
# Dimension : 335, `reduction`: mean
# Result: True
#
#
# Test: 243
# Dimension : 233, `reduction`: none
# Result: True
#
#
# Test: 244
# Dimension : 271, `reduction`: none
# Result: True
#
#
# Test: 245
# Dimension : 271, `reduction`: none
# Result: True
#
#
# Test: 246
# Dimension : 175, `reduction`: sum
# Result: True
#
#
# Test: 247
# Dimension : 137, `reduction`: sum
# Result: True
#
#
# Test: 248
# Dimension : 268, `reduction`: sum
# Result: True
#
#
# Test: 249
# Dimension : 315, `reduction`: sum
# Result: True
#
#
# Test: 250
# Dimension : 239, `reduction`: none
# Result: True
#
#
# Test: 251
# Dimension : 126, `reduction`: mean
# Result: True
#
#
# Test: 252
# Dimension : 424, `reduction`: none
# Result: True
#
#
# Test: 253
# Dimension : 30, `reduction`: sum
# Result: True
#
#
# Test: 254
# Dimension : 248, `reduction`: sum
# Result: True
#
#
# Test: 255
# Dimension : 353, `reduction`: mean
# Result: True
#
#
# Test: 256
# Dimension : 152, `reduction`: none
# Result: True
#
#
# Test: 257
# Dimension : 254, `reduction`: sum
# Result: True
#
#
# Test: 258
# Dimension : 368, `reduction`: none
# Result: True
#
#
# Test: 259
# Dimension : 493, `reduction`: none
# Result: True
#
#
# Test: 260
# Dimension : 384, `reduction`: sum
# Result: True
#
#
# Test: 261
# Dimension : 471, `reduction`: none
# Result: True
#
#
# Test: 262
# Dimension : 95, `reduction`: sum
# Result: True
#
#
# Test: 263
# Dimension : 476, `reduction`: mean
# Result: True
#
#
# Test: 264
# Dimension : 385, `reduction`: none
# Result: True
#
#
# Test: 265
# Dimension : 196, `reduction`: none
# Result: True
#
#
# Test: 266
# Dimension : 350, `reduction`: none
# Result: True
#
#
# Test: 267
# Dimension : 266, `reduction`: mean
# Result: True
#
#
# Test: 268
# Dimension : 274, `reduction`: mean
# Result: True
#
#
# Test: 269
# Dimension : 93, `reduction`: none
# Result: True
#
#
# Test: 270
# Dimension : 489, `reduction`: none
# Result: True
#
#
# Test: 271
# Dimension : 374, `reduction`: sum
# Result: True
#
#
# Test: 272
# Dimension : 159, `reduction`: mean
# Result: True
#
#
# Test: 273
# Dimension : 313, `reduction`: mean
# Result: True
#
#
# Test: 274
# Dimension : 13, `reduction`: sum
# Result: True
#
#
# Test: 275
# Dimension : 271, `reduction`: sum
# Result: True
#
#
# Test: 276
# Dimension : 423, `reduction`: mean
# Result: True
#
#
# Test: 277
# Dimension : 81, `reduction`: sum
# Result: True
#
#
# Test: 278
# Dimension : 438, `reduction`: mean
# Result: True
#
#
# Test: 279
# Dimension : 396, `reduction`: sum
# Result: True
#
#
# Test: 280
# Dimension : 204, `reduction`: sum
# Result: True
#
#
# Test: 281
# Dimension : 42, `reduction`: mean
# Result: True
#
#
# Test: 282
# Dimension : 297, `reduction`: none
# Result: True
#
#
# Test: 283
# Dimension : 289, `reduction`: mean
# Result: True
#
#
# Test: 284
# Dimension : 369, `reduction`: mean
# Result: True
#
#
# Test: 285
# Dimension : 188, `reduction`: none
# Result: True
#
#
# Test: 286
# Dimension : 217, `reduction`: sum
# Result: True
#
#
# Test: 287
# Dimension : 466, `reduction`: sum
# Result: True
#
#
# Test: 288
# Dimension : 202, `reduction`: mean
# Result: True
#
#
# Test: 289
# Dimension : 411, `reduction`: mean
# Result: True
#
#
# Test: 290
# Dimension : 166, `reduction`: none
# Result: True
#
#
# Test: 291
# Dimension : 244, `reduction`: mean
# Result: True
#
#
# Test: 292
# Dimension : 53, `reduction`: none
# Result: True
#
#
# Test: 293
# Dimension : 330, `reduction`: sum
# Result: True
#
#
# Test: 294
# Dimension : 391, `reduction`: mean
# Result: True
#
#
# Test: 295
# Dimension : 234, `reduction`: sum
# Result: True
#
#
# Test: 296
# Dimension : 479, `reduction`: sum
# Result: True
#
#
# Test: 297
# Dimension : 365, `reduction`: sum
# Result: True
#
#
# Test: 298
# Dimension : 55, `reduction`: sum
# Result: True
#
#
# Test: 299
# Dimension : 205, `reduction`: none
# Result: True
#
#
# Test: 300
# Dimension : 158, `reduction`: none
# Result: True
#
#
# Test: 301
# Dimension : 224, `reduction`: mean
# Result: True
#
#
# Test: 302
# Dimension : 59, `reduction`: sum
# Result: True
#
#
# Test: 303
# Dimension : 79, `reduction`: sum
# Result: True
#
#
# Test: 304
# Dimension : 158, `reduction`: sum
# Result: True
#
#
# Test: 305
# Dimension : 150, `reduction`: sum
# Result: True
#
#
# Test: 306
# Dimension : 193, `reduction`: sum
# Result: True
#
#
# Test: 307
# Dimension : 242, `reduction`: none
# Result: True
#
#
# Test: 308
# Dimension : 75, `reduction`: sum
# Result: True
#
#
# Test: 309
# Dimension : 410, `reduction`: sum
# Result: True
#
#
# Test: 310
# Dimension : 359, `reduction`: sum
# Result: True
#
#
# Test: 311
# Dimension : 353, `reduction`: sum
# Result: True
#
#
# Test: 312
# Dimension : 445, `reduction`: sum
# Result: True
#
#
# Test: 313
# Dimension : 498, `reduction`: mean
# Result: True
#
#
# Test: 314
# Dimension : 273, `reduction`: sum
# Result: True
#
#
# Test: 315
# Dimension : 156, `reduction`: sum
# Result: True
#
#
# Test: 316
# Dimension : 144, `reduction`: mean
# Result: True
#
#
# Test: 317
# Dimension : 420, `reduction`: none
# Result: True
#
#
# Test: 318
# Dimension : 143, `reduction`: mean
# Result: True
#
#
# Test: 319
# Dimension : 383, `reduction`: none
# Result: True
#
#
# Test: 320
# Dimension : 301, `reduction`: none
# Result: True
#
#
# Test: 321
# Dimension : 307, `reduction`: sum
# Result: True
#
#
# Test: 322
# Dimension : 410, `reduction`: sum
# Result: True
#
#
# Test: 323
# Dimension : 360, `reduction`: none
# Result: True
#
#
# Test: 324
# Dimension : 261, `reduction`: none
# Result: True
#
#
# Test: 325
# Dimension : 371, `reduction`: sum
# Result: True
#
#
# Test: 326
# Dimension : 177, `reduction`: sum
# Result: True
#
#
# Test: 327
# Dimension : 387, `reduction`: none
# Result: True
#
#
# Test: 328
# Dimension : 257, `reduction`: mean
# Result: True
#
#
# Test: 329
# Dimension : 9, `reduction`: sum
# Result: True
#
#
# Test: 330
# Dimension : 450, `reduction`: none
# Result: True
#
#
# Test: 331
# Dimension : 71, `reduction`: mean
# Result: True
#
#
# Test: 332
# Dimension : 169, `reduction`: none
# Result: True
#
#
# Test: 333
# Dimension : 297, `reduction`: sum
# Result: True
#
#
# Test: 334
# Dimension : 39, `reduction`: sum
# Result: True
#
#
# Test: 335
# Dimension : 188, `reduction`: sum
# Result: True
#
#
# Test: 336
# Dimension : 499, `reduction`: sum
# Result: True
#
#
# Test: 337
# Dimension : 284, `reduction`: sum
# Result: True
#
#
# Test: 338
# Dimension : 262, `reduction`: mean
# Result: True
#
#
# Test: 339
# Dimension : 375, `reduction`: sum
# Result: True
#
#
# Test: 340
# Dimension : 23, `reduction`: sum
# Result: True
#
#
# Test: 341
# Dimension : 431, `reduction`: none
# Result: True
#
#
# Test: 342
# Dimension : 198, `reduction`: mean
# Result: True
#
#
# Test: 343
# Dimension : 200, `reduction`: sum
# Result: True
#
#
# Test: 344
# Dimension : 137, `reduction`: none
# Result: True
#
#
# Test: 345
# Dimension : 37, `reduction`: none
# Result: True
#
#
# Test: 346
# Dimension : 471, `reduction`: mean
# Result: True
#
#
# Test: 347
# Dimension : 238, `reduction`: mean
# Result: True
#
#
# Test: 348
# Dimension : 135, `reduction`: none
# Result: True
#
#
# Test: 349
# Dimension : 225, `reduction`: mean
# Result: True
#
#
# Test: 350
# Dimension : 391, `reduction`: sum
# Result: True
#
#
# Test: 351
# Dimension : 156, `reduction`: sum
# Result: True
#
#
# Test: 352
# Dimension : 439, `reduction`: mean
# Result: True
#
#
# Test: 353
# Dimension : 314, `reduction`: none
# Result: True
#
#
# Test: 354
# Dimension : 432, `reduction`: none
# Result: True
#
#
# Test: 355
# Dimension : 199, `reduction`: mean
# Result: True
#
#
# Test: 356
# Dimension : 28, `reduction`: mean
# Result: True
#
#
# Test: 357
# Dimension : 87, `reduction`: mean
# Result: True
#
#
# Test: 358
# Dimension : 223, `reduction`: sum
# Result: True
#
#
# Test: 359
# Dimension : 93, `reduction`: sum
# Result: True
#
#
# Test: 360
# Dimension : 303, `reduction`: none
# Result: True
#
#
# Test: 361
# Dimension : 407, `reduction`: none
# Result: True
#
#
# Test: 362
# Dimension : 20, `reduction`: mean
# Result: True
#
#
# Test: 363
# Dimension : 195, `reduction`: none
# Result: True
#
#
# Test: 364
# Dimension : 131, `reduction`: mean
# Result: True
#
#
# Test: 365
# Dimension : 485, `reduction`: mean
# Result: True
#
#
# Test: 366
# Dimension : 89, `reduction`: none
# Result: True
#
#
# Test: 367
# Dimension : 282, `reduction`: mean
# Result: True
#
#
# Test: 368
# Dimension : 416, `reduction`: none
# Result: True
#
#
# Test: 369
# Dimension : 321, `reduction`: mean
# Result: True
#
#
# Test: 370
# Dimension : 354, `reduction`: sum
# Result: True
#
#
# Test: 371
# Dimension : 291, `reduction`: sum
# Result: True
#
#
# Test: 372
# Dimension : 438, `reduction`: none
# Result: True
#
#
# Test: 373
# Dimension : 203, `reduction`: mean
# Result: True
#
#
# Test: 374
# Dimension : 351, `reduction`: sum
# Result: True
#
#
# Test: 375
# Dimension : 477, `reduction`: mean
# Result: True
#
#
# Test: 376
# Dimension : 97, `reduction`: none
# Result: True
#
#
# Test: 377
# Dimension : 191, `reduction`: none
# Result: True
#
#
# Test: 378
# Dimension : 20, `reduction`: none
# Result: True
#
#
# Test: 379
# Dimension : 352, `reduction`: sum
# Result: True
#
#
# Test: 380
# Dimension : 55, `reduction`: sum
# Result: True
#
#
# Test: 381
# Dimension : 445, `reduction`: none
# Result: True
#
#
# Test: 382
# Dimension : 87, `reduction`: none
# Result: True
#
#
# Test: 383
# Dimension : 195, `reduction`: sum
# Result: True
#
#
# Test: 384
# Dimension : 480, `reduction`: sum
# Result: True
#
#
# Test: 385
# Dimension : 324, `reduction`: none
# Result: True
#
#
# Test: 386
# Dimension : 358, `reduction`: sum
# Result: True
#
#
# Test: 387
# Dimension : 409, `reduction`: sum
# Result: True
#
#
# Test: 388
# Dimension : 223, `reduction`: sum
# Result: True
#
#
# Test: 389
# Dimension : 378, `reduction`: mean
# Result: True
#
#
# Test: 390
# Dimension : 349, `reduction`: sum
# Result: True
#
#
# Test: 391
# Dimension : 98, `reduction`: none
# Result: True
#
#
# Test: 392
# Dimension : 229, `reduction`: sum
# Result: True
#
#
# Test: 393
# Dimension : 237, `reduction`: sum
# Result: True
#
#
# Test: 394
# Dimension : 14, `reduction`: mean
# Result: True
#
#
# Test: 395
# Dimension : 349, `reduction`: mean
# Result: True
#
#
# Test: 396
# Dimension : 30, `reduction`: sum
# Result: True
#
#
# Test: 397
# Dimension : 21, `reduction`: sum
# Result: True
#
#
# Test: 398
# Dimension : 214, `reduction`: none
# Result: True
#
#
# Test: 399
# Dimension : 296, `reduction`: none
# Result: True
#
#
# Test: 400
# Dimension : 190, `reduction`: none
# Result: True
#
#
# Test: 401
# Dimension : 146, `reduction`: sum
# Result: True
#
#
# Test: 402
# Dimension : 484, `reduction`: sum
# Result: True
#
#
# Test: 403
# Dimension : 52, `reduction`: none
# Result: True
#
#
# Test: 404
# Dimension : 173, `reduction`: sum
# Result: True
#
#
# Test: 405
# Dimension : 97, `reduction`: none
# Result: True
#
#
# Test: 406
# Dimension : 197, `reduction`: mean
# Result: True
#
#
# Test: 407
# Dimension : 174, `reduction`: none
# Result: True
#
#
# Test: 408
# Dimension : 8, `reduction`: sum
# Result: True
#
#
# Test: 409
# Dimension : 463, `reduction`: mean
# Result: True
#
#
# Test: 410
# Dimension : 415, `reduction`: none
# Result: True
#
#
# Test: 411
# Dimension : 70, `reduction`: sum
# Result: True
#
#
# Test: 412
# Dimension : 458, `reduction`: none
# Result: True
#
#
# Test: 413
# Dimension : 471, `reduction`: sum
# Result: True
#
#
# Test: 414
# Dimension : 124, `reduction`: none
# Result: True
#
#
# Test: 415
# Dimension : 285, `reduction`: sum
# Result: True
#
#
# Test: 416
# Dimension : 477, `reduction`: none
# Result: True
#
#
# Test: 417
# Dimension : 404, `reduction`: none
# Result: True
#
#
# Test: 418
# Dimension : 470, `reduction`: sum
# Result: True
#
#
# Test: 419
# Dimension : 413, `reduction`: sum
# Result: True
#
#
# Test: 420
# Dimension : 240, `reduction`: sum
# Result: True
#
#
# Test: 421
# Dimension : 200, `reduction`: none
# Result: True
#
#
# Test: 422
# Dimension : 106, `reduction`: mean
# Result: True
#
#
# Test: 423
# Dimension : 311, `reduction`: mean
# Result: True
#
#
# Test: 424
# Dimension : 465, `reduction`: none
# Result: True
#
#
# Test: 425
# Dimension : 70, `reduction`: mean
# Result: True
#
#
# Test: 426
# Dimension : 270, `reduction`: none
# Result: True
#
#
# Test: 427
# Dimension : 256, `reduction`: none
# Result: True
#
#
# Test: 428
# Dimension : 478, `reduction`: none
# Result: True
#
#
# Test: 429
# Dimension : 48, `reduction`: none
# Result: True
#
#
# Test: 430
# Dimension : 4, `reduction`: none
# Result: True
#
#
# Test: 431
# Dimension : 381, `reduction`: sum
# Result: True
#
#
# Test: 432
# Dimension : 202, `reduction`: sum
# Result: True
#
#
# Test: 433
# Dimension : 321, `reduction`: sum
# Result: True
#
#
# Test: 434
# Dimension : 416, `reduction`: none
# Result: True
#
#
# Test: 435
# Dimension : 234, `reduction`: none
# Result: True
#
#
# Test: 436
# Dimension : 438, `reduction`: none
# Result: True
#
#
# Test: 437
# Dimension : 91, `reduction`: none
# Result: True
#
#
# Test: 438
# Dimension : 449, `reduction`: mean
# Result: True
#
#
# Test: 439
# Dimension : 397, `reduction`: sum
# Result: True
#
#
# Test: 440
# Dimension : 122, `reduction`: mean
# Result: True
#
#
# Test: 441
# Dimension : 181, `reduction`: sum
# Result: True
#
#
# Test: 442
# Dimension : 468, `reduction`: sum
# Result: True
#
#
# Test: 443
# Dimension : 95, `reduction`: sum
# Result: True
#
#
# Test: 444
# Dimension : 50, `reduction`: sum
# Result: True
#
#
# Test: 445
# Dimension : 288, `reduction`: mean
# Result: True
#
#
# Test: 446
# Dimension : 69, `reduction`: mean
# Result: True
#
#
# Test: 447
# Dimension : 103, `reduction`: none
# Result: True
#
#
# Test: 448
# Dimension : 206, `reduction`: sum
# Result: True
#
#
# Test: 449
# Dimension : 140, `reduction`: sum
# Result: True
#
#
# Test: 450
# Dimension : 171, `reduction`: mean
# Result: True
#
#
# Test: 451
# Dimension : 193, `reduction`: sum
# Result: True
#
#
# Test: 452
# Dimension : 80, `reduction`: sum
# Result: True
#
#
# Test: 453
# Dimension : 34, `reduction`: mean
# Result: True
#
#
# Test: 454
# Dimension : 304, `reduction`: none
# Result: True
#
#
# Test: 455
# Dimension : 21, `reduction`: sum
# Result: True
#
#
# Test: 456
# Dimension : 434, `reduction`: mean
# Result: True
#
#
# Test: 457
# Dimension : 446, `reduction`: none
# Result: True
#
#
# Test: 458
# Dimension : 128, `reduction`: sum
# Result: True
#
#
# Test: 459
# Dimension : 226, `reduction`: sum
# Result: True
#
#
# Test: 460
# Dimension : 405, `reduction`: mean
# Result: True
#
#
# Test: 461
# Dimension : 160, `reduction`: sum
# Result: True
#
#
# Test: 462
# Dimension : 101, `reduction`: none
# Result: True
#
#
# Test: 463
# Dimension : 356, `reduction`: mean
# Result: True
#
#
# Test: 464
# Dimension : 18, `reduction`: sum
# Result: True
#
#
# Test: 465
# Dimension : 377, `reduction`: mean
# Result: True
#
#
# Test: 466
# Dimension : 24, `reduction`: sum
# Result: True
#
#
# Test: 467
# Dimension : 88, `reduction`: sum
# Result: True
#
#
# Test: 468
# Dimension : 277, `reduction`: mean
# Result: True
#
#
# Test: 469
# Dimension : 108, `reduction`: none
# Result: True
#
#
# Test: 470
# Dimension : 257, `reduction`: sum
# Result: True
#
#
# Test: 471
# Dimension : 282, `reduction`: none
# Result: True
#
#
# Test: 472
# Dimension : 434, `reduction`: sum
# Result: True
#
#
# Test: 473
# Dimension : 224, `reduction`: none
# Result: True
#
#
# Test: 474
# Dimension : 445, `reduction`: sum
# Result: True
#
#
# Test: 475
# Dimension : 350, `reduction`: none
# Result: True
#
#
# Test: 476
# Dimension : 181, `reduction`: mean
# Result: True
#
#
# Test: 477
# Dimension : 173, `reduction`: mean
# Result: True
#
#
# Test: 478
# Dimension : 250, `reduction`: none
# Result: True
#
#
# Test: 479
# Dimension : 211, `reduction`: none
# Result: True
#
#
# Test: 480
# Dimension : 340, `reduction`: none
# Result: True
#
#
# Test: 481
# Dimension : 211, `reduction`: sum
# Result: True
#
#
# Test: 482
# Dimension : 484, `reduction`: sum
# Result: True
#
#
# Test: 483
# Dimension : 27, `reduction`: mean
# Result: True
#
#
# Test: 484
# Dimension : 484, `reduction`: none
# Result: True
#
#
# Test: 485
# Dimension : 399, `reduction`: mean
# Result: True
#
#
# Test: 486
# Dimension : 64, `reduction`: sum
# Result: True
#
#
# Test: 487
# Dimension : 298, `reduction`: sum
# Result: True
#
#
# Test: 488
# Dimension : 125, `reduction`: mean
# Result: True
#
#
# Test: 489
# Dimension : 85, `reduction`: mean
# Result: True
#
#
# Test: 490
# Dimension : 89, `reduction`: sum
# Result: True
#
#
# Test: 491
# Dimension : 66, `reduction`: none
# Result: True
#
#
# Test: 492
# Dimension : 361, `reduction`: none
# Result: True
#
#
# Test: 493
# Dimension : 460, `reduction`: sum
# Result: True
#
#
# Test: 494
# Dimension : 485, `reduction`: none
# Result: True
#
#
# Test: 495
# Dimension : 254, `reduction`: none
# Result: True
#
#
# Test: 496
# Dimension : 77, `reduction`: none
# Result: True
#
#
# Test: 497
# Dimension : 324, `reduction`: none
# Result: True
#
#
# Test: 498
# Dimension : 480, `reduction`: mean
# Result: True
#
#
# Test: 499
# Dimension : 387, `reduction`: none
# Result: True
#
#
# Test: 500
# Dimension : 354, `reduction`: none
# Result: True
#
#
# Test: 501
# Dimension : 470, `reduction`: mean
# Result: True
#
#
# Test: 502
# Dimension : 15, `reduction`: sum
# Result: True
#
#
# Test: 503
# Dimension : 32, `reduction`: none
# Result: True
#
#
# Test: 504
# Dimension : 78, `reduction`: mean
# Result: True
#
#
# Test: 505
# Dimension : 56, `reduction`: none
# Result: True
#
#
# Test: 506
# Dimension : 437, `reduction`: none
# Result: True
#
#
# Test: 507
# Dimension : 185, `reduction`: none
# Result: True
#
#
# Test: 508
# Dimension : 374, `reduction`: mean
# Result: True
#
#
# Test: 509
# Dimension : 470, `reduction`: none
# Result: True
#
#
# Test: 510
# Dimension : 455, `reduction`: sum
# Result: True
#
#
# Test: 511
# Dimension : 376, `reduction`: none
# Result: True
#
#
# Test: 512
# Dimension : 331, `reduction`: sum
# Result: True
#
#
# Test: 513
# Dimension : 8, `reduction`: mean
# Result: True
#
#
# Test: 514
# Dimension : 346, `reduction`: none
# Result: True
#
#
# Test: 515
# Dimension : 329, `reduction`: sum
# Result: True
#
#
# Test: 516
# Dimension : 352, `reduction`: sum
# Result: True
#
#
# Test: 517
# Dimension : 151, `reduction`: none
# Result: True
#
#
# Test: 518
# Dimension : 105, `reduction`: mean
# Result: True
#
#
# Test: 519
# Dimension : 13, `reduction`: mean
# Result: True
#
#
# Test: 520
# Dimension : 382, `reduction`: none
# Result: True
#
#
# Test: 521
# Dimension : 324, `reduction`: sum
# Result: True
#
#
# Test: 522
# Dimension : 452, `reduction`: none
# Result: True
#
#
# Test: 523
# Dimension : 190, `reduction`: none
# Result: True
#
#
# Test: 524
# Dimension : 386, `reduction`: sum
# Result: True
#
#
# Test: 525
# Dimension : 275, `reduction`: mean
# Result: True
#
#
# Test: 526
# Dimension : 105, `reduction`: sum
# Result: True
#
#
# Test: 527
# Dimension : 328, `reduction`: sum
# Result: True
#
#
# Test: 528
# Dimension : 291, `reduction`: sum
# Result: True
#
#
# Test: 529
# Dimension : 229, `reduction`: none
# Result: True
#
#
# Test: 530
# Dimension : 119, `reduction`: mean
# Result: True
#
#
# Test: 531
# Dimension : 40, `reduction`: none
# Result: True
#
#
# Test: 532
# Dimension : 112, `reduction`: sum
# Result: True
#
#
# Test: 533
# Dimension : 10, `reduction`: mean
# Result: True
#
#
# Test: 534
# Dimension : 312, `reduction`: none
# Result: True
#
#
# Test: 535
# Dimension : 75, `reduction`: mean
# Result: True
#
#
# Test: 536
# Dimension : 73, `reduction`: mean
# Result: True
#
#
# Test: 537
# Dimension : 32, `reduction`: mean
# Result: True
#
#
# Test: 538
# Dimension : 187, `reduction`: none
# Result: True
#
#
# Test: 539
# Dimension : 95, `reduction`: none
# Result: True
#
#
# Test: 540
# Dimension : 488, `reduction`: none
# Result: True
#
#
# Test: 541
# Dimension : 291, `reduction`: sum
# Result: True
#
#
# Test: 542
# Dimension : 156, `reduction`: none
# Result: True
#
#
# Test: 543
# Dimension : 40, `reduction`: none
# Result: True
#
#
# Test: 544
# Dimension : 450, `reduction`: sum
# Result: True
#
#
# Test: 545
# Dimension : 25, `reduction`: mean
# Result: True
#
#
# Test: 546
# Dimension : 120, `reduction`: none
# Result: True
#
#
# Test: 547
# Dimension : 104, `reduction`: sum
# Result: True
#
#
# Test: 548
# Dimension : 494, `reduction`: sum
# Result: True
#
#
# Test: 549
# Dimension : 414, `reduction`: mean
# Result: True
#
#
# Test: 550
# Dimension : 245, `reduction`: sum
# Result: True
#
#
# Test: 551
# Dimension : 202, `reduction`: mean
# Result: True
#
#
# Test: 552
# Dimension : 439, `reduction`: sum
# Result: True
#
#
# Test: 553
# Dimension : 484, `reduction`: sum
# Result: True
#
#
# Test: 554
# Dimension : 460, `reduction`: sum
# Result: True
#
#
# Test: 555
# Dimension : 296, `reduction`: sum
# Result: True
#
#
# Test: 556
# Dimension : 452, `reduction`: mean
# Result: True
#
#
# Test: 557
# Dimension : 243, `reduction`: sum
# Result: True
#
#
# Test: 558
# Dimension : 330, `reduction`: sum
# Result: True
#
#
# Test: 559
# Dimension : 280, `reduction`: mean
# Result: True
#
#
# Test: 560
# Dimension : 23, `reduction`: none
# Result: True
#
#
# Test: 561
# Dimension : 13, `reduction`: mean
# Result: True
#
#
# Test: 562
# Dimension : 195, `reduction`: mean
# Result: True
#
#
# Test: 563
# Dimension : 163, `reduction`: sum
# Result: True
#
#
# Test: 564
# Dimension : 39, `reduction`: mean
# Result: True
#
#
# Test: 565
# Dimension : 466, `reduction`: sum
# Result: True
#
#
# Test: 566
# Dimension : 363, `reduction`: mean
# Result: True
#
#
# Test: 567
# Dimension : 90, `reduction`: sum
# Result: True
#
#
# Test: 568
# Dimension : 293, `reduction`: sum
# Result: True
#
#
# Test: 569
# Dimension : 277, `reduction`: none
# Result: True
#
#
# Test: 570
# Dimension : 177, `reduction`: mean
# Result: True
#
#
# Test: 571
# Dimension : 440, `reduction`: mean
# Result: True
#
#
# Test: 572
# Dimension : 126, `reduction`: sum
# Result: True
#
#
# Test: 573
# Dimension : 253, `reduction`: none
# Result: True
#
#
# Test: 574
# Dimension : 256, `reduction`: mean
# Result: True
#
#
# Test: 575
# Dimension : 243, `reduction`: none
# Result: True
#
#
# Test: 576
# Dimension : 268, `reduction`: mean
# Result: True
#
#
# Test: 577
# Dimension : 296, `reduction`: mean
# Result: True
#
#
# Test: 578
# Dimension : 21, `reduction`: mean
# Result: True
#
#
# Test: 579
# Dimension : 104, `reduction`: sum
# Result: True
#
#
# Test: 580
# Dimension : 402, `reduction`: sum
# Result: True
#
#
# Test: 581
# Dimension : 425, `reduction`: none
# Result: True
#
#
# Test: 582
# Dimension : 437, `reduction`: none
# Result: True
#
#
# Test: 583
# Dimension : 206, `reduction`: mean
# Result: True
#
#
# Test: 584
# Dimension : 406, `reduction`: mean
# Result: True
#
#
# Test: 585
# Dimension : 479, `reduction`: sum
# Result: True
#
#
# Test: 586
# Dimension : 36, `reduction`: mean
# Result: True
#
#
# Test: 587
# Dimension : 454, `reduction`: none
# Result: True
#
#
# Test: 588
# Dimension : 13, `reduction`: mean
# Result: True
#
#
# Test: 589
# Dimension : 443, `reduction`: none
# Result: True
#
#
# Test: 590
# Dimension : 197, `reduction`: none
# Result: True
#
#
# Test: 591
# Dimension : 239, `reduction`: sum
# Result: True
#
#
# Test: 592
# Dimension : 92, `reduction`: sum
# Result: True
#
#
# Test: 593
# Dimension : 103, `reduction`: sum
# Result: True
#
#
# Test: 594
# Dimension : 244, `reduction`: mean
# Result: True
#
#
# Test: 595
# Dimension : 209, `reduction`: sum
# Result: True
#
#
# Test: 596
# Dimension : 163, `reduction`: sum
# Result: True
#
#
# Test: 597
# Dimension : 65, `reduction`: none
# Result: True
#
#
# Test: 598
# Dimension : 366, `reduction`: none
# Result: True
#
#
# Test: 599
# Dimension : 120, `reduction`: none
# Result: True
#
#
# Test: 600
# Dimension : 355, `reduction`: none
# Result: True
#
#
# Test: 601
# Dimension : 332, `reduction`: mean
# Result: True
#
#
# Test: 602
# Dimension : 474, `reduction`: mean
# Result: True
#
#
# Test: 603
# Dimension : 215, `reduction`: mean
# Result: True
#
#
# Test: 604
# Dimension : 60, `reduction`: mean
# Result: True
#
#
# Test: 605
# Dimension : 85, `reduction`: mean
# Result: True
#
#
# Test: 606
# Dimension : 95, `reduction`: sum
# Result: True
#
#
# Test: 607
# Dimension : 353, `reduction`: none
# Result: True
#
#
# Test: 608
# Dimension : 110, `reduction`: mean
# Result: True
#
#
# Test: 609
# Dimension : 288, `reduction`: mean
# Result: True
#
#
# Test: 610
# Dimension : 129, `reduction`: none
# Result: True
#
#
# Test: 611
# Dimension : 193, `reduction`: none
# Result: True
#
#
# Test: 612
# Dimension : 389, `reduction`: none
# Result: True
#
#
# Test: 613
# Dimension : 276, `reduction`: sum
# Result: True
#
#
# Test: 614
# Dimension : 356, `reduction`: none
# Result: True
#
#
# Test: 615
# Dimension : 331, `reduction`: sum
# Result: True
#
#
# Test: 616
# Dimension : 78, `reduction`: sum
# Result: True
#
#
# Test: 617
# Dimension : 52, `reduction`: mean
# Result: True
#
#
# Test: 618
# Dimension : 110, `reduction`: none
# Result: True
#
#
# Test: 619
# Dimension : 495, `reduction`: none
# Result: True
#
#
# Test: 620
# Dimension : 24, `reduction`: none
# Result: True
#
#
# Test: 621
# Dimension : 45, `reduction`: mean
# Result: True
#
#
# Test: 622
# Dimension : 172, `reduction`: mean
# Result: True
#
#
# Test: 623
# Dimension : 31, `reduction`: sum
# Result: True
#
#
# Test: 624
# Dimension : 323, `reduction`: mean
# Result: True
#
#
# Test: 625
# Dimension : 170, `reduction`: none
# Result: True
#
#
# Test: 626
# Dimension : 115, `reduction`: mean
# Result: True
#
#
# Test: 627
# Dimension : 175, `reduction`: sum
# Result: True
#
#
# Test: 628
# Dimension : 241, `reduction`: mean
# Result: True
#
#
# Test: 629
# Dimension : 344, `reduction`: none
# Result: True
#
#
# Test: 630
# Dimension : 448, `reduction`: none
# Result: True
#
#
# Test: 631
# Dimension : 234, `reduction`: mean
# Result: True
#
#
# Test: 632
# Dimension : 430, `reduction`: none
# Result: True
#
#
# Test: 633
# Dimension : 383, `reduction`: sum
# Result: True
#
#
# Test: 634
# Dimension : 251, `reduction`: sum
# Result: True
#
#
# Test: 635
# Dimension : 121, `reduction`: sum
# Result: True
#
#
# Test: 636
# Dimension : 272, `reduction`: sum
# Result: True
#
#
# Test: 637
# Dimension : 443, `reduction`: mean
# Result: True
#
#
# Test: 638
# Dimension : 190, `reduction`: none
# Result: True
#
#
# Test: 639
# Dimension : 329, `reduction`: none
# Result: True
#
#
# Test: 640
# Dimension : 254, `reduction`: none
# Result: True
#
#
# Test: 641
# Dimension : 4, `reduction`: mean
# Result: True
#
#
# Test: 642
# Dimension : 472, `reduction`: none
# Result: True
#
#
# Test: 643
# Dimension : 32, `reduction`: mean
# Result: True
#
#
# Test: 644
# Dimension : 128, `reduction`: mean
# Result: True
#
#
# Test: 645
# Dimension : 136, `reduction`: sum
# Result: True
#
#
# Test: 646
# Dimension : 385, `reduction`: none
# Result: True
#
#
# Test: 647
# Dimension : 233, `reduction`: mean
# Result: True
#
#
# Test: 648
# Dimension : 251, `reduction`: none
# Result: True
#
#
# Test: 649
# Dimension : 439, `reduction`: mean
# Result: True
#
#
# Test: 650
# Dimension : 347, `reduction`: mean
# Result: True
#
#
# Test: 651
# Dimension : 55, `reduction`: sum
# Result: True
#
#
# Test: 652
# Dimension : 275, `reduction`: none
# Result: True
#
#
# Test: 653
# Dimension : 310, `reduction`: none
# Result: True
#
#
# Test: 654
# Dimension : 223, `reduction`: none
# Result: True
#
#
# Test: 655
# Dimension : 159, `reduction`: sum
# Result: True
#
#
# Test: 656
# Dimension : 476, `reduction`: mean
# Result: True
#
#
# Test: 657
# Dimension : 348, `reduction`: sum
# Result: True
#
#
# Test: 658
# Dimension : 272, `reduction`: sum
# Result: True
#
#
# Test: 659
# Dimension : 338, `reduction`: mean
# Result: True
#
#
# Test: 660
# Dimension : 322, `reduction`: none
# Result: True
#
#
# Test: 661
# Dimension : 347, `reduction`: sum
# Result: True
#
#
# Test: 662
# Dimension : 490, `reduction`: none
# Result: True
#
#
# Test: 663
# Dimension : 355, `reduction`: sum
# Result: True
#
#
# Test: 664
# Dimension : 118, `reduction`: none
# Result: True
#
#
# Test: 665
# Dimension : 276, `reduction`: mean
# Result: True
#
#
# Test: 666
# Dimension : 433, `reduction`: none
# Result: True
#
#
# Test: 667
# Dimension : 141, `reduction`: none
# Result: True
#
#
# Test: 668
# Dimension : 342, `reduction`: sum
# Result: True
#
#
# Test: 669
# Dimension : 478, `reduction`: none
# Result: True
#
#
# Test: 670
# Dimension : 305, `reduction`: none
# Result: True
#
#
# Test: 671
# Dimension : 318, `reduction`: mean
# Result: True
#
#
# Test: 672
# Dimension : 328, `reduction`: none
# Result: True
#
#
# Test: 673
# Dimension : 141, `reduction`: sum
# Result: True
#
#
# Test: 674
# Dimension : 399, `reduction`: mean
# Result: True
#
#
# Test: 675
# Dimension : 119, `reduction`: none
# Result: True
#
#
# Test: 676
# Dimension : 3, `reduction`: none
# Result: True
#
#
# Test: 677
# Dimension : 49, `reduction`: mean
# Result: True
#
#
# Test: 678
# Dimension : 158, `reduction`: mean
# Result: True
#
#
# Test: 679
# Dimension : 381, `reduction`: sum
# Result: True
#
#
# Test: 680
# Dimension : 145, `reduction`: none
# Result: True
#
#
# Test: 681
# Dimension : 38, `reduction`: sum
# Result: True
#
#
# Test: 682
# Dimension : 377, `reduction`: sum
# Result: True
#
#
# Test: 683
# Dimension : 69, `reduction`: mean
# Result: True
#
#
# Test: 684
# Dimension : 11, `reduction`: sum
# Result: True
#
#
# Test: 685
# Dimension : 196, `reduction`: none
# Result: True
#
#
# Test: 686
# Dimension : 340, `reduction`: sum
# Result: True
#
#
# Test: 687
# Dimension : 247, `reduction`: none
# Result: True
#
#
# Test: 688
# Dimension : 114, `reduction`: none
# Result: True
#
#
# Test: 689
# Dimension : 60, `reduction`: none
# Result: True
#
#
# Test: 690
# Dimension : 411, `reduction`: mean
# Result: True
#
#
# Test: 691
# Dimension : 306, `reduction`: sum
# Result: True
#
#
# Test: 692
# Dimension : 217, `reduction`: mean
# Result: True
#
#
# Test: 693
# Dimension : 350, `reduction`: none
# Result: True
#
#
# Test: 694
# Dimension : 117, `reduction`: mean
# Result: True
#
#
# Test: 695
# Dimension : 366, `reduction`: sum
# Result: True
#
#
# Test: 696
# Dimension : 186, `reduction`: none
# Result: True
#
#
# Test: 697
# Dimension : 94, `reduction`: sum
# Result: True
#
#
# Test: 698
# Dimension : 119, `reduction`: sum
# Result: True
#
#
# Test: 699
# Dimension : 239, `reduction`: none
# Result: True
#
#
# Test: 700
# Dimension : 484, `reduction`: sum
# Result: True
#
#
# Test: 701
# Dimension : 7, `reduction`: none
# Result: True
#
#
# Test: 702
# Dimension : 226, `reduction`: sum
# Result: True
#
#
# Test: 703
# Dimension : 64, `reduction`: none
# Result: True
#
#
# Test: 704
# Dimension : 116, `reduction`: mean
# Result: True
#
#
# Test: 705
# Dimension : 30, `reduction`: sum
# Result: True
#
#
# Test: 706
# Dimension : 424, `reduction`: sum
# Result: True
#
#
# Test: 707
# Dimension : 390, `reduction`: none
# Result: True
#
#
# Test: 708
# Dimension : 338, `reduction`: none
# Result: True
#
#
# Test: 709
# Dimension : 444, `reduction`: mean
# Result: True
#
#
# Test: 710
# Dimension : 34, `reduction`: none
# Result: True
#
#
# Test: 711
# Dimension : 124, `reduction`: mean
# Result: True
#
#
# Test: 712
# Dimension : 185, `reduction`: sum
# Result: True
#
#
# Test: 713
# Dimension : 23, `reduction`: sum
# Result: True
#
#
# Test: 714
# Dimension : 164, `reduction`: none
# Result: True
#
#
# Test: 715
# Dimension : 176, `reduction`: none
# Result: True
#
#
# Test: 716
# Dimension : 192, `reduction`: mean
# Result: True
#
#
# Test: 717
# Dimension : 332, `reduction`: none
# Result: True
#
#
# Test: 718
# Dimension : 468, `reduction`: none
# Result: True
#
#
# Test: 719
# Dimension : 406, `reduction`: none
# Result: True
#
#
# Test: 720
# Dimension : 317, `reduction`: none
# Result: True
#
#
# Test: 721
# Dimension : 425, `reduction`: sum
# Result: True
#
#
# Test: 722
# Dimension : 496, `reduction`: sum
# Result: True
#
#
# Test: 723
# Dimension : 218, `reduction`: none
# Result: True
#
#
# Test: 724
# Dimension : 426, `reduction`: none
# Result: True
#
#
# Test: 725
# Dimension : 100, `reduction`: none
# Result: True
#
#
# Test: 726
# Dimension : 325, `reduction`: sum
# Result: True
#
#
# Test: 727
# Dimension : 106, `reduction`: sum
# Result: True
#
#
# Test: 728
# Dimension : 275, `reduction`: mean
# Result: True
#
#
# Test: 729
# Dimension : 430, `reduction`: sum
# Result: True
#
#
# Test: 730
# Dimension : 89, `reduction`: mean
# Result: True
#
#
# Test: 731
# Dimension : 464, `reduction`: mean
# Result: True
#
#
# Test: 732
# Dimension : 371, `reduction`: mean
# Result: True
#
#
# Test: 733
# Dimension : 427, `reduction`: sum
# Result: True
#
#
# Test: 734
# Dimension : 238, `reduction`: mean
# Result: True
#
#
# Test: 735
# Dimension : 352, `reduction`: mean
# Result: True
#
#
# Test: 736
# Dimension : 340, `reduction`: sum
# Result: True
#
#
# Test: 737
# Dimension : 133, `reduction`: mean
# Result: True
#
#
# Test: 738
# Dimension : 105, `reduction`: mean
# Result: True
#
#
# Test: 739
# Dimension : 106, `reduction`: none
# Result: True
#
#
# Test: 740
# Dimension : 23, `reduction`: sum
# Result: True
#
#
# Test: 741
# Dimension : 45, `reduction`: mean
# Result: True
#
#
# Test: 742
# Dimension : 400, `reduction`: mean
# Result: True
#
#
# Test: 743
# Dimension : 196, `reduction`: sum
# Result: True
#
#
# Test: 744
# Dimension : 311, `reduction`: none
# Result: True
#
#
# Test: 745
# Dimension : 497, `reduction`: sum
# Result: True
#
#
# Test: 746
# Dimension : 496, `reduction`: mean
# Result: True
#
#
# Test: 747
# Dimension : 452, `reduction`: none
# Result: True
#
#
# Test: 748
# Dimension : 499, `reduction`: none
# Result: True
#
#
# Test: 749
# Dimension : 229, `reduction`: sum
# Result: True
#
#
# Test: 750
# Dimension : 457, `reduction`: sum
# Result: True
#
#
# Test: 751
# Dimension : 36, `reduction`: sum
# Result: True
#
#
# Test: 752
# Dimension : 120, `reduction`: none
# Result: True
#
#
# Test: 753
# Dimension : 182, `reduction`: none
# Result: True
#
#
# Test: 754
# Dimension : 396, `reduction`: sum
# Result: True
#
#
# Test: 755
# Dimension : 281, `reduction`: none
# Result: True
#
#
# Test: 756
# Dimension : 215, `reduction`: sum
# Result: True
#
#
# Test: 757
# Dimension : 38, `reduction`: none
# Result: True
#
#
# Test: 758
# Dimension : 186, `reduction`: mean
# Result: True
#
#
# Test: 759
# Dimension : 388, `reduction`: none
# Result: True
#
#
# Test: 760
# Dimension : 225, `reduction`: none
# Result: True
#
#
# Test: 761
# Dimension : 243, `reduction`: none
# Result: True
#
#
# Test: 762
# Dimension : 315, `reduction`: mean
# Result: True
#
#
# Test: 763
# Dimension : 401, `reduction`: mean
# Result: True
#
#
# Test: 764
# Dimension : 458, `reduction`: sum
# Result: True
#
#
# Test: 765
# Dimension : 105, `reduction`: none
# Result: True
#
#
# Test: 766
# Dimension : 156, `reduction`: sum
# Result: True
#
#
# Test: 767
# Dimension : 383, `reduction`: mean
# Result: True
#
#
# Test: 768
# Dimension : 220, `reduction`: sum
# Result: True
#
#
# Test: 769
# Dimension : 478, `reduction`: none
# Result: True
#
#
# Test: 770
# Dimension : 401, `reduction`: sum
# Result: True
#
#
# Test: 771
# Dimension : 455, `reduction`: none
# Result: True
#
#
# Test: 772
# Dimension : 439, `reduction`: mean
# Result: True
#
#
# Test: 773
# Dimension : 131, `reduction`: none
# Result: True
#
#
# Test: 774
# Dimension : 220, `reduction`: none
# Result: True
#
#
# Test: 775
# Dimension : 234, `reduction`: none
# Result: True
#
#
# Test: 776
# Dimension : 133, `reduction`: none
# Result: True
#
#
# Test: 777
# Dimension : 196, `reduction`: none
# Result: True
#
#
# Test: 778
# Dimension : 370, `reduction`: sum
# Result: True
#
#
# Test: 779
# Dimension : 58, `reduction`: mean
# Result: True
#
#
# Test: 780
# Dimension : 18, `reduction`: none
# Result: True
#
#
# Test: 781
# Dimension : 457, `reduction`: mean
# Result: True
#
#
# Test: 782
# Dimension : 378, `reduction`: mean
# Result: True
#
#
# Test: 783
# Dimension : 82, `reduction`: sum
# Result: True
#
#
# Test: 784
# Dimension : 375, `reduction`: mean
# Result: True
#
#
# Test: 785
# Dimension : 358, `reduction`: mean
# Result: True
#
#
# Test: 786
# Dimension : 117, `reduction`: none
# Result: True
#
#
# Test: 787
# Dimension : 301, `reduction`: none
# Result: True
#
#
# Test: 788
# Dimension : 440, `reduction`: none
# Result: True
#
#
# Test: 789
# Dimension : 336, `reduction`: none
# Result: True
#
#
# Test: 790
# Dimension : 293, `reduction`: mean
# Result: True
#
#
# Test: 791
# Dimension : 429, `reduction`: sum
# Result: True
#
#
# Test: 792
# Dimension : 42, `reduction`: mean
# Result: True
#
#
# Test: 793
# Dimension : 17, `reduction`: none
# Result: True
#
#
# Test: 794
# Dimension : 184, `reduction`: none
# Result: True
#
#
# Test: 795
# Dimension : 394, `reduction`: mean
# Result: True
#
#
# Test: 796
# Dimension : 10, `reduction`: sum
# Result: True
#
#
# Test: 797
# Dimension : 356, `reduction`: sum
# Result: True
#
#
# Test: 798
# Dimension : 28, `reduction`: mean
# Result: True
#
#
# Test: 799
# Dimension : 336, `reduction`: mean
# Result: True
#
#
# Test: 800
# Dimension : 237, `reduction`: none
# Result: True
#
#
# Test: 801
# Dimension : 19, `reduction`: none
# Result: True
#
#
# Test: 802
# Dimension : 54, `reduction`: sum
# Result: True
#
#
# Test: 803
# Dimension : 258, `reduction`: none
# Result: True
#
#
# Test: 804
# Dimension : 284, `reduction`: sum
# Result: True
#
#
# Test: 805
# Dimension : 126, `reduction`: mean
# Result: True
#
#
# Test: 806
# Dimension : 294, `reduction`: mean
# Result: True
#
#
# Test: 807
# Dimension : 249, `reduction`: mean
# Result: True
#
#
# Test: 808
# Dimension : 13, `reduction`: none
# Result: True
#
#
# Test: 809
# Dimension : 155, `reduction`: mean
# Result: True
#
#
# Test: 810
# Dimension : 428, `reduction`: none
# Result: True
#
#
# Test: 811
# Dimension : 471, `reduction`: sum
# Result: True
#
#
# Test: 812
# Dimension : 106, `reduction`: sum
# Result: True
#
#
# Test: 813
# Dimension : 60, `reduction`: mean
# Result: True
#
#
# Test: 814
# Dimension : 202, `reduction`: none
# Result: True
#
#
# Test: 815
# Dimension : 164, `reduction`: none
# Result: True
#
#
# Test: 816
# Dimension : 173, `reduction`: sum
# Result: True
#
#
# Test: 817
# Dimension : 342, `reduction`: none
# Result: True
#
#
# Test: 818
# Dimension : 291, `reduction`: none
# Result: True
#
#
# Test: 819
# Dimension : 201, `reduction`: none
# Result: True
#
#
# Test: 820
# Dimension : 424, `reduction`: sum
# Result: True
#
#
# Test: 821
# Dimension : 256, `reduction`: mean
# Result: True
#
#
# Test: 822
# Dimension : 399, `reduction`: mean
# Result: True
#
#
# Test: 823
# Dimension : 160, `reduction`: mean
# Result: True
#
#
# Test: 824
# Dimension : 486, `reduction`: sum
# Result: True
#
#
# Test: 825
# Dimension : 227, `reduction`: sum
# Result: True
#
#
# Test: 826
# Dimension : 33, `reduction`: sum
# Result: True
#
#
# Test: 827
# Dimension : 440, `reduction`: none
# Result: True
#
#
# Test: 828
# Dimension : 240, `reduction`: mean
# Result: True
#
#
# Test: 829
# Dimension : 264, `reduction`: sum
# Result: True
#
#
# Test: 830
# Dimension : 263, `reduction`: none
# Result: True
#
#
# Test: 831
# Dimension : 476, `reduction`: mean
# Result: True
#
#
# Test: 832
# Dimension : 244, `reduction`: mean
# Result: True
#
#
# Test: 833
# Dimension : 474, `reduction`: sum
# Result: True
#
#
# Test: 834
# Dimension : 121, `reduction`: sum
# Result: True
#
#
# Test: 835
# Dimension : 215, `reduction`: mean
# Result: True
#
#
# Test: 836
# Dimension : 204, `reduction`: sum
# Result: True
#
#
# Test: 837
# Dimension : 469, `reduction`: mean
# Result: True
#
#
# Test: 838
# Dimension : 169, `reduction`: sum
# Result: True
#
#
# Test: 839
# Dimension : 160, `reduction`: sum
# Result: True
#
#
# Test: 840
# Dimension : 436, `reduction`: mean
# Result: True
#
#
# Test: 841
# Dimension : 288, `reduction`: mean
# Result: True
#
#
# Test: 842
# Dimension : 14, `reduction`: sum
# Result: True
#
#
# Test: 843
# Dimension : 103, `reduction`: sum
# Result: True
#
#
# Test: 844
# Dimension : 370, `reduction`: sum
# Result: True
#
#
# Test: 845
# Dimension : 484, `reduction`: sum
# Result: True
#
#
# Test: 846
# Dimension : 37, `reduction`: none
# Result: True
#
#
# Test: 847
# Dimension : 365, `reduction`: mean
# Result: True
#
#
# Test: 848
# Dimension : 254, `reduction`: none
# Result: True
#
#
# Test: 849
# Dimension : 471, `reduction`: mean
# Result: True
#
#
# Test: 850
# Dimension : 79, `reduction`: sum
# Result: True
#
#
# Test: 851
# Dimension : 357, `reduction`: mean
# Result: True
#
#
# Test: 852
# Dimension : 164, `reduction`: mean
# Result: True
#
#
# Test: 853
# Dimension : 29, `reduction`: none
# Result: True
#
#
# Test: 854
# Dimension : 330, `reduction`: none
# Result: True
#
#
# Test: 855
# Dimension : 252, `reduction`: none
# Result: True
#
#
# Test: 856
# Dimension : 34, `reduction`: mean
# Result: True
#
#
# Test: 857
# Dimension : 324, `reduction`: sum
# Result: True
#
#
# Test: 858
# Dimension : 124, `reduction`: none
# Result: True
#
#
# Test: 859
# Dimension : 92, `reduction`: mean
# Result: True
#
#
# Test: 860
# Dimension : 298, `reduction`: sum
# Result: True
#
#
# Test: 861
# Dimension : 62, `reduction`: sum
# Result: True
#
#
# Test: 862
# Dimension : 44, `reduction`: mean
# Result: True
#
#
# Test: 863
# Dimension : 497, `reduction`: sum
# Result: True
#
#
# Test: 864
# Dimension : 129, `reduction`: none
# Result: True
#
#
# Test: 865
# Dimension : 161, `reduction`: sum
# Result: True
#
#
# Test: 866
# Dimension : 126, `reduction`: mean
# Result: True
#
#
# Test: 867
# Dimension : 288, `reduction`: sum
# Result: True
#
#
# Test: 868
# Dimension : 267, `reduction`: mean
# Result: True
#
#
# Test: 869
# Dimension : 405, `reduction`: mean
# Result: True
#
#
# Test: 870
# Dimension : 151, `reduction`: none
# Result: True
#
#
# Test: 871
# Dimension : 324, `reduction`: mean
# Result: True
#
#
# Test: 872
# Dimension : 216, `reduction`: none
# Result: True
#
#
# Test: 873
# Dimension : 184, `reduction`: none
# Result: True
#
#
# Test: 874
# Dimension : 147, `reduction`: sum
# Result: True
#
#
# Test: 875
# Dimension : 409, `reduction`: none
# Result: True
#
#
# Test: 876
# Dimension : 128, `reduction`: none
# Result: True
#
#
# Test: 877
# Dimension : 106, `reduction`: none
# Result: True
#
#
# Test: 878
# Dimension : 4, `reduction`: sum
# Result: True
#
#
# Test: 879
# Dimension : 171, `reduction`: sum
# Result: True
#
#
# Test: 880
# Dimension : 414, `reduction`: none
# Result: True
#
#
# Test: 881
# Dimension : 428, `reduction`: mean
# Result: True
#
#
# Test: 882
# Dimension : 225, `reduction`: none
# Result: True
#
#
# Test: 883
# Dimension : 172, `reduction`: sum
# Result: True
#
#
# Test: 884
# Dimension : 25, `reduction`: none
# Result: True
#
#
# Test: 885
# Dimension : 42, `reduction`: sum
# Result: True
#
#
# Test: 886
# Dimension : 24, `reduction`: mean
# Result: True
#
#
# Test: 887
# Dimension : 206, `reduction`: none
# Result: True
#
#
# Test: 888
# Dimension : 150, `reduction`: sum
# Result: True
#
#
# Test: 889
# Dimension : 409, `reduction`: sum
# Result: True
#
#
# Test: 890
# Dimension : 376, `reduction`: none
# Result: True
#
#
# Test: 891
# Dimension : 132, `reduction`: sum
# Result: True
#
#
# Test: 892
# Dimension : 59, `reduction`: none
# Result: True
#
#
# Test: 893
# Dimension : 445, `reduction`: none
# Result: True
#
#
# Test: 894
# Dimension : 139, `reduction`: sum
# Result: True
#
#
# Test: 895
# Dimension : 78, `reduction`: none
# Result: True
#
#
# Test: 896
# Dimension : 29, `reduction`: mean
# Result: True
#
#
# Test: 897
# Dimension : 331, `reduction`: sum
# Result: True
#
#
# Test: 898
# Dimension : 463, `reduction`: mean
# Result: True
#
#
# Test: 899
# Dimension : 183, `reduction`: mean
# Result: True
#
#
# Test: 900
# Dimension : 306, `reduction`: mean
# Result: True
#
#
# Test: 901
# Dimension : 236, `reduction`: none
# Result: True
#
#
# Test: 902
# Dimension : 409, `reduction`: mean
# Result: True
#
#
# Test: 903
# Dimension : 12, `reduction`: mean
# Result: True
#
#
# Test: 904
# Dimension : 26, `reduction`: mean
# Result: True
#
#
# Test: 905
# Dimension : 478, `reduction`: none
# Result: True
#
#
# Test: 906
# Dimension : 419, `reduction`: mean
# Result: True
#
#
# Test: 907
# Dimension : 346, `reduction`: none
# Result: True
#
#
# Test: 908
# Dimension : 287, `reduction`: sum
# Result: True
#
#
# Test: 909
# Dimension : 110, `reduction`: mean
# Result: True
#
#
# Test: 910
# Dimension : 412, `reduction`: mean
# Result: True
#
#
# Test: 911
# Dimension : 27, `reduction`: mean
# Result: True
#
#
# Test: 912
# Dimension : 364, `reduction`: none
# Result: True
#
#
# Test: 913
# Dimension : 122, `reduction`: mean
# Result: True
#
#
# Test: 914
# Dimension : 148, `reduction`: mean
# Result: True
#
#
# Test: 915
# Dimension : 285, `reduction`: none
# Result: True
#
#
# Test: 916
# Dimension : 364, `reduction`: sum
# Result: True
#
#
# Test: 917
# Dimension : 365, `reduction`: sum
# Result: True
#
#
# Test: 918
# Dimension : 405, `reduction`: mean
# Result: True
#
#
# Test: 919
# Dimension : 214, `reduction`: none
# Result: True
#
#
# Test: 920
# Dimension : 363, `reduction`: mean
# Result: True
#
#
# Test: 921
# Dimension : 266, `reduction`: sum
# Result: True
#
#
# Test: 922
# Dimension : 243, `reduction`: mean
# Result: True
#
#
# Test: 923
# Dimension : 331, `reduction`: mean
# Result: True
#
#
# Test: 924
# Dimension : 283, `reduction`: mean
# Result: True
#
#
# Test: 925
# Dimension : 112, `reduction`: sum
# Result: True
#
#
# Test: 926
# Dimension : 427, `reduction`: none
# Result: True
#
#
# Test: 927
# Dimension : 52, `reduction`: sum
# Result: True
#
#
# Test: 928
# Dimension : 403, `reduction`: sum
# Result: True
#
#
# Test: 929
# Dimension : 205, `reduction`: mean
# Result: True
#
#
# Test: 930
# Dimension : 364, `reduction`: sum
# Result: True
#
#
# Test: 931
# Dimension : 318, `reduction`: sum
# Result: True
#
#
# Test: 932
# Dimension : 242, `reduction`: sum
# Result: True
#
#
# Test: 933
# Dimension : 282, `reduction`: mean
# Result: True
#
#
# Test: 934
# Dimension : 337, `reduction`: sum
# Result: True
#
#
# Test: 935
# Dimension : 161, `reduction`: none
# Result: True
#
#
# Test: 936
# Dimension : 373, `reduction`: none
# Result: True
#
#
# Test: 937
# Dimension : 476, `reduction`: sum
# Result: True
#
#
# Test: 938
# Dimension : 407, `reduction`: mean
# Result: True
#
#
# Test: 939
# Dimension : 191, `reduction`: none
# Result: True
#
#
# Test: 940
# Dimension : 400, `reduction`: mean
# Result: True
#
#
# Test: 941
# Dimension : 389, `reduction`: none
# Result: True
#
#
# Test: 942
# Dimension : 155, `reduction`: sum
# Result: True
#
#
# Test: 943
# Dimension : 54, `reduction`: sum
# Result: True
#
#
# Test: 944
# Dimension : 177, `reduction`: none
# Result: True
#
#
# Test: 945
# Dimension : 146, `reduction`: sum
# Result: True
#
#
# Test: 946
# Dimension : 71, `reduction`: sum
# Result: True
#
#
# Test: 947
# Dimension : 41, `reduction`: sum
# Result: True
#
#
# Test: 948
# Dimension : 16, `reduction`: mean
# Result: True
#
#
# Test: 949
# Dimension : 350, `reduction`: mean
# Result: True
#
#
# Test: 950
# Dimension : 426, `reduction`: none
# Result: True
#
#
# Test: 951
# Dimension : 156, `reduction`: none
# Result: True
#
#
# Test: 952
# Dimension : 364, `reduction`: sum
# Result: True
#
#
# Test: 953
# Dimension : 361, `reduction`: mean
# Result: True
#
#
# Test: 954
# Dimension : 127, `reduction`: sum
# Result: True
#
#
# Test: 955
# Dimension : 202, `reduction`: mean
# Result: True
#
#
# Test: 956
# Dimension : 54, `reduction`: none
# Result: True
#
#
# Test: 957
# Dimension : 205, `reduction`: mean
# Result: True
#
#
# Test: 958
# Dimension : 64, `reduction`: sum
# Result: True
#
#
# Test: 959
# Dimension : 188, `reduction`: none
# Result: True
#
#
# Test: 960
# Dimension : 375, `reduction`: none
# Result: True
#
#
# Test: 961
# Dimension : 249, `reduction`: mean
# Result: True
#
#
# Test: 962
# Dimension : 404, `reduction`: none
# Result: True
#
#
# Test: 963
# Dimension : 425, `reduction`: sum
# Result: True
#
#
# Test: 964
# Dimension : 447, `reduction`: mean
# Result: True
#
#
# Test: 965
# Dimension : 217, `reduction`: sum
# Result: True
#
#
# Test: 966
# Dimension : 11, `reduction`: mean
# Result: True
#
#
# Test: 967
# Dimension : 326, `reduction`: sum
# Result: True
#
#
# Test: 968
# Dimension : 419, `reduction`: sum
# Result: True
#
#
# Test: 969
# Dimension : 50, `reduction`: mean
# Result: True
#
#
# Test: 970
# Dimension : 47, `reduction`: none
# Result: True
#
#
# Test: 971
# Dimension : 52, `reduction`: none
# Result: True
#
#
# Test: 972
# Dimension : 22, `reduction`: sum
# Result: True
#
#
# Test: 973
# Dimension : 59, `reduction`: sum
# Result: True
#
#
# Test: 974
# Dimension : 388, `reduction`: mean
# Result: True
#
#
# Test: 975
# Dimension : 107, `reduction`: sum
# Result: True
#
#
# Test: 976
# Dimension : 95, `reduction`: sum
# Result: True
#
#
# Test: 977
# Dimension : 203, `reduction`: sum
# Result: True
#
#
# Test: 978
# Dimension : 20, `reduction`: none
# Result: True
#
#
# Test: 979
# Dimension : 175, `reduction`: none
# Result: True
#
#
# Test: 980
# Dimension : 29, `reduction`: sum
# Result: True
#
#
# Test: 981
# Dimension : 379, `reduction`: sum
# Result: True
#
#
# Test: 982
# Dimension : 301, `reduction`: sum
# Result: True
#
#
# Test: 983
# Dimension : 427, `reduction`: sum
# Result: True
#
#
# Test: 984
# Dimension : 283, `reduction`: sum
# Result: True
#
#
# Test: 985
# Dimension : 146, `reduction`: mean
# Result: True
#
#
# Test: 986
# Dimension : 357, `reduction`: sum
# Result: True
#
#
# Test: 987
# Dimension : 130, `reduction`: mean
# Result: True
#
#
# Test: 988
# Dimension : 1, `reduction`: mean
# Result: True
#
#
# Test: 989
# Dimension : 286, `reduction`: sum
# Result: True
#
#
# Test: 990
# Dimension : 179, `reduction`: sum
# Result: True
#
#
# Test: 991
# Dimension : 273, `reduction`: sum
# Result: True
#
#
# Test: 992
# Dimension : 221, `reduction`: none
# Result: True
#
#
# Test: 993
# Dimension : 292, `reduction`: none
# Result: True
#
#
# Test: 994
# Dimension : 257, `reduction`: sum
# Result: True
#
#
# Test: 995
# Dimension : 36, `reduction`: none
# Result: True
#
#
# Test: 996
# Dimension : 311, `reduction`: sum
# Result: True
#
#
# Test: 997
# Dimension : 487, `reduction`: none
# Result: True
#
#
# Test: 998
# Dimension : 256, `reduction`: mean
# Result: True
#
#
# Test: 999
# Dimension : 192, `reduction`: mean
# Result: True
#
#
# 1000 out of 1000 (100.0%) tests passed
